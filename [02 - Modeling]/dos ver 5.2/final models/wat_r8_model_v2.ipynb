# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.1/wat_r8_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
dfgurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r8-good.csv?token=AKVFSOF74AO4WXTKIYI257K6X2W3E"
dfmurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r8-mal.csv?token=AKVFSOFYFMLIIQ3TQ4VV7TS6X2W3S"

dfg = pd.read_csv(dfgurl)
dfm = pd.read_csv(dfmurl)

# %% [markdown]
# Characteristics of Dataset

# %%
dfg
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            117        0       3  ...             27                 9       1
# 1            125        2       0  ...             27                18       1
# 2            180        0       1  ...             27                27       1
# 3            181        3       1  ...             85               100       1
# 4            182        3       1  ...             85               100       1
# ...          ...      ...     ...  ...            ...               ...     ...
# 20204    3250548        3       1  ...             85               100       1
# 20205    3250549        3       1  ...             85               100       1
# 20206    3250550        3       1  ...             85               100       1
# 20207    3250551        3       1  ...             85               100       1
# 20208    3250555        3       1  ...             85               100       1
#
# [20209 rows x 30 columns]

# %%
dfm
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            113        0       3  ...             27                 9       0
# 1            121        2       0  ...             27                18       0
# 2            134        0       3  ...             27                 9       0
# 3            142        2       0  ...             30                18       0
# 4            176        0       1  ...             27                27       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 12944    2009875        3       1  ...             85               100       0
# 12945    2009876        3       1  ...             85               100       0
# 12946    2009877        3       1  ...             85               100       0
# 12947    2009878        3       1  ...             85               100       0
# 12948    2009882        3       1  ...             85               100       0
#
# [12949 rows x 30 columns]

# %%
df = dfg.append(dfm, ignore_index=True,sort=False)

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df = df.sort_values('timestamp')
df.to_csv('wat-r1-model.csv',index=False)

# %%
df = pd.read_csv("wat-r1-model.csv")
df
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             19        0       3  ...             27                 9       0
# 1             23        0       3  ...             27                 9       1
# 2             23        0       3  ...             30                 9       0
# 3             27        4       0  ...             27                18       0
# 4             31        4       0  ...             30                18       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 16128    3250723        4       0  ...             27                54       1
# 16129    3250730        4       0  ...             27                54       1
# 16130    3250731        4       0  ...             30                18       1
# 16131    3250732        4       0  ...             33                63       1
# 16132    3250784        0       3  ...             27                27       1
#
# [16133 rows x 30 columns]

# %%
df.corr()
# Out:
#                             timestamp   outport  ...  vnet_vc_cc_index    target
# timestamp                    1.000000 -0.005703  ...          0.031435  0.449091
# outport                     -0.005703  1.000000  ...          0.355783 -0.000344
# inport                       0.014424 -0.963413  ...         -0.355466  0.001768
# cache_coherence_type         0.031435  0.355783  ...          1.000000  0.008778
# flit_id                      0.022551 -0.022055  ...          0.422705  0.005705
# flit_type                   -0.033329  0.032566  ...         -0.623016 -0.008223
# vnet                              NaN       NaN  ...               NaN       NaN
# vc                          -0.015019  0.643468  ...         -0.017686 -0.010540
# src_ni                      -0.029473  0.876704  ...          0.281486 -0.020427
# src_router                  -0.043955  0.940129  ...          0.332155 -0.060568
# dst_ni                       0.012190 -0.631852  ...         -0.342688 -0.000824
# dst_router                   0.015152 -0.648728  ...         -0.276161 -0.000984
# traversal_id                 0.841024 -0.008189  ...          0.037380 -0.027557
# hop_count                    0.079054 -0.561772  ...         -0.157096  0.128692
# current_hop                  0.066244 -0.903529  ...         -0.307401  0.105474
# hop_percentage               0.017590 -0.990599  ...         -0.350427  0.019323
# enqueue_time                 0.057228 -0.475742  ...         -0.469203  0.057304
# packet_count_decr           -0.249120  0.032892  ...          0.033373 -0.201119
# packet_count_incr           -0.249115  0.124285  ...          0.010386 -0.201119
# max_packet_count            -0.296553  0.093553  ...          0.026045 -0.239415
# packet_count_index          -0.222175  0.091874  ...          0.032525 -0.179788
# packet_max_index            -0.167092  0.076835  ...          0.028606 -0.135551
# port_index                   0.033388 -0.320602  ...         -0.158950  0.005184
# cache_coherence_flit_index   0.024740  0.115631  ...          0.584922  0.006553
# flit_index                   0.017616  0.118120  ...          0.460792  0.004786
# traversal_index              0.437397  0.080056  ...          0.344635 -0.014069
# cache_coherence_vnet_index   0.031435  0.355783  ...          1.000000  0.008778
# vnet_vc_index               -0.015019  0.643468  ...         -0.017686 -0.010540
# vnet_vc_cc_index             0.031435  0.355783  ...          1.000000  0.008778
# target                       0.449091 -0.000344  ...          0.008778  1.000000
#
# [30 rows x 30 columns]

# %%
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target','timestamp','src_ni','src_router'])
train_X
# Out:
#        outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0            0       3  ...             27                 9
# 1            0       3  ...             27                 9
# 2            0       3  ...             30                 9
# 3            4       0  ...             27                18
# 4            4       0  ...             30                18
# ...        ...     ...  ...            ...               ...
# 16128        4       0  ...             27                54
# 16129        4       0  ...             27                54
# 16130        4       0  ...             30                18
# 16131        4       0  ...             33                63
# 16132        0       3  ...             27                27
#
# [16133 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#        outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0          0.0     1.0  ...       0.000000          0.000000
# 1          0.0     1.0  ...       0.000000          0.000000
# 2          0.0     1.0  ...       0.333333          0.000000
# 3          1.0     0.0  ...       0.000000          0.166667
# 4          1.0     0.0  ...       0.333333          0.166667
# ...        ...     ...  ...            ...               ...
# 16128      1.0     0.0  ...       0.000000          0.833333
# 16129      1.0     0.0  ...       0.000000          0.833333
# 16130      1.0     0.0  ...       0.333333          0.166667
# 16131      1.0     0.0  ...       0.666667          1.000000
# 16132      0.0     1.0  ...       0.000000          0.333333
#
# [16133 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (42, 26)

# %%
corr_df = pd.concat([train_X, df[['target']]], axis = 1)
corr_df.corr()
# Out:
#                              outport    inport  ...  vnet_vc_cc_index    target
# outport                     1.000000 -0.963413  ...          0.355783 -0.000344
# inport                     -0.963413  1.000000  ...         -0.355466  0.001768
# cache_coherence_type        0.355783 -0.355466  ...          1.000000  0.008778
# flit_id                    -0.022055  0.041908  ...          0.422705  0.005705
# flit_type                   0.032566 -0.061872  ...         -0.623016 -0.008223
# vnet                             NaN       NaN  ...               NaN       NaN
# vc                          0.643468 -0.665009  ...         -0.017686 -0.010540
# dst_ni                     -0.631852  0.761213  ...         -0.342688 -0.000824
# dst_router                 -0.648728  0.814046  ...         -0.276161 -0.000984
# traversal_id               -0.008189  0.019738  ...          0.037380 -0.027557
# hop_count                  -0.561772  0.724049  ...         -0.157096  0.128692
# current_hop                -0.903529  0.955820  ...         -0.307401  0.105474
# hop_percentage             -0.990599  0.943680  ...         -0.350427  0.019323
# enqueue_time               -0.475742  0.522017  ...         -0.469203  0.057304
# packet_count_decr           0.032892 -0.056154  ...          0.033373 -0.201119
# packet_count_incr           0.124285 -0.133941  ...          0.010386 -0.201119
# max_packet_count            0.093553 -0.113146  ...          0.026045 -0.239415
# packet_count_index          0.091874 -0.109517  ...          0.032525 -0.179788
# packet_max_index            0.076835 -0.093404  ...          0.028606 -0.135551
# port_index                 -0.320602  0.562745  ...         -0.158950  0.005184
# cache_coherence_flit_index  0.115631 -0.101181  ...          0.584922  0.006553
# flit_index                  0.118120 -0.110913  ...          0.460792  0.004786
# traversal_index             0.080056 -0.069382  ...          0.344635 -0.014069
# cache_coherence_vnet_index  0.355783 -0.355466  ...          1.000000  0.008778
# vnet_vc_index               0.643468 -0.665009  ...         -0.017686 -0.010540
# vnet_vc_cc_index            0.355783 -0.355466  ...          1.000000  0.008778
# target                     -0.000344  0.001768  ...          0.008778  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# Principal Component Analysis

# %%
pca = PCA(0.95)
pca.fit(train_X)
principal_components = pca.transform(train_X)
principal_components
# Out:
# array([[-159301.47071566],
#        [-159305.47852557],
#        [-159305.48052285],
#        ...,
#        [ -79065.69075746],
#        [ 121278.01894631],
#        [ -38991.34757077]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.46867115, 0.1950111 , 0.10741859, 0.10060904, 0.040734  ,
#        0.03340178, 0.0204362 ])

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xticks(features)
plt.xlabel("PCs")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %%
principal_df = pd.DataFrame(data = principal_components)
principal_df
# Out:
#               0         1         2         3         4         5         6
# 0     -0.339748  1.279958  0.766296 -0.027868  0.449579 -0.295260 -0.061398
# 1     -0.525484  1.250832  0.726546  0.002276  0.431661 -0.209672  0.073842
# 2     -0.392320  1.326780  0.663123  0.148450  0.430286  0.196885  0.111486
# 3      1.316773  1.056431 -0.004498  0.171698  0.498763 -0.916877 -0.183642
# 4      1.447871  1.132120 -0.069819  0.317839  0.477763 -0.513027 -0.142394
# ...         ...       ...       ...       ...       ...       ...       ...
# 16128  1.468009 -0.734841  0.100433  0.004212 -0.411032 -0.560996 -0.295831
# 16129  1.477737 -1.131853  0.387989  0.507272 -0.473332 -0.670318 -0.127894
# 16130  1.365390  1.054004 -0.001396  0.523312 -0.423182 -0.509497 -0.239965
# 16131  1.822005  0.160090 -0.333138 -0.020358 -0.487810  0.027842  0.983159
# 16132 -0.058805  0.874111  0.737620 -0.243495 -0.454477 -0.361591  0.036260
#
# [16133 rows x 7 columns]

# %%
final_df = pd.concat([principal_df, df[['target']]], axis = 1)
final_df.corr()
# Out:
#                    0             1  ...             6    target
# 0       1.000000e+00 -6.473093e-16  ...  1.617650e-15 -0.037314
# 1      -6.473093e-16  1.000000e+00  ...  1.588918e-15 -0.016132
# 2       2.136431e-15  1.105885e-15  ...  1.963717e-15 -0.012793
# 3      -2.213329e-15  9.979448e-16  ...  5.355746e-16  0.002649
# 4       6.644116e-17  1.693375e-16  ...  3.589394e-16  0.008839
# 5      -1.800814e-15  9.596918e-16  ... -3.949548e-16  0.052536
# 6       1.617650e-15  1.588918e-15  ...  1.000000e+00  0.117352
# target -3.731446e-02 -1.613214e-02  ...  1.173519e-01  1.000000
#
# [8 rows x 8 columns]

# %%
dimentional_components = pd.DataFrame()
dimentional_components['target'] = corr_df["target"]
dimentional_components['pca-one'] = principal_components[:,0]
dimentional_components['pca-two'] = principal_components[:,1] 
dimentional_components['pca-three'] = principal_components[:,2]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 2', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-two", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-two'], 
    zs=dimentional_components['pca-three'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-two'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-two')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-two'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-one'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-two')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-one')
plt.show()

# %% [markdown]
# T-distributed Stochastic Neighbor Embedding

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_components = tsne.fit_transform(train_X)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 42.3899245262146 seconds

# %%
dimentional_components['tsne-2d-one'] = tsne_components[:,0]
dimentional_components['tsne-2d-two'] = tsne_components[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3
)

# %%
plt.figure(figsize=(16,7))
ax1 = plt.subplot(1, 2, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 2, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_pca_components = tsne.fit_transform(principal_components)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 40.00039768218994 seconds

# %%
dimentional_components['tsne-pca9-one'] = tsne_pca_components[:,0]
dimentional_components['tsne-pca9-two'] = tsne_pca_components[:,1]
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1, 3, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 3, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)
ax3 = plt.subplot(1, 3, 3)
sns.scatterplot(
    x="tsne-pca9-one", y="tsne-pca9-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax3
)

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 1    8166
# 0    7967
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs       Score
# 16            max_packet_count  349.002779
# 14           packet_count_decr  177.570034
# 15           packet_count_incr  171.432745
# 17          packet_count_index  143.671018
# 18            packet_max_index   88.785535
# 10                   hop_count   59.308676
# 11                 current_hop   39.075538
# 13                enqueue_time    6.295973
# 9                 traversal_id    1.760540
# 12              hop_percentage    1.099670
# 6                           vc    0.724458
# 24               vnet_vc_index    0.724458
# 19                  port_index    0.632478
# 22             traversal_index    0.561558
# 3                      flit_id    0.211313
# 20  cache_coherence_flit_index    0.145127
# 21                  flit_index    0.124668

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
#result=logit_model.fit()
#print(result.summary2())

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 63.42786300945297
# Test Prediction  62.3179423613263

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 12              hop_percentage   20.084629
# 7                       dst_ni   15.100795
# 0                      outport   11.231281
# 10                   hop_count    8.993079
# 4                    flit_type    4.390860
# 20  cache_coherence_flit_index    3.256101
# 2         cache_coherence_type    1.267529
# 23  cache_coherence_vnet_index    1.267529
# 25            vnet_vc_cc_index    1.267529
# 5                         vnet    0.000000
# 6                           vc   -0.068518
# 24               vnet_vc_index   -0.068518
# 11                 current_hop   -0.307386
# 18            packet_max_index   -0.533605
# 9                 traversal_id   -0.669462
# 22             traversal_index   -0.905255
# 19                  port_index   -1.431591
# 13                enqueue_time   -1.869642
# 3                      flit_id   -1.898376
# 21                  flit_index   -1.919674
# 17          packet_count_index   -2.851007
# 8                   dst_router   -5.876937
# 15           packet_count_incr   -7.313057
# 14           packet_count_decr   -7.759441
# 1                       inport  -11.735994
# 16            max_packet_count  -15.072498

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67      1587
#            1       0.68      0.89      0.77      1640
#
#     accuracy                           0.73      3227
#    macro avg       0.75      0.72      0.72      3227
# weighted avg       0.75      0.73      0.72      3227

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 69.6420269642027
# Test Prediction  54.26092345832042

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52      1587
#            1       0.55      0.59      0.57      1640
#
#     accuracy                           0.54      3227
#    macro avg       0.54      0.54      0.54      3227
# weighted avg       0.54      0.54      0.54      3227

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 56.95025569502556
# Test Prediction Score 49.17880384257825

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1587
#            1       0.00      0.00      0.00      1640
#
#     accuracy                           0.49      3227
#    macro avg       0.25      0.50      0.33      3227
# weighted avg       0.24      0.49      0.32      3227
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 10324 samples, validate on 2582 samples
# Epoch 1/10
# 10324/10324 [==============================] - 0s 44us/step - loss: 0.5062 - accuracy: 0.4934 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 2/10
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5062 - accuracy: 0.4934 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 3/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5062 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 4/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5062 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 5/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4932 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 6/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 7/10
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 8/10
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4981
# Epoch 9/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5020 - val_accuracy: 0.4977
# Epoch 10/10
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4934 - val_loss: 0.5021 - val_accuracy: 0.4977

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 49.18%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2 )
# Out:
# Train on 10324 samples, validate on 2582 samples
# Epoch 1/15
# 10324/10324 [==============================] - 0s 42us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 2/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 3/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 4/15
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 5/15
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 6/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 7/15
# 10324/10324 [==============================] - 0s 36us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 8/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 9/15
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 10/15
# 10324/10324 [==============================] - 0s 36us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 11/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 12/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 13/15
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 14/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023
# Epoch 15/15
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4935 - accuracy: 0.5065 - val_loss: 0.4977 - val_accuracy: 0.5023

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 50.82%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 10324 samples, validate on 2582 samples
# Epoch 1/30
# 10324/10324 [==============================] - 0s 44us/step - loss: 0.4931 - accuracy: 0.5064 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 2/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4930 - accuracy: 0.5064 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 3/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4930 - accuracy: 0.5064 - val_loss: 0.4974 - val_accuracy: 0.5023
# Epoch 4/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4964 - accuracy: 0.5026 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 5/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4929 - accuracy: 0.5064 - val_loss: 0.4972 - val_accuracy: 0.5023
# Epoch 6/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4975 - accuracy: 0.5019 - val_loss: 0.4976 - val_accuracy: 0.5023
# Epoch 7/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4932 - accuracy: 0.5063 - val_loss: 0.4976 - val_accuracy: 0.5023
# Epoch 8/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4931 - accuracy: 0.5064 - val_loss: 0.4976 - val_accuracy: 0.5023
# Epoch 9/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4931 - accuracy: 0.5064 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 10/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4931 - accuracy: 0.5063 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 11/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4931 - accuracy: 0.5063 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 12/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4931 - accuracy: 0.5062 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 13/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4931 - accuracy: 0.5062 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 14/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4930 - accuracy: 0.5063 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 15/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4930 - accuracy: 0.5063 - val_loss: 0.4975 - val_accuracy: 0.5023
# Epoch 16/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.4929 - accuracy: 0.5063 - val_loss: 0.4974 - val_accuracy: 0.5023
# Epoch 17/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.4928 - accuracy: 0.5063 - val_loss: 0.4970 - val_accuracy: 0.5023
# Epoch 18/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5043 - accuracy: 0.4948 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 19/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 20/30
# 10324/10324 [==============================] - 0s 39us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 21/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 22/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 23/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 24/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 25/30
# 10324/10324 [==============================] - 0s 39us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 26/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 27/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 28/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 29/30
# 10324/10324 [==============================] - 0s 37us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977
# Epoch 30/30
# 10324/10324 [==============================] - 0s 38us/step - loss: 0.5061 - accuracy: 0.4935 - val_loss: 0.5023 - val_accuracy: 0.4977

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 49.18%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 10324 samples, validate on 2582 samples
# Epoch 1/100
# 10324/10324 [==============================] - 1s 119us/step - loss: 0.2501 - accuracy: 0.5051 - val_loss: 0.2503 - val_accuracy: 0.4923
# Epoch 2/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5061 - val_loss: 0.2555 - val_accuracy: 0.5000
# Epoch 3/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2502 - accuracy: 0.5056 - val_loss: 0.2496 - val_accuracy: 0.5012
# Epoch 4/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2501 - accuracy: 0.5129 - val_loss: 0.2495 - val_accuracy: 0.5147
# Epoch 5/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2500 - accuracy: 0.5139 - val_loss: 0.2535 - val_accuracy: 0.5077
# Epoch 6/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2500 - accuracy: 0.5098 - val_loss: 0.2548 - val_accuracy: 0.5027
# Epoch 7/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2501 - accuracy: 0.5101 - val_loss: 0.2498 - val_accuracy: 0.5035
# Epoch 8/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2500 - accuracy: 0.5091 - val_loss: 0.2491 - val_accuracy: 0.5201
# Epoch 9/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2500 - accuracy: 0.5112 - val_loss: 0.2490 - val_accuracy: 0.5221
# Epoch 10/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2499 - accuracy: 0.5148 - val_loss: 0.2493 - val_accuracy: 0.5279
# Epoch 11/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2499 - accuracy: 0.5101 - val_loss: 0.2501 - val_accuracy: 0.5120
# Epoch 12/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2500 - accuracy: 0.5131 - val_loss: 0.2504 - val_accuracy: 0.5077
# Epoch 13/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2498 - accuracy: 0.5190 - val_loss: 0.2511 - val_accuracy: 0.5097
# Epoch 14/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2497 - accuracy: 0.5132 - val_loss: 0.2527 - val_accuracy: 0.5070
# Epoch 15/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2497 - accuracy: 0.5175 - val_loss: 0.2502 - val_accuracy: 0.5008
# Epoch 16/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2499 - accuracy: 0.5145 - val_loss: 0.2488 - val_accuracy: 0.5170
# Epoch 17/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5173 - val_loss: 0.2490 - val_accuracy: 0.5159
# Epoch 18/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2499 - accuracy: 0.5174 - val_loss: 0.2489 - val_accuracy: 0.5174
# Epoch 19/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2499 - accuracy: 0.5142 - val_loss: 0.2494 - val_accuracy: 0.5112
# Epoch 20/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2500 - accuracy: 0.5131 - val_loss: 0.2500 - val_accuracy: 0.4946
# Epoch 21/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2500 - accuracy: 0.5101 - val_loss: 0.2490 - val_accuracy: 0.5147
# Epoch 22/100
# 10324/10324 [==============================] - 1s 70us/step - loss: 0.2499 - accuracy: 0.5142 - val_loss: 0.2494 - val_accuracy: 0.5054
# Epoch 23/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2499 - accuracy: 0.5090 - val_loss: 0.2492 - val_accuracy: 0.5174
# Epoch 24/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2495 - accuracy: 0.5184 - val_loss: 0.2499 - val_accuracy: 0.5093
# Epoch 25/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2498 - accuracy: 0.5175 - val_loss: 0.2490 - val_accuracy: 0.5252
# Epoch 26/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5147 - val_loss: 0.2503 - val_accuracy: 0.5101
# Epoch 27/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2494 - accuracy: 0.5160 - val_loss: 0.2494 - val_accuracy: 0.5271
# Epoch 28/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5173 - val_loss: 0.2492 - val_accuracy: 0.5201
# Epoch 29/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2498 - accuracy: 0.5142 - val_loss: 0.2486 - val_accuracy: 0.5256
# Epoch 30/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2488 - accuracy: 0.5249 - val_loss: 0.2514 - val_accuracy: 0.5321
# Epoch 31/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2501 - accuracy: 0.5156 - val_loss: 0.2495 - val_accuracy: 0.5240
# Epoch 32/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2501 - accuracy: 0.5127 - val_loss: 0.2491 - val_accuracy: 0.5244
# Epoch 33/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2497 - accuracy: 0.5146 - val_loss: 0.2491 - val_accuracy: 0.5155
# Epoch 34/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2499 - accuracy: 0.5198 - val_loss: 0.2489 - val_accuracy: 0.5225
# Epoch 35/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2500 - accuracy: 0.5117 - val_loss: 0.2490 - val_accuracy: 0.5190
# Epoch 36/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2497 - accuracy: 0.5148 - val_loss: 0.2486 - val_accuracy: 0.5263
# Epoch 37/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2497 - accuracy: 0.5218 - val_loss: 0.2491 - val_accuracy: 0.5174
# Epoch 38/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2498 - val_accuracy: 0.5159
# Epoch 39/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2495 - accuracy: 0.5181 - val_loss: 0.2490 - val_accuracy: 0.5236
# Epoch 40/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2497 - accuracy: 0.5177 - val_loss: 0.2490 - val_accuracy: 0.5310
# Epoch 41/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2492 - accuracy: 0.5231 - val_loss: 0.2489 - val_accuracy: 0.5294
# Epoch 42/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5170 - val_loss: 0.2488 - val_accuracy: 0.5283
# Epoch 43/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5227 - val_loss: 0.2493 - val_accuracy: 0.5321
# Epoch 44/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5190 - val_loss: 0.2485 - val_accuracy: 0.5368
# Epoch 45/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2491 - accuracy: 0.5243 - val_loss: 0.2491 - val_accuracy: 0.5275
# Epoch 46/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2493 - accuracy: 0.5186 - val_loss: 0.2489 - val_accuracy: 0.5244
# Epoch 47/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2493 - accuracy: 0.5252 - val_loss: 0.2500 - val_accuracy: 0.5105
# Epoch 48/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2492 - accuracy: 0.5284 - val_loss: 0.2493 - val_accuracy: 0.5147
# Epoch 49/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5164 - val_loss: 0.2489 - val_accuracy: 0.5205
# Epoch 50/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2497 - accuracy: 0.5175 - val_loss: 0.2489 - val_accuracy: 0.5314
# Epoch 51/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2489 - accuracy: 0.5271 - val_loss: 0.2489 - val_accuracy: 0.5314
# Epoch 52/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2497 - accuracy: 0.5186 - val_loss: 0.2485 - val_accuracy: 0.5256
# Epoch 53/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2492 - accuracy: 0.5238 - val_loss: 0.2492 - val_accuracy: 0.5337
# Epoch 54/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2493 - accuracy: 0.5224 - val_loss: 0.2485 - val_accuracy: 0.5383
# Epoch 55/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2498 - accuracy: 0.5163 - val_loss: 0.2506 - val_accuracy: 0.5151
# Epoch 56/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2493 - accuracy: 0.5235 - val_loss: 0.2501 - val_accuracy: 0.5252
# Epoch 57/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2492 - accuracy: 0.5216 - val_loss: 0.2491 - val_accuracy: 0.5275
# Epoch 58/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2490 - accuracy: 0.5284 - val_loss: 0.2490 - val_accuracy: 0.5263
# Epoch 59/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2492 - accuracy: 0.5297 - val_loss: 0.2488 - val_accuracy: 0.5345
# Epoch 60/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2493 - accuracy: 0.5220 - val_loss: 0.2489 - val_accuracy: 0.5194
# Epoch 61/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2490 - accuracy: 0.5286 - val_loss: 0.2490 - val_accuracy: 0.5194
# Epoch 62/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2491 - accuracy: 0.5266 - val_loss: 0.2495 - val_accuracy: 0.5120
# Epoch 63/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2496 - accuracy: 0.5200 - val_loss: 0.2526 - val_accuracy: 0.5225
# Epoch 64/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2494 - accuracy: 0.5184 - val_loss: 0.2486 - val_accuracy: 0.5411
# Epoch 65/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2491 - accuracy: 0.5251 - val_loss: 0.2491 - val_accuracy: 0.5252
# Epoch 66/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2492 - accuracy: 0.5230 - val_loss: 0.2499 - val_accuracy: 0.5275
# Epoch 67/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2500 - accuracy: 0.5224 - val_loss: 0.2486 - val_accuracy: 0.5271
# Epoch 68/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2495 - accuracy: 0.5203 - val_loss: 0.2485 - val_accuracy: 0.5349
# Epoch 69/100
# 10324/10324 [==============================] - 1s 69us/step - loss: 0.2493 - accuracy: 0.5245 - val_loss: 0.2485 - val_accuracy: 0.5321
# Epoch 70/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2492 - accuracy: 0.5192 - val_loss: 0.2484 - val_accuracy: 0.5329
# Epoch 71/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2490 - accuracy: 0.5275 - val_loss: 0.2492 - val_accuracy: 0.5221
# Epoch 72/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2492 - accuracy: 0.5205 - val_loss: 0.2484 - val_accuracy: 0.5213
# Epoch 73/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2494 - accuracy: 0.5246 - val_loss: 0.2488 - val_accuracy: 0.5198
# Epoch 74/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2492 - accuracy: 0.5218 - val_loss: 0.2486 - val_accuracy: 0.5240
# Epoch 75/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2492 - accuracy: 0.5280 - val_loss: 0.2481 - val_accuracy: 0.5182
# Epoch 76/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2493 - accuracy: 0.5245 - val_loss: 0.2488 - val_accuracy: 0.5275
# Epoch 77/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2492 - accuracy: 0.5212 - val_loss: 0.2486 - val_accuracy: 0.5271
# Epoch 78/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2489 - accuracy: 0.5283 - val_loss: 0.2496 - val_accuracy: 0.5321
# Epoch 79/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2493 - accuracy: 0.5253 - val_loss: 0.2483 - val_accuracy: 0.5155
# Epoch 80/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2493 - accuracy: 0.5275 - val_loss: 0.2485 - val_accuracy: 0.5217
# Epoch 81/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2492 - accuracy: 0.5241 - val_loss: 0.2488 - val_accuracy: 0.5333
# Epoch 82/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2490 - accuracy: 0.5243 - val_loss: 0.2481 - val_accuracy: 0.5213
# Epoch 83/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2495 - accuracy: 0.5214 - val_loss: 0.2481 - val_accuracy: 0.5275
# Epoch 84/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2491 - accuracy: 0.5274 - val_loss: 0.2487 - val_accuracy: 0.5217
# Epoch 85/100
# 10324/10324 [==============================] - 1s 68us/step - loss: 0.2490 - accuracy: 0.5216 - val_loss: 0.2490 - val_accuracy: 0.5236
# Epoch 86/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2493 - accuracy: 0.5197 - val_loss: 0.2484 - val_accuracy: 0.5407
# Epoch 87/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2490 - accuracy: 0.5271 - val_loss: 0.2484 - val_accuracy: 0.5333
# Epoch 88/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2491 - accuracy: 0.5277 - val_loss: 0.2486 - val_accuracy: 0.5248
# Epoch 89/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2494 - accuracy: 0.5219 - val_loss: 0.2487 - val_accuracy: 0.5391
# Epoch 90/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2491 - accuracy: 0.5267 - val_loss: 0.2491 - val_accuracy: 0.5232
# Epoch 91/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5207 - val_loss: 0.2497 - val_accuracy: 0.5294
# Epoch 92/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2491 - accuracy: 0.5312 - val_loss: 0.2486 - val_accuracy: 0.5217
# Epoch 93/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2494 - accuracy: 0.5268 - val_loss: 0.2486 - val_accuracy: 0.5279
# Epoch 94/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2491 - accuracy: 0.5249 - val_loss: 0.2484 - val_accuracy: 0.5209
# Epoch 95/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2489 - accuracy: 0.5302 - val_loss: 0.2491 - val_accuracy: 0.5128
# Epoch 96/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2486 - accuracy: 0.5378 - val_loss: 0.2506 - val_accuracy: 0.5132
# Epoch 97/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2491 - accuracy: 0.5228 - val_loss: 0.2498 - val_accuracy: 0.5112
# Epoch 98/100
# 10324/10324 [==============================] - 1s 66us/step - loss: 0.2487 - accuracy: 0.5335 - val_loss: 0.2490 - val_accuracy: 0.5302
# Epoch 99/100
# 10324/10324 [==============================] - 1s 65us/step - loss: 0.2487 - accuracy: 0.5300 - val_loss: 0.2512 - val_accuracy: 0.5190
# Epoch 100/100
# 10324/10324 [==============================] - 1s 67us/step - loss: 0.2498 - accuracy: 0.5127 - val_loss: 0.2497 - val_accuracy: 0.5263

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 50.82%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2) ,
            'max_features':range(0,25,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)
# Out:
# Best parameters: {'max_depth': 24, 'max_features': 24}
# Accuracy : 0.8459631179296451

# %%
dt = DecisionTreeClassifier(max_depth=25,max_features=25,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=25, max_features=25, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 49.43437161010383
# Test Prediction Score 49.17880384257825

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89      1587
#            1       0.87      0.92      0.90      1640
#
#     accuracy                           0.89      3227
#    macro avg       0.89      0.89      0.89      3227
# weighted avg       0.89      0.89      0.89      3227

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
#param_grid={'max_depth':range(0,25,2),
#            'n_estimators':[125,250],
#            'max_features':range(0,25,2)}
#dt_g=RandomForestClassifier(random_state=42)
#dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
#dt_cv.fit(X_train,y_train)

#print("Best parameters:",dt_cv.best_params_)
#print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=25,max_features=25,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features=25,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 49.43437161010383
# Test Prediction Score 49.17880384257825

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1587
#            1       0.00      0.00      0.00      1640
#
#     accuracy                           0.49      3227
#    macro avg       0.25      0.50      0.33      3227
# weighted avg       0.24      0.49      0.32      3227
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
#param_grid={'max_depth':range(0,25,2),
#            'n_estimators':[125,250,500],
#           'min_child_weight':[1,3,6]}
#xgb_g=XGBClassifier(random_state=42)
#xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
#xgb_cv.fit(X_train,y_train)

#print("Best parameters:",xgb_cv.best_params_)
#print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=25,min_child_weight=1,n_estimators=500,random_state=42)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=25,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.78304664497134
# Test Prediction Score 49.17880384257825

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1587
#            1       0.00      0.00      0.00      1640
#
#     accuracy                           0.49      3227
#    macro avg       0.25      0.50      0.33      3227
# weighted avg       0.24      0.49      0.32      3227
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
#param_grid = {'n_estimators': [x for x in range(24,40,2)],
#              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
#lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
#lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
#lgb_cv.fit(X_train, y_train)

#print("Best parameters:",lgb_cv.best_params_)
#print("Accuracy :",lgb_cv.best_score_)

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.2,  n_estimators = 500, max_depth = 21, random_state=42, min_child_weight=1,metric='l2')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.2, max_depth=21,
#                metric='l2', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 89.40802727413606
# Test Prediction Score 49.17880384257825

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,7100), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [7063,
#  3164,
#  854,
#  796,
#  625,
#  617,
#  535,
#  249,
#  197,
#  176,
#  174,
#  143,
#  133,
#  107,
#  97,
#  27,
#  18,
#  12,
#  11,
#  2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      1587
#            1       0.00      0.00      0.00      1640
#
#     accuracy                           0.49      3227
#    macro avg       0.25      0.50      0.33      3227
# weighted avg       0.24      0.49      0.32      3227
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
