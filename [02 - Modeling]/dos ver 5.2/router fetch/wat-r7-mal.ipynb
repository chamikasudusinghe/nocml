# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 7]
df = df.drop(columns=['router'])
df.to_csv('wat-r7-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r7-mal.csv')
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            19        0       3                     1        1          4
# 1            23        0       3                     1        1          4
# 2            27        4       0                     2        1          4
# 3            31        4       0                     2        1          4
# 4            82        0       3                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 7962    2008981        1       3                     5        3          2
# 7963    2008988        1       3                     5        4          2
# 7964    2008995        1       3                     5        5          3
# 7965    2008996        1       3                     1        1          4
# 7966    2021710        1       3                     5        1          1
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       1           1      23           7             1
# 1        3  10       0           0      23           7             0
# 2        3   9      23           7      18           2             1
# 3        3  10      23           7      18           2             0
# 4        3   9      18           2      23           7             1
# ...    ...  ..     ...         ...     ...         ...           ...
# 7962     3   9       0           0      27          11         11064
# 7963     3   9       0           0      27          11         11064
# 7964     3   9       0           0      27          11         11064
# 7965     3  10       0           0      27          11         11065
# 7966     3   9       1           1      27          11         11080
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             3            3            1.00            16
# 1             4            4            1.00            20
# 2             2            0            0.00             4
# 3             2            0            0.00             4
# 4             2            2            1.00            12
# ...         ...          ...             ...           ...
# 7962          5            4            0.80            34
# 7963          5            4            0.80            41
# 7964          5            4            0.80            48
# 7965          5            4            0.80            48
# 7966          4            3            0.75            16
#
# [7967 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 7967

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0          19        0       3                     1        1          4
# 1          23        0       3                     1        1          4
# 2          27        4       0                     2        1          4
# 3          31        4       0                     2        1          4
# 4          82        0       3                     3        1          4
# 5         107        0       3                     3        1          4
# 6         345        0       3                     1        1          4
# 7         353        4       0                     2        1          4
# 8         381        0       3                     1        1          4
# 9         389        4       0                     2        1          4
# 10        409        0       3                     3        1          4
# 11        442        0       3                     3        1          4
# 12        596        0       3                     1        1          4
# 13        604        4       0                     2        1          4
# 14        654        0       3                     1        1          4
# 15        658        0       3                     3        1          4
# 16        662        4       0                     2        1          4
# 17        714        0       3                     3        1          4
# 18        856        1       3                     1        1          4
# 19        934        1       3                     1        1          4
# 20       2096        1       3                     1        1          4
# 21       2256        1       3                     1        1          4
# 22       2705        1       3                     1        1          4
# 23       2896        1       3                     1        1          4
# 24       3521        0       3                     1        1          4
# 25       3529        4       0                     2        1          4
# 26       3582        0       3                     3        1          4
# 27       3733        0       3                     1        1          4
# 28       3741        4       0                     2        1          4
# 29       3798        0       3                     3        1          4
# 30       4001        1       3                     1        1          4
# 31       4241        1       3                     1        1          4
# 32       4820        0       3                     1        1          4
# 33       4828        4       0                     2        1          4
# 34       4882        0       3                     3        1          4
# 35       5104        0       3                     1        1          4
# 36       5112        4       0                     2        1          4
# 37       5168        0       3                     3        1          4
# 38       5517        1       3                     1        1          4
# 39       5740        0       3                     1        1          4
# 40       5748        4       0                     2        1          4
# 41       5800        0       3                     3        1          4
# 42       5849        1       3                     1        1          4
# 43       6016        1       3                     1        1          4
# 44       6089        0       3                     1        1          4
# 45       6097        4       0                     2        1          4
# 46       6154        0       3                     3        1          4
# 47       6382        1       3                     1        1          4
# 48       7754        0       3                     1        1          4
# 49       7762        4       0                     2        1          4
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       1           1  ...                 5                   5
# 1      3  10       0           0  ...                 5                   8
# 2      3   9      23           7  ...                 5                   9
# 3      3  10      23           7  ...                 5                   8
# 4      3   9      18           2  ...                 5                   5
# 5      3   9      18           2  ...                 1                   1
# 6      3   9       1           1  ...                 1                   1
# 7      3  11      23           7  ...                 3                   3
# 8      3   9       0           0  ...                 3                   4
# 9      3  12      23           7  ...                 3                   3
# 10     3   9      18           2  ...                 2                   2
# 11     3   9      18           2  ...                 2                   2
# 12     3   9       1           1  ...                 1                   1
# 13     3   9      23           7  ...                 4                   4
# 14     3   9       0           0  ...                 4                   6
# 15     3  10      18           2  ...                 4                   6
# 16     3  10      23           7  ...                 4                   4
# 17     3   9      18           2  ...                 1                   1
# 18     3   9       1           1  ...                 1                   1
# 19     3   9       0           0  ...                 1                   1
# 20     3   9       1           1  ...                 1                   1
# 21     3   9       0           0  ...                 1                   1
# 22     3   9       1           1  ...                 1                   1
# 23     3   9       0           0  ...                 1                   1
# 24     3   9       1           1  ...                 1                   1
# 25     3  11      23           7  ...                 1                   1
# 26     3   9      18           2  ...                 1                   1
# 27     3   9       0           0  ...                 1                   1
# 28     3  12      23           7  ...                 1                   1
# 29     3   9      18           2  ...                 1                   1
# 30     3   9       1           1  ...                 1                   1
# 31     3   9       0           0  ...                 1                   1
# 32     3   9       1           1  ...                 1                   1
# 33     3   9      23           7  ...                 1                   1
# 34     3   9      18           2  ...                 1                   1
# 35     3   9       0           0  ...                 1                   1
# 36     3  10      23           7  ...                 1                   1
# 37     3   9      18           2  ...                 1                   1
# 38     3   9       1           1  ...                 1                   1
# 39     3   9       1           1  ...                 1                   1
# 40     3  11      23           7  ...                 1                   1
# 41     3   9      18           2  ...                 1                   1
# 42     3   9       0           0  ...                 1                   1
# 43     3   9       1           1  ...                 1                   1
# 44     3   9       0           0  ...                 1                   1
# 45     3  12      23           7  ...                 1                   1
# 46     3   9      18           2  ...                 1                   1
# 47     3   9       0           0  ...                 1                   1
# 48     3   9       1           1  ...                 1                   1
# 49     3   9      23           7  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 25           0                           1           4
# 1                 40           0                           1           4
# 2                 45           0                           2           8
# 3                 40           0                           2           8
# 4                 25           0                           3          12
# 5                  1           0                           3          12
# 6                  1           0                           1           4
# 7                  9           0                           2           8
# 8                 12           0                           1           4
# 9                  9           0                           2           8
# 10                 4           0                           3          12
# 11                 4           0                           3          12
# 12                 1           0                           1           4
# 13                16           0                           2           8
# 14                24           0                           1           4
# 15                24           0                           3          12
# 16                16           0                           2           8
# 17                 1           0                           3          12
# 18                 1           3                           1           4
# 19                 1           3                           1           4
# 20                 1           3                           1           4
# 21                 1           3                           1           4
# 22                 1           3                           1           4
# 23                 1           3                           1           4
# 24                 1           0                           1           4
# 25                 1           0                           2           8
# 26                 1           0                           3          12
# 27                 1           0                           1           4
# 28                 1           0                           2           8
# 29                 1           0                           3          12
# 30                 1           3                           1           4
# 31                 1           3                           1           4
# 32                 1           0                           1           4
# 33                 1           0                           2           8
# 34                 1           0                           3          12
# 35                 1           0                           1           4
# 36                 1           0                           2           8
# 37                 1           0                           3          12
# 38                 1           3                           1           4
# 39                 1           0                           1           4
# 40                 1           0                           2           8
# 41                 1           0                           3          12
# 42                 1           3                           1           4
# 43                 1           3                           1           4
# 44                 1           0                           1           4
# 45                 1           0                           2           8
# 46                 1           0                           3          12
# 47                 1           3                           1           4
# 48                 1           0                           1           4
# 49                 1           0                           2           8
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 4                           3             27
# 1                 0                           3             30
# 2                 8                           6             27
# 3                 0                           6             30
# 4                12                           9             27
# 5                 0                           9             27
# 6                24                           3             27
# 7                48                           6             33
# 8                28                           3             27
# 9                56                           6             36
# 10               72                           9             27
# 11               84                           9             27
# 12               48                           3             27
# 13               96                           6             27
# 14               52                           3             27
# 15              144                           9             30
# 16              104                           6             30
# 17              156                           9             27
# 18               72                           3             27
# 19               76                           3             27
# 20              172                           3             27
# 21              184                           3             27
# 22              212                           3             27
# 23              220                           3             27
# 24              252                           3             27
# 25              504                           6             33
# 26              756                           9             27
# 27              264                           3             27
# 28              528                           6             36
# 29              792                           9             27
# 30              280                           3             27
# 31              300                           3             27
# 32              340                           3             27
# 33              680                           6             27
# 34             1020                           9             27
# 35              360                           3             27
# 36              720                           6             30
# 37             1080                           9             27
# 38              392                           3             27
# 39              408                           3             27
# 40              816                           6             33
# 41             1224                           9             27
# 42              416                           3             27
# 43              428                           3             27
# 44              432                           3             27
# 45              864                           6             36
# 46             1296                           9             27
# 47              452                           3             27
# 48              544                           3             27
# 49             1088                           6             27
#
#     vnet_vc_cc_index
# 0                  9
# 1                  9
# 2                 18
# 3                 18
# 4                 27
# 5                 27
# 6                  9
# 7                 18
# 8                  9
# 9                 18
# 10                27
# 11                27
# 12                 9
# 13                18
# 14                 9
# 15                27
# 16                18
# 17                27
# 18                 9
# 19                 9
# 20                 9
# 21                 9
# 22                 9
# 23                 9
# 24                 9
# 25                18
# 26                27
# 27                 9
# 28                18
# 29                27
# 30                 9
# 31                 9
# 32                 9
# 33                18
# 34                27
# 35                 9
# 36                18
# 37                27
# 38                 9
# 39                 9
# 40                18
# 41                27
# 42                 9
# 43                 9
# 44                 9
# 45                18
# 46                27
# 47                 9
# 48                 9
# 49                18
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            19        0       3                     1        1          4
# 1            23        0       3                     1        1          4
# 2            27        4       0                     2        1          4
# 3            31        4       0                     2        1          4
# 4            82        0       3                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 7962    2008981        1       3                     5        3          2
# 7963    2008988        1       3                     5        4          2
# 7964    2008995        1       3                     5        5          3
# 7965    2008996        1       3                     1        1          4
# 7966    2021710        1       3                     5        1          1
#
#       vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0        3   9       1           1  ...                 5                   5
# 1        3  10       0           0  ...                 5                   8
# 2        3   9      23           7  ...                 5                   9
# 3        3  10      23           7  ...                 5                   8
# 4        3   9      18           2  ...                 5                   5
# ...    ...  ..     ...         ...  ...               ...                 ...
# 7962     3   9       0           0  ...                 1                   1
# 7963     3   9       0           0  ...                 1                   1
# 7964     3   9       0           0  ...                 1                   1
# 7965     3  10       0           0  ...                 1                   1
# 7966     3   9       1           1  ...                 1                   1
#
#       packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                   25           0                           1           4
# 1                   40           0                           1           4
# 2                   45           0                           2           8
# 3                   40           0                           2           8
# 4                   25           0                           3          12
# ...                ...         ...                         ...         ...
# 7962                 1           3                          15          30
# 7963                 1           3                          20          40
# 7964                 1           3                          25          75
# 7965                 1           3                           1           4
# 7966                 1           3                           5           5
#
#       traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                   4                           3             27
# 1                   0                           3             30
# 2                   8                           6             27
# 3                   0                           6             30
# 4                  12                           9             27
# ...               ...                         ...            ...
# 7962           331920                          15             27
# 7963           442560                          15             27
# 7964           829800                          15             27
# 7965            44260                           3             30
# 7966            55400                          15             27
#
#       vnet_vc_cc_index
# 0                    9
# 1                    9
# 2                   18
# 3                   18
# 4                   27
# ...                ...
# 7962                45
# 7963                45
# 7964                45
# 7965                 9
# 7966                45
#
# [7967 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            19        0       3                     1        1          4
# 1            23        0       3                     1        1          4
# 2            27        4       0                     2        1          4
# 3            31        4       0                     2        1          4
# 4            82        0       3                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 7962    2008981        1       3                     5        3          2
# 7963    2008988        1       3                     5        4          2
# 7964    2008995        1       3                     5        5          3
# 7965    2008996        1       3                     1        1          4
# 7966    2021710        1       3                     5        1          1
#
#       vnet  vc  src_ni  src_router  ...  packet_count_index  packet_max_index  \
# 0        3   9       1           1  ...                   5                25
# 1        3  10       0           0  ...                   8                40
# 2        3   9      23           7  ...                   9                45
# 3        3  10      23           7  ...                   8                40
# 4        3   9      18           2  ...                   5                25
# ...    ...  ..     ...         ...  ...                 ...               ...
# 7962     3   9       0           0  ...                   1                 1
# 7963     3   9       0           0  ...                   1                 1
# 7964     3   9       0           0  ...                   1                 1
# 7965     3  10       0           0  ...                   1                 1
# 7966     3   9       1           1  ...                   1                 1
#
#       port_index  cache_coherence_flit_index  flit_index  traversal_index  \
# 0              0                           1           4                4
# 1              0                           1           4                0
# 2              0                           2           8                8
# 3              0                           2           8                0
# 4              0                           3          12               12
# ...          ...                         ...         ...              ...
# 7962           3                          15          30           331920
# 7963           3                          20          40           442560
# 7964           3                          25          75           829800
# 7965           3                           1           4            44260
# 7966           3                           5           5            55400
#
#       cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index  target
# 0                              3             27                 9       0
# 1                              3             30                 9       0
# 2                              6             27                18       0
# 3                              6             30                18       0
# 4                              9             27                27       0
# ...                          ...            ...               ...     ...
# 7962                          15             27                45       0
# 7963                          15             27                45       0
# 7964                          15             27                45       0
# 7965                           3             30                 9       0
# 7966                          15             27                45       0
#
# [7967 rows x 30 columns]

# %%
df.to_csv('wat-r7-mal.csv',index=False)
