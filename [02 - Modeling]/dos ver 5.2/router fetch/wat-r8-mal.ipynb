# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 8]
df = df.drop(columns=['router'])
df.to_csv('wat-r8-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r8-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        0       3                     1        1          4
# 1            121        2       0                     2        1          4
# 2            134        0       3                     1        1          4
# 3            142        2       0                     2        1          4
# 4            176        0       1                     3        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 12944    2009875        3       1                     4        1          1
# 12945    2009876        3       1                     4        2          2
# 12946    2009877        3       1                     4        3          2
# 12947    2009878        3       1                     4        4          2
# 12948    2009882        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       1           1      24           8             2
# 1         3   9      24           8      29          13             2
# 2         3   9       0           0      24           8             3
# 3         3  10      24           8      29          13             3
# 4         3   9      29          13      24           8             2
# ...     ...  ..     ...         ...     ...         ...           ...
# 12944     5  17      30          14       0           0         11071
# 12945     5  17      30          14       0           0         11071
# 12946     5  17      30          14       0           0         11071
# 12947     5  17      30          14       0           0         11071
# 12948     5  17      30          14       0           0         11071
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              3            3             1.0            16
# 1              2            0             0.0             4
# 2              2            2             1.0            12
# 3              2            0             0.0             4
# 4              2            2             1.0            12
# ...          ...          ...             ...           ...
# 12944          5            3             0.6            17
# 12945          5            3             0.6            18
# 12946          5            3             0.6            19
# 12947          5            3             0.6            20
# 12948          5            3             0.6            24
#
# [12949 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 12949

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         113        0       3                     1        1          4
# 1         121        2       0                     2        1          4
# 2         134        0       3                     1        1          4
# 3         142        2       0                     2        1          4
# 4         176        0       1                     3        1          4
# 5         198        3       1                     4        1          1
# 6         199        3       1                     4        2          2
# 7         200        3       1                     4        3          2
# 8         201        0       1                     3        1          4
# 9         202        3       1                     4        4          2
# 10        205        3       1                     4        5          3
# 11        888        3       1                     4        1          1
# 12        889        3       1                     4        2          2
# 13        890        3       1                     4        3          2
# 14        891        3       1                     4        4          2
# 15        895        3       1                     4        5          3
# 16       1003        3       1                     4        1          1
# 17       1004        3       1                     4        2          2
# 18       1005        3       1                     4        3          2
# 19       1006        3       1                     4        4          2
# 20       1010        3       1                     4        5          3
# 21       1107        3       1                     4        1          1
# 22       1108        3       1                     4        2          2
# 23       1109        3       1                     4        3          2
# 24       1110        3       1                     4        4          2
# 25       1114        3       1                     4        5          3
# 26       1152        1       3                     1        1          4
# 27       1241        1       3                     1        1          4
# 28       1310        3       1                     4        1          1
# 29       1312        3       1                     4        2          2
# 30       1313        3       1                     4        3          2
# 31       1314        3       1                     4        4          2
# 32       1317        3       1                     4        5          3
# 33       1434        3       1                     4        1          1
# 34       1435        3       1                     4        2          2
# 35       1436        3       1                     4        3          2
# 36       1437        3       1                     4        4          2
# 37       1441        3       1                     4        5          3
# 38       1541        3       1                     4        1          1
# 39       1542        3       1                     4        2          2
# 40       1543        3       1                     4        3          2
# 41       1544        3       1                     4        4          2
# 42       1548        3       1                     4        5          3
# 43       1750        3       1                     4        1          1
# 44       1751        3       1                     4        2          2
# 45       1752        3       1                     4        3          2
# 46       1753        3       1                     4        4          2
# 47       1757        3       1                     4        5          3
# 48       2325        3       1                     4        1          1
# 49       2326        3       1                     4        2          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       1           1  ...                 7                   7
# 1      3   9      24           8  ...                 7                  12
# 2      3   9       0           0  ...                 7                  15
# 3      3  10      24           8  ...                 7                  16
# 4      3   9      29          13  ...                 7                  15
# 5      5  17      29          13  ...                 7                  12
# 6      5  17      29          13  ...                 7                   7
# 7      5  17      29          13  ...                 4                   4
# 8      3   9      29          13  ...                 4                   6
# 9      5  17      29          13  ...                 4                   6
# 10     5  17      29          13  ...                 4                   4
# 11     5  17      30          14  ...                 1                   1
# 12     5  17      30          14  ...                 1                   1
# 13     5  17      30          14  ...                 1                   1
# 14     5  17      30          14  ...                 1                   1
# 15     5  17      30          14  ...                 1                   1
# 16     5  17      29          13  ...                 1                   1
# 17     5  17      29          13  ...                 1                   1
# 18     5  17      29          13  ...                 3                   3
# 19     5  17      29          13  ...                 3                   4
# 20     5  17      29          13  ...                 3                   3
# 21     5  17      29          13  ...                 6                   6
# 22     5  17      29          13  ...                 6                  10
# 23     5  17      29          13  ...                 6                  12
# 24     5  17      29          13  ...                 6                  12
# 25     5  17      29          13  ...                 6                  10
# 26     3   9       1           1  ...                 6                   6
# 27     3   9       0           0  ...                 1                   1
# 28     5  17      30          14  ...                 5                   5
# 29     5  17      30          14  ...                 5                   8
# 30     5  17      30          14  ...                 5                   9
# 31     5  17      30          14  ...                 5                   8
# 32     5  17      30          14  ...                 5                   5
# 33     5  17      29          13  ...                 5                   5
# 34     5  17      29          13  ...                 5                   8
# 35     5  17      29          13  ...                 5                   9
# 36     5  17      29          13  ...                 5                   8
# 37     5  17      29          13  ...                 5                   5
# 38     5  17      30          14  ...                 5                   5
# 39     5  17      30          14  ...                 5                   8
# 40     5  17      30          14  ...                 5                   9
# 41     5  17      30          14  ...                 5                   8
# 42     5  17      30          14  ...                 5                   5
# 43     5  17      30          14  ...                 1                   1
# 44     5  17      30          14  ...                 4                   4
# 45     5  17      30          14  ...                 4                   6
# 46     5  17      30          14  ...                 4                   6
# 47     5  17      30          14  ...                 4                   4
# 48     5  17      29          13  ...                 1                   1
# 49     5  17      29          13  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 49           0                           1           4
# 1                 84           0                           2           8
# 2                105           0                           1           4
# 3                112           0                           2           8
# 4                105           0                           3          12
# 5                 84           3                           4           4
# 6                 49           3                           8          16
# 7                 16           3                          12          24
# 8                 24           0                           3          12
# 9                 24           3                          16          32
# 10                16           3                          20          60
# 11                 1           3                           4           4
# 12                 1           3                           8          16
# 13                 1           3                          12          24
# 14                 1           3                          16          32
# 15                 1           3                          20          60
# 16                 1           3                           4           4
# 17                 1           3                           8          16
# 18                 9           3                          12          24
# 19                12           3                          16          32
# 20                 9           3                          20          60
# 21                36           3                           4           4
# 22                60           3                           8          16
# 23                72           3                          12          24
# 24                72           3                          16          32
# 25                60           3                          20          60
# 26                36           3                           1           4
# 27                 1           3                           1           4
# 28                25           3                           4           4
# 29                40           3                           8          16
# 30                45           3                          12          24
# 31                40           3                          16          32
# 32                25           3                          20          60
# 33                25           3                           4           4
# 34                40           3                           8          16
# 35                45           3                          12          24
# 36                40           3                          16          32
# 37                25           3                          20          60
# 38                25           3                           4           4
# 39                40           3                           8          16
# 40                45           3                          12          24
# 41                40           3                          16          32
# 42                25           3                          20          60
# 43                 1           3                           4           4
# 44                16           3                           8          16
# 45                24           3                          12          24
# 46                24           3                          16          32
# 47                16           3                          20          60
# 48                 1           3                           4           4
# 49                 1           3                           8          16
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 8                           3             27
# 1                16                           6             27
# 2                12                           3             27
# 3                24                           6             30
# 4                24                           9             27
# 5                12                          20             85
# 6                48                          20             85
# 7                72                          20             85
# 8                36                           9             27
# 9                96                          20             85
# 10              180                          20             85
# 11               68                          20             85
# 12              272                          20             85
# 13              408                          20             85
# 14              544                          20             85
# 15             1020                          20             85
# 16               76                          20             85
# 17              304                          20             85
# 18              456                          20             85
# 19              608                          20             85
# 20             1140                          20             85
# 21               84                          20             85
# 22              336                          20             85
# 23              504                          20             85
# 24              672                          20             85
# 25             1260                          20             85
# 26               96                           3             27
# 27              100                           3             27
# 28              100                          20             85
# 29              400                          20             85
# 30              600                          20             85
# 31              800                          20             85
# 32             1500                          20             85
# 33              108                          20             85
# 34              432                          20             85
# 35              648                          20             85
# 36              864                          20             85
# 37             1620                          20             85
# 38              116                          20             85
# 39              464                          20             85
# 40              696                          20             85
# 41              928                          20             85
# 42             1740                          20             85
# 43              136                          20             85
# 44              544                          20             85
# 45              816                          20             85
# 46             1088                          20             85
# 47             2040                          20             85
# 48              184                          20             85
# 49              736                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                 18
# 2                  9
# 3                 18
# 4                 27
# 5                100
# 6                100
# 7                100
# 8                 27
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19               100
# 20               100
# 21               100
# 22               100
# 23               100
# 24               100
# 25               100
# 26                 9
# 27                 9
# 28               100
# 29               100
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        0       3                     1        1          4
# 1            121        2       0                     2        1          4
# 2            134        0       3                     1        1          4
# 3            142        2       0                     2        1          4
# 4            176        0       1                     3        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 12944    2009875        3       1                     4        1          1
# 12945    2009876        3       1                     4        2          2
# 12946    2009877        3       1                     4        3          2
# 12947    2009878        3       1                     4        4          2
# 12948    2009882        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9       1           1  ...                 7
# 1         3   9      24           8  ...                 7
# 2         3   9       0           0  ...                 7
# 3         3  10      24           8  ...                 7
# 4         3   9      29          13  ...                 7
# ...     ...  ..     ...         ...  ...               ...
# 12944     5  17      30          14  ...                 1
# 12945     5  17      30          14  ...                 1
# 12946     5  17      30          14  ...                 1
# 12947     5  17      30          14  ...                 1
# 12948     5  17      30          14  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       7                49           0
# 1                      12                84           0
# 2                      15               105           0
# 3                      16               112           0
# 4                      15               105           0
# ...                   ...               ...         ...
# 12944                   1                 1           3
# 12945                   1                 1           3
# 12946                   1                 1           3
# 12947                   1                 1           3
# 12948                   1                 1           3
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               1           4                8
# 1                               2           8               16
# 2                               1           4               12
# 3                               2           8               24
# 4                               3          12               24
# ...                           ...         ...              ...
# 12944                           4           4            44284
# 12945                           8          16           177136
# 12946                          12          24           265704
# 12947                          16          32           354272
# 12948                          20          60           664260
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               3             27                 9
# 1                               6             27                18
# 2                               3             27                 9
# 3                               6             30                18
# 4                               9             27                27
# ...                           ...            ...               ...
# 12944                          20             85               100
# 12945                          20             85               100
# 12946                          20             85               100
# 12947                          20             85               100
# 12948                          20             85               100
#
# [12949 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        0       3                     1        1          4
# 1            121        2       0                     2        1          4
# 2            134        0       3                     1        1          4
# 3            142        2       0                     2        1          4
# 4            176        0       1                     3        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 12944    2009875        3       1                     4        1          1
# 12945    2009876        3       1                     4        2          2
# 12946    2009877        3       1                     4        3          2
# 12947    2009878        3       1                     4        4          2
# 12948    2009882        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   7
# 1         3   9      24           8  ...                  12
# 2         3   9       0           0  ...                  15
# 3         3  10      24           8  ...                  16
# 4         3   9      29          13  ...                  15
# ...     ...  ..     ...         ...  ...                 ...
# 12944     5  17      30          14  ...                   1
# 12945     5  17      30          14  ...                   1
# 12946     5  17      30          14  ...                   1
# 12947     5  17      30          14  ...                   1
# 12948     5  17      30          14  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    49           0                           1           4
# 1                    84           0                           2           8
# 2                   105           0                           1           4
# 3                   112           0                           2           8
# 4                   105           0                           3          12
# ...                 ...         ...                         ...         ...
# 12944                 1           3                           4           4
# 12945                 1           3                           8          16
# 12946                 1           3                          12          24
# 12947                 1           3                          16          32
# 12948                 1           3                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    8                           3             27
# 1                   16                           6             27
# 2                   12                           3             27
# 3                   24                           6             30
# 4                   24                           9             27
# ...                ...                         ...            ...
# 12944            44284                          20             85
# 12945           177136                          20             85
# 12946           265704                          20             85
# 12947           354272                          20             85
# 12948           664260                          20             85
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                    18       0
# 2                     9       0
# 3                    18       0
# 4                    27       0
# ...                 ...     ...
# 12944               100       0
# 12945               100       0
# 12946               100       0
# 12947               100       0
# 12948               100       0
#
# [12949 rows x 30 columns]

# %%
df.to_csv('wat-r8-mal.csv',index=False)
