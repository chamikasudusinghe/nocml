# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/dos%20results%20ver%201/final%20models/fft_r1_model_single.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
df = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-train.csv?token=AKVFSODWB4TNVPOZTGCD2UC6Y6FLY')
df1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-mal-1.csv?token=AKVFSOCEFO5KEAUA37PWBPS6Y6FL2')
df2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-mal-2.csv?token=AKVFSODIQ3JWY2R5ZQHFDTS6Y6FMA')

# %%
cols = list(df.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df = df[cols]
df
# Out:
#         timestamp  outport  inport  ...  sim  sim_traversal  target
# 0              11        2       4  ...    1              1       1
# 1              11        2       4  ...    1              1       0
# 2              84        4       2  ...    1              4       0
# 3              84        4       2  ...    1              3       1
# 4             216        2       4  ...    1              6       1
# ...           ...      ...     ...  ...  ...            ...     ...
# 108206    3268816        4       2  ...    1          20042       1
# 108207    3268823        4       2  ...    1          20042       1
# 108208    3268830        4       2  ...    1          20042       1
# 108209    3268837        4       2  ...    1          20042       1
# 108210    3268838        4       2  ...    1          20043       1
#
# [108211 rows x 32 columns]

# %%
cols = list(df1.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df1 = df1[cols]
df1
# Out:
#         timestamp  outport  inport  ...  sim  sim_traversal  target
# 0               7        2       0  ...    1              2       0
# 1              11        2       4  ...    1              1       0
# 2              84        0       1  ...    1              2       0
# 3              84        4       2  ...    1              4       0
# 4              85        0       1  ...    1              2       0
# ...           ...      ...     ...  ...  ...            ...     ...
# 127845    3270078        4       2  ...    1          30070       0
# 127846    3270085        4       2  ...    1          30070       0
# 127847    3270092        4       2  ...    1          30070       0
# 127848    3270099        4       2  ...    1          30070       0
# 127849    3270100        4       2  ...    1          30071       0
#
# [127850 rows x 32 columns]

# %%
cols = list(df2.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df2 = df2[cols]
df2
# Out:
#        timestamp  outport  inport  ...  sim  sim_traversal  target
# 0             11        2       4  ...    1              1       0
# 1             84        4       2  ...    1              4       0
# 2            238        2       4  ...    1              9       0
# 3            365        2       4  ...    1             12       0
# 4            386        1       2  ...    1             13       0
# ...          ...      ...     ...  ...  ...            ...     ...
# 69448    3276626        4       2  ...    1          30066       0
# 69449    3276633        4       2  ...    1          30066       0
# 69450    3276640        4       2  ...    1          30066       0
# 69451    3276647        4       2  ...    1          30066       0
# 69452    3276648        4       2  ...    1          30067       0
#
# [69453 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# sim                           0
# sim_traversal                 0
# target                        0
# dtype: int64

# %%
df = df.drop(columns=['timestamp','src_ni','src_router'])

# %%
df.corr()
# Out:
#                              outport    inport  ...  sim_traversal    target
# outport                     1.000000 -0.459807  ...      -0.028973 -0.005102
# inport                     -0.459807  1.000000  ...       0.033701  0.112608
# cache_coherence_type        0.237770 -0.206231  ...       0.005233 -0.034337
# flit_id                     0.029889  0.058969  ...       0.020819  0.014935
# flit_type                  -0.044490 -0.087775  ...      -0.030988 -0.022230
# vnet                             NaN       NaN  ...            NaN       NaN
# vc                          0.255669 -0.446856  ...      -0.016882 -0.049744
# dst_ni                     -0.060509  0.346364  ...       0.078248  0.078969
# dst_router                 -0.055797  0.344889  ...       0.098127  0.071653
# traversal_id               -0.028973  0.033701  ...       1.000000 -0.052864
# hop_count                   0.242957  0.275137  ...       0.071956  0.073165
# current_hop                -0.157727  0.136175  ...       0.014618  0.008832
# hop_percentage             -0.569855  0.184449  ...      -0.025590 -0.025730
# enqueue_time                0.003471  0.096469  ...       0.029473  0.017730
# packet_count_decr          -0.051228 -0.015962  ...       0.024670 -0.088003
# packet_count_incr           0.136610 -0.194196  ...       0.024730 -0.088003
# max_packet_count            0.055251 -0.135994  ...       0.031966 -0.113894
# packet_count_index          0.062876 -0.145334  ...       0.022297 -0.104126
# packet_max_index            0.044747 -0.136597  ...       0.016694 -0.099685
# port_index                  0.431340  0.497773  ...       0.010961  0.077057
# cache_coherence_flit_index  0.129405 -0.038854  ...       0.012686 -0.000858
# flit_index                  0.103778 -0.053851  ...       0.007132 -0.006201
# traversal_index             0.059824 -0.022035  ...       0.505255 -0.031958
# cache_coherence_vnet_index  0.237770 -0.206231  ...       0.005233 -0.034337
# vnet_vc_index               0.255669 -0.446856  ...      -0.016882 -0.049744
# vnet_vc_cc_index            0.237770 -0.206231  ...       0.005233 -0.034337
# sim                              NaN       NaN  ...            NaN       NaN
# sim_traversal              -0.028973  0.033701  ...       1.000000 -0.052864
# target                     -0.005102  0.112608  ...      -0.052864  1.000000
#
# [29 rows x 29 columns]

# %%
plt.figure(figsize=(27,27))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target'])
train_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0             2       4  ...    1              1
# 1             2       4  ...    1              1
# 2             4       2  ...    1              4
# 3             4       2  ...    1              3
# 4             2       4  ...    1              6
# ...         ...     ...  ...  ...            ...
# 108206        4       2  ...    1          20042
# 108207        4       2  ...    1          20042
# 108208        4       2  ...    1          20042
# 108209        4       2  ...    1          20042
# 108210        4       2  ...    1          20043
#
# [108211 rows x 28 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0           0.5     1.0  ...  0.0       0.000000
# 1           0.5     1.0  ...  0.0       0.000000
# 2           1.0     0.5  ...  0.0       0.000143
# 3           1.0     0.5  ...  0.0       0.000095
# 4           0.5     1.0  ...  0.0       0.000239
# ...         ...     ...  ...  ...            ...
# 108206      1.0     0.5  ...  0.0       0.956200
# 108207      1.0     0.5  ...  0.0       0.956200
# 108208      1.0     0.5  ...  0.0       0.956200
# 108209      1.0     0.5  ...  0.0       0.956200
# 108210      1.0     0.5  ...  0.0       0.956248
#
# [108211 rows x 28 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (371, 28)

# %%
test_X = df1.drop(columns=['target','timestamp','src_ni','src_router'])
test_Y = df1['target']
test_XX = df2.drop(columns=['target','timestamp','src_ni','src_router'])
test_YY = df2['target']

# %%
#standardization
x = test_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X = pd.DataFrame(x_scaled)
test_X.columns = columns
test_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0           0.5    0.00  ...  0.0       0.000033
# 1           0.5    1.00  ...  0.0       0.000000
# 2           0.0    0.25  ...  0.0       0.000033
# 3           1.0    0.50  ...  0.0       0.000100
# 4           0.0    0.25  ...  0.0       0.000033
# ...         ...     ...  ...  ...            ...
# 127845      1.0    0.50  ...  0.0       0.999967
# 127846      1.0    0.50  ...  0.0       0.999967
# 127847      1.0    0.50  ...  0.0       0.999967
# 127848      1.0    0.50  ...  0.0       0.999967
# 127849      1.0    0.50  ...  0.0       1.000000
#
# [127850 rows x 28 columns]

# %%
test_X[test_X.duplicated()].shape
# Out:
# (2, 28)

# %%
#standardization
x = test_XX.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_XX.columns
x_scaled = min_max_scaler.fit_transform(x)
test_XX = pd.DataFrame(x_scaled)
test_XX.columns = columns
test_XX
# Out:
#        outport  inport  ...  sim  sim_traversal
# 0         0.50     1.0  ...  0.0       0.000000
# 1         1.00     0.5  ...  0.0       0.000100
# 2         0.50     1.0  ...  0.0       0.000266
# 3         0.50     1.0  ...  0.0       0.000366
# 4         0.25     0.5  ...  0.0       0.000399
# ...        ...     ...  ...  ...            ...
# 69448     1.00     0.5  ...  0.0       0.999967
# 69449     1.00     0.5  ...  0.0       0.999967
# 69450     1.00     0.5  ...  0.0       0.999967
# 69451     1.00     0.5  ...  0.0       0.999967
# 69452     1.00     0.5  ...  0.0       1.000000
#
# [69453 rows x 28 columns]

# %%
test_XX[test_XX.duplicated()].shape
# Out:
# (55, 28)

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 1    56917
# 0    51294
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                    Specs       Score
# 16      max_packet_count  239.624836
# 1                 inport  207.085568
# 19            port_index  159.391740
# 17    packet_count_index  130.055301
# 15     packet_count_incr  122.394148
# 14     packet_count_decr  117.256820
# 18      packet_max_index  109.017541
# 6                     vc  104.190946
# 24         vnet_vc_index  104.190946
# 8             dst_router   87.940361
# 10             hop_count   66.558575
# 9           traversal_id   35.763485
# 27         sim_traversal   35.763485
# 7                 dst_ni   25.292913
# 22       traversal_index   20.562627
# 4              flit_type   12.287656
# 2   cache_coherence_type   10.789955

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
#result=logit_model.fit()
#print(result.summary2())

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 58.18431753072729
# Test Prediction  58.78113015755672

# %%
y_pred_test = logreg.predict(test_X)
logreg_score_test = accuracy_score(test_Y,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  68.97614391865467

# %%
y_pred_test1 = logreg.predict(test_XX)
logreg_score_test = accuracy_score(test_YY,y_pred_test1)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  63.797100197255695

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 3                      flit_id    1.979446
# 17          packet_count_index    1.960976
# 1                       inport    1.871481
# 0                      outport    1.238446
# 10                   hop_count    0.831297
# 11                 current_hop    0.615587
# 21                  flit_index    0.327037
# 26                         sim    0.000000
# 5                         vnet    0.000000
# 24               vnet_vc_index   -0.033867
# 6                           vc   -0.033867
# 9                 traversal_id   -0.166513
# 27               sim_traversal   -0.166513
# 23  cache_coherence_vnet_index   -0.202817
# 25            vnet_vc_cc_index   -0.202817
# 2         cache_coherence_type   -0.202817
# 15           packet_count_incr   -0.243181
# 4                    flit_type   -0.285546
# 22             traversal_index   -0.287671
# 8                   dst_router   -0.503147
# 14           packet_count_decr   -0.536071
# 7                       dst_ni   -0.639644
# 16            max_packet_count   -0.779252
# 12              hop_percentage   -0.803713
# 13                enqueue_time   -0.938310
# 19                  port_index   -1.266810
# 20  cache_coherence_flit_index   -2.120363
# 18            packet_max_index   -3.108107

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.42      0.49     10243
#            1       0.59      0.73      0.65     11400
#
#     accuracy                           0.59     21643
#    macro avg       0.59      0.58      0.57     21643
# weighted avg       0.59      0.59      0.58     21643

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y, y_pred_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.82    127850
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.69    127850
#    macro avg       0.50      0.34      0.41    127850
# weighted avg       1.00      0.69      0.82    127850
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 80.72613436835783
# Test Prediction  71.30249965346763

# %%
y_pred_knn_test= knn.predict(test_X)
knn_score_test = accuracy_score(test_Y,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  54.878373093468916

# %%
y_pred_knn_test_x= knn.predict(test_XX)
knn_score_test = accuracy_score(test_YY,y_pred_knn_test_x)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  39.302837890371904

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.66      0.68     10243
#            1       0.71      0.76      0.74     11400
#
#     accuracy                           0.71     21643
#    macro avg       0.71      0.71      0.71     21643
# weighted avg       0.71      0.71      0.71     21643

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y, y_pred_knn_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y,y_pred_knn_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71    127850
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.55    127850
#    macro avg       0.50      0.27      0.35    127850
# weighted avg       1.00      0.55      0.71    127850
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 56.09463081046114
# Test Prediction Score 56.341542300050826

# %%
y_pred_nb_test= nb.predict(test_X)
nb_score_test = accuracy_score(test_Y,y_pred_nb_test)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Test Prediction Score 57.040281579976536

# %%
y_pred_nb_test= nb.predict(test_XX)
nb_score_test = accuracy_score(test_YY,y_pred_nb_test)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Test Prediction Score 33.239744863432826

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.32      0.41     10243
#            1       0.56      0.78      0.65     11400
#
#     accuracy                           0.56     21643
#    macro avg       0.57      0.55      0.53     21643
# weighted avg       0.57      0.56      0.54     21643

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/10
# 69254/69254 [==============================] - 3s 41us/step - loss: 0.2495 - accuracy: 0.5258 - val_loss: 0.2470 - val_accuracy: 0.5461
# Epoch 2/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2451 - accuracy: 0.5539 - val_loss: 0.2420 - val_accuracy: 0.5751
# Epoch 3/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2429 - accuracy: 0.5700 - val_loss: 0.2415 - val_accuracy: 0.5751
# Epoch 4/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2425 - accuracy: 0.5688 - val_loss: 0.2410 - val_accuracy: 0.5725
# Epoch 5/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2423 - accuracy: 0.5681 - val_loss: 0.2411 - val_accuracy: 0.5743
# Epoch 6/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2422 - accuracy: 0.5686 - val_loss: 0.2409 - val_accuracy: 0.5761
# Epoch 7/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2420 - accuracy: 0.5689 - val_loss: 0.2405 - val_accuracy: 0.5734
# Epoch 8/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2418 - accuracy: 0.5679 - val_loss: 0.2406 - val_accuracy: 0.5728
# Epoch 9/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2417 - accuracy: 0.5690 - val_loss: 0.2402 - val_accuracy: 0.5724
# Epoch 10/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2414 - accuracy: 0.5688 - val_loss: 0.2398 - val_accuracy: 0.5720

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 57.46%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 65.92%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2 )
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2495 - accuracy: 0.5241 - val_loss: 0.2491 - val_accuracy: 0.5290
# Epoch 2/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2493 - accuracy: 0.5232 - val_loss: 0.2491 - val_accuracy: 0.5271
# Epoch 3/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2493 - accuracy: 0.5232 - val_loss: 0.2490 - val_accuracy: 0.5286
# Epoch 4/30
# 69254/69254 [==============================] - 3s 36us/step - loss: 0.2492 - accuracy: 0.5254 - val_loss: 0.2489 - val_accuracy: 0.5322
# Epoch 5/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2489 - accuracy: 0.5309 - val_loss: 0.2486 - val_accuracy: 0.5375
# Epoch 6/30
# 69254/69254 [==============================] - 3s 36us/step - loss: 0.2486 - accuracy: 0.5412 - val_loss: 0.2484 - val_accuracy: 0.5449
# Epoch 7/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2484 - accuracy: 0.5462 - val_loss: 0.2482 - val_accuracy: 0.5465
# Epoch 8/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2481 - accuracy: 0.5482 - val_loss: 0.2480 - val_accuracy: 0.5451
# Epoch 9/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2478 - accuracy: 0.5473 - val_loss: 0.2476 - val_accuracy: 0.5446
# Epoch 10/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2474 - accuracy: 0.5462 - val_loss: 0.2470 - val_accuracy: 0.5476
# Epoch 11/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2466 - accuracy: 0.5492 - val_loss: 0.2462 - val_accuracy: 0.5483
# Epoch 12/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2457 - accuracy: 0.5562 - val_loss: 0.2451 - val_accuracy: 0.5546
# Epoch 13/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2448 - accuracy: 0.5616 - val_loss: 0.2443 - val_accuracy: 0.5587
# Epoch 14/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2441 - accuracy: 0.5635 - val_loss: 0.2436 - val_accuracy: 0.5613
# Epoch 15/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2436 - accuracy: 0.5673 - val_loss: 0.2431 - val_accuracy: 0.5677
# Epoch 16/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2433 - accuracy: 0.5696 - val_loss: 0.2427 - val_accuracy: 0.5695
# Epoch 17/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2430 - accuracy: 0.5728 - val_loss: 0.2423 - val_accuracy: 0.5736
# Epoch 18/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2427 - accuracy: 0.5760 - val_loss: 0.2420 - val_accuracy: 0.5760
# Epoch 19/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2425 - accuracy: 0.5773 - val_loss: 0.2417 - val_accuracy: 0.5744
# Epoch 20/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2423 - accuracy: 0.5781 - val_loss: 0.2415 - val_accuracy: 0.5784
# Epoch 21/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2422 - accuracy: 0.5789 - val_loss: 0.2413 - val_accuracy: 0.5791
# Epoch 22/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2421 - accuracy: 0.5793 - val_loss: 0.2412 - val_accuracy: 0.5787
# Epoch 23/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2419 - accuracy: 0.5789 - val_loss: 0.2410 - val_accuracy: 0.5798
# Epoch 24/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2418 - accuracy: 0.5797 - val_loss: 0.2409 - val_accuracy: 0.5794
# Epoch 25/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2417 - accuracy: 0.5803 - val_loss: 0.2409 - val_accuracy: 0.5805
# Epoch 26/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2417 - accuracy: 0.5804 - val_loss: 0.2407 - val_accuracy: 0.5799
# Epoch 27/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2415 - accuracy: 0.5808 - val_loss: 0.2406 - val_accuracy: 0.5829
# Epoch 28/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2415 - accuracy: 0.5804 - val_loss: 0.2405 - val_accuracy: 0.5819
# Epoch 29/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2413 - accuracy: 0.5807 - val_loss: 0.2405 - val_accuracy: 0.5826
# Epoch 30/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2413 - accuracy: 0.5817 - val_loss: 0.2404 - val_accuracy: 0.5824

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 58.79%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 69.73%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 36.17%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2489 - accuracy: 0.5341 - val_loss: 0.2476 - val_accuracy: 0.5449
# Epoch 2/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2467 - accuracy: 0.5501 - val_loss: 0.2451 - val_accuracy: 0.5573
# Epoch 3/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2446 - accuracy: 0.5677 - val_loss: 0.2431 - val_accuracy: 0.5743
# Epoch 4/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2434 - accuracy: 0.5713 - val_loss: 0.2422 - val_accuracy: 0.5736
# Epoch 5/30
# 69254/69254 [==============================] - 3s 41us/step - loss: 0.2427 - accuracy: 0.5715 - val_loss: 0.2416 - val_accuracy: 0.5781
# Epoch 6/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2421 - accuracy: 0.5745 - val_loss: 0.2410 - val_accuracy: 0.5782
# Epoch 7/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2417 - accuracy: 0.5760 - val_loss: 0.2406 - val_accuracy: 0.5813
# Epoch 8/30
# 69254/69254 [==============================] - 3s 42us/step - loss: 0.2413 - accuracy: 0.5772 - val_loss: 0.2402 - val_accuracy: 0.5809
# Epoch 9/30
# 69254/69254 [==============================] - 3s 41us/step - loss: 0.2410 - accuracy: 0.5797 - val_loss: 0.2398 - val_accuracy: 0.5833
# Epoch 10/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2407 - accuracy: 0.5816 - val_loss: 0.2394 - val_accuracy: 0.5850
# Epoch 11/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2404 - accuracy: 0.5804 - val_loss: 0.2391 - val_accuracy: 0.5873
# Epoch 12/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2401 - accuracy: 0.5822 - val_loss: 0.2387 - val_accuracy: 0.5895
# Epoch 13/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2398 - accuracy: 0.5837 - val_loss: 0.2385 - val_accuracy: 0.5878
# Epoch 14/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2395 - accuracy: 0.5827 - val_loss: 0.2381 - val_accuracy: 0.5869
# Epoch 15/30
# 69254/69254 [==============================] - 3s 44us/step - loss: 0.2393 - accuracy: 0.5819 - val_loss: 0.2383 - val_accuracy: 0.5906
# Epoch 16/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2390 - accuracy: 0.5822 - val_loss: 0.2377 - val_accuracy: 0.5897
# Epoch 17/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2389 - accuracy: 0.5835 - val_loss: 0.2375 - val_accuracy: 0.5862
# Epoch 18/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2387 - accuracy: 0.5831 - val_loss: 0.2374 - val_accuracy: 0.5897
# Epoch 19/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2386 - accuracy: 0.5846 - val_loss: 0.2372 - val_accuracy: 0.5865
# Epoch 20/30
# 69254/69254 [==============================] - 3s 41us/step - loss: 0.2385 - accuracy: 0.5843 - val_loss: 0.2375 - val_accuracy: 0.5979
# Epoch 21/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2384 - accuracy: 0.5848 - val_loss: 0.2370 - val_accuracy: 0.5876
# Epoch 22/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2383 - accuracy: 0.5854 - val_loss: 0.2370 - val_accuracy: 0.5884
# Epoch 23/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2383 - accuracy: 0.5839 - val_loss: 0.2369 - val_accuracy: 0.5947
# Epoch 24/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2381 - accuracy: 0.5851 - val_loss: 0.2369 - val_accuracy: 0.5895
# Epoch 25/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2380 - accuracy: 0.5868 - val_loss: 0.2368 - val_accuracy: 0.5879
# Epoch 26/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2380 - accuracy: 0.5860 - val_loss: 0.2367 - val_accuracy: 0.5935
# Epoch 27/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2379 - accuracy: 0.5860 - val_loss: 0.2365 - val_accuracy: 0.5904
# Epoch 28/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2378 - accuracy: 0.5869 - val_loss: 0.2364 - val_accuracy: 0.5951
# Epoch 29/30
# 69254/69254 [==============================] - 3s 42us/step - loss: 0.2377 - accuracy: 0.5880 - val_loss: 0.2364 - val_accuracy: 0.5939
# Epoch 30/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2376 - accuracy: 0.5862 - val_loss: 0.2363 - val_accuracy: 0.5963

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 59.60%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 57.34%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 36.00%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/100
# 69254/69254 [==============================] - 6s 86us/step - loss: 0.2387 - accuracy: 0.5894 - val_loss: 0.2326 - val_accuracy: 0.6123
# Epoch 2/100
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.2309 - accuracy: 0.6132 - val_loss: 0.2306 - val_accuracy: 0.6129
# Epoch 3/100
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2258 - accuracy: 0.6282 - val_loss: 0.2221 - val_accuracy: 0.6338
# Epoch 4/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2218 - accuracy: 0.6382 - val_loss: 0.2126 - val_accuracy: 0.6622
# Epoch 5/100
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2180 - accuracy: 0.6472 - val_loss: 0.2105 - val_accuracy: 0.6751
# Epoch 6/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2134 - accuracy: 0.6564 - val_loss: 0.2050 - val_accuracy: 0.6685
# Epoch 7/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.2107 - accuracy: 0.6634 - val_loss: 0.1990 - val_accuracy: 0.6892
# Epoch 8/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2084 - accuracy: 0.6664 - val_loss: 0.2013 - val_accuracy: 0.6877
# Epoch 9/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2063 - accuracy: 0.6714 - val_loss: 0.1915 - val_accuracy: 0.7002
# Epoch 10/100
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.2045 - accuracy: 0.6777 - val_loss: 0.1928 - val_accuracy: 0.7039
# Epoch 11/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.2023 - accuracy: 0.6811 - val_loss: 0.1990 - val_accuracy: 0.6834
# Epoch 12/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2002 - accuracy: 0.6859 - val_loss: 0.1897 - val_accuracy: 0.7015
# Epoch 13/100
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1989 - accuracy: 0.6866 - val_loss: 0.1859 - val_accuracy: 0.7176
# Epoch 14/100
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1980 - accuracy: 0.6934 - val_loss: 0.1899 - val_accuracy: 0.7058
# Epoch 15/100
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1963 - accuracy: 0.6920 - val_loss: 0.1818 - val_accuracy: 0.7237
# Epoch 16/100
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1951 - accuracy: 0.6954 - val_loss: 0.1866 - val_accuracy: 0.7109
# Epoch 17/100
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.1939 - accuracy: 0.6978 - val_loss: 0.1841 - val_accuracy: 0.7076
# Epoch 18/100
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1922 - accuracy: 0.7015 - val_loss: 0.1905 - val_accuracy: 0.7018
# Epoch 19/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1915 - accuracy: 0.7034 - val_loss: 0.1860 - val_accuracy: 0.7119
# Epoch 20/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1904 - accuracy: 0.7055 - val_loss: 0.1778 - val_accuracy: 0.7256
# Epoch 21/100
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.1904 - accuracy: 0.7054 - val_loss: 0.1750 - val_accuracy: 0.7340
# Epoch 22/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1885 - accuracy: 0.7085 - val_loss: 0.1738 - val_accuracy: 0.7362
# Epoch 23/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1879 - accuracy: 0.7086 - val_loss: 0.1733 - val_accuracy: 0.7325
# Epoch 24/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1868 - accuracy: 0.7121 - val_loss: 0.1820 - val_accuracy: 0.7177
# Epoch 25/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1874 - accuracy: 0.7086 - val_loss: 0.1744 - val_accuracy: 0.7274
# Epoch 26/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1864 - accuracy: 0.7130 - val_loss: 0.1749 - val_accuracy: 0.7294
# Epoch 27/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1850 - accuracy: 0.7154 - val_loss: 0.1792 - val_accuracy: 0.7263
# Epoch 28/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1843 - accuracy: 0.7164 - val_loss: 0.1815 - val_accuracy: 0.7114
# Epoch 29/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1841 - accuracy: 0.7166 - val_loss: 0.1733 - val_accuracy: 0.7304
# Epoch 30/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1838 - accuracy: 0.7184 - val_loss: 0.1800 - val_accuracy: 0.7262
# Epoch 31/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1833 - accuracy: 0.7169 - val_loss: 0.1698 - val_accuracy: 0.7397
# Epoch 32/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1827 - accuracy: 0.7198 - val_loss: 0.1743 - val_accuracy: 0.7344
# Epoch 33/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1821 - accuracy: 0.7187 - val_loss: 0.1722 - val_accuracy: 0.7343
# Epoch 34/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1821 - accuracy: 0.7189 - val_loss: 0.1766 - val_accuracy: 0.7274
# Epoch 35/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1826 - accuracy: 0.7172 - val_loss: 0.1704 - val_accuracy: 0.7370
# Epoch 36/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1818 - accuracy: 0.7198 - val_loss: 0.1752 - val_accuracy: 0.7281
# Epoch 37/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1804 - accuracy: 0.7230 - val_loss: 0.1827 - val_accuracy: 0.7180
# Epoch 38/100
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.1806 - accuracy: 0.7214 - val_loss: 0.1739 - val_accuracy: 0.7382
# Epoch 39/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1818 - accuracy: 0.7206 - val_loss: 0.1731 - val_accuracy: 0.7351
# Epoch 40/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1803 - accuracy: 0.7226 - val_loss: 0.1725 - val_accuracy: 0.7377
# Epoch 41/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1804 - accuracy: 0.7214 - val_loss: 0.1716 - val_accuracy: 0.7353
# Epoch 42/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1802 - accuracy: 0.7223 - val_loss: 0.1735 - val_accuracy: 0.7354
# Epoch 43/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1797 - accuracy: 0.7244 - val_loss: 0.1707 - val_accuracy: 0.7400
# Epoch 44/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1793 - accuracy: 0.7249 - val_loss: 0.1699 - val_accuracy: 0.7347
# Epoch 45/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1791 - accuracy: 0.7247 - val_loss: 0.1659 - val_accuracy: 0.7458
# Epoch 46/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1785 - accuracy: 0.7246 - val_loss: 0.1718 - val_accuracy: 0.7350
# Epoch 47/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1788 - accuracy: 0.7233 - val_loss: 0.1690 - val_accuracy: 0.7417
# Epoch 48/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1783 - accuracy: 0.7255 - val_loss: 0.1668 - val_accuracy: 0.7343
# Epoch 49/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1792 - accuracy: 0.7256 - val_loss: 0.1739 - val_accuracy: 0.7283
# Epoch 50/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1794 - accuracy: 0.7222 - val_loss: 0.1667 - val_accuracy: 0.7447
# Epoch 51/100
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1780 - accuracy: 0.7270 - val_loss: 0.1656 - val_accuracy: 0.7475
# Epoch 52/100
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.1777 - accuracy: 0.7266 - val_loss: 0.1656 - val_accuracy: 0.7462
# Epoch 53/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1776 - accuracy: 0.7287 - val_loss: 0.1647 - val_accuracy: 0.7401
# Epoch 54/100
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.1780 - accuracy: 0.7279 - val_loss: 0.1667 - val_accuracy: 0.7382
# Epoch 55/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1773 - accuracy: 0.7278 - val_loss: 0.1702 - val_accuracy: 0.7356
# Epoch 56/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1777 - accuracy: 0.7278 - val_loss: 0.1799 - val_accuracy: 0.7242
# Epoch 57/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1771 - accuracy: 0.7292 - val_loss: 0.1670 - val_accuracy: 0.7470
# Epoch 58/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1775 - accuracy: 0.7253 - val_loss: 0.1638 - val_accuracy: 0.7430
# Epoch 59/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1770 - accuracy: 0.7260 - val_loss: 0.1645 - val_accuracy: 0.7474
# Epoch 60/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1769 - accuracy: 0.7258 - val_loss: 0.1659 - val_accuracy: 0.7391
# Epoch 61/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1767 - accuracy: 0.7272 - val_loss: 0.1700 - val_accuracy: 0.7339
# Epoch 62/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1770 - accuracy: 0.7274 - val_loss: 0.1647 - val_accuracy: 0.7432
# Epoch 63/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1770 - accuracy: 0.7274 - val_loss: 0.1631 - val_accuracy: 0.7504
# Epoch 64/100
# 69254/69254 [==============================] - 4s 64us/step - loss: 0.1767 - accuracy: 0.7290 - val_loss: 0.1651 - val_accuracy: 0.7470
# Epoch 65/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1762 - accuracy: 0.7296 - val_loss: 0.1658 - val_accuracy: 0.7451
# Epoch 66/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1754 - accuracy: 0.7304 - val_loss: 0.1641 - val_accuracy: 0.7489
# Epoch 67/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1764 - accuracy: 0.7291 - val_loss: 0.1672 - val_accuracy: 0.7382
# Epoch 68/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1756 - accuracy: 0.7303 - val_loss: 0.1622 - val_accuracy: 0.7560
# Epoch 69/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1765 - accuracy: 0.7289 - val_loss: 0.1645 - val_accuracy: 0.7515
# Epoch 70/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1757 - accuracy: 0.7296 - val_loss: 0.1641 - val_accuracy: 0.7557
# Epoch 71/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1753 - accuracy: 0.7304 - val_loss: 0.1702 - val_accuracy: 0.7395
# Epoch 72/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1751 - accuracy: 0.7301 - val_loss: 0.1712 - val_accuracy: 0.7404
# Epoch 73/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1749 - accuracy: 0.7329 - val_loss: 0.1721 - val_accuracy: 0.7382
# Epoch 74/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1751 - accuracy: 0.7320 - val_loss: 0.1745 - val_accuracy: 0.7289
# Epoch 75/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1750 - accuracy: 0.7325 - val_loss: 0.1643 - val_accuracy: 0.7498
# Epoch 76/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1748 - accuracy: 0.7332 - val_loss: 0.1649 - val_accuracy: 0.7519
# Epoch 77/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1748 - accuracy: 0.7324 - val_loss: 0.1692 - val_accuracy: 0.7410
# Epoch 78/100
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.1750 - accuracy: 0.7311 - val_loss: 0.1747 - val_accuracy: 0.7225
# Epoch 79/100
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1755 - accuracy: 0.7307 - val_loss: 0.1627 - val_accuracy: 0.7499
# Epoch 80/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1749 - accuracy: 0.7308 - val_loss: 0.1660 - val_accuracy: 0.7475
# Epoch 81/100
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1751 - accuracy: 0.7312 - val_loss: 0.1677 - val_accuracy: 0.7458
# Epoch 82/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1745 - accuracy: 0.7333 - val_loss: 0.1627 - val_accuracy: 0.7491
# Epoch 83/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1740 - accuracy: 0.7336 - val_loss: 0.1654 - val_accuracy: 0.7463
# Epoch 84/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1739 - accuracy: 0.7324 - val_loss: 0.1614 - val_accuracy: 0.7518
# Epoch 85/100
# 69254/69254 [==============================] - 5s 65us/step - loss: 0.1741 - accuracy: 0.7338 - val_loss: 0.1641 - val_accuracy: 0.7449
# Epoch 86/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1741 - accuracy: 0.7335 - val_loss: 0.1704 - val_accuracy: 0.7343
# Epoch 87/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1738 - accuracy: 0.7339 - val_loss: 0.1633 - val_accuracy: 0.7526
# Epoch 88/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1732 - accuracy: 0.7342 - val_loss: 0.1665 - val_accuracy: 0.7456
# Epoch 89/100
# 69254/69254 [==============================] - 4s 64us/step - loss: 0.1749 - accuracy: 0.7309 - val_loss: 0.1630 - val_accuracy: 0.7510
# Epoch 90/100
# 69254/69254 [==============================] - 5s 65us/step - loss: 0.1734 - accuracy: 0.7337 - val_loss: 0.1614 - val_accuracy: 0.7578
# Epoch 91/100
# 69254/69254 [==============================] - 4s 64us/step - loss: 0.1744 - accuracy: 0.7320 - val_loss: 0.1614 - val_accuracy: 0.7528
# Epoch 92/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1734 - accuracy: 0.7346 - val_loss: 0.1622 - val_accuracy: 0.7507
# Epoch 93/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1742 - accuracy: 0.7328 - val_loss: 0.1605 - val_accuracy: 0.7471
# Epoch 94/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1728 - accuracy: 0.7341 - val_loss: 0.1611 - val_accuracy: 0.7515
# Epoch 95/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1736 - accuracy: 0.7337 - val_loss: 0.1734 - val_accuracy: 0.7188
# Epoch 96/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1791 - accuracy: 0.7250 - val_loss: 0.1655 - val_accuracy: 0.7426
# Epoch 97/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1774 - accuracy: 0.7275 - val_loss: 0.1679 - val_accuracy: 0.7378
# Epoch 98/100
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1763 - accuracy: 0.7302 - val_loss: 0.1672 - val_accuracy: 0.7478
# Epoch 99/100
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1769 - accuracy: 0.7279 - val_loss: 0.1657 - val_accuracy: 0.7433
# Epoch 100/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1761 - accuracy: 0.7296 - val_loss: 0.1705 - val_accuracy: 0.7367

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 73.59%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 58.12%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 42.00%

# %%
#6layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(Dense(2))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/50
# 69254/69254 [==============================] - 6s 87us/step - loss: 0.2391 - accuracy: 0.5844 - val_loss: 0.2314 - val_accuracy: 0.6079
# Epoch 2/50
# 69254/69254 [==============================] - 6s 81us/step - loss: 0.2316 - accuracy: 0.6096 - val_loss: 0.2302 - val_accuracy: 0.6119
# Epoch 3/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.2280 - accuracy: 0.6197 - val_loss: 0.2266 - val_accuracy: 0.6265
# Epoch 4/50
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.2250 - accuracy: 0.6285 - val_loss: 0.2224 - val_accuracy: 0.6298
# Epoch 5/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2234 - accuracy: 0.6316 - val_loss: 0.2151 - val_accuracy: 0.6517
# Epoch 6/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2203 - accuracy: 0.6389 - val_loss: 0.2144 - val_accuracy: 0.6431
# Epoch 7/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2172 - accuracy: 0.6463 - val_loss: 0.2119 - val_accuracy: 0.6641
# Epoch 8/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.2155 - accuracy: 0.6514 - val_loss: 0.2139 - val_accuracy: 0.6626
# Epoch 9/50
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.2147 - accuracy: 0.6510 - val_loss: 0.2027 - val_accuracy: 0.6784
# Epoch 10/50
# 69254/69254 [==============================] - 6s 80us/step - loss: 0.2122 - accuracy: 0.6558 - val_loss: 0.1987 - val_accuracy: 0.6930
# Epoch 11/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.2113 - accuracy: 0.6583 - val_loss: 0.2025 - val_accuracy: 0.6706
# Epoch 12/50
# 69254/69254 [==============================] - 6s 87us/step - loss: 0.2091 - accuracy: 0.6633 - val_loss: 0.1955 - val_accuracy: 0.6992
# Epoch 13/50
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.2078 - accuracy: 0.6680 - val_loss: 0.1962 - val_accuracy: 0.6943
# Epoch 14/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2067 - accuracy: 0.6700 - val_loss: 0.1945 - val_accuracy: 0.7008
# Epoch 15/50
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.2061 - accuracy: 0.6692 - val_loss: 0.1951 - val_accuracy: 0.6982
# Epoch 16/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.2057 - accuracy: 0.6687 - val_loss: 0.2016 - val_accuracy: 0.6848
# Epoch 17/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2039 - accuracy: 0.6731 - val_loss: 0.2035 - val_accuracy: 0.6743
# Epoch 18/50
# 69254/69254 [==============================] - 6s 80us/step - loss: 0.2044 - accuracy: 0.6742 - val_loss: 0.1952 - val_accuracy: 0.7005
# Epoch 19/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2049 - accuracy: 0.6724 - val_loss: 0.1924 - val_accuracy: 0.7033
# Epoch 20/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.2052 - accuracy: 0.6727 - val_loss: 0.1973 - val_accuracy: 0.6882
# Epoch 21/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.2023 - accuracy: 0.6787 - val_loss: 0.1947 - val_accuracy: 0.6941
# Epoch 22/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2010 - accuracy: 0.6808 - val_loss: 0.1853 - val_accuracy: 0.7075
# Epoch 23/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2006 - accuracy: 0.6825 - val_loss: 0.1919 - val_accuracy: 0.6975
# Epoch 24/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1991 - accuracy: 0.6879 - val_loss: 0.1991 - val_accuracy: 0.6822
# Epoch 25/50
# 69254/69254 [==============================] - 6s 80us/step - loss: 0.1998 - accuracy: 0.6863 - val_loss: 0.1846 - val_accuracy: 0.7192
# Epoch 26/50
# 69254/69254 [==============================] - 6s 84us/step - loss: 0.1986 - accuracy: 0.6867 - val_loss: 0.1877 - val_accuracy: 0.7183
# Epoch 27/50
# 69254/69254 [==============================] - 6s 80us/step - loss: 0.1984 - accuracy: 0.6894 - val_loss: 0.1852 - val_accuracy: 0.7192
# Epoch 28/50
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1976 - accuracy: 0.6905 - val_loss: 0.1857 - val_accuracy: 0.7207
# Epoch 29/50
# 69254/69254 [==============================] - 6s 81us/step - loss: 0.1979 - accuracy: 0.6889 - val_loss: 0.1886 - val_accuracy: 0.7075
# Epoch 30/50
# 69254/69254 [==============================] - 6s 85us/step - loss: 0.1967 - accuracy: 0.6898 - val_loss: 0.1896 - val_accuracy: 0.7083
# Epoch 31/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.1962 - accuracy: 0.6935 - val_loss: 0.1913 - val_accuracy: 0.7030
# Epoch 32/50
# 69254/69254 [==============================] - 6s 82us/step - loss: 0.1967 - accuracy: 0.6922 - val_loss: 0.1904 - val_accuracy: 0.7162
# Epoch 33/50
# 69254/69254 [==============================] - 6s 82us/step - loss: 0.1968 - accuracy: 0.6928 - val_loss: 0.1883 - val_accuracy: 0.7091
# Epoch 34/50
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1965 - accuracy: 0.6935 - val_loss: 0.1954 - val_accuracy: 0.6920
# Epoch 35/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1949 - accuracy: 0.6967 - val_loss: 0.1836 - val_accuracy: 0.7262
# Epoch 36/50
# 69254/69254 [==============================] - 6s 84us/step - loss: 0.1965 - accuracy: 0.6933 - val_loss: 0.1849 - val_accuracy: 0.7152
# Epoch 37/50
# 69254/69254 [==============================] - 6s 91us/step - loss: 0.1957 - accuracy: 0.6960 - val_loss: 0.1844 - val_accuracy: 0.7236
# Epoch 38/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.1948 - accuracy: 0.6958 - val_loss: 0.1891 - val_accuracy: 0.7078
# Epoch 39/50
# 69254/69254 [==============================] - 6s 81us/step - loss: 0.1946 - accuracy: 0.6944 - val_loss: 0.1974 - val_accuracy: 0.6903
# Epoch 40/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1946 - accuracy: 0.6981 - val_loss: 0.1850 - val_accuracy: 0.7154
# Epoch 41/50
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1950 - accuracy: 0.6939 - val_loss: 0.1886 - val_accuracy: 0.7050
# Epoch 42/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.1939 - accuracy: 0.6976 - val_loss: 0.1973 - val_accuracy: 0.6886
# Epoch 43/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.1935 - accuracy: 0.6985 - val_loss: 0.1799 - val_accuracy: 0.7365
# Epoch 44/50
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1933 - accuracy: 0.6979 - val_loss: 0.1829 - val_accuracy: 0.7237
# Epoch 45/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1930 - accuracy: 0.6989 - val_loss: 0.1832 - val_accuracy: 0.7203
# Epoch 46/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1932 - accuracy: 0.7006 - val_loss: 0.1799 - val_accuracy: 0.7323
# Epoch 47/50
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.1926 - accuracy: 0.7012 - val_loss: 0.1961 - val_accuracy: 0.6889
# Epoch 48/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1922 - accuracy: 0.7018 - val_loss: 0.1846 - val_accuracy: 0.7187
# Epoch 49/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1927 - accuracy: 0.6996 - val_loss: 0.1842 - val_accuracy: 0.7237
# Epoch 50/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1926 - accuracy: 0.7007 - val_loss: 0.1929 - val_accuracy: 0.6974

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,29,2) ,
            'max_features':range(0,29,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
dt = DecisionTreeClassifier(max_depth=28,max_features=28,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=28, max_features=28, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 99.00540615469919
# Test Prediction Score 91.78949313865915

# %%
y_pred_dt_test= dt.predict(test_X)
dt_score_test = accuracy_score(test_Y,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Test Prediction Score 50.251857645678534

# %%
y_pred_dt_test= dt.predict(test_XX)
dt_score_test = accuracy_score(test_YY,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Test Prediction Score 41.52304436093473

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91     10243
#            1       0.92      0.92      0.92     11400
#
#     accuracy                           0.92     21643
#    macro avg       0.92      0.92      0.92     21643
# weighted avg       0.92      0.92      0.92     21643

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250],
            'max_features':range(0,25,2)}
dt_g=RandomForestClassifier(random_state=42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=28,max_features=28,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=28, max_features=28,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 99.79438129562887
# Test Prediction Score 92.49641916555007

# %%
y_pred_rf_test= rf.predict(test_X)
rf_score_test = accuracy_score(test_Y,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Test Prediction Score 61.21314039890496

# %%
y_pred_rf_test= rf.predict(test_XX)
rf_score_test = accuracy_score(test_YY,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Test Prediction Score 39.217888356154525

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92     10243
#            1       0.92      0.94      0.93     11400
#
#     accuracy                           0.92     21643
#    macro avg       0.93      0.92      0.92     21643
# weighted avg       0.93      0.92      0.92     21643

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250,500],
           'min_child_weight':[1,3,6]}
xgb_g=XGBClassifier(random_state=42)
xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
xgb_cv.fit(X_train,y_train)

print("Best parameters:",xgb_cv.best_params_)
print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=28,min_child_weight=1,n_estimators=500,random_state=42,learning_rate=0.2)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=28,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.7978467794104
# Test Prediction Score 95.03303608557039

# %%
y_pred_xgbc_test= xgbc.predict(test_X)
xgbc_score_test = accuracy_score(test_Y,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)

# %%
y_pred_xgbc_test= xgbc.predict(test_XX)
xgbc_score_test = accuracy_score(test_YY,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Test Prediction Score 40.437418110088835

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     10243
#            1       0.95      0.96      0.95     11400
#
#     accuracy                           0.95     21643
#    macro avg       0.95      0.95      0.95     21643
# weighted avg       0.95      0.95      0.95     21643

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
param_grid = {'n_estimators': [x for x in range(24,40,2)],
              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
lgb_cv.fit(X_train, y_train)

print("Best parameters:",lgb_cv.best_params_)
print("Accuracy :",lgb_cv.best_score_)

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.6,  n_estimators = 500, max_depth = 28, random_state=42, min_child_weight=1,metric='binary',boosting_type = 'dart')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.6, max_depth=28,
#                metric='binary', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 87.98978837445708
# Test Prediction Score 84.6878898489119

# %%
y_pred_gbm_test = gbm.predict(test_X)
gbm_score_test = accuracy_score(test_Y,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Test Prediction Score 61.22565506452875

# %%
y_pred_gbm_test = gbm.predict(test_XX)
gbm_score_test = accuracy_score(test_YY,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Test Prediction Score 35.645688451182814

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,5500), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [7363,
#  2447,
#  880,
#  400,
#  389,
#  385,
#  314,
#  312,
#  311,
#  305,
#  244,
#  239,
#  235,
#  233,
#  232,
#  204,
#  157,
#  146,
#  100,
#  68,
#  20,
#  16,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83     10243
#            1       0.83      0.90      0.86     11400
#
#     accuracy                           0.85     21643
#    macro avg       0.85      0.84      0.85     21643
# weighted avg       0.85      0.85      0.85     21643

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
