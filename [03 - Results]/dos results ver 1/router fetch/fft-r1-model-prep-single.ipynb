# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r1_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %% [markdown]
# Importing Dataset from GitHub

# %%
dfg1 = pd.read_csv('2-fft-normal-n-0-3-data-r1-good-single.csv')
dfm1 = pd.read_csv('2-fft-normal-n-0-3-m-9-data-r1-mal.csv')
dfm2 = pd.read_csv('2-fft-normal-n-0-3-m-1-data-r1-mal.csv')
dfm3 = pd.read_csv('2-fft-normal-n-0-3-m-15-data-r1-mal.csv')

# %% [markdown]
# Characteristics of Dataset

# %%
dfg1
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             11        2       4                     1        1          4
# 1             84        4       2                     1        1          4
# 2            216        2       4                     1        1          4
# 3            342        2       4                     1        1          4
# 4            388        1       2                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 56912    3268816        4       2                     6        2          2
# 56913    3268823        4       2                     6        3          2
# 56914    3268830        4       2                     6        4          2
# 56915    3268837        4       2                     6        5          3
# 56916    3268838        4       2                     2        1          4
#
# ...

# %%
dfm1
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             11        2       4                     1        1          4
# 1             84        4       2                     1        1          4
# 2            238        2       4                     1        1          4
# 3            365        2       4                     1        1          4
# 4            386        1       2                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 51289    2508624        4       2                     5        2          2
# 51290    2508631        4       2                     5        3          2
# 51291    2508638        4       2                     5        4          2
# 51292    2508645        4       2                     5        5          3
# 51293    2508646        4       2                     1        1          4
#
# ...

# %%
dfg1['sim'] = 1
dfm1['sim'] = 1
dfm2['sim'] = 1
dfm3['sim'] = 1

# %%
dfg1['sim_traversal'] = dfg1['sim']*dfg1['traversal_id']
df1.shape
# Out:
# (108211, 32)

# %%
dfm2['sim_traversal'] = dfm2['sim']*dfm2['traversal_id']
dfm2.shape
# Out:
# (127850, 32)

# %%
dfm3['sim_traversal'] = dfm3['sim']*dfm3['traversal_id']
dfm3.shape
# Out:
# (69453, 32)

# %%
dfm2.to_csv('fft-r1-mal-1.csv',index=False)
dfm3.to_csv('fft-r1-mal-2.csv',index=False)

# %%
df1.to_csv('fft-r1-train.csv',index=False)
