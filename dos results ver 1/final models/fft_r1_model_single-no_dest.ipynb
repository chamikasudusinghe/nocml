# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/dos%20results%20ver%201/final%20models/fft_r1_model_single-no_dest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
df = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-train.csv?token=AKVFSODWB4TNVPOZTGCD2UC6Y6FLY')
df1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-mal-1.csv?token=AKVFSOCEFO5KEAUA37PWBPS6Y6FL2')
df2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201/router%20fetch/fft-r1-mal-2.csv?token=AKVFSODIQ3JWY2R5ZQHFDTS6Y6FMA')

# %%
cols = list(df.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df = df[cols]
df
# Out:
#         timestamp  outport  inport  ...  sim  sim_traversal  target
# 0              11        2       4  ...    1              1       1
# 1              11        2       4  ...    1              1       0
# 2              84        4       2  ...    1              4       0
# 3              84        4       2  ...    1              3       1
# 4             216        2       4  ...    1              6       1
# ...           ...      ...     ...  ...  ...            ...     ...
# 108206    3268816        4       2  ...    1          20042       1
# 108207    3268823        4       2  ...    1          20042       1
# 108208    3268830        4       2  ...    1          20042       1
# 108209    3268837        4       2  ...    1          20042       1
# 108210    3268838        4       2  ...    1          20043       1
#
# [108211 rows x 32 columns]

# %%
cols = list(df1.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df1 = df1[cols]
df1
# Out:
#         timestamp  outport  inport  ...  sim  sim_traversal  target
# 0               7        2       0  ...    1              2       0
# 1              11        2       4  ...    1              1       0
# 2              84        0       1  ...    1              2       0
# 3              84        4       2  ...    1              4       0
# 4              85        0       1  ...    1              2       0
# ...           ...      ...     ...  ...  ...            ...     ...
# 127845    3270078        4       2  ...    1          30070       0
# 127846    3270085        4       2  ...    1          30070       0
# 127847    3270092        4       2  ...    1          30070       0
# 127848    3270099        4       2  ...    1          30070       0
# 127849    3270100        4       2  ...    1          30071       0
#
# [127850 rows x 32 columns]

# %%
cols = list(df2.columns)
a, b = cols.index('sim'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
a, b = cols.index('sim_traversal'), cols.index('target')
cols[b], cols[a] = cols[a], cols[b]
df2 = df2[cols]
df2
# Out:
#        timestamp  outport  inport  ...  sim  sim_traversal  target
# 0             11        2       4  ...    1              1       0
# 1             84        4       2  ...    1              4       0
# 2            238        2       4  ...    1              9       0
# 3            365        2       4  ...    1             12       0
# 4            386        1       2  ...    1             13       0
# ...          ...      ...     ...  ...  ...            ...     ...
# 69448    3276626        4       2  ...    1          30066       0
# 69449    3276633        4       2  ...    1          30066       0
# 69450    3276640        4       2  ...    1          30066       0
# 69451    3276647        4       2  ...    1          30066       0
# 69452    3276648        4       2  ...    1          30067       0
#
# [69453 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# sim                           0
# sim_traversal                 0
# target                        0
# dtype: int64

# %%
df = df.drop(columns=['timestamp','src_ni','src_router'])

# %%
df.corr()
# Out:
#                              outport    inport  ...  sim_traversal    target
# outport                     1.000000 -0.459807  ...      -0.028973 -0.005102
# inport                     -0.459807  1.000000  ...       0.033701  0.112608
# cache_coherence_type        0.237770 -0.206231  ...       0.005233 -0.034337
# flit_id                     0.029889  0.058969  ...       0.020819  0.014935
# flit_type                  -0.044490 -0.087775  ...      -0.030988 -0.022230
# vnet                             NaN       NaN  ...            NaN       NaN
# vc                          0.255669 -0.446856  ...      -0.016882 -0.049744
# dst_ni                     -0.060509  0.346364  ...       0.078248  0.078969
# dst_router                 -0.055797  0.344889  ...       0.098127  0.071653
# traversal_id               -0.028973  0.033701  ...       1.000000 -0.052864
# hop_count                   0.242957  0.275137  ...       0.071956  0.073165
# current_hop                -0.157727  0.136175  ...       0.014618  0.008832
# hop_percentage             -0.569855  0.184449  ...      -0.025590 -0.025730
# enqueue_time                0.003471  0.096469  ...       0.029473  0.017730
# packet_count_decr          -0.051228 -0.015962  ...       0.024670 -0.088003
# packet_count_incr           0.136610 -0.194196  ...       0.024730 -0.088003
# max_packet_count            0.055251 -0.135994  ...       0.031966 -0.113894
# packet_count_index          0.062876 -0.145334  ...       0.022297 -0.104126
# packet_max_index            0.044747 -0.136597  ...       0.016694 -0.099685
# port_index                  0.431340  0.497773  ...       0.010961  0.077057
# cache_coherence_flit_index  0.129405 -0.038854  ...       0.012686 -0.000858
# flit_index                  0.103778 -0.053851  ...       0.007132 -0.006201
# traversal_index             0.059824 -0.022035  ...       0.505255 -0.031958
# cache_coherence_vnet_index  0.237770 -0.206231  ...       0.005233 -0.034337
# vnet_vc_index               0.255669 -0.446856  ...      -0.016882 -0.049744
# vnet_vc_cc_index            0.237770 -0.206231  ...       0.005233 -0.034337
# sim                              NaN       NaN  ...            NaN       NaN
# sim_traversal              -0.028973  0.033701  ...       1.000000 -0.052864
# target                     -0.005102  0.112608  ...      -0.052864  1.000000
#
# [29 rows x 29 columns]

# %%
plt.figure(figsize=(27,27))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target','dst_ni','dst_router'])
train_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0             2       4  ...    1              1
# 1             2       4  ...    1              1
# 2             4       2  ...    1              4
# 3             4       2  ...    1              3
# 4             2       4  ...    1              6
# ...         ...     ...  ...  ...            ...
# 108206        4       2  ...    1          20042
# 108207        4       2  ...    1          20042
# 108208        4       2  ...    1          20042
# 108209        4       2  ...    1          20042
# 108210        4       2  ...    1          20043
#
# [108211 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0           0.5     1.0  ...  0.0       0.000000
# 1           0.5     1.0  ...  0.0       0.000000
# 2           1.0     0.5  ...  0.0       0.000143
# 3           1.0     0.5  ...  0.0       0.000095
# 4           0.5     1.0  ...  0.0       0.000239
# ...         ...     ...  ...  ...            ...
# 108206      1.0     0.5  ...  0.0       0.956200
# 108207      1.0     0.5  ...  0.0       0.956200
# 108208      1.0     0.5  ...  0.0       0.956200
# 108209      1.0     0.5  ...  0.0       0.956200
# 108210      1.0     0.5  ...  0.0       0.956248
#
# [108211 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (400, 26)

# %%
test_X = df1.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y = df1['target']
test_XX = df2.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_YY = df2['target']

# %%
#standardization
x = test_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X = pd.DataFrame(x_scaled)
test_X.columns = columns
test_X
# Out:
#         outport  inport  ...  sim  sim_traversal
# 0           0.5    0.00  ...  0.0       0.000033
# 1           0.5    1.00  ...  0.0       0.000000
# 2           0.0    0.25  ...  0.0       0.000033
# 3           1.0    0.50  ...  0.0       0.000100
# 4           0.0    0.25  ...  0.0       0.000033
# ...         ...     ...  ...  ...            ...
# 127845      1.0    0.50  ...  0.0       0.999967
# 127846      1.0    0.50  ...  0.0       0.999967
# 127847      1.0    0.50  ...  0.0       0.999967
# 127848      1.0    0.50  ...  0.0       0.999967
# 127849      1.0    0.50  ...  0.0       1.000000
#
# [127850 rows x 26 columns]

# %%
test_X[test_X.duplicated()].shape
# Out:
# (2, 26)

# %%
#standardization
x = test_XX.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_XX.columns
x_scaled = min_max_scaler.fit_transform(x)
test_XX = pd.DataFrame(x_scaled)
test_XX.columns = columns
test_XX
# Out:
#        outport  inport  ...  sim  sim_traversal
# 0         0.50     1.0  ...  0.0       0.000000
# 1         1.00     0.5  ...  0.0       0.000100
# 2         0.50     1.0  ...  0.0       0.000266
# 3         0.50     1.0  ...  0.0       0.000366
# 4         0.25     0.5  ...  0.0       0.000399
# ...        ...     ...  ...  ...            ...
# 69448     1.00     0.5  ...  0.0       0.999967
# 69449     1.00     0.5  ...  0.0       0.999967
# 69450     1.00     0.5  ...  0.0       0.999967
# 69451     1.00     0.5  ...  0.0       0.999967
# 69452     1.00     0.5  ...  0.0       1.000000
#
# [69453 rows x 26 columns]

# %%
test_XX[test_XX.duplicated()].shape
# Out:
# (55, 26)

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 1    56917
# 0    51294
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs       Score
# 14            max_packet_count  239.624836
# 1                       inport  207.085568
# 17                  port_index  159.391740
# 15          packet_count_index  130.055301
# 13           packet_count_incr  122.394148
# 12           packet_count_decr  117.256820
# 16            packet_max_index  109.017541
# 6                           vc  104.190946
# 22               vnet_vc_index  104.190946
# 8                    hop_count   66.558575
# 7                 traversal_id   35.763485
# 25               sim_traversal   35.763485
# 20             traversal_index   20.562627
# 4                    flit_type   12.287656
# 2         cache_coherence_type   10.789955
# 21  cache_coherence_vnet_index   10.789955
# 23            vnet_vc_cc_index   10.789955

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
#result=logit_model.fit()
#print(result.summary2())

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 57.92325108585159
# Test Prediction  58.550108580141384

# %%
y_pred_test = logreg.predict(test_X)
logreg_score_test = accuracy_score(test_Y,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  84.4904184591318

# %%
y_pred_test1 = logreg.predict(test_XX)
logreg_score_test = accuracy_score(test_YY,y_pred_test1)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  69.10140670669374

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 3                      flit_id    2.217497
# 15          packet_count_index    1.798034
# 1                       inport    1.729304
# 0                      outport    1.322277
# 9                  current_hop    0.753368
# 19                  flit_index    0.245864
# 5                         vnet    0.000000
# 24                         sim    0.000000
# 6                           vc   -0.011277
# 22               vnet_vc_index   -0.011277
# 2         cache_coherence_type   -0.047392
# 23            vnet_vc_cc_index   -0.047392
# 21  cache_coherence_vnet_index   -0.047392
# 4                    flit_type   -0.065976
# 8                    hop_count   -0.068004
# 7                 traversal_id   -0.169221
# 25               sim_traversal   -0.169221
# 13           packet_count_incr   -0.238977
# 20             traversal_index   -0.297396
# 12           packet_count_decr   -0.521151
# 10              hop_percentage   -0.617539
# 14            max_packet_count   -0.760128
# 11                enqueue_time   -0.867233
# 17                  port_index   -1.051420
# 18  cache_coherence_flit_index   -2.559754
# 16            packet_max_index   -2.918809

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.42      0.49     10243
#            1       0.58      0.73      0.65     11400
#
#     accuracy                           0.59     21643
#    macro avg       0.59      0.58      0.57     21643
# weighted avg       0.59      0.59      0.57     21643

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y, y_pred_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92    127850
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.84    127850
#    macro avg       0.50      0.42      0.46    127850
# weighted avg       1.00      0.84      0.92    127850
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 80.72844469087885
# Test Prediction  71.2747770641778

# %%
y_pred_knn_test= knn.predict(test_X)
knn_score_test = accuracy_score(test_Y,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  44.92999608916699

# %%
y_pred_knn_test_x= knn.predict(test_XX)
knn_score_test = accuracy_score(test_YY,y_pred_knn_test_x)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  38.78162210415677

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.66      0.68     10243
#            1       0.71      0.76      0.74     11400
#
#     accuracy                           0.71     21643
#    macro avg       0.71      0.71      0.71     21643
# weighted avg       0.71      0.71      0.71     21643

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y, y_pred_knn_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y,y_pred_knn_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.45      0.62    127850
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.45    127850
#    macro avg       0.50      0.22      0.31    127850
# weighted avg       1.00      0.45      0.62    127850
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 56.074993069032445
# Test Prediction Score 56.28147668992284

# %%
y_pred_nb_test= nb.predict(test_X)
nb_score_test = accuracy_score(test_Y,y_pred_nb_test)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Test Prediction Score 56.552209620649194

# %%
y_pred_nb_test= nb.predict(test_XX)
nb_score_test = accuracy_score(test_YY,y_pred_nb_test)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Test Prediction Score 32.25490619555671

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.30      0.40     10243
#            1       0.56      0.80      0.66     11400
#
#     accuracy                           0.56     21643
#    macro avg       0.57      0.55      0.53     21643
# weighted avg       0.57      0.56      0.53     21643

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2462 - accuracy: 0.5540 - val_loss: 0.2435 - val_accuracy: 0.5818
# Epoch 2/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2433 - accuracy: 0.5737 - val_loss: 0.2418 - val_accuracy: 0.5784
# Epoch 3/10
# 69254/69254 [==============================] - 3s 36us/step - loss: 0.2425 - accuracy: 0.5780 - val_loss: 0.2410 - val_accuracy: 0.5855
# Epoch 4/10
# 69254/69254 [==============================] - 3s 36us/step - loss: 0.2420 - accuracy: 0.5800 - val_loss: 0.2406 - val_accuracy: 0.5856
# Epoch 5/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2417 - accuracy: 0.5815 - val_loss: 0.2408 - val_accuracy: 0.5816
# Epoch 6/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2416 - accuracy: 0.5819 - val_loss: 0.2402 - val_accuracy: 0.5842
# Epoch 7/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2415 - accuracy: 0.5805 - val_loss: 0.2401 - val_accuracy: 0.5878
# Epoch 8/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2414 - accuracy: 0.5817 - val_loss: 0.2404 - val_accuracy: 0.5822
# Epoch 9/10
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2412 - accuracy: 0.5808 - val_loss: 0.2400 - val_accuracy: 0.5817
# Epoch 10/10
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2412 - accuracy: 0.5802 - val_loss: 0.2398 - val_accuracy: 0.5843

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 58.99%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 59.41%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2 )
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2490 - accuracy: 0.5381 - val_loss: 0.2467 - val_accuracy: 0.5528
# Epoch 2/30
# 69254/69254 [==============================] - 3s 36us/step - loss: 0.2466 - accuracy: 0.5545 - val_loss: 0.2457 - val_accuracy: 0.5574
# Epoch 3/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2458 - accuracy: 0.5563 - val_loss: 0.2450 - val_accuracy: 0.5606
# Epoch 4/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2452 - accuracy: 0.5590 - val_loss: 0.2446 - val_accuracy: 0.5570
# Epoch 5/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2446 - accuracy: 0.5604 - val_loss: 0.2439 - val_accuracy: 0.5626
# Epoch 6/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2442 - accuracy: 0.5615 - val_loss: 0.2434 - val_accuracy: 0.5658
# Epoch 7/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2438 - accuracy: 0.5651 - val_loss: 0.2430 - val_accuracy: 0.5673
# Epoch 8/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2434 - accuracy: 0.5674 - val_loss: 0.2427 - val_accuracy: 0.5667
# Epoch 9/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2430 - accuracy: 0.5685 - val_loss: 0.2422 - val_accuracy: 0.5714
# Epoch 10/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2427 - accuracy: 0.5709 - val_loss: 0.2419 - val_accuracy: 0.5708
# Epoch 11/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2424 - accuracy: 0.5723 - val_loss: 0.2417 - val_accuracy: 0.5728
# Epoch 12/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2422 - accuracy: 0.5729 - val_loss: 0.2414 - val_accuracy: 0.5736
# Epoch 13/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2421 - accuracy: 0.5741 - val_loss: 0.2412 - val_accuracy: 0.5755
# Epoch 14/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2420 - accuracy: 0.5749 - val_loss: 0.2411 - val_accuracy: 0.5759
# Epoch 15/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2418 - accuracy: 0.5759 - val_loss: 0.2409 - val_accuracy: 0.5767
# Epoch 16/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2417 - accuracy: 0.5761 - val_loss: 0.2407 - val_accuracy: 0.5769
# Epoch 17/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2416 - accuracy: 0.5759 - val_loss: 0.2407 - val_accuracy: 0.5798
# Epoch 18/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2415 - accuracy: 0.5774 - val_loss: 0.2405 - val_accuracy: 0.5789
# Epoch 19/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2414 - accuracy: 0.5779 - val_loss: 0.2404 - val_accuracy: 0.5778
# Epoch 20/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2413 - accuracy: 0.5780 - val_loss: 0.2402 - val_accuracy: 0.5795
# Epoch 21/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2412 - accuracy: 0.5777 - val_loss: 0.2401 - val_accuracy: 0.5783
# Epoch 22/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2411 - accuracy: 0.5780 - val_loss: 0.2400 - val_accuracy: 0.5799
# Epoch 23/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2410 - accuracy: 0.5769 - val_loss: 0.2399 - val_accuracy: 0.5811
# Epoch 24/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2410 - accuracy: 0.5790 - val_loss: 0.2398 - val_accuracy: 0.5789
# Epoch 25/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2409 - accuracy: 0.5776 - val_loss: 0.2398 - val_accuracy: 0.5816
# Epoch 26/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2408 - accuracy: 0.5788 - val_loss: 0.2396 - val_accuracy: 0.5802
# Epoch 27/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2407 - accuracy: 0.5785 - val_loss: 0.2395 - val_accuracy: 0.5816
# Epoch 28/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2407 - accuracy: 0.5797 - val_loss: 0.2394 - val_accuracy: 0.5816
# Epoch 29/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2405 - accuracy: 0.5798 - val_loss: 0.2395 - val_accuracy: 0.5812
# Epoch 30/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2405 - accuracy: 0.5785 - val_loss: 0.2392 - val_accuracy: 0.5810

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 58.79%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 63.06%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 37.29%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2497 - accuracy: 0.5158 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 2/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 3/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 4/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 5/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 6/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 7/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 8/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 9/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 10/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 11/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 12/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 13/30
# 69254/69254 [==============================] - 3s 40us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 14/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 15/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 16/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 17/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 18/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 19/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 20/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 21/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 22/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 23/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 24/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 25/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296
# Epoch 26/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 27/30
# 69254/69254 [==============================] - 3s 37us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 28/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 29/30
# 69254/69254 [==============================] - 3s 39us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2492 - val_accuracy: 0.5296
# Epoch 30/30
# 69254/69254 [==============================] - 3s 38us/step - loss: 0.2494 - accuracy: 0.5249 - val_loss: 0.2491 - val_accuracy: 0.5296

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 52.67%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 0.00%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 0.00%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/100
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.2389 - accuracy: 0.5872 - val_loss: 0.2381 - val_accuracy: 0.5844
# Epoch 2/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.2315 - accuracy: 0.6089 - val_loss: 0.2265 - val_accuracy: 0.6237
# Epoch 3/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.2285 - accuracy: 0.6169 - val_loss: 0.2218 - val_accuracy: 0.6354
# Epoch 4/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.2241 - accuracy: 0.6306 - val_loss: 0.2165 - val_accuracy: 0.6507
# Epoch 5/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.2199 - accuracy: 0.6416 - val_loss: 0.2172 - val_accuracy: 0.6420
# Epoch 6/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2169 - accuracy: 0.6477 - val_loss: 0.2159 - val_accuracy: 0.6335
# Epoch 7/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.2132 - accuracy: 0.6564 - val_loss: 0.2106 - val_accuracy: 0.6618
# Epoch 8/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.2103 - accuracy: 0.6618 - val_loss: 0.2073 - val_accuracy: 0.6737
# Epoch 9/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.2090 - accuracy: 0.6664 - val_loss: 0.1945 - val_accuracy: 0.6938
# Epoch 10/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.2079 - accuracy: 0.6688 - val_loss: 0.1979 - val_accuracy: 0.6881
# Epoch 11/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2059 - accuracy: 0.6711 - val_loss: 0.1925 - val_accuracy: 0.7024
# Epoch 12/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2042 - accuracy: 0.6770 - val_loss: 0.1878 - val_accuracy: 0.7088
# Epoch 13/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.2032 - accuracy: 0.6768 - val_loss: 0.1932 - val_accuracy: 0.7034
# Epoch 14/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.2032 - accuracy: 0.6798 - val_loss: 0.1875 - val_accuracy: 0.7113
# Epoch 15/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.2012 - accuracy: 0.6824 - val_loss: 0.1899 - val_accuracy: 0.7008
# Epoch 16/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2003 - accuracy: 0.6861 - val_loss: 0.1902 - val_accuracy: 0.7027
# Epoch 17/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.2003 - accuracy: 0.6851 - val_loss: 0.1841 - val_accuracy: 0.7115
# Epoch 18/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1992 - accuracy: 0.6870 - val_loss: 0.1926 - val_accuracy: 0.6981
# Epoch 19/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1984 - accuracy: 0.6911 - val_loss: 0.1854 - val_accuracy: 0.7167
# Epoch 20/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1977 - accuracy: 0.6924 - val_loss: 0.1863 - val_accuracy: 0.7211
# Epoch 21/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1987 - accuracy: 0.6875 - val_loss: 0.1830 - val_accuracy: 0.7158
# Epoch 22/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1971 - accuracy: 0.6924 - val_loss: 0.1821 - val_accuracy: 0.7198
# Epoch 23/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1968 - accuracy: 0.6923 - val_loss: 0.1889 - val_accuracy: 0.7137
# Epoch 24/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1964 - accuracy: 0.6933 - val_loss: 0.1829 - val_accuracy: 0.7212
# Epoch 25/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1965 - accuracy: 0.6931 - val_loss: 0.1857 - val_accuracy: 0.7038
# Epoch 26/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1961 - accuracy: 0.6925 - val_loss: 0.1884 - val_accuracy: 0.7084
# Epoch 27/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1947 - accuracy: 0.6950 - val_loss: 0.1841 - val_accuracy: 0.7178
# Epoch 28/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1951 - accuracy: 0.6948 - val_loss: 0.1792 - val_accuracy: 0.7291
# Epoch 29/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1944 - accuracy: 0.6974 - val_loss: 0.1825 - val_accuracy: 0.7229
# Epoch 30/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1943 - accuracy: 0.6974 - val_loss: 0.1826 - val_accuracy: 0.7150
# Epoch 31/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1943 - accuracy: 0.6971 - val_loss: 0.1791 - val_accuracy: 0.7290
# Epoch 32/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1946 - accuracy: 0.6973 - val_loss: 0.1808 - val_accuracy: 0.7303
# Epoch 33/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1941 - accuracy: 0.6982 - val_loss: 0.1810 - val_accuracy: 0.7255
# Epoch 34/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1939 - accuracy: 0.6994 - val_loss: 0.1795 - val_accuracy: 0.7290
# Epoch 35/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1936 - accuracy: 0.7014 - val_loss: 0.1817 - val_accuracy: 0.7212
# Epoch 36/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1931 - accuracy: 0.6999 - val_loss: 0.1790 - val_accuracy: 0.7241
# Epoch 37/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1928 - accuracy: 0.7009 - val_loss: 0.1826 - val_accuracy: 0.7206
# Epoch 38/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1926 - accuracy: 0.7018 - val_loss: 0.1865 - val_accuracy: 0.7102
# Epoch 39/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1926 - accuracy: 0.7020 - val_loss: 0.1855 - val_accuracy: 0.7163
# Epoch 40/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1927 - accuracy: 0.7021 - val_loss: 0.1814 - val_accuracy: 0.7302
# Epoch 41/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1932 - accuracy: 0.6983 - val_loss: 0.1866 - val_accuracy: 0.7020
# Epoch 42/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1920 - accuracy: 0.7019 - val_loss: 0.1808 - val_accuracy: 0.7319
# Epoch 43/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1929 - accuracy: 0.7021 - val_loss: 0.1774 - val_accuracy: 0.7337
# Epoch 44/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1914 - accuracy: 0.7033 - val_loss: 0.1760 - val_accuracy: 0.7331
# Epoch 45/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1913 - accuracy: 0.7042 - val_loss: 0.1849 - val_accuracy: 0.7265
# Epoch 46/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1908 - accuracy: 0.7072 - val_loss: 0.1799 - val_accuracy: 0.7278
# Epoch 47/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1909 - accuracy: 0.7035 - val_loss: 0.1820 - val_accuracy: 0.7289
# Epoch 48/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1909 - accuracy: 0.7060 - val_loss: 0.1798 - val_accuracy: 0.7268
# Epoch 49/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1906 - accuracy: 0.7053 - val_loss: 0.1783 - val_accuracy: 0.7317
# Epoch 50/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1906 - accuracy: 0.7052 - val_loss: 0.1779 - val_accuracy: 0.7315
# Epoch 51/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1901 - accuracy: 0.7065 - val_loss: 0.1779 - val_accuracy: 0.7325
# Epoch 52/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1891 - accuracy: 0.7099 - val_loss: 0.1792 - val_accuracy: 0.7296
# Epoch 53/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1889 - accuracy: 0.7083 - val_loss: 0.1756 - val_accuracy: 0.7330
# Epoch 54/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1889 - accuracy: 0.7103 - val_loss: 0.1774 - val_accuracy: 0.7261
# Epoch 55/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1885 - accuracy: 0.7096 - val_loss: 0.1752 - val_accuracy: 0.7325
# Epoch 56/100
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.1874 - accuracy: 0.7125 - val_loss: 0.1786 - val_accuracy: 0.7307
# Epoch 57/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1872 - accuracy: 0.7144 - val_loss: 0.1800 - val_accuracy: 0.7294
# Epoch 58/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1869 - accuracy: 0.7131 - val_loss: 0.1776 - val_accuracy: 0.7322
# Epoch 59/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1863 - accuracy: 0.7160 - val_loss: 0.1710 - val_accuracy: 0.7356
# Epoch 60/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1861 - accuracy: 0.7136 - val_loss: 0.1747 - val_accuracy: 0.7343
# Epoch 61/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1860 - accuracy: 0.7138 - val_loss: 0.1772 - val_accuracy: 0.7310
# Epoch 62/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1856 - accuracy: 0.7159 - val_loss: 0.1714 - val_accuracy: 0.7380
# Epoch 63/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1855 - accuracy: 0.7159 - val_loss: 0.1715 - val_accuracy: 0.7385
# Epoch 64/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1851 - accuracy: 0.7153 - val_loss: 0.1759 - val_accuracy: 0.7298
# Epoch 65/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1858 - accuracy: 0.7125 - val_loss: 0.1712 - val_accuracy: 0.7385
# Epoch 66/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1837 - accuracy: 0.7172 - val_loss: 0.1720 - val_accuracy: 0.7454
# Epoch 67/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1848 - accuracy: 0.7175 - val_loss: 0.1833 - val_accuracy: 0.7222
# Epoch 68/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1842 - accuracy: 0.7170 - val_loss: 0.1734 - val_accuracy: 0.7359
# Epoch 69/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1841 - accuracy: 0.7175 - val_loss: 0.1787 - val_accuracy: 0.7234
# Epoch 70/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1827 - accuracy: 0.7172 - val_loss: 0.1716 - val_accuracy: 0.7396
# Epoch 71/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1833 - accuracy: 0.7169 - val_loss: 0.1756 - val_accuracy: 0.7351
# Epoch 72/100
# 69254/69254 [==============================] - 5s 65us/step - loss: 0.1825 - accuracy: 0.7200 - val_loss: 0.1733 - val_accuracy: 0.7373
# Epoch 73/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1825 - accuracy: 0.7199 - val_loss: 0.1792 - val_accuracy: 0.7316
# Epoch 74/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1822 - accuracy: 0.7201 - val_loss: 0.1735 - val_accuracy: 0.7330
# Epoch 75/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1828 - accuracy: 0.7203 - val_loss: 0.1672 - val_accuracy: 0.7466
# Epoch 76/100
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1831 - accuracy: 0.7166 - val_loss: 0.1701 - val_accuracy: 0.7456
# Epoch 77/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1822 - accuracy: 0.7210 - val_loss: 0.1823 - val_accuracy: 0.7132
# Epoch 78/100
# 69254/69254 [==============================] - 5s 65us/step - loss: 0.1815 - accuracy: 0.7217 - val_loss: 0.1670 - val_accuracy: 0.7379
# Epoch 79/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1815 - accuracy: 0.7220 - val_loss: 0.1690 - val_accuracy: 0.7385
# Epoch 80/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1815 - accuracy: 0.7226 - val_loss: 0.1710 - val_accuracy: 0.7433
# Epoch 81/100
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1813 - accuracy: 0.7196 - val_loss: 0.1709 - val_accuracy: 0.7320
# Epoch 82/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1805 - accuracy: 0.7228 - val_loss: 0.1686 - val_accuracy: 0.7449
# Epoch 83/100
# 69254/69254 [==============================] - 4s 64us/step - loss: 0.1807 - accuracy: 0.7212 - val_loss: 0.1697 - val_accuracy: 0.7447
# Epoch 84/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1805 - accuracy: 0.7227 - val_loss: 0.1762 - val_accuracy: 0.7309
# Epoch 85/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1938 - accuracy: 0.6975 - val_loss: 0.1869 - val_accuracy: 0.7037
# Epoch 86/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1898 - accuracy: 0.7020 - val_loss: 0.1738 - val_accuracy: 0.7300
# Epoch 87/100
# 69254/69254 [==============================] - 4s 64us/step - loss: 0.1889 - accuracy: 0.7031 - val_loss: 0.1750 - val_accuracy: 0.7301
# Epoch 88/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1878 - accuracy: 0.7070 - val_loss: 0.1743 - val_accuracy: 0.7332
# Epoch 89/100
# 69254/69254 [==============================] - 5s 68us/step - loss: 0.1877 - accuracy: 0.7063 - val_loss: 0.1739 - val_accuracy: 0.7294
# Epoch 90/100
# 69254/69254 [==============================] - 5s 69us/step - loss: 0.1868 - accuracy: 0.7105 - val_loss: 0.1744 - val_accuracy: 0.7348
# Epoch 91/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1872 - accuracy: 0.7087 - val_loss: 0.1743 - val_accuracy: 0.7407
# Epoch 92/100
# 69254/69254 [==============================] - 4s 65us/step - loss: 0.1869 - accuracy: 0.7099 - val_loss: 0.1741 - val_accuracy: 0.7344
# Epoch 93/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1865 - accuracy: 0.7102 - val_loss: 0.1755 - val_accuracy: 0.7311
# Epoch 94/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1854 - accuracy: 0.7129 - val_loss: 0.1740 - val_accuracy: 0.7373
# Epoch 95/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1857 - accuracy: 0.7134 - val_loss: 0.1885 - val_accuracy: 0.7000
# Epoch 96/100
# 69254/69254 [==============================] - 5s 67us/step - loss: 0.1853 - accuracy: 0.7132 - val_loss: 0.1733 - val_accuracy: 0.7356
# Epoch 97/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1847 - accuracy: 0.7137 - val_loss: 0.1742 - val_accuracy: 0.7329
# Epoch 98/100
# 69254/69254 [==============================] - 6s 88us/step - loss: 0.1844 - accuracy: 0.7156 - val_loss: 0.1803 - val_accuracy: 0.7212
# Epoch 99/100
# 69254/69254 [==============================] - 6s 92us/step - loss: 0.1850 - accuracy: 0.7155 - val_loss: 0.1730 - val_accuracy: 0.7394
# Epoch 100/100
# 69254/69254 [==============================] - 5s 66us/step - loss: 0.1840 - accuracy: 0.7176 - val_loss: 0.1785 - val_accuracy: 0.7192

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 72.40%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 65.85%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 47.07%

# %%
#6layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(Dense(2))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Train on 69254 samples, validate on 17314 samples
# Epoch 1/50
# 69254/69254 [==============================] - 6s 83us/step - loss: 0.2412 - accuracy: 0.5777 - val_loss: 0.2375 - val_accuracy: 0.5975
# Epoch 2/50
# 69254/69254 [==============================] - 5s 74us/step - loss: 0.2325 - accuracy: 0.6084 - val_loss: 0.2242 - val_accuracy: 0.6371
# Epoch 3/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2261 - accuracy: 0.6258 - val_loss: 0.2228 - val_accuracy: 0.6323
# Epoch 4/50
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.2220 - accuracy: 0.6379 - val_loss: 0.2172 - val_accuracy: 0.6407
# Epoch 5/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.2183 - accuracy: 0.6465 - val_loss: 0.2072 - val_accuracy: 0.6684
# Epoch 6/50
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.2143 - accuracy: 0.6548 - val_loss: 0.2111 - val_accuracy: 0.6688
# Epoch 7/50
# 69254/69254 [==============================] - 5s 72us/step - loss: 0.2123 - accuracy: 0.6596 - val_loss: 0.2045 - val_accuracy: 0.6828
# Epoch 8/50
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.2092 - accuracy: 0.6665 - val_loss: 0.2048 - val_accuracy: 0.6744
# Epoch 9/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2077 - accuracy: 0.6729 - val_loss: 0.1974 - val_accuracy: 0.6966
# Epoch 10/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2052 - accuracy: 0.6758 - val_loss: 0.1957 - val_accuracy: 0.6933
# Epoch 11/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.2047 - accuracy: 0.6773 - val_loss: 0.2045 - val_accuracy: 0.6640
# Epoch 12/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.2042 - accuracy: 0.6755 - val_loss: 0.1947 - val_accuracy: 0.6962
# Epoch 13/50
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.2010 - accuracy: 0.6848 - val_loss: 0.1935 - val_accuracy: 0.7028
# Epoch 14/50
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.2001 - accuracy: 0.6867 - val_loss: 0.1868 - val_accuracy: 0.7129
# Epoch 15/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1976 - accuracy: 0.6920 - val_loss: 0.1837 - val_accuracy: 0.7201
# Epoch 16/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1972 - accuracy: 0.6940 - val_loss: 0.1795 - val_accuracy: 0.7295
# Epoch 17/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1957 - accuracy: 0.6966 - val_loss: 0.2025 - val_accuracy: 0.6748
# Epoch 18/50
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1959 - accuracy: 0.6956 - val_loss: 0.1760 - val_accuracy: 0.7313
# Epoch 19/50
# 69254/69254 [==============================] - 5s 75us/step - loss: 0.1946 - accuracy: 0.6984 - val_loss: 0.1832 - val_accuracy: 0.7145
# Epoch 20/50
# 69254/69254 [==============================] - 5s 70us/step - loss: 0.1947 - accuracy: 0.6982 - val_loss: 0.1867 - val_accuracy: 0.7148
# Epoch 21/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1932 - accuracy: 0.7004 - val_loss: 0.1856 - val_accuracy: 0.7195
# Epoch 22/50
# 69254/69254 [==============================] - 5s 71us/step - loss: 0.1929 - accuracy: 0.7036 - val_loss: 0.1778 - val_accuracy: 0.7333
# Epoch 23/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1923 - accuracy: 0.7027 - val_loss: 0.1801 - val_accuracy: 0.7242
# Epoch 24/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1913 - accuracy: 0.7040 - val_loss: 0.1791 - val_accuracy: 0.7225
# Epoch 25/50
# 69254/69254 [==============================] - 5s 79us/step - loss: 0.1916 - accuracy: 0.7027 - val_loss: 0.1849 - val_accuracy: 0.7105
# Epoch 26/50
# 69254/69254 [==============================] - 5s 73us/step - loss: 0.1908 - accuracy: 0.7076 - val_loss: 0.1850 - val_accuracy: 0.7180
# Epoch 27/50
# 69254/69254 [==============================] - 5s 76us/step - loss: 0.1905 - accuracy: 0.7075 - val_loss: 0.1822 - val_accuracy: 0.7243
# Epoch 28/50
# 69254/69254 [==============================] - 5s 78us/step - loss: 0.1900 - accuracy: 0.7075 - val_loss: 0.2050 - val_accuracy: 0.6625
# Epoch 29/50
# 69254/69254 [==============================] - 5s 77us/step - loss: 0.1895 - accuracy: 0.7086 - val_loss: 0.1738 - val_accuracy: 0.7426
# Epoch 30/50
# 69254/69254 [==============================] - 6s 85us/step - loss: 0.1892 - accuracy: 0.7093 - val_loss: 0.1760 - val_accuracy: 0.7288
# Epoch 31/50
# 69254/69254 [==============================] - 6s 84us/step - loss: 0.1886 - accuracy: 0.7101 - val_loss: 0.1818 - val_accuracy: 0.7236
# Epoch 32/50
# 69254/69254 [==============================] - 6s 80us/step - loss: 0.1890 - accuracy: 0.7087 - val_loss: 0.1774 - val_accuracy: 0.7290
# Epoch 33/50
# 69254/69254 [==============================] - 6s 79us/step - loss: 0.1886 - accuracy: 0.7101 - val_loss: 0.1844 - val_accuracy: 0.7168
# Epoch 34/50
# 69254/69254 [==============================] - 6s 79us/step - loss: 0.1881 - accuracy: 0.7112 - val_loss: 0.1750 - val_accuracy: 0.7365
# Epoch 35/50
# 69254/69254 [==============================] - 6s 82us/step - loss: 0.1869 - accuracy: 0.7156 - val_loss: 0.1779 - val_accuracy: 0.7240
# Epoch 36/50
# 69254/69254 [==============================] - 6s 83us/step - loss: 0.1868 - accuracy: 0.7148 - val_loss: 0.1789 - val_accuracy: 0.7246
# Epoch 37/50
# 69254/69254 [==============================] - 6s 81us/step - loss: 0.1862 - accuracy: 0.7148 - val_loss: 0.1772 - val_accuracy: 0.7257
# Epoch 38/50
# 69254/69254 [==============================] - 6s 82us/step - loss: 0.1866 - accuracy: 0.7136 - val_loss: 0.1715 - val_accuracy: 0.7411
# Epoch 39/50
# 69254/69254 [==============================] - 6s 87us/step - loss: 0.1857 - accuracy: 0.7145 - val_loss: 0.1712 - val_accuracy: 0.7399
# Epoch 40/50
# 69254/69254 [==============================] - 6s 87us/step - loss: 0.1851 - accuracy: 0.7176 - val_loss: 0.1730 - val_accuracy: 0.7384
# Epoch 41/50
# 69254/69254 [==============================] - 6s 94us/step - loss: 0.1849 - accuracy: 0.7184 - val_loss: 0.1723 - val_accuracy: 0.7423
# Epoch 42/50
# 69254/69254 [==============================] - 7s 104us/step - loss: 0.1850 - accuracy: 0.7180 - val_loss: 0.1753 - val_accuracy: 0.7360
# Epoch 43/50
# 69254/69254 [==============================] - 7s 101us/step - loss: 0.1841 - accuracy: 0.7177 - val_loss: 0.1712 - val_accuracy: 0.7389
# Epoch 44/50
# 69254/69254 [==============================] - 7s 107us/step - loss: 0.1836 - accuracy: 0.7183 - val_loss: 0.1741 - val_accuracy: 0.7289
# Epoch 45/50
# 69254/69254 [==============================] - 8s 119us/step - loss: 0.1835 - accuracy: 0.7192 - val_loss: 0.1697 - val_accuracy: 0.7434
# Epoch 46/50
# 69254/69254 [==============================] - 7s 94us/step - loss: 0.1832 - accuracy: 0.7199 - val_loss: 0.1654 - val_accuracy: 0.7477
# Epoch 47/50
# 69254/69254 [==============================] - 7s 96us/step - loss: 0.1822 - accuracy: 0.7216 - val_loss: 0.1709 - val_accuracy: 0.7388
# Epoch 48/50
# 69254/69254 [==============================] - 6s 89us/step - loss: 0.1822 - accuracy: 0.7218 - val_loss: 0.1733 - val_accuracy: 0.7353
# Epoch 49/50
# 69254/69254 [==============================] - 6s 91us/step - loss: 0.1824 - accuracy: 0.7210 - val_loss: 0.1692 - val_accuracy: 0.7402
# Epoch 50/50
# 69254/69254 [==============================] - 7s 94us/step - loss: 0.1809 - accuracy: 0.7242 - val_loss: 0.1734 - val_accuracy: 0.7334

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 73.28%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 73.86%

# %%
scores = model.evaluate(test_XX, test_YY, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 58.72%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,29,2) ,
            'max_features':range(0,29,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
dt = DecisionTreeClassifier(max_depth=26,max_features=26,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=26, max_features=26, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 98.01081230939839
# Test Prediction Score 89.81194843598392

# %%
y_pred_dt_test= dt.predict(test_X)
dt_score_test = accuracy_score(test_Y,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Test Prediction Score 59.414157215486895

# %%
y_pred_dt_test= dt.predict(test_XX)
dt_score_test = accuracy_score(test_YY,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Test Prediction Score 41.10405598030323

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89     10243
#            1       0.90      0.91      0.90     11400
#
#     accuracy                           0.90     21643
#    macro avg       0.90      0.90      0.90     21643
# weighted avg       0.90      0.90      0.90     21643

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250],
            'max_features':range(0,25,2)}
dt_g=RandomForestClassifier(random_state=42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=26,max_features=26,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=26, max_features=26,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 99.73431291008225
# Test Prediction Score 91.64163932911335

# %%
y_pred_rf_test= rf.predict(test_X)
rf_score_test = accuracy_score(test_Y,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Test Prediction Score 61.17403206883066

# %%
y_pred_rf_test= rf.predict(test_XX)
rf_score_test = accuracy_score(test_YY,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Test Prediction Score 39.18765208126359

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     10243
#            1       0.91      0.93      0.92     11400
#
#     accuracy                           0.92     21643
#    macro avg       0.92      0.92      0.92     21643
# weighted avg       0.92      0.92      0.92     21643

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250,500],
           'min_child_weight':[1,3,6]}
xgb_g=XGBClassifier(random_state=42)
xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
xgb_cv.fit(X_train,y_train)

print("Best parameters:",xgb_cv.best_params_)
print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=26,min_child_weight=1,n_estimators=500,random_state=42,learning_rate=0.2)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=26,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.76088161907403
# Test Prediction Score 94.51554775216006

# %%
y_pred_xgbc_test= xgbc.predict(test_X)
xgbc_score_test = accuracy_score(test_Y,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Test Prediction Score 63.77942901838092

# %%
y_pred_xgbc_test= xgbc.predict(test_XX)
xgbc_score_test = accuracy_score(test_YY,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Test Prediction Score 40.06594387571451

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     10243
#            1       0.94      0.95      0.95     11400
#
#     accuracy                           0.95     21643
#    macro avg       0.95      0.94      0.94     21643
# weighted avg       0.95      0.95      0.95     21643

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
param_grid = {'n_estimators': [x for x in range(24,40,2)],
              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
lgb_cv.fit(X_train, y_train)

print("Best parameters:",lgb_cv.best_params_)
print("Accuracy :",lgb_cv.best_score_)

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.6,  n_estimators = 500, max_depth = 26, random_state=42, min_child_weight=1,metric='binary',boosting_type = 'dart')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.6, max_depth=26,
#                metric='binary', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 87.24586452268737
# Test Prediction Score 84.11033590537356

# %%
y_pred_gbm_test = gbm.predict(test_X)
gbm_score_test = accuracy_score(test_Y,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Test Prediction Score 62.483378959718415

# %%
y_pred_gbm_test = gbm.predict(test_XX)
gbm_score_test = accuracy_score(test_YY,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Test Prediction Score 34.85090636833542

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,5500), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [7293,
#  2555,
#  633,
#  567,
#  479,
#  465,
#  401,
#  391,
#  365,
#  333,
#  265,
#  264,
#  259,
#  230,
#  168,
#  137,
#  112,
#  41,
#  27,
#  15,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82     10243
#            1       0.82      0.90      0.86     11400
#
#     accuracy                           0.84     21643
#    macro avg       0.85      0.84      0.84     21643
# weighted avg       0.84      0.84      0.84     21643

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
