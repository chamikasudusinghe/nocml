# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r2_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
dfgurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r2-good.csv?token=AKVFSODJHCSL4YTM5ZKMY3C6XZY7G"
dfmurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r2-mal.csv?token=AKVFSOGYF3JIWAA6UVHBLXS6XZY7K"

dfg = pd.read_csv(dfgurl)
dfm = pd.read_csv(dfmurl)

# %% [markdown]
# Characteristics of Dataset

# %%
dfg
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             15        2       4  ...             27                 9       1
# 1             39        0       1  ...             27                18       1
# 2             78        2       0  ...             27                27       1
# 3             79        4       0  ...             85               100       1
# 4             80        4       0  ...             85               100       1
# ...          ...      ...     ...  ...            ...               ...     ...
# 36474    3251169        1       4  ...             27                45       1
# 36475    3251176        1       4  ...             27                45       1
# 36476    3251183        1       4  ...             27                45       1
# 36477    3251184        1       4  ...             30                 9       1
# 36478    3251199        0       1  ...             27                54       1
#
# [36479 rows x 30 columns]

# %%
dfm
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             11        2       4  ...             27                 9       0
# 1             15        2       4  ...             30                 9       0
# 2             35        0       1  ...             27                18       0
# 3             39        0       1  ...             30                18       0
# 4             74        2       0  ...             27                27       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 40843    2021342        1       4  ...             27                45       0
# 40844    2021349        1       4  ...             27                45       0
# 40845    2021350        1       4  ...             30                 9       0
# 40846    2021702        2       4  ...             27                45       0
# 40847    2021709        2       4  ...             27                45       0
#
# [40848 rows x 30 columns]

# %%
df = dfg.append(dfm, ignore_index=True,sort=False)

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df = df.sort_values('timestamp')
df.to_csv('wat-r1-model.csv',index=False)

# %%
df = pd.read_csv("wat-r1-model.csv")
df
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             11        2       4  ...             27                 9       0
# 1             15        2       4  ...             30                 9       0
# 2             15        2       4  ...             27                 9       1
# 3             35        0       1  ...             27                18       0
# 4             39        0       1  ...             30                18       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 77322    3251169        1       4  ...             27                45       1
# 77323    3251176        1       4  ...             27                45       1
# 77324    3251183        1       4  ...             27                45       1
# 77325    3251184        1       4  ...             30                 9       1
# 77326    3251199        0       1  ...             27                54       1
#
# [77327 rows x 30 columns]

# %%
df.corr()
# Out:
#                             timestamp   outport  ...  vnet_vc_cc_index    target
# timestamp                    1.000000 -0.044098  ...          0.010486  0.414406
# outport                     -0.044098  1.000000  ...          0.486179 -0.017080
# inport                       0.003850 -0.433601  ...         -0.578601  0.001500
# cache_coherence_type         0.021906 -0.004058  ...          0.400702  0.001289
# flit_id                      0.019749  0.013541  ...          0.332111  0.006264
# flit_type                   -0.029814 -0.020321  ...         -0.499661 -0.009416
# vnet                        -0.001657  0.526235  ...          0.840482  0.004165
# vc                          -0.006219  0.570262  ...          0.785634 -0.001512
# src_ni                      -0.018601  0.270744  ...          0.398883 -0.019239
# src_router                  -0.010176 -0.167276  ...          0.158954 -0.051047
# dst_ni                       0.030027 -0.543367  ...         -0.773859  0.008537
# dst_router                   0.048041 -0.299633  ...         -0.422507  0.017106
# traversal_id                 0.839774 -0.040102  ...          0.003374 -0.066502
# hop_count                    0.092778 -0.193674  ...         -0.308805  0.138607
# current_hop                  0.081068 -0.737016  ...         -0.512511  0.132084
# hop_percentage               0.027105 -0.832598  ...         -0.445554  0.037426
# enqueue_time                 0.044910 -0.435529  ...         -0.559112  0.040587
# packet_count_decr           -0.304050 -0.057495  ...          0.024982 -0.361268
# packet_count_incr           -0.304036  0.111819  ...          0.088651 -0.361268
# max_packet_count            -0.377563  0.033730  ...          0.070555 -0.448626
# packet_count_index          -0.276063  0.031946  ...          0.065966 -0.363805
# packet_max_index            -0.208170  0.020090  ...          0.054376 -0.304583
# port_index                  -0.019683  0.159788  ...         -0.373650 -0.008633
# cache_coherence_flit_index   0.021530 -0.040027  ...          0.294770  0.004779
# flit_index                   0.014119 -0.020382  ...          0.209832  0.002565
# traversal_index              0.440902 -0.041502  ...          0.148073 -0.035514
# cache_coherence_vnet_index   0.019042  0.300955  ...          0.852441  0.003588
# vnet_vc_index               -0.003628  0.547464  ...          0.820061  0.001717
# vnet_vc_cc_index             0.010486  0.486179  ...          1.000000  0.004573
# target                       0.414406 -0.017080  ...          0.004573  1.000000
#
# [30 rows x 30 columns]

# %%
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target','timestamp','src_ni','src_router'])
train_X
# Out:
#        outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0            2       4  ...             27                 9
# 1            2       4  ...             30                 9
# 2            2       4  ...             27                 9
# 3            0       1  ...             27                18
# 4            0       1  ...             30                18
# ...        ...     ...  ...            ...               ...
# 77322        1       4  ...             27                45
# 77323        1       4  ...             27                45
# 77324        1       4  ...             27                45
# 77325        1       4  ...             30                 9
# 77326        0       1  ...             27                54
#
# [77327 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#        outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0         0.50    1.00  ...       0.000000          0.000000
# 1         0.50    1.00  ...       0.041096          0.000000
# 2         0.50    1.00  ...       0.000000          0.000000
# 3         0.00    0.25  ...       0.000000          0.098901
# 4         0.00    0.25  ...       0.041096          0.098901
# ...        ...     ...  ...            ...               ...
# 77322     0.25    1.00  ...       0.000000          0.395604
# 77323     0.25    1.00  ...       0.000000          0.395604
# 77324     0.25    1.00  ...       0.000000          0.395604
# 77325     0.25    1.00  ...       0.041096          0.000000
# 77326     0.00    0.25  ...       0.000000          0.494505
#
# [77327 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (351, 26)

# %%
corr_df = pd.concat([train_X, df[['target']]], axis = 1)
corr_df.corr()
# Out:
#                              outport    inport  ...  vnet_vc_cc_index    target
# outport                     1.000000 -0.433601  ...          0.486179 -0.017080
# inport                     -0.433601  1.000000  ...         -0.578601  0.001500
# cache_coherence_type       -0.004058 -0.118298  ...          0.400702  0.001289
# flit_id                     0.013541 -0.015309  ...          0.332111  0.006264
# flit_type                  -0.020321  0.023008  ...         -0.499661 -0.009416
# vnet                        0.526235 -0.553456  ...          0.840482  0.004165
# vc                          0.570262 -0.600813  ...          0.785634 -0.001512
# dst_ni                     -0.543367  0.709603  ...         -0.773859  0.008537
# dst_router                 -0.299633  0.647779  ...         -0.422507  0.017106
# traversal_id               -0.040102  0.011672  ...          0.003374 -0.066502
# hop_count                  -0.193674  0.630434  ...         -0.308805  0.138607
# current_hop                -0.737016  0.601884  ...         -0.512511  0.132084
# hop_percentage             -0.832598  0.354500  ...         -0.445554  0.037426
# enqueue_time               -0.435529  0.407063  ...         -0.559112  0.040587
# packet_count_decr          -0.057495 -0.038239  ...          0.024982 -0.361268
# packet_count_incr           0.111819 -0.162743  ...          0.088651 -0.361268
# max_packet_count            0.033730 -0.124791  ...          0.070555 -0.448626
# packet_count_index          0.031946 -0.119424  ...          0.065966 -0.363805
# packet_max_index            0.020090 -0.103251  ...          0.054376 -0.304583
# port_index                  0.159788  0.681523  ...         -0.373650 -0.008633
# cache_coherence_flit_index -0.040027 -0.028877  ...          0.294770  0.004779
# flit_index                 -0.020382 -0.033273  ...          0.209832  0.002565
# traversal_index            -0.041502 -0.017087  ...          0.148073 -0.035514
# cache_coherence_vnet_index  0.300955 -0.428428  ...          0.852441  0.003588
# vnet_vc_index               0.547464 -0.576240  ...          0.820061  0.001717
# vnet_vc_cc_index            0.486179 -0.578601  ...          1.000000  0.004573
# target                     -0.017080  0.001500  ...          0.004573  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# Principal Component Analysis

# %%
pca = PCA(0.95)
pca.fit(train_X)
principal_components = pca.transform(train_X)
principal_components
# Out:
# array([[-0.78280868, -1.13282974, -0.29024068, ...,  0.04170911,
#         -0.00451017, -0.17900485],
#        [-0.90510231, -1.07909077, -0.24473694, ..., -0.07174305,
#          0.00533193,  0.12605706],
#        [-0.95655768, -1.07280154, -0.25183715, ..., -0.14801427,
#         -0.18778832,  0.09675167],
#        ...,
#        [-0.6223612 ,  0.99585457, -0.1337395 , ..., -0.08669059,
#          0.4948901 , -0.09612333],
#        [-0.88346096, -0.89845303,  0.28337973, ..., -0.21735002,
#          0.46176657, -0.00162554],
#        [-0.00151708, -0.0657907 ,  0.9851006 , ...,  0.09393127,
#          0.40759329, -0.0887776 ]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.37860528, 0.16941841, 0.13604488, 0.08262099, 0.06315962,
#        0.04414365, 0.04115154, 0.03173611, 0.01877275])

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xticks(features)
plt.xlabel("PCs")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %%
principal_df = pd.DataFrame(data = principal_components)
principal_df
# Out:
#               0         1         2  ...         6         7         8
# 0     -0.782809 -1.132830 -0.290241  ...  0.041709 -0.004510 -0.179005
# 1     -0.905102 -1.079091 -0.244737  ... -0.071743  0.005332  0.126057
# 2     -0.956558 -1.072802 -0.251837  ... -0.148014 -0.187788  0.096752
# 3     -0.398812 -0.677461  1.145003  ...  0.075815 -0.077095  0.231993
# 4     -0.357007 -0.686032  1.135207  ...  0.064463 -0.061073  0.240335
# ...         ...       ...       ...  ...       ...       ...       ...
# 77322 -0.606968  0.275948  0.017933  ... -0.041621  0.470966 -0.108654
# 77323 -0.605280  0.572336 -0.050058  ... -0.046792  0.469061 -0.127970
# 77324 -0.622361  0.995855 -0.133739  ... -0.086691  0.494890 -0.096123
# 77325 -0.883461 -0.898453  0.283380  ... -0.217350  0.461767 -0.001626
# 77326 -0.001517 -0.065791  0.985101  ...  0.093931  0.407593 -0.088778
#
# [77327 rows x 9 columns]

# %%
final_df = pd.concat([principal_df, df[['target']]], axis = 1)
final_df.corr()
# Out:
#                    0             1  ...             8    target
# 0       1.000000e+00  1.062637e-16  ... -7.632800e-16 -0.029411
# 1       1.062637e-16  1.000000e+00  ...  1.638485e-16  0.012577
# 2      -4.630458e-16  3.327990e-16  ...  1.117170e-15 -0.005522
# 3      -1.019387e-16 -1.337687e-15  ... -2.711778e-16 -0.044808
# 4       1.015399e-17  5.191556e-16  ... -6.691293e-16 -0.092027
# 5       3.280962e-16  9.062907e-19  ...  6.925045e-16 -0.241741
# 6      -1.597428e-16  1.015287e-16  ... -2.610478e-16 -0.138776
# 7      -1.438166e-17 -1.756420e-16  ... -1.889108e-16 -0.373230
# 8      -7.632800e-16  1.638485e-16  ...  1.000000e+00  0.123661
# target -2.941114e-02  1.257683e-02  ...  1.236608e-01  1.000000
#
# [10 rows x 10 columns]

# %%
dimentional_components = pd.DataFrame()
dimentional_components['target'] = corr_df["target"]
dimentional_components['pca-one'] = principal_components[:,0]
dimentional_components['pca-two'] = principal_components[:,1] 
dimentional_components['pca-three'] = principal_components[:,2]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 2', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-two", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-two'], 
    zs=dimentional_components['pca-three'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-two'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-two')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-two'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-one'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-two')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-one')
plt.show()

# %% [markdown]
# T-distributed Stochastic Neighbor Embedding

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_components = tsne.fit_transform(train_X)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 434.93178248405457 seconds

# %%
dimentional_components['tsne-2d-one'] = tsne_components[:,0]
dimentional_components['tsne-2d-two'] = tsne_components[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3
)

# %%
plt.figure(figsize=(16,7))
ax1 = plt.subplot(1, 2, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 2, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_pca_components = tsne.fit_transform(principal_components)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 283.51238560676575 seconds

# %%
dimentional_components['tsne-pca9-one'] = tsne_pca_components[:,0]
dimentional_components['tsne-pca9-two'] = tsne_pca_components[:,1]
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1, 3, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 3, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)
ax3 = plt.subplot(1, 3, 3)
sns.scatterplot(
    x="tsne-pca9-one", y="tsne-pca9-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax3
)

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 0    40848
# 1    36479
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                  Specs        Score
# 16    max_packet_count  4336.641750
# 14   packet_count_decr  2171.011972
# 15   packet_count_incr  2165.638763
# 17  packet_count_index  1971.535439
# 18    packet_max_index  1306.291292
# 10           hop_count   264.396878
# 11         current_hop   229.881634
# 9         traversal_id    45.141354
# 12      hop_percentage    23.046021
# 22     traversal_index    14.712478
# 13        enqueue_time    11.793452
# 8           dst_router     6.261060
# 0              outport     5.275171
# 19          port_index     2.885647
# 4            flit_type     2.704691
# 5                 vnet     1.661273
# 3              flit_id     1.086750

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.502493
#          Iterations: 35
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                        Results: Logit
# ============================================================================================
# Model:                       Logit                     Pseudo R-squared:          0.273
# Dependent Variable:          target                    AIC:                       77758.5073
# Date:                        2020-05-08 10:56          BIC:                       77971.3907
# No. Observations:            77327                     Log-Likelihood:            -38856.
# Df Model:                    22                        LL-Null:                   -53476.
# Df Residuals:                77304                     LLR p-value:               0.0000
# Converged:                   0.0000                    Scale:                     1.0000
# No. Iterations:              35.0000
# --------------------------------------------------------------------------------------------
#                             Coef.    Std.Err.      z     P>|z|      [0.025         0.975]
# --------------------------------------------------------------------------------------------
# outport                    -0.2963       0.1053  -2.8133 0.0049        -0.5027       -0.0899
# inport                      0.1305       0.0488   2.6758 0.0075         0.0349        0.2260
# cache_coherence_type       -0.1549  679143.0634  -0.0000 1.0000  -1331096.0995  1331095.7898
# flit_id                    -0.0928       0.1995  -0.4651 0.6419        -0.4838        0.2982
# flit_type                   0.3755       0.0554   6.7820 0.0000         0.2670        0.4840
# vnet                        0.6420  944554.8226   0.0000 1.0000  -1851292.7916  1851294.0757
# vc                          0.2486       0.6829   0.3640 0.7158        -1.0899        1.5870
# dst_ni                      3.6595       0.1442  25.3713 0.0000         3.3768        3.9422
# dst_router                 -8.1372       0.2101 -38.7248 0.0000        -8.5491       -7.7254
# traversal_id               -1.8337       0.0544 -33.7009 0.0000        -1.9403       -1.7270
# hop_count                   9.3803       0.1918  48.9021 0.0000         9.0044        9.7563
# current_hop                -2.1870       0.1427 -15.3243 0.0000        -2.4668       -1.9073
# hop_percentage              0.0950       0.1101   0.8634 0.3879        -0.1207        0.3108
# enqueue_time               -0.0432       0.1394  -0.3099 0.7567        -0.3164        0.2300
# packet_count_decr          -3.0842 6305487.3000  -0.0000 1.0000 -12358531.0972 12358524.9289
# packet_count_incr          -2.8555 6305487.3000  -0.0000 1.0000 -12358530.8685 12358525.1576
# max_packet_count           -5.9396 6305487.3000  -0.0000 1.0000 -12358533.9527 12358522.0734
# packet_count_index          3.4722       0.9223   3.7647 0.0002         1.6645        5.2798
# packet_max_index           -0.5711       1.1210  -0.5094 0.6104        -2.7682        1.6261
# port_index                 -1.6228       0.0511 -31.7349 0.0000        -1.7230       -1.5225
# cache_coherence_flit_index  0.3397       0.3305   1.0280 0.3040        -0.3080        0.9874
# flit_index                 -0.0512       0.1559  -0.3285 0.7426        -0.3568        0.2544
# traversal_index            -0.4720       0.1240  -3.8056 0.0001        -0.7152       -0.2289
# cache_coherence_vnet_index  0.1305  431707.2038   0.0000 1.0000   -846130.4408   846130.7017
# vnet_vc_index              -0.7438       1.1018  -0.6751 0.4996        -2.9033        1.4157
# vnet_vc_cc_index            0.3596 1516105.8739   0.0000 1.0000  -2971512.5500  2971513.2692
# ============================================================================================

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 75.80866781978953
# Test Prediction  75.55929134876503

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 10                   hop_count    9.258149
# 7                       dst_ni    5.084097
# 17          packet_count_index    2.530116
# 5                         vnet    1.263264
# 25            vnet_vc_cc_index    0.956175
# 4                    flit_type    0.929644
# 6                           vc    0.912968
# 23  cache_coherence_vnet_index    0.675581
# 13                enqueue_time    0.384500
# 18            packet_max_index    0.354093
# 1                       inport    0.330582
# 12              hop_percentage    0.165908
# 2         cache_coherence_type    0.114131
# 3                      flit_id    0.008142
# 20  cache_coherence_flit_index   -0.027066
# 0                      outport   -0.097396
# 21                  flit_index   -0.408857
# 22             traversal_index   -0.488156
# 24               vnet_vc_index   -1.562827
# 19                  port_index   -1.725160
# 9                 traversal_id   -1.818768
# 11                 current_hop   -2.089711
# 15           packet_count_incr   -2.761477
# 14           packet_count_decr   -3.041242
# 16            max_packet_count   -5.802718
# 8                   dst_router   -8.650199

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      8239
#            1       0.71      0.82      0.76      7227
#
#     accuracy                           0.76     15466
#    macro avg       0.76      0.76      0.76     15466
# weighted avg       0.76      0.76      0.76     15466

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 87.75157207287305
# Test Prediction  82.4453640243114

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83      8239
#            1       0.78      0.86      0.82      7227
#
#     accuracy                           0.82     15466
#    macro avg       0.83      0.83      0.82     15466
# weighted avg       0.83      0.82      0.82     15466

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 67.34776353437546
# Test Prediction Score 67.09556446398551

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.45      0.59      8239
#            1       0.60      0.92      0.72      7227
#
#     accuracy                           0.67     15466
#    macro avg       0.73      0.69      0.66     15466
# weighted avg       0.74      0.67      0.65     15466

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 49488 samples, validate on 12373 samples
# Epoch 1/10
# 49488/49488 [==============================] - 2s 42us/step - loss: 0.2099 - accuracy: 0.6635 - val_loss: 0.1846 - val_accuracy: 0.7330
# Epoch 2/10
# 49488/49488 [==============================] - 2s 39us/step - loss: 0.1788 - accuracy: 0.7486 - val_loss: 0.1748 - val_accuracy: 0.7531
# Epoch 3/10
# 49488/49488 [==============================] - 2s 38us/step - loss: 0.1723 - accuracy: 0.7569 - val_loss: 0.1710 - val_accuracy: 0.7551
# Epoch 4/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1696 - accuracy: 0.7582 - val_loss: 0.1695 - val_accuracy: 0.7570
# Epoch 5/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1681 - accuracy: 0.7597 - val_loss: 0.1686 - val_accuracy: 0.7541
# Epoch 6/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1672 - accuracy: 0.7588 - val_loss: 0.1681 - val_accuracy: 0.7587
# Epoch 7/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1666 - accuracy: 0.7604 - val_loss: 0.1675 - val_accuracy: 0.7563
# Epoch 8/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1660 - accuracy: 0.7613 - val_loss: 0.1670 - val_accuracy: 0.7581
# Epoch 9/10
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.1654 - accuracy: 0.7614 - val_loss: 0.1670 - val_accuracy: 0.7530
# Epoch 10/10
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.1651 - accuracy: 0.7626 - val_loss: 0.1664 - val_accuracy: 0.7575

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 75.54%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2 )
# Out:
# Train on 49488 samples, validate on 12373 samples
# Epoch 1/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2508 - accuracy: 0.5266 - val_loss: 0.2501 - val_accuracy: 0.5291
# Epoch 2/15
# 49488/49488 [==============================] - 2s 38us/step - loss: 0.2499 - accuracy: 0.5266 - val_loss: 0.2494 - val_accuracy: 0.5291
# Epoch 3/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2494 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 4/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 5/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 6/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 7/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 8/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 9/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 10/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 11/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 12/15
# 49488/49488 [==============================] - 2s 38us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 13/15
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 14/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291
# Epoch 15/15
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2493 - accuracy: 0.5266 - val_loss: 0.2492 - val_accuracy: 0.5291

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 53.27%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 49488 samples, validate on 12373 samples
# Epoch 1/30
# 49488/49488 [==============================] - 2s 39us/step - loss: 0.2492 - accuracy: 0.5248 - val_loss: 0.2467 - val_accuracy: 0.5434
# Epoch 2/30
# 49488/49488 [==============================] - 2s 36us/step - loss: 0.2452 - accuracy: 0.5510 - val_loss: 0.2429 - val_accuracy: 0.5882
# Epoch 3/30
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2397 - accuracy: 0.6252 - val_loss: 0.2347 - val_accuracy: 0.6819
# Epoch 4/30
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2279 - accuracy: 0.7084 - val_loss: 0.2187 - val_accuracy: 0.7239
# Epoch 5/30
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.2098 - accuracy: 0.7363 - val_loss: 0.2001 - val_accuracy: 0.7403
# Epoch 6/30
# 49488/49488 [==============================] - 2s 37us/step - loss: 0.
100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1169 - accuracy: 0.8274 - val_loss: 0.1107 - val_accuracy: 0.8333
# Epoch 21/100
# 49488/49488 [==============================] - 4s 72us/step - loss: 0.1175 - accuracy: 0.8285 - val_loss: 0.1152 - val_accuracy: 0.8312
# Epoch 22/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1171 - accuracy: 0.8285 - val_loss: 0.1120 - val_accuracy: 0.8301
# Epoch 23/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1166 - accuracy: 0.8278 - val_loss: 0.1509 - val_accuracy: 0.7725
# Epoch 24/100
# 49488/49488 [==============================] - 3s 70us/step - loss: 0.1158 - accuracy: 0.8297 - val_loss: 0.1121 - val_accuracy: 0.8228
# Epoch 25/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1154 - accuracy: 0.8309 - val_loss: 0.1091 - val_accuracy: 0.8368
# Epoch 26/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1155 - accuracy: 0.8305 - val_loss: 0.1098 - val_accuracy: 0.8356
# Epoch 27/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1151 - accuracy: 0.8308 - val_loss: 0.1085 - val_accuracy: 0.8354
# Epoch 28/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1150 - accuracy: 0.8296 - val_loss: 0.1100 - val_accuracy: 0.8363
# Epoch 29/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1150 - accuracy: 0.8298 - val_loss: 0.1079 - val_accuracy: 0.8366
# Epoch 30/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1144 - accuracy: 0.8304 - val_loss: 0.1107 - val_accuracy: 0.8325
# Epoch 31/100
# 49488/49488 [==============================] - 4s 71us/step - loss: 0.1142 - accuracy: 0.8302 - val_loss: 0.1110 - val_accuracy: 0.8359
# Epoch 32/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1144 - accuracy: 0.8316 - val_loss: 0.1095 - val_accuracy: 0.8375
# Epoch 33/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1143 - accuracy: 0.8316 - val_loss: 0.1112 - val_accuracy: 0.8336
# Epoch 34/100
# 49488/49488 [==============================] - 3s 71us/step - loss: 0.1129 - accuracy: 0.8325 - val_loss: 0.1073 - val_accuracy: 0.8379
# Epoch 35/100
# 49488/49488 [==============================] - 4s 72us/step - loss: 0.1128 - accuracy: 0.8329 - val_loss: 0.1099 - val_accuracy: 0.8385
# Epoch 36/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1127 - accuracy: 0.8319 - val_loss: 0.1074 - val_accuracy: 0.8377
# Epoch 37/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1152 - accuracy: 0.8312 - val_loss: 0.1159 - val_accuracy: 0.8253
# Epoch 38/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1124 - accuracy: 0.8324 - val_loss: 0.1061 - val_accuracy: 0.8378
# Epoch 39/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1146 - accuracy: 0.8313 - val_loss: 0.1103 - val_accuracy: 0.8348
# Epoch 40/100
# 49488/49488 [==============================] - 4s 71us/step - loss: 0.1132 - accuracy: 0.8326 - val_loss: 0.1082 - val_accuracy: 0.8347
# Epoch 41/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1144 - accuracy: 0.8299 - val_loss: 0.1089 - val_accuracy: 0.8338
# Epoch 42/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1143 - accuracy: 0.8295 - val_loss: 0.1079 - val_accuracy: 0.8378
# Epoch 43/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1135 - accuracy: 0.8314 - val_loss: 0.1100 - val_accuracy: 0.8333
# Epoch 44/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1139 - accuracy: 0.8325 - val_loss: 0.1082 - val_accuracy: 0.8380
# Epoch 45/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.
100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1104 - accuracy: 0.8353 - val_loss: 0.1060 - val_accuracy: 0.8383
# Epoch 73/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1106 - accuracy: 0.8351 - val_loss: 0.1071 - val_accuracy: 0.8395
# Epoch 74/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1104 - accuracy: 0.8355 - val_loss: 0.1059 - val_accuracy: 0.8378
# Epoch 75/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1102 - accuracy: 0.8352 - val_loss: 0.1049 - val_accuracy: 0.8391
# Epoch 76/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1098 - accuracy: 0.8361 - val_loss: 0.1059 - val_accuracy: 0.8414
# Epoch 77/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1103 - accuracy: 0.8343 - val_loss: 0.1056 - val_accuracy: 0.8369
# Epoch 78/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1102 - accuracy: 0.8350 - val_loss: 0.1057 - val_accuracy: 0.8401
# Epoch 79/100
# 49488/49488 [==============================] - 4s 72us/step - loss: 0.1106 - accuracy: 0.8334 - val_loss: 0.1055 - val_accuracy: 0.8399
# Epoch 80/100
# 49488/49488 [==============================] - 3s 70us/step - loss: 0.1100 - accuracy: 0.8365 - val_loss: 0.1049 - val_accuracy: 0.8407
# Epoch 81/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1094 - accuracy: 0.8368 - val_loss: 0.1054 - val_accuracy: 0.8388
# Epoch 82/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1100 - accuracy: 0.8355 - val_loss: 0.1044 - val_accuracy: 0.8392
# Epoch 83/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1101 - accuracy: 0.8359 - val_loss: 0.1043 - val_accuracy: 0.8400
# Epoch 84/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1093 - accuracy: 0.8362 - val_loss: 0.1055 - val_accuracy: 0.8388
# Epoch 85/100
# 49488/49488 [==============================] - 4s 71us/step - loss: 0.1092 - accuracy: 0.8366 - val_loss: 0.1045 - val_accuracy: 0.8394
# Epoch 86/100
# 49488/49488 [==============================] - 3s 69us/step - loss: 0.1100 - accuracy: 0.8349 - val_loss: 0.1055 - val_accuracy: 0.8397
# Epoch 87/100
# 49488/49488 [==============================] - 4s 72us/step - loss: 0.1095 - accuracy: 0.8362 - val_loss: 0.1062 - val_accuracy: 0.8408
# Epoch 88/100
# 49488/49488 [==============================] - 3s 70us/step - loss: 0.1098 - accuracy: 0.8358 - val_loss: 0.1061 - val_accuracy: 0.8417
# Epoch 89/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1098 - accuracy: 0.8361 - val_loss: 0.1056 - val_accuracy: 0.8426
# Epoch 90/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1101 - accuracy: 0.8353 - val_loss: 0.1058 - val_accuracy: 0.8364
# Epoch 91/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1098 - accuracy: 0.8360 - val_loss: 0.1056 - val_accuracy: 0.8381
# Epoch 92/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1095 - accuracy: 0.8374 - val_loss: 0.1087 - val_accuracy: 0.8370
# Epoch 93/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1093 - accuracy: 0.8372 - val_loss: 0.1052 - val_accuracy: 0.8380
# Epoch 94/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1112 - accuracy: 0.8334 - val_loss: 0.1047 - val_accuracy: 0.8411
# Epoch 95/100
# 49488/49488 [==============================] - 3s 68us/step - loss: 0.1095 - accuracy: 0.8374 - val_loss: 0.1056 - val_accuracy: 0.8388
# Epoch 96/100
# 49488/49488 [==============================] - 3s 67us/step - loss: 0.1091 - accuracy: 0.8379 - val_loss: 0.1044 - val_accuracy: 0.8411
# Epoch 97/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1087 - accuracy: 0.8388 - val_loss: 0.1074 - val_accuracy: 0.8367
# Epoch 98/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1085 - accuracy: 0.8382 - val_loss: 0.1059 - val_accuracy: 0.8400
# Epoch 99/100
# 49488/49488 [==============================] - 3s 65us/step - loss: 0.1094 - accuracy: 0.8369 - val_loss: 0.1084 - val_accuracy: 0.8354
# Epoch 100/100
# 49488/49488 [==============================] - 3s 66us/step - loss: 0.1091 - accuracy: 0.8372 - val_loss: 0.1072 - val_accuracy: 0.8371

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 83.96%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2) ,
            'max_features':range(0,25,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)
# Out:
# Best parameters: {'max_depth': 24, 'max_features': 24}
# Accuracy : 0.8935840558357785

# %%
dt = DecisionTreeClassifier(max_depth=25,max_features=25,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=25, max_features=25, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 97.61400559318471
# Test Prediction Score 92.81650071123755

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      8239
#            1       0.91      0.94      0.92      7227
#
#     accuracy                           0.93     15466
#    macro avg       0.93      0.93      0.93     15466
# weighted avg       0.93      0.93      0.93     15466

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250],
            'max_features':range(0,25,2)}
dt_g=RandomForestClassifier(random_state=42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=25,max_features=25,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features=25,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 99.19335283943033
# Test Prediction Score 93.04280356911936

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      8239
#            1       0.91      0.95      0.93      7227
#
#     accuracy                           0.93     15466
#    macro avg       0.93      0.93      0.93     15466
# weighted avg       0.93      0.93      0.93     15466

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250,500],
           'min_child_weight':[1,3,6]}
xgb_g=XGBClassifier(random_state=42)
xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
xgb_cv.fit(X_train,y_train)

print("Best parameters:",xgb_cv.best_params_)
print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=25,min_child_weight=1,n_estimators=500,random_state=42)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=25,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.56030455375762
# Test Prediction Score 96.01060390534076

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      8239
#            1       0.95      0.97      0.96      7227
#
#     accuracy                           0.96     15466
#    macro avg       0.96      0.96      0.96     15466
# weighted avg       0.96      0.96      0.96     15466

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
param_grid = {'n_estimators': [x for x in range(24,40,2)],
              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
lgb_cv.fit(X_train, y_train)

print("Best parameters:",lgb_cv.best_params_)
print("Accuracy :",lgb_cv.best_score_)

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.2,  n_estimators = 500, max_depth = 21, random_state=42, min_child_weight=1,metric='l2')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.2, max_depth=21,
#                metric='l2', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 91.5811254263591
# Test Prediction Score 87.80550885814044

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,5100), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [5486,
#  1484,
#  1086,
#  1066,
#  777,
#  718,
#  655,
#  412,
#  400,
#  356,
#  346,
#  337,
#  313,
#  295,
#  295,
#  260,
#  243,
#  129,
#  97,
#  79,
#  76,
#  59,
#  30,
#  1,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      8239
#            1       0.85      0.90      0.87      7227
#
#     accuracy                           0.88     15466
#    macro avg       0.88      0.88      0.88     15466
# weighted avg       0.88      0.88      0.88     15466

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
