# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 4]
df = df.drop(columns=['router'])
df.to_csv('wat-r4-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r4-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            109        1       3                     1        1          4
# 1            130        1       3                     1        1          4
# 2            202        3       1                     4        1          1
# 3            203        3       1                     4        2          2
# 4            204        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 15574    2009879        3       1                     4        1          1
# 15575    2009880        3       1                     4        2          2
# 15576    2009881        3       1                     4        3          2
# 15577    2009882        3       1                     4        4          2
# 15578    2009886        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       1           1      24           8             2
# 1         3   9       0           0      24           8             3
# 2         5  17      29          13       0           0             3
# 3         5  17      29          13       0           0             3
# 4         5  17      29          13       0           0             3
# ...     ...  ..     ...         ...     ...         ...           ...
# 15574     5  17      30          14       0           0         11071
# 15575     5  17      30          14       0           0         11071
# 15576     5  17      30          14       0           0         11071
# 15577     5  17      30          14       0           0         11071
# 15578     5  17      30          14       0           0         11071
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              3            2        0.666667            12
# 1              2            1        0.500000             8
# 2              4            3        0.750000            16
# 3              4            3        0.750000            17
# 4              4            3        0.750000            18
# ...          ...          ...             ...           ...
# 15574          5            4        0.800000            21
# 15575          5            4        0.800000            22
# 15576          5            4        0.800000            23
# 15577          5            4        0.800000            24
# 15578          5            4        0.800000            28
#
# [15579 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 15579

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         109        1       3                     1        1          4
# 1         130        1       3                     1        1          4
# 2         202        3       1                     4        1          1
# 3         203        3       1                     4        2          2
# 4         204        3       1                     4        3          2
# 5         206        3       1                     4        4          2
# 6         209        3       1                     4        5          3
# 7         892        3       1                     4        1          1
# 8         893        3       1                     4        2          2
# 9         894        3       1                     4        3          2
# 10        895        3       1                     4        4          2
# 11        899        3       1                     4        5          3
# 12       1007        3       1                     4        1          1
# 13       1008        3       1                     4        2          2
# 14       1009        3       1                     4        3          2
# 15       1010        3       1                     4        4          2
# 16       1014        3       1                     4        5          3
# 17       1056        0       3                     1        1          4
# 18       1064        2       0                     2        1          4
# 19       1111        3       1                     4        1          1
# 20       1112        3       1                     4        2          2
# 21       1113        3       1                     4        3          2
# 22       1114        3       1                     4        4          2
# 23       1118        3       1                     4        5          3
# 24       1128        0       3                     3        1          4
# 25       1143        0       3                     1        1          4
# 26       1148        1       3                     1        1          4
# 27       1151        2       0                     2        1          4
# 28       1212        0       3                     3        1          4
# 29       1237        1       3                     1        1          4
# 30       1314        3       1                     4        1          1
# 31       1316        3       1                     4        2          2
# 32       1317        3       1                     4        3          2
# 33       1318        3       1                     4        4          2
# 34       1321        3       1                     4        5          3
# 35       1438        3       1                     4        1          1
# 36       1439        3       1                     4        2          2
# 37       1440        3       1                     4        3          2
# 38       1441        3       1                     4        4          2
# 39       1445        3       1                     4        5          3
# 40       1545        3       1                     4        1          1
# 41       1546        3       1                     4        2          2
# 42       1547        3       1                     4        3          2
# 43       1548        3       1                     4        4          2
# 44       1552        3       1                     4        5          3
# 45       1670        0       3                     1        1          4
# 46       1678        2       0                     2        1          4
# 47       1738        0       3                     3        1          4
# 48       1754        3       1                     4        1          1
# 49       1755        3       1                     4        2          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       1           1  ...                 2                   2
# 1      3   9       0           0  ...                 2                   2
# 2      5  17      29          13  ...                 5                   5
# 3      5  17      29          13  ...                 5                   8
# 4      5  17      29          13  ...                 5                   9
# 5      5  17      29          13  ...                 5                   8
# 6      5  17      29          13  ...                 5                   5
# 7      5  17      30          14  ...                 1                   1
# 8      5  17      30          14  ...                 1                   1
# 9      5  17      30          14  ...                 1                   1
# 10     5  17      30          14  ...                 1                   1
# 11     5  17      30          14  ...                 1                   1
# 12     5  17      29          13  ...                 1                   1
# 13     5  17      29          13  ...                 1                   1
# 14     5  17      29          13  ...                 5                   5
# 15     5  17      29          13  ...                 5                   8
# 16     5  17      29          13  ...                 5                   9
# 17     3   9       1           1  ...                 5                   8
# 18     3   9      20           4  ...                 5                   5
# 19     5  17      29          13  ...                 9                   9
# 20     5  17      29          13  ...                 9                  16
# 21     5  17      29          13  ...                 9                  21
# 22     5  17      29          13  ...                 9                  24
# 23     5  17      29          13  ...                 9                  25
# 24     3   9      18           2  ...                 9                  24
# 25     3   9       0           0  ...                 9                  21
# 26     3  10       1           1  ...                 9                  16
# 27     3  10      20           4  ...                 9                   9
# 28     3   9      18           2  ...                 2                   2
# 29     3   9       0           0  ...                 2                   2
# 30     5  17      30          14  ...                 5                   5
# 31     5  17      30          14  ...                 5                   8
# 32     5  17      30          14  ...                 5                   9
# 33     5  17      30          14  ...                 5                   8
# 34     5  17      30          14  ...                 5                   5
# 35     5  17      29          13  ...                 5                   5
# 36     5  17      29          13  ...                 5                   8
# 37     5  17      29          13  ...                 5                   9
# 38     5  17      29          13  ...                 5                   8
# 39     5  17      29          13  ...                 5                   5
# 40     5  17      30          14  ...                 5                   5
# 41     5  17      30          14  ...                 5                   8
# 42     5  17      30          14  ...                 5                   9
# 43     5  17      30          14  ...                 5                   8
# 44     5  17      30          14  ...                 5                   5
# 45     3   9       1           1  ...                 2                   2
# 46     3  11      20           4  ...                 2                   2
# 47     3   9      18           2  ...                 8                   8
# 48     5  17      30          14  ...                 8                  14
# 49     5  17      30          14  ...                 8                  18
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                  4           3                           1           4
# 1                  4           3                           1           4
# 2                 25           3                           4           4
# 3                 40           3                           8          16
# 4                 45           3                          12          24
# 5                 40           3                          16          32
# 6                 25           3                          20          60
# 7                  1           3                           4           4
# 8                  1           3                           8          16
# 9                  1           3                          12          24
# 10                 1           3                          16          32
# 11                 1           3                          20          60
# 12                 1           3                           4           4
# 13                 1           3                           8          16
# 14                25           3                          12          24
# 15                40           3                          16          32
# 16                45           3                          20          60
# 17                40           0                           1           4
# 18                25           0                           2           8
# 19                81           3                           4           4
# 20               144           3                           8          16
# 21               189           3                          12          24
# 22               216           3                          16          32
# 23               225           3                          20          60
# 24               216           0                           3          12
# 25               189           0                           1           4
# 26               144           3                           1           4
# 27                81           0                           2           8
# 28                 4           0                           3          12
# 29                 4           3                           1           4
# 30                25           3                           4           4
# 31                40           3                           8          16
# 32                45           3                          12          24
# 33                40           3                          16          32
# 34                25           3                          20          60
# 35                25           3                           4           4
# 36                40           3                           8          16
# 37                45           3                          12          24
# 38                40           3                          16          32
# 39                25           3                          20          60
# 40                25           3                           4           4
# 41                40           3                           8          16
# 42                45           3                          12          24
# 43                40           3                          16          32
# 44                25           3                          20          60
# 45                 4           0                           1           4
# 46                 4           0                           2           8
# 47                64           0                           3          12
# 48               112           3                           4           4
# 49               144           3                           8          16
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 8                           3             27
# 1                12                           3             27
# 2                12                          20             85
# 3                48                          20             85
# 4                72                          20             85
# 5                96                          20             85
# 6               180                          20             85
# 7                68                          20             85
# 8               272                          20             85
# 9               408                          20             85
# 10              544                          20             85
# 11             1020                          20             85
# 12               76                          20             85
# 13              304                          20             85
# 14              456                          20             85
# 15              608                          20             85
# 16             1140                          20             85
# 17               88                           3             27
# 18              176                           6             27
# 19               84                          20             85
# 20              336                          20             85
# 21              504                          20             85
# 22              672                          20             85
# 23             1260                          20             85
# 24              264                           9             27
# 25               92                           3             27
# 26               96                           3             30
# 27              184                           6             30
# 28              276                           9             27
# 29              100                           3             27
# 30              100                          20             85
# 31              400                          20             85
# 32              600                          20             85
# 33              800                          20             85
# 34             1500                          20             85
# 35              108                          20             85
# 36              432                          20             85
# 37              648                          20             85
# 38              864                          20             85
# 39             1620                          20             85
# 40              116                          20             85
# 41              464                          20             85
# 42              696                          20             85
# 43              928                          20             85
# 44             1740                          20             85
# 45              132                           3             27
# 46              264                           6             33
# 47              396                           9             27
# 48              136                          20             85
# 49              544                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                  9
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17                 9
# 18                18
# 19               100
# 20               100
# 21               100
# 22               100
# 23               100
# 24                27
# 25                 9
# 26                 9
# 27                18
# 28                27
# 29                 9
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43               100
# 44               100
# 45                 9
# 46                18
# 47                27
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            109        1       3                     1        1          4
# 1            130        1       3                     1        1          4
# 2            202        3       1                     4        1          1
# 3            203        3       1                     4        2          2
# 4            204        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 15574    2009879        3       1                     4        1          1
# 15575    2009880        3       1                     4        2          2
# 15576    2009881        3       1                     4        3          2
# 15577    2009882        3       1                     4        4          2
# 15578    2009886        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9       1           1  ...                 2
# 1         3   9       0           0  ...                 2
# 2         5  17      29          13  ...                 5
# 3         5  17      29          13  ...                 5
# 4         5  17      29          13  ...                 5
# ...     ...  ..     ...         ...  ...               ...
# 15574     5  17      30          14  ...                 1
# 15575     5  17      30          14  ...                 1
# 15576     5  17      30          14  ...                 1
# 15577     5  17      30          14  ...                 1
# 15578     5  17      30          14  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       2                 4           3
# 1                       2                 4           3
# 2                       5                25           3
# 3                       8                40           3
# 4                       9                45           3
# ...                   ...               ...         ...
# 15574                   1                 1           3
# 15575                   1                 1           3
# 15576                   1                 1           3
# 15577                   1                 1           3
# 15578                   1                 1           3
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               1           4                8
# 1                               1           4               12
# 2                               4           4               12
# 3                               8          16               48
# 4                              12          24               72
# ...                           ...         ...              ...
# 15574                           4           4            44284
# 15575                           8          16           177136
# 15576                          12          24           265704
# 15577                          16          32           354272
# 15578                          20          60           664260
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               3             27                 9
# 1                               3             27                 9
# 2                              20             85               100
# 3                              20             85               100
# 4                              20             85               100
# ...                           ...            ...               ...
# 15574                          20             85               100
# 15575                          20             85               100
# 15576                          20             85               100
# 15577                          20             85               100
# 15578                          20             85               100
#
# [15579 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            109        1       3                     1        1          4
# 1            130        1       3                     1        1          4
# 2            202        3       1                     4        1          1
# 3            203        3       1                     4        2          2
# 4            204        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 15574    2009879        3       1                     4        1          1
# 15575    2009880        3       1                     4        2          2
# 15576    2009881        3       1                     4        3          2
# 15577    2009882        3       1                     4        4          2
# 15578    2009886        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   2
# 1         3   9       0           0  ...                   2
# 2         5  17      29          13  ...                   5
# 3         5  17      29          13  ...                   8
# 4         5  17      29          13  ...                   9
# ...     ...  ..     ...         ...  ...                 ...
# 15574     5  17      30          14  ...                   1
# 15575     5  17      30          14  ...                   1
# 15576     5  17      30          14  ...                   1
# 15577     5  17      30          14  ...                   1
# 15578     5  17      30          14  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     4           3                           1           4
# 1                     4           3                           1           4
# 2                    25           3                           4           4
# 3                    40           3                           8          16
# 4                    45           3                          12          24
# ...                 ...         ...                         ...         ...
# 15574                 1           3                           4           4
# 15575                 1           3                           8          16
# 15576                 1           3                          12          24
# 15577                 1           3                          16          32
# 15578                 1           3                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    8                           3             27
# 1                   12                           3             27
# 2                   12                          20             85
# 3                   48                          20             85
# 4                   72                          20             85
# ...                ...                         ...            ...
# 15574            44284                          20             85
# 15575           177136                          20             85
# 15576           265704                          20             85
# 15577           354272                          20             85
# 15578           664260                          20             85
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                     9       0
# 2                   100       0
# 3                   100       0
# 4                   100       0
# ...                 ...     ...
# 15574               100       0
# 15575               100       0
# 15576               100       0
# 15577               100       0
# 15578               100       0
#
# [15579 rows x 30 columns]

# %%
df.to_csv('wat-r4-mal.csv',index=False)
