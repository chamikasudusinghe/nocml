# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 5]
df = df.drop(columns=['router'])
df.to_csv('wat-r5-good.csv',index=False)

# %%
df = pd.read_csv('wat-r5-good.csv')
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           463        0       3                     1        1          4
# 1           471        2       0                     2        1          4
# 2           524        0       3                     3        1          4
# 3          1030        1       3                     1        1          4
# 4          1139        2       4                     2        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8657    3250234        1       3                     5        3          2
# 8658    3250241        1       3                     5        4          2
# 8659    3250248        1       3                     5        5          3
# 8660    3250249        1       3                     1        1          4
# 8661    3250740        4       2                     7        1          4
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       0           0      21           5             4
# 1        3   9      21           5      18           2             4
# 2        3   9      18           2      21           5             4
# 3        3   9       0           0      25           9            10
# 4        3   9      20           4      18           2            11
# ...    ...  ..     ...         ...     ...         ...           ...
# 8657     3   9       0           0      29          13         10014
# 8658     3   9       0           0      29          13         10014
# 8659     3   9       0           0      29          13         10014
# 8660     3  10       0           0      29          13         10015
# 8661     3   9      23           7       0           0         10018
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             2            2        1.000000            12
# 1             2            0        0.000000             4
# 2             2            2        1.000000            12
# 3             3            2        0.666667            12
# 4             3            1        0.333333             8
# ...         ...          ...             ...           ...
# 8657          4            2        0.500000            26
# 8658          4            2        0.500000            33
# 8659          4            2        0.500000            40
# 8660          4            2        0.500000            40
# 8661          4            2        0.500000            14
#
# [8662 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 8662

# %%
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           463        0       3                     1        1          4
# 1           471        2       0                     2        1          4
# 2           524        0       3                     3        1          4
# 3          1030        1       3                     1        1          4
# 4          1139        2       4                     2        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8657    3250234        1       3                     5        3          2
# 8658    3250241        1       3                     5        4          2
# 8659    3250248        1       3                     5        5          3
# 8660    3250249        1       3                     1        1          4
# 8661    3250740        4       2                     7        1          4
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       0           0      21           5             4
# 1        3   9      21           5      18           2             4
# 2        3   9      18           2      21           5             4
# 3        3   9       0           0      25           9            10
# 4        3   9      20           4      18           2            11
# ...    ...  ..     ...         ...     ...         ...           ...
# 8657     3   9       0           0      29          13         10014
# 8658     3   9       0           0      29          13         10014
# 8659     3   9       0           0      29          13         10014
# 8660     3  10       0           0      29          13         10015
# 8661     3   9      23           7       0           0         10018
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             2            2        1.000000            12
# 1             2            0        0.000000             4
# 2             2            2        1.000000            12
# 3             3            2        0.666667            12
# 4             3            1        0.333333             8
# ...         ...          ...             ...           ...
# 8657          4            2        0.500000            26
# 8658          4            2        0.500000            33
# 8659          4            2        0.500000            40
# 8660          4            2        0.500000            40
# 8661          4            2        0.500000            14
#
# [8662 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         463        0       3                     1        1          4
# 1         471        2       0                     2        1          4
# 2         524        0       3                     3        1          4
# 3        1030        1       3                     1        1          4
# 4        1139        2       4                     2        1          4
# 5        1457        1       3                     1        1          4
# 6        1567        0       3                     1        1          4
# 7        1575        2       0                     2        1          4
# 8        1628        0       3                     3        1          4
# 9        1788        2       4                     2        1          4
# 10       2715        1       3                     1        1          4
# 11       3507        1       3                     1        1          4
# 12       4099        1       3                     1        1          4
# 13       4331        1       3                     1        1          4
# 14       4434        1       3                     1        1          4
# 15       5168        1       3                     1        1          4
# 16       5358        1       3                     1        1          4
# 17       5568        1       3                     1        1          4
# 18       6460        2       4                     2        1          4
# 19       6835        1       3                     1        1          4
# 20       7100        1       3                     1        1          4
# 21       7332        2       4                     2        1          4
# 22       7621        1       3                     1        1          4
# 23       8599        1       3                     5        1          1
# 24       8606        1       3                     5        2          2
# 25       8613        1       3                     5        3          2
# 26       8620        1       3                     5        4          2
# 27       8627        1       3                     5        5          3
# 28       8628        1       3                     1        1          4
# 29       9916        2       4                     2        1          4
# 30      10009        2       4                     2        1          4
# 31      10141        0       3                     1        1          4
# 32      10149        2       0                     2        1          4
# 33      10206        0       3                     3        1          4
# 34      10420        4       2                     7        1          4
# 35      10618        4       2                     7        1          4
# 36      10792        1       3                     1        1          4
# 37      12373        2       4                     6        1          1
# 38      12380        2       4                     6        2          2
# 39      12387        2       4                     6        3          2
# 40      12394        2       4                     6        4          2
# 41      12401        2       4                     6        5          3
# 42      12402        2       4                     2        1          4
# 43      12806        0       3                     1        1          4
# 44      12814        2       0                     2        1          4
# 45      12866        0       3                     3        1          4
# 46      13213        2       4                     6        1          1
# 47      13220        2       4                     6        2          2
# 48      13227        2       4                     6        3          2
# 49      13234        2       4                     6        4          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       0           0  ...                 1                   1
# 1      3   9      21           5  ...                 1                   1
# 2      3   9      18           2  ...                 1                   1
# 3      3   9       0           0  ...                 1                   1
# 4      3   9      20           4  ...                 1                   1
# 5      3   9       0           0  ...                 1                   1
# 6      3   9       0           0  ...                 1                   1
# 7      3  10      21           5  ...                 1                   1
# 8      3   9      18           2  ...                 1                   1
# 9      3   9      20           4  ...                 1                   1
# 10     3   9       0           0  ...                 1                   1
# 11     3   9       0           0  ...                 1                   1
# 12     3   9       0           0  ...                 1                   1
# 13     3   9       0           0  ...                 1                   1
# 14     3   9       0           0  ...                 1                   1
# 15     3   9       0           0  ...                 1                   1
# 16     3   9       0           0  ...                 1                   1
# 17     3   9       0           0  ...                 1                   1
# 18     3   9      20           4  ...                 1                   1
# 19     3   9       0           0  ...                 1                   1
# 20     3   9       0           0  ...                 1                   1
# 21     3   9      20           4  ...                 1                   1
# 22     3   9       0           0  ...                 1                   1
# 23     3   9       0           0  ...                 1                   1
# 24     3   9       0           0  ...                 1                   1
# 25     3   9       0           0  ...                 1                   1
# 26     3   9       0           0  ...                 1                   1
# 27     3   9       0           0  ...                 1                   1
# 28     3  10       0           0  ...                 1                   1
# 29     3   9      20           4  ...                 1                   1
# 30     3   9      20           4  ...                 1                   1
# 31     3   9       0           0  ...                 1                   1
# 32     3  11      21           5  ...                 1                   1
# 33     3   9      18           2  ...                 1                   1
# 34     3   9      22           6  ...                 1                   1
# 35     3   9      23           7  ...                 1                   1
# 36     3   9       0           0  ...                 1                   1
# 37     3   9      20           4  ...                 1                   1
# 38     3   9      20           4  ...                 1                   1
# 39     3   9      20           4  ...                 1                   1
# 40     3   9      20           4  ...                 1                   1
# 41     3   9      20           4  ...                 1                   1
# 42     3  10      20           4  ...                 1                   1
# 43     3   9       0           0  ...                 1                   1
# 44     3  12      21           5  ...                 1                   1
# 45     3   9      18           2  ...                 1                   1
# 46     3   9      20           4  ...                 1                   1
# 47     3   9      20           4  ...                 1                   1
# 48     3   9      20           4  ...                 1                   1
# 49     3   9      20           4  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                  1           0                           1           4
# 1                  1           0                           2           8
# 2                  1           0                           3          12
# 3                  1           3                           1           4
# 4                  1           8                           2           8
# 5                  1           3                           1           4
# 6                  1           0                           1           4
# 7                  1           0                           2           8
# 8                  1           0                           3          12
# 9                  1           8                           2           8
# 10                 1           3                           1           4
# 11                 1           3                           1           4
# 12                 1           3                           1           4
# 13                 1           3                           1           4
# 14                 1           3                           1           4
# 15                 1           3                           1           4
# 16                 1           3                           1           4
# 17                 1           3                           1           4
# 18                 1           8                           2           8
# 19                 1           3                           1           4
# 20                 1           3                           1           4
# 21                 1           8                           2           8
# 22                 1           3                           1           4
# 23                 1           3                           5           5
# 24                 1           3                          10          20
# 25                 1           3                          15          30
# 26                 1           3                          20          40
# 27                 1           3                          25          75
# 28                 1           3                           1           4
# 29                 1           8                           2           8
# 30                 1           8                           2           8
# 31                 1           0                           1           4
# 32                 1           0                           2           8
# 33                 1           0                           3          12
# 34                 1           8                           7          28
# 35                 1           8                           7          28
# 36                 1           3                           1           4
# 37                 1           8                           6           6
# 38                 1           8                          12          24
# 39                 1           8                          18          36
# 40                 1           8                          24          48
# 41                 1           8                          30          90
# 42                 1           8                           2           8
# 43                 1           0                           1           4
# 44                 1           0                           2           8
# 45                 1           0                           3          12
# 46                 1           8                           6           6
# 47                 1           8                          12          24
# 48                 1           8                          18          36
# 49                 1           8                          24          48
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                16                           3             27
# 1                32                           6             27
# 2                48                           9             27
# 3                40                           3             27
# 4                88                           6             27
# 5                56                           3             27
# 6                60                           3             27
# 7               120                           6             30
# 8               180                           9             27
# 9               136                           6             27
# 10              104                           3             27
# 11              124                           3             27
# 12              140                           3             27
# 13              148                           3             27
# 14              152                           3             27
# 15              176                           3             27
# 16              184                           3             27
# 17              192                           3             27
# 18              448                           6             27
# 19              236                           3             27
# 20              244                           3             27
# 21              504                           6             27
# 22              260                           3             27
# 23              370                          15             27
# 24             1480                          15             27
# 25             2220                          15             27
# 26             2960                          15             27
# 27             5550                          15             27
# 28              300                           3             30
# 29              704                           6             27
# 30              712                           6             27
# 31              360                           3             27
# 32              720                           6             33
# 33             1080                           9             27
# 34             2576                          21             27
# 35             2632                          21             27
# 36              388                           3             27
# 37              684                          18             27
# 38             2736                          18             27
# 39             4104                          18             27
# 40             5472                          18             27
# 41            10260                          18             27
# 42              920                           6             30
# 43              476                           3             27
# 44              952                           6             36
# 45             1428                           9             27
# 46              738                          18             27
# 47             2952                          18             27
# 48             4428                          18             27
# 49             5904                          18             27
#
#     vnet_vc_cc_index
# 0                  9
# 1                 18
# 2                 27
# 3                  9
# 4                 18
# 5                  9
# 6                  9
# 7                 18
# 8                 27
# 9                 18
# 10                 9
# 11                 9
# 12                 9
# 13                 9
# 14                 9
# 15                 9
# 16                 9
# 17                 9
# 18                18
# 19                 9
# 20                 9
# 21                18
# 22                 9
# 23                45
# 24                45
# 25                45
# 26                45
# 27                45
# 28                 9
# 29                18
# 30                18
# 31                 9
# 32                18
# 33                27
# 34                63
# 35                63
# 36                 9
# 37                54
# 38                54
# 39                54
# 40                54
# 41                54
# 42                18
# 43                 9
# 44                18
# 45                27
# 46                54
# 47                54
# 48                54
# 49                54
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           463        0       3                     1        1          4
# 1           471        2       0                     2        1          4
# 2           524        0       3                     3        1          4
# 3          1030        1       3                     1        1          4
# 4          1139        2       4                     2        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8657    3250234        1       3                     5        3          2
# 8658    3250241        1       3                     5        4          2
# 8659    3250248        1       3                     5        5          3
# 8660    3250249        1       3                     1        1          4
# 8661    3250740        4       2                     7        1          4
#
#       vnet  vc  src_ni  src_router  ...  packet_count_index  packet_max_index  \
# 0        3   9       0           0  ...                   1                 1
# 1        3   9      21           5  ...                   1                 1
# 2        3   9      18           2  ...                   1                 1
# 3        3   9       0           0  ...                   1                 1
# 4        3   9      20           4  ...                   1                 1
# ...    ...  ..     ...         ...  ...                 ...               ...
# 8657     3   9       0           0  ...                   1                 1
# 8658     3   9       0           0  ...                   1                 1
# 8659     3   9       0           0  ...                   1                 1
# 8660     3  10       0           0  ...                   1                 1
# 8661     3   9      23           7  ...                   1                 1
#
#       port_index  cache_coherence_flit_index  flit_index  traversal_index  \
# 0              0                           1           4               16
# 1              0                           2           8               32
# 2              0                           3          12               48
# 3              3                           1           4               40
# 4              8                           2           8               88
# ...          ...                         ...         ...              ...
# 8657           3                          15          30           300420
# 8658           3                          20          40           400560
# 8659           3                          25          75           751050
# 8660           3                           1           4            40060
# 8661           8                           7          28           280504
#
#       cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index  target
# 0                              3             27                 9       1
# 1                              6             27                18       1
# 2                              9             27                27       1
# 3                              3             27                 9       1
# 4                              6             27                18       1
# ...                          ...            ...               ...     ...
# 8657                          15             27                45       1
# 8658                          15             27                45       1
# 8659                          15             27                45       1
# 8660                           3             30                 9       1
# 8661                          21             27                63       1
#
# [8662 rows x 30 columns]

# %%
df.to_csv('wat-r5-good.csv',index=False)
