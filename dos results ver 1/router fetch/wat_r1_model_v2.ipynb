# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r1_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
df1 = pd.read_csv('2-fft-normal-n-0-3-data-r1-good.csv')
df2 = pd.read_csv('2-fft-normal-n-0-5-data-r1-good.csv')
df3 = pd.read_csv('2-fft-normal-n-0-10-data-r1-good.csv')
df4 = pd.read_csv('2-fft-normal-n-0-12-data-r1-good.csv')
df5 = pd.read_csv('2-fft-normal-n-0-15-data-r1-good.csv')

# %%
df1m = pd.read_csv('2-fft-normal-n-0-3-data-r1-mal.csv')
df2m = pd.read_csv('2-fft-normal-n-0-5-data-r1-mal.csv')
df3m = pd.read_csv('2-fft-normal-n-0-10-data-r1-mal.csv')
df4m = pd.read_csv('2-fft-normal-n-0-12-data-r1-mal.csv')
df5m = pd.read_csv('2-fft-normal-n-0-15-data-r1-mal.csv')

# %% [markdown]
# Characteristics of Dataset

# %%
df1
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             11        2       4                     1        1          4
# 1             84        4       2                     1        1          4
# 2            216        2       4                     1        1          4
# 3            342        2       4                     1        1          4
# 4            388        1       2                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 56912    3268816        4       2                     6        2          2
# 56913    3268823        4       2                     6        3          2
# 56914    3268830        4       2                     6        4          2
# 56915    3268837        4       2                     6        5          3
# 56916    3268838        4       2                     2        1          4
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       0           0  ...                   2
# 1         3   9       3           3  ...                   2
# 2         3   9       0           0  ...                   1
# 3         3   9       0           0  ...                   1
# 4         3   9       3           3  ...                   1
# ...     ...  ..     ...         ...  ...                 ...
# 56912     3   9      18           2  ...                   5
# 56913     3   9      18           2  ...                   8
# 56914     3   9      18           2  ...                   9
# 56915     3   9      18           2  ...                   8
# 56916     3  10      18           2  ...                   5
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     4           8                           1           4
# 1                     4           8                           1           4
# 2                     1           8                           1           4
# 3                     1           8                           1           4
# 4                     1           2                           1           4
# ...                 ...         ...                         ...         ...
# 56912                25           8                          12          24
# 56913                40           8                          18          36
# 56914                45           8                          24          48
# 56915                40           8                          30          90
# 56916                25           8                           2           8
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    0                           3             27
# 1                    8                           3             27
# 2                   20                           3             27
# 3                   28                           3             27
# 4                   32                           3             27
# ...                ...                         ...            ...
# 56912           480984                          18             27
# 56913           721476                          18             27
# 56914           961968                          18             27
# 56915          1803690                          18             27
# 56916           160336                           6             30
#
#        vnet_vc_cc_index  target
# 0                     9       1
# 1                     9       1
# 2                     9       1
# 3                     9       1
# 4                     9       1
# ...                 ...     ...
# 56912                54       1
# 56913                54       1
# 56914                54       1
# 56915                54       1
# 56916                18       1
#
# [56917 rows x 30 columns]

# %%
df1m
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             11        2       4                     1        1          4
# 2             84        0       1                     4        1          1
# 3             84        4       2                     1        1          4
# 4             85        0       1                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 89536    2490410        0       4                     5        3          2
# 89537    2490417        0       4                     5        4          2
# 89538    2490424        0       4                     5        5          3
# 89539    2490425        0       4                     1        1          4
# 89540    2490432        4       0                     6        1          1
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   8
# 1         3   9       0           0  ...                  14
# 2         5  17      23           7  ...                  18
# 3         3   9       3           3  ...                  20
# 4         5  17      23           7  ...                  20
# ...     ...  ..     ...         ...  ...                 ...
# 89536     3   9       0           0  ...                  15
# 89537     3   9       0           0  ...                  16
# 89538     3   9       0           0  ...                  15
# 89539     3  10       0           0  ...                  12
# 89540     3  10      17           1  ...                   7
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    64           0                           1           4
# 1                   112           8                           1           4
# 2                   144           0                           4           4
# 3                   160           8                           1           4
# 4                   160           0                           8          16
# ...                 ...         ...                         ...         ...
# 89536               105           0                          15          30
# 89537               112           0                          20          40
# 89538               105           0                          25          75
# 89539                84           0                           1           4
# 89540                49           0                           6           6
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    0                           3             27
# 2                    4                          20             85
# 3                   12                           3             27
# 4                   16                          20             85
# ...                ...                         ...            ...
# 89536           607980                          15             27
# 89537           810640                          15             27
# 89538          1519950                          15             27
# 89539            81068                           3             30
# 89540           121596                          18             30
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                     9       0
# 2                   100       0
# 3                     9       0
# 4                   100       0
# ...                 ...     ...
# 89536                45       0
# 89537                45       0
# 89538                45       0
# 89539                 9       0
# 89540                54       0
#
# [89541 rows x 30 columns]

# %%
df1gm = df1.append(df1m, ignore_index=True,sort=False)

# %%
df1gm.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df1gm = df1gm.sort_values('timestamp')
df1gm.to_csv('fft-r1-df1gm.csv',index=False)

# %%
df = pd.read_csv("fft-r1-df1gm.csv")
df
# Out:
#         timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0               7        2       0                     1        1          4
# 1              11        2       4                     1        1          4
# 2              11        2       4                     1        1          4
# 3              84        4       2                     1        1          4
# 4              84        0       1                     4        1          1
# ...           ...      ...     ...                   ...      ...        ...
# 146453    3268816        4       2                     6        2          2
# 146454    3268823        4       2                     6        3          2
# 146455    3268830        4       2                     6        4          2
# 146456    3268837        4       2                     6        5          3
# 146457    3268838        4       2                     2        1          4
#
#         vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0          3   9       1           1  ...                   8
# 1          3   9       0           0  ...                  14
# 2          3   9       0           0  ...                   2
# 3          3   9       3           3  ...                   2
# 4          5  17      23           7  ...                  18
# ...      ...  ..     ...         ...  ...                 ...
# 146453     3   9      18           2  ...                   5
# 146454     3   9      18           2  ...                   8
# 146455     3   9      18           2  ...                   9
# 146456     3   9      18           2  ...                   8
# 146457     3  10      18           2  ...                   5
#
#         packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     64           0                           1           4
# 1                    112           8                           1           4
# 2                      4           8                           1           4
# 3                      4           8                           1           4
# 4                    144           0                           4           4
# ...                  ...         ...                         ...         ...
# 146453                25           8                          12          24
# 146454                40           8                          18          36
# 146455                45           8                          24          48
# 146456                40           8                          30          90
# 146457                25           8                           2           8
#
#         traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                     4                           3             27
# 1                     0                           3             27
# 2                     0                           3             27
# 3                     8                           3             27
# 4                     4                          20             85
# ...                 ...                         ...            ...
# 146453           480984                          18             27
# 146454           721476                          18             27
# 146455           961968                          18             27
# 146456          1803690                          18             27
# 146457           160336                           6             30
#
#         vnet_vc_cc_index  target
# 0                      9       0
# 1                      9       0
# 2                      9       1
# 3                      9       1
# 4                    100       0
# ...                  ...     ...
# 146453                54       1
# 146454                54       1
# 146455                54       1
# 146456                54       1
# 146457                18       1
#
# [146458 rows x 30 columns]

# %%
df.corr()
# Out:
#                             timestamp   outport    inport  \
# timestamp                    1.000000  0.029840  0.107025
# outport                      0.029840  1.000000 -0.132664
# inport                       0.107025 -0.132664  1.000000
# cache_coherence_type         0.016592  0.207682 -0.078479
# flit_id                      0.009556 -0.002812  0.014421
# flit_type                   -0.014531  0.004249 -0.021890
# vnet                        -0.093791 -0.496226 -0.229975
# vc                          -0.109495 -0.432913 -0.368822
# src_ni                      -0.104773  0.051049 -0.447236
# src_router                  -0.071617 -0.316993 -0.353110
# dst_ni                       0.115554  0.398419  0.294941
# dst_router                   0.111368  0.158332  0.247456
# traversal_id                 0.931720 -0.020164  0.003884
# hop_count                    0.088380  0.256329  0.316213
# current_hop                 -0.012229 -0.354105  0.154340
# hop_percentage              -0.039216 -0.585929  0.194719
# enqueue_time                 0.054168  0.116519  0.189693
# packet_count_decr           -0.088383 -0.065046 -0.050770
# packet_count_incr           -0.088361  0.068523 -0.166603
# max_packet_count            -0.119081  0.002342 -0.146455
# packet_count_index          -0.105814  0.029084 -0.105432
# packet_max_index            -0.096180  0.029332 -0.079098
# port_index                   0.081460  0.510095  0.658992
# cache_coherence_flit_index   0.016190  0.129254 -0.003756
# flit_index                   0.010659  0.097628 -0.014892
# traversal_index              0.485323  0.059859 -0.008131
# cache_coherence_vnet_index  -0.034322 -0.070042 -0.195019
# vnet_vc_index               -0.101481 -0.476178 -0.290458
# vnet_vc_cc_index            -0.074530 -0.323419 -0.253217
# target                       0.270047  0.181708  0.358546
#
#                             cache_coherence_type   flit_id  flit_type  \
# timestamp                               0.016592  0.009556  -0.014531
# outport                                 0.207682 -0.002812   0.004249
# inport                                 -0.078479  0.014421  -0.021890
# cache_coherence_type                    1.000000  0.325794  -0.495156
# flit_id                                 0.325794  1.000000  -0.011620
# flit_type                              -0.495156 -0.011620   1.000000
# vnet                                   -0.148916  0.104046  -0.158119
# vc                                     -0.204262  0.044485  -0.067604
# src_ni                                  0.191909 -0.037081   0.056338
# src_router                             -0.010202  0.006238  -0.009471
# dst_ni                                 -0.086781  0.049014  -0.074494
# dst_router                             -0.082146  0.036340  -0.055224
# traversal_id                            0.011487  0.015807  -0.024061
# hop_count                              -0.049691  0.042068  -0.063917
# current_hop                            -0.072235  0.021598  -0.032799
# hop_percentage                         -0.095623  0.000507  -0.000745
# enqueue_time                           -0.398152  0.489439   0.562637
# packet_count_decr                       0.065220 -0.005011  -0.131614
# packet_count_incr                      -0.046305  0.054545   0.169408
# max_packet_count                        0.012745  0.033373   0.025463
# packet_count_index                      0.026875  0.048142  -0.010168
# packet_max_index                        0.025563  0.029972  -0.008426
# port_index                              0.055418  0.008649  -0.013125
# cache_coherence_flit_index              0.525600  0.962205  -0.101472
# flit_index                              0.422901  0.924849   0.152598
# traversal_index                         0.312439  0.701214   0.112343
# cache_coherence_vnet_index              0.851346  0.358300  -0.544553
# vnet_vc_index                          -0.173743  0.080640  -0.122550
# vnet_vc_cc_index                        0.457456  0.286229  -0.435011
# target                                  0.029924 -0.013865   0.021088
#
#                                 vnet        vc    src_ni  src_router  ...  \
# timestamp                  -0.093791 -0.109495 -0.104773   -0.071617  ...
# outport                    -0.496226 -0.432913  0.051049   -0.316993  ...
# inport                     -0.229975 -0.368822 -0.447236   -0.353110  ...
# cache_coherence_type       -0.148916 -0.204262  0.191909   -0.010202  ...
# flit_id                     0.104046  0.044485 -0.037081    0.006238  ...
# flit_type                  -0.158119 -0.067604  0.056338   -0.009471  ...
# vnet                        1.000000  0.949144  0.560853    0.703425  ...
# vc                          0.949144  1.000000  0.562388    0.646036  ...
# src_ni                      0.560853  0.562388  1.000000    0.700663  ...
# src_router                  0.703425  0.646036  0.700663    1.000000  ...
# dst_ni                     -0.742893 -0.730156 -0.684191   -0.680228  ...
# dst_router                 -0.356939 -0.355419 -0.501310   -0.401449  ...
# traversal_id               -0.005898 -0.011838 -0.053991    0.004335  ...
# hop_count                  -0.054122 -0.134884 -0.091135    0.124545  ...
# current_hop                 0.589835  0.447725  0.474043    0.831937  ...
# hop_percentage              0.587619  0.455830  0.388815    0.640923  ...
# enqueue_time               -0.147949 -0.142669 -0.141712   -0.029010  ...
# packet_count_decr           0.064902  0.063043  0.029135    0.041576  ...
# packet_count_incr           0.058449  0.111464  0.136893    0.026261  ...
# max_packet_count            0.083108  0.117574  0.111862    0.045706  ...
# packet_count_index          0.043241  0.070278  0.077140    0.009786  ...
# packet_max_index            0.019497  0.043053  0.057383   -0.003758  ...
# port_index                 -0.365664 -0.460334 -0.202777   -0.287033  ...
# cache_coherence_flit_index -0.030990 -0.087824  0.001482   -0.056201  ...
# flit_index                 -0.039909 -0.076852  0.032669   -0.029114  ...
# traversal_index            -0.034003 -0.066738 -0.007730   -0.021754  ...
# cache_coherence_vnet_index  0.391977  0.313506  0.476086    0.363690  ...
# vnet_vc_index               0.991433  0.982136  0.568518    0.688432  ...
# vnet_vc_cc_index            0.811195  0.732732  0.617841    0.626529  ...
# target                     -0.302356 -0.339539 -0.182012   -0.246643  ...
#
#                             packet_count_index  packet_max_index  port_index  \
# timestamp                            -0.105814         -0.096180    0.081460
# outport                               0.029084          0.029332    0.510095
# inport                               -0.105432         -0.079098    0.658992
# cache_coherence_type                  0.026875          0.025563    0.055418
# flit_id                               0.048142          0.029972    0.008649
# flit_type                            -0.010168         -0.008426   -0.013125
# vnet                                  0.043241          0.019497   -0.365664
# vc                                    0.070278          0.043053   -0.460334
# src_ni                                0.077140          0.057383   -0.202777
# src_router                            0.009786         -0.003758   -0.287033
# dst_ni                               -0.062224         -0.045834    0.389462
# dst_router                           -0.093429         -0.082740    0.277818
# traversal_id                         -0.023606         -0.029938   -0.008965
# hop_count                            -0.106335         -0.096031    0.553527
# current_hop                          -0.046753         -0.045748    0.094675
# hop_percentage                       -0.016787         -0.015371   -0.146238
# enqueue_time                          0.014798          0.009908    0.231524
# packet_count_decr                     0.635026          0.571059   -0.081610
# packet_count_incr                     0.635026          0.571059   -0.082229
# max_packet_count                      0.855699          0.769504   -0.110387
# packet_count_index                    1.000000          0.962768   -0.068802
# packet_max_index                      0.962768          1.000000   -0.049194
# port_index                           -0.068802         -0.049194    1.000000
# cache_coherence_flit_index            0.052557          0.036762    0.062417
# flit_index                            0.041677          0.028693    0.039682
# traversal_index                       0.018970          0.004806    0.023741
# cache_coherence_vnet_index            0.047944          0.034126   -0.142434
# vnet_vc_index                         0.054999          0.029513   -0.409520
# vnet_vc_cc_index                      0.054778          0.032650   -0.296054
# target                               -0.291840         -0.245844    0.337653
#
#                             cache_coherence_flit_index  flit_index  \
# timestamp                                     0.016190    0.010659
# outport                                       0.129254    0.097628
# inport                                       -0.003756   -0.014892
# cache_coherence_type                          0.525600    0.422901
# flit_id                                       0.962205    0.924849
# flit_type                                    -0.101472    0.152598
# vnet                                         -0.030990   -0.039909
# vc                                           -0.087824   -0.076852
# src_ni                                        0.001482    0.032669
# src_router                                   -0.056201   -0.029114
# dst_ni                                        0.095279    0.032034
# dst_router                                    0.034454    0.003134
# traversal_id                                  0.011381    0.007455
# hop_count                                     0.029760    0.006250
# current_hop                                  -0.054429   -0.038573
# hop_percentage                               -0.084764   -0.057267
# enqueue_time                                  0.395349    0.486016
# packet_count_decr                             0.007559   -0.024772
# packet_count_incr                             0.039539    0.076149
# max_packet_count                              0.031732    0.034615
# packet_count_index                            0.052557    0.041677
# packet_max_index                              0.036762    0.028693
# port_index                                    0.062417    0.039682
# cache_coherence_flit_index                    1.000000    0.942889
# flit_index                                    0.942889    1.000000
# traversal_index                               0.707917    0.751172
# cache_coherence_vnet_index                    0.472550    0.372273
# vnet_vc_index                                -0.054956   -0.055735
# vnet_vc_cc_index                              0.282956    0.214202
# target                                        0.024743    0.017057
#
#                             traversal_index  cache_coherence_vnet_index  \
# timestamp                          0.485323                   -0.034322
# outport                            0.059859                   -0.070042
# inport                            -0.008131                   -0.195019
# cache_coherence_type               0.312439                    0.851346
# flit_id                            0.701214                    0.358300
# flit_type                          0.112343                   -0.544553
# vnet                              -0.034003                    0.391977
# vc                                -0.066738                    0.313506
# src_ni                            -0.007730                    0.476086
# src_router                        -0.021754                    0.363690
# dst_ni                             0.048152                   -0.474856
# dst_router                         0.047013                   -0.265788
# traversal_id                       0.515750                    0.007558
# hop_count                          0.033385                   -0.074943
# current_hop                       -0.031032                    0.245716
# hop_percentage                    -0.058374                    0.222781
# enqueue_time                       0.369559                   -0.448910
# packet_count_decr                 -0.022477                    0.095110
# packet_count_incr                  0.055583                   -0.012071
# max_packet_count                   0.022306                    0.055947
# packet_count_index                 0.018970                    0.047944
# packet_max_index                   0.004806                    0.034126
# port_index                         0.023741                   -0.142434
# cache_coherence_flit_index         0.707917                    0.472550
# flit_index                         0.751172                    0.372273
# traversal_index                    1.000000                    0.272637
# cache_coherence_vnet_index         0.272637                    1.000000
# vnet_vc_index                     -0.048010                    0.364335
# vnet_vc_cc_index                   0.154189                    0.855949
# target                            -0.005574                   -0.132566
#
#                             vnet_vc_index  vnet_vc_cc_index    target
# timestamp                       -0.101481         -0.074530  0.270047
# outport                         -0.476178         -0.323419  0.181708
# inport                          -0.290458         -0.253217  0.358546
# cache_coherence_type            -0.173743          0.457456  0.029924
# flit_id                          0.080640          0.286229 -0.013865
# flit_type                       -0.122550         -0.435011  0.021088
# vnet                             0.991433          0.811195 -0.302356
# vc                               0.982136          0.732732 -0.339539
# src_ni                           0.568518          0.617841 -0.182012
# src_router                       0.688432          0.626529 -0.246643
# dst_ni                          -0.746918         -0.719372  0.262518
# dst_router                      -0.360781         -0.369559  0.130114
# traversal_id                    -0.008436          0.001489 -0.033987
# hop_count                       -0.088304         -0.078056  0.151037
# current_hop                      0.538272          0.487697 -0.029668
# hop_percentage                   0.540309          0.471873 -0.049467
# enqueue_time                    -0.147613         -0.368500  0.122710
# packet_count_decr                0.064944          0.096933 -0.273348
# packet_count_incr                0.081175          0.025178 -0.273348
# max_packet_count                 0.098448          0.082272 -0.368336
# packet_count_index               0.054999          0.054778 -0.291840
# packet_max_index                 0.029513          0.032650 -0.245844
# port_index                      -0.409520         -0.296054  0.337653
# cache_coherence_flit_index      -0.054956          0.282956  0.024743
# flit_index                      -0.055735          0.214202  0.017057
# traversal_index                 -0.048010          0.154189 -0.005574
# cache_coherence_vnet_index       0.364335          0.855949 -0.132566
# vnet_vc_index                    1.000000          0.788809 -0.321570
# vnet_vc_cc_index                 0.788809          1.000000 -0.254200
# target                          -0.321570         -0.254200  1.000000
#
# [30 rows x 30 columns]

# %%
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target','timestamp','src_ni','src_router'])
train_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  vc  \
# 0             2       0                     1        1          4     3   9
# 1             2       4                     1        1          4     3   9
# 2             2       4                     1        1          4     3   9
# 3             4       2                     1        1          4     3   9
# 4             0       1                     4        1          1     5  17
# ...         ...     ...                   ...      ...        ...   ...  ..
# 146453        4       2                     6        2          2     3   9
# 146454        4       2                     6        3          2     3   9
# 146455        4       2                     6        4          2     3   9
# 146456        4       2                     6        5          3     3   9
# 146457        4       2                     2        1          4     3  10
#
#         dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0           23           7             1  ...                 8
# 1           23           7             0  ...                 8
# 2           23           7             0  ...                 2
# 3           24           8             2  ...                 2
# 4            1           1             1  ...                 8
# ...        ...         ...           ...  ...               ...
# 146453      20           4         20041  ...                 5
# 146454      20           4         20041  ...                 5
# 146455      20           4         20041  ...                 5
# 146456      20           4         20041  ...                 5
# 146457      20           4         20042  ...                 5
#
#         packet_count_index  packet_max_index  port_index  \
# 0                        8                64           0
# 1                       14               112           8
# 2                        2                 4           8
# 3                        2                 4           8
# 4                       18               144           0
# ...                    ...               ...         ...
# 146453                   5                25           8
# 146454                   8                40           8
# 146455                   9                45           8
# 146456                   8                40           8
# 146457                   5                25           8
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                                1           4                4
# 1                                1           4                0
# 2                                1           4                0
# 3                                1           4                8
# 4                                4           4                4
# ...                            ...         ...              ...
# 146453                          12          24           480984
# 146454                          18          36           721476
# 146455                          24          48           961968
# 146456                          30          90          1803690
# 146457                           2           8           160336
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                                3             27                 9
# 1                                3             27                 9
# 2                                3             27                 9
# 3                                3             27                 9
# 4                               20             85               100
# ...                            ...            ...               ...
# 146453                          18             27                54
# 146454                          18             27                54
# 146455                          18             27                54
# 146456                          18             27                54
# 146457                           6             30                18
#
# [146458 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  \
# 0           0.5    0.00              0.000000     0.00   1.000000   0.0
# 1           0.5    1.00              0.000000     0.00   1.000000   0.0
# 2           0.5    1.00              0.000000     0.00   1.000000   0.0
# 3           1.0    0.50              0.000000     0.00   1.000000   0.0
# 4           0.0    0.25              0.500000     0.00   0.000000   1.0
# ...         ...     ...                   ...      ...        ...   ...
# 146453      1.0    0.50              0.833333     0.25   0.333333   0.0
# 146454      1.0    0.50              0.833333     0.50   0.333333   0.0
# 146455      1.0    0.50              0.833333     0.75   0.333333   0.0
# 146456      1.0    0.50              0.833333     1.00   0.666667   0.0
# 146457      1.0    0.50              0.166667     0.00   1.000000   0.0
#
#            vc    dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0       0.000  0.741935    0.466667      0.000049  ...          0.205882
# 1       0.000  0.741935    0.466667      0.000000  ...          0.205882
# 2       0.000  0.741935    0.466667      0.000000  ...          0.029412
# 3       0.000  0.774194    0.533333      0.000099  ...          0.029412
# 4       1.000  0.032258    0.066667      0.000049  ...          0.205882
# ...       ...       ...         ...           ...  ...               ...
# 146453  0.000  0.645161    0.266667      0.988849  ...          0.117647
# 146454  0.000  0.645161    0.266667      0.988849  ...          0.117647
# 146455  0.000  0.645161    0.266667      0.988849  ...          0.117647
# 146456  0.000  0.645161    0.266667      0.988849  ...          0.117647
# 146457  0.125  0.645161    0.266667      0.988898  ...          0.117647
#
#         packet_count_index  packet_max_index  port_index  \
# 0                 0.021672          0.005556         0.0
# 1                 0.040248          0.009789         1.0
# 2                 0.003096          0.000265         1.0
# 3                 0.003096          0.000265         1.0
# 4                 0.052632          0.012611         0.0
# ...                    ...               ...         ...
# 146453            0.012384          0.002117         1.0
# 146454            0.021672          0.003439         1.0
# 146455            0.024768          0.003880         1.0
# 146456            0.021672          0.003439         1.0
# 146457            0.012384          0.002117         1.0
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                         0.000000    0.000000         0.000002
# 1                         0.000000    0.000000         0.000000
# 2                         0.000000    0.000000         0.000000
# 3                         0.000000    0.000000         0.000004
# 4                         0.103448    0.000000         0.000002
# ...                            ...         ...              ...
# 146453                    0.379310    0.232558         0.263758
# 146454                    0.586207    0.372093         0.395637
# 146455                    0.793103    0.511628         0.527516
# 146456                    1.000000    1.000000         0.989093
# 146457                    0.034483    0.046512         0.087924
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                         0.000000       0.000000          0.000000
# 1                         0.000000       0.000000          0.000000
# 2                         0.000000       0.000000          0.000000
# 3                         0.000000       0.000000          0.000000
# 4                         0.944444       1.000000          1.000000
# ...                            ...            ...               ...
# 146453                    0.833333       0.000000          0.494505
# 146454                    0.833333       0.000000          0.494505
# 146455                    0.833333       0.000000          0.494505
# 146456                    0.833333       0.000000          0.494505
# 146457                    0.166667       0.051724          0.098901
#
# [146458 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (164, 26)

# %%
corr_df = pd.concat([train_X, df[['target']]], axis = 1)
corr_df.corr()
# Out:
#                              outport    inport  cache_coherence_type  \
# outport                     1.000000 -0.132664              0.207682
# inport                     -0.132664  1.000000             -0.078479
# cache_coherence_type        0.207682 -0.078479              1.000000
# flit_id                    -0.002812  0.014421              0.325794
# flit_type                   0.004249 -0.021890             -0.495156
# vnet                       -0.496226 -0.229975             -0.148916
# vc                         -0.432913 -0.368822             -0.204262
# dst_ni                      0.398419  0.294941             -0.086781
# dst_router                  0.158332  0.247456             -0.082146
# traversal_id               -0.020164  0.003884              0.011487
# hop_count                   0.256329  0.316213             -0.049691
# current_hop                -0.354105  0.154340             -0.072235
# hop_percentage             -0.585929  0.194719             -0.095623
# enqueue_time                0.116519  0.189693             -0.398152
# packet_count_decr          -0.065046 -0.050770              0.065220
# packet_count_incr           0.068523 -0.166603             -0.046305
# max_packet_count            0.002342 -0.146455              0.012745
# packet_count_index          0.029084 -0.105432              0.026875
# packet_max_index            0.029332 -0.079098              0.025563
# port_index                  0.510095  0.658992              0.055418
# cache_coherence_flit_index  0.129254 -0.003756              0.525600
# flit_index                  0.097628 -0.014892              0.422901
# traversal_index             0.059859 -0.008131              0.312439
# cache_coherence_vnet_index -0.070042 -0.195019              0.851346
# vnet_vc_index              -0.476178 -0.290458             -0.173743
# vnet_vc_cc_index           -0.323419 -0.253217              0.457456
# target                      0.181708  0.358546              0.029924
#
#                              flit_id  flit_type      vnet        vc    dst_ni  \
# outport                    -0.002812   0.004249 -0.496226 -0.432913  0.398419
# inport                      0.014421  -0.021890 -0.229975 -0.368822  0.294941
# cache_coherence_type        0.325794  -0.495156 -0.148916 -0.204262 -0.086781
# flit_id                     1.000000  -0.011620  0.104046  0.044485  0.049014
# flit_type                  -0.011620   1.000000 -0.158119 -0.067604 -0.074494
# vnet                        0.104046  -0.158119  1.000000  0.949144 -0.742893
# vc                          0.044485  -0.067604  0.949144  1.000000 -0.730156
# dst_ni                      0.049014  -0.074494 -0.742893 -0.730156  1.000000
# dst_router                  0.036340  -0.055224 -0.356939 -0.355419  0.781493
# traversal_id                0.015807  -0.024061 -0.005898 -0.011838  0.043533
# hop_count                   0.042068  -0.063917 -0.054122 -0.134884  0.427963
# current_hop                 0.021598  -0.032799  0.589835  0.447725 -0.517720
# hop_percentage              0.000507  -0.000745  0.587619  0.455830 -0.644214
# enqueue_time                0.489439   0.562637 -0.147949 -0.142669  0.234756
# packet_count_decr          -0.005011  -0.131614  0.064902  0.063043 -0.078146
# packet_count_incr           0.054545   0.169408  0.058449  0.111464 -0.099053
# max_packet_count            0.033373   0.025463  0.083108  0.117574 -0.119388
# packet_count_index          0.048142  -0.010168  0.043241  0.070278 -0.062224
# packet_max_index            0.029972  -0.008426  0.019497  0.043053 -0.045834
# port_index                  0.008649  -0.013125 -0.365664 -0.460334  0.389462
# cache_coherence_flit_index  0.962205  -0.101472 -0.030990 -0.087824  0.095279
# flit_index                  0.924849   0.152598 -0.039909 -0.076852  0.032034
# traversal_index             0.701214   0.112343 -0.034003 -0.066738  0.048152
# cache_coherence_vnet_index  0.358300  -0.544553  0.391977  0.313506 -0.474856
# vnet_vc_index               0.080640  -0.122550  0.991433  0.982136 -0.746918
# vnet_vc_cc_index            0.286229  -0.435011  0.811195  0.732732 -0.719372
# target                     -0.013865   0.021088 -0.302356 -0.339539  0.262518
#
#                             dst_router  traversal_id  ...  packet_count_index  \
# outport                       0.158332     -0.020164  ...            0.029084
# inport                        0.247456      0.003884  ...           -0.105432
# cache_coherence_type         -0.082146      0.011487  ...            0.026875
# flit_id                       0.036340      0.015807  ...            0.048142
# flit_type                    -0.055224     -0.024061  ...           -0.010168
# vnet                         -0.356939     -0.005898  ...            0.043241
# vc                           -0.355419     -0.011838  ...            0.070278
# dst_ni                        0.781493      0.043533  ...           -0.062224
# dst_router                    1.000000      0.083597  ...           -0.093429
# traversal_id                  0.083597      1.000000  ...           -0.023606
# hop_count                     0.702823      0.057484  ...           -0.106335
# current_hop                  -0.290468     -0.000784  ...           -0.046753
# hop_percentage               -0.530694     -0.029498  ...           -0.016787
# enqueue_time                  0.111436      0.022501  ...            0.014798
# packet_count_decr            -0.115178     -0.007864  ...            0.635026
# packet_count_incr            -0.069318     -0.007770  ...            0.635026
# max_packet_count             -0.124304     -0.010534  ...            0.855699
# packet_count_index           -0.093429     -0.023606  ...            1.000000
# packet_max_index             -0.082740     -0.029938  ...            0.962768
# port_index                    0.277818     -0.008965  ...           -0.068802
# cache_coherence_flit_index    0.034454      0.011381  ...            0.052557
# flit_index                    0.003134      0.007455  ...            0.041677
# traversal_index               0.047013      0.515750  ...            0.018970
# cache_coherence_vnet_index   -0.265788      0.007558  ...            0.047944
# vnet_vc_index                -0.360781     -0.008436  ...            0.054999
# vnet_vc_cc_index             -0.369559      0.001489  ...            0.054778
# target                        0.130114     -0.033987  ...           -0.291840
#
#                             packet_max_index  port_index  \
# outport                             0.029332    0.510095
# inport                             -0.079098    0.658992
# cache_coherence_type                0.025563    0.055418
# flit_id                             0.029972    0.008649
# flit_type                          -0.008426   -0.013125
# vnet                                0.019497   -0.365664
# vc                                  0.043053   -0.460334
# dst_ni                             -0.045834    0.389462
# dst_router                         -0.082740    0.277818
# traversal_id                       -0.029938   -0.008965
# hop_count                          -0.096031    0.553527
# current_hop                        -0.045748    0.094675
# hop_percentage                     -0.015371   -0.146238
# enqueue_time                        0.009908    0.231524
# packet_count_decr                   0.571059   -0.081610
# packet_count_incr                   0.571059   -0.082229
# max_packet_count                    0.769504   -0.110387
# packet_count_index                  0.962768   -0.068802
# packet_max_index                    1.000000   -0.049194
# port_index                         -0.049194    1.000000
# cache_coherence_flit_index          0.036762    0.062417
# flit_index                          0.028693    0.039682
# traversal_index                     0.004806    0.023741
# cache_coherence_vnet_index          0.034126   -0.142434
# vnet_vc_index                       0.029513   -0.409520
# vnet_vc_cc_index                    0.032650   -0.296054
# target                             -0.245844    0.337653
#
#                             cache_coherence_flit_index  flit_index  \
# outport                                       0.129254    0.097628
# inport                                       -0.003756   -0.014892
# cache_coherence_type                          0.525600    0.422901
# flit_id                                       0.962205    0.924849
# flit_type                                    -0.101472    0.152598
# vnet                                         -0.030990   -0.039909
# vc                                           -0.087824   -0.076852
# dst_ni                                        0.095279    0.032034
# dst_router                                    0.034454    0.003134
# traversal_id                                  0.011381    0.007455
# hop_count                                     0.029760    0.006250
# current_hop                                  -0.054429   -0.038573
# hop_percentage                               -0.084764   -0.057267
# enqueue_time                                  0.395349    0.486016
# packet_count_decr                             0.007559   -0.024772
# packet_count_incr                             0.039539    0.076149
# max_packet_count                              0.031732    0.034615
# packet_count_index                            0.052557    0.041677
# packet_max_index                              0.036762    0.028693
# port_index                                    0.062417    0.039682
# cache_coherence_flit_index                    1.000000    0.942889
# flit_index                                    0.942889    1.000000
# traversal_index                               0.707917    0.751172
# cache_coherence_vnet_index                    0.472550    0.372273
# vnet_vc_index                                -0.054956   -0.055735
# vnet_vc_cc_index                              0.282956    0.214202
# target                                        0.024743    0.017057
#
#                             traversal_index  cache_coherence_vnet_index  \
# outport                            0.059859                   -0.070042
# inport                            -0.008131                   -0.195019
# cache_coherence_type               0.312439                    0.851346
# flit_id                            0.701214                    0.358300
# flit_type                          0.112343                   -0.544553
# vnet                              -0.034003                    0.391977
# vc                                -0.066738                    0.313506
# dst_ni                             0.048152                   -0.474856
# dst_router                         0.047013                   -0.265788
# traversal_id                       0.515750                    0.007558
# hop_count                          0.033385                   -0.074943
# current_hop                       -0.031032                    0.245716
# hop_percentage                    -0.058374                    0.222781
# enqueue_time                       0.369559                   -0.448910
# packet_count_decr                 -0.022477                    0.095110
# packet_count_incr                  0.055583                   -0.012071
# max_packet_count                   0.022306                    0.055947
# packet_count_index                 0.018970                    0.047944
# packet_max_index                   0.004806                    0.034126
# port_index                         0.023741                   -0.142434
# cache_coherence_flit_index         0.707917                    0.472550
# flit_index                         0.751172                    0.372273
# traversal_index                    1.000000                    0.272637
# cache_coherence_vnet_index         0.272637                    1.000000
# vnet_vc_index                     -0.048010                    0.364335
# vnet_vc_cc_index                   0.154189                    0.855949
# target                            -0.005574                   -0.132566
#
#                             vnet_vc_index  vnet_vc_cc_index    target
# outport                         -0.476178         -0.323419  0.181708
# inport                          -0.290458         -0.253217  0.358546
# cache_coherence_type            -0.173743          0.457456  0.029924
# flit_id                          0.080640          0.286229 -0.013865
# flit_type                       -0.122550         -0.435011  0.021088
# vnet                             0.991433          0.811195 -0.302356
# vc                               0.982136          0.732732 -0.339539
# dst_ni                          -0.746918         -0.719372  0.262518
# dst_router                      -0.360781         -0.369559  0.130114
# traversal_id                    -0.008436          0.001489 -0.033987
# hop_count                       -0.088304         -0.078056  0.151037
# current_hop                      0.538272          0.487697 -0.029668
# hop_percentage                   0.540309          0.471873 -0.049467
# enqueue_time                    -0.147613         -0.368500  0.122710
# packet_count_decr                0.064944          0.096933 -0.273348
# packet_count_incr                0.081175          0.025178 -0.273348
# max_packet_count                 0.098448          0.082272 -0.368336
# packet_count_index               0.054999          0.054778 -0.291840
# packet_max_index                 0.029513          0.032650 -0.245844
# port_index                      -0.409520         -0.296054  0.337653
# cache_coherence_flit_index      -0.054956          0.282956  0.024743
# flit_index                      -0.055735          0.214202  0.017057
# traversal_index                 -0.048010          0.154189 -0.005574
# cache_coherence_vnet_index       0.364335          0.855949 -0.132566
# vnet_vc_index                    1.000000          0.788809 -0.321570
# vnet_vc_cc_index                 0.788809          1.000000 -0.254200
# target                          -0.321570         -0.254200  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 0    89541
# 1    56917
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs        Score
# 5                         vnet  9354.092855
# 24               vnet_vc_index  8528.314308
# 6                           vc  7772.046650
# 19                  port_index  6644.703412
# 1                       inport  4426.325266
# 16            max_packet_count  2892.892813
# 15           packet_count_incr  1447.191060
# 14           packet_count_decr  1445.701760
# 17          packet_count_index  1354.775830
# 0                      outport  1176.021492
# 25            vnet_vc_cc_index  1148.821156
# 7                       dst_ni  1090.805541
# 18            packet_max_index   894.195512
# 8                   dst_router   472.370569
# 23  cache_coherence_vnet_index   248.435020
# 10                   hop_count   247.184554
# 13                enqueue_time   173.272612

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.470660
#          Iterations: 35
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\base\model.py:1354: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                                       Results: Logit
# ==========================================================================================
# Model:                      Logit                    Pseudo R-squared:         0.296
# Dependent Variable:         target                   AIC:                      137907.6996
# Date:                       2020-05-13 20:03         BIC:                      138125.3784
# No. Observations:           146458                   Log-Likelihood:           -68932.
# Df Model:                   21                       LL-Null:                  -97853.
# Df Residuals:               146436                   LLR p-value:              0.0000
# Converged:                  0.0000                   Scale:                    1.0000
# No. Iterations:             35.0000
# ------------------------------------------------------------------------------------------
#                             Coef.     Std.Err.     z     P>|z|      [0.025       0.975]
# ------------------------------------------------------------------------------------------
# outport                      2.6569      0.0484  54.9432 0.0000        2.5621       2.7517
# inport                       3.5039      0.0500  70.0844 0.0000        3.4059       3.6019
# cache_coherence_type         4.5030         nan      nan    nan           nan          nan
# flit_id                     -2.4928      0.1670 -14.9289 0.0000       -2.8200      -2.1655
# flit_type                   -0.6025      0.0410 -14.6916 0.0000       -0.6829      -0.5221
# vnet                       -15.0027         nan      nan    nan           nan          nan
# vc                           3.4130         nan      nan    nan           nan          nan
# dst_ni                      -1.4833      0.0665 -22.2991 0.0000       -1.6137      -1.3529
# dst_router                   1.4251      0.0995  14.3218 0.0000        1.2301       1.6201
# traversal_id                -0.4330      0.0382 -11.3446 0.0000       -0.5078      -0.3582
# hop_count                   -2.0042      0.1319 -15.1911 0.0000       -2.2628      -1.7456
# current_hop                  4.3659      0.1468  29.7440 0.0000        4.0782       4.6536
# hop_percentage              -0.3716      0.0669  -5.5587 0.0000       -0.5027      -0.2406
# enqueue_time                -0.8440      0.1171  -7.2055 0.0000       -1.0735      -0.6144
# packet_count_decr           -1.9172 881172.2195  -0.0000 1.0000 -1727067.7316 1727063.8972
# packet_count_incr           -1.4362 881172.2195  -0.0000 1.0000 -1727067.2506 1727064.3782
# max_packet_count            -3.3535 881172.2195  -0.0000 1.0000 -1727069.1679 1727062.4609
# packet_count_index           4.2353      0.5081   8.3363 0.0000        3.2395       5.2311
# packet_max_index            -8.1792      0.7711 -10.6068 0.0000       -9.6906      -6.6678
# port_index                  -1.4876      0.0440 -33.7879 0.0000       -1.5739      -1.4013
# cache_coherence_flit_index   4.1603      0.2492  16.6935 0.0000        3.6718       4.6487
# flit_index                   0.1704      0.1141   1.4940 0.1352       -0.0532       0.3940
# traversal_index              0.2788      0.0880   3.1679 0.0015        0.1063       0.4512
# cache_coherence_vnet_index  -2.1648 303423.1286  -0.0000 1.0000  -594700.5689  594696.2392
# vnet_vc_index               -7.3824         nan      nan    nan           nan          nan
# vnet_vc_cc_index            -7.8792         nan      nan    nan           nan          nan
# ==========================================================================================

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 76.63827390198522
# Test Prediction  76.3211798443261

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 7                       dst_ni    4.430778
# 1                       inport    4.034577
# 11                 current_hop    4.017661
# 0                      outport    2.700167
# 2         cache_coherence_type    2.698352
# 17          packet_count_index    2.496695
# 4                    flit_type    1.751927
# 6                           vc    1.739502
# 20  cache_coherence_flit_index    1.034562
# 23  cache_coherence_vnet_index    0.619224
# 13                enqueue_time    0.267729
# 22             traversal_index    0.016473
# 9                 traversal_id   -0.284317
# 12              hop_percentage   -0.403028
# 3                      flit_id   -0.681823
# 21                  flit_index   -1.270603
# 10                   hop_count   -1.367117
# 15           packet_count_incr   -1.375566
# 8                   dst_router   -1.657292
# 25            vnet_vc_cc_index   -1.688830
# 19                  port_index   -1.817383
# 14           packet_count_decr   -1.833771
# 24               vnet_vc_index   -2.022505
# 16            max_packet_count   -3.209338
# 5                         vnet   -4.678040
# 18            packet_max_index   -6.206137

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80     18075
#            1       0.68      0.73      0.70     11217
#
#     accuracy                           0.76     29292
#    macro avg       0.75      0.76      0.75     29292
# weighted avg       0.77      0.76      0.76     29292

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89     14371
#            1       0.82      0.89      0.85     10015
#
#     accuracy                           0.87     24386
#    macro avg       0.87      0.88      0.87     24386
# weighted avg       0.88      0.87      0.87     24386

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 71.13931577490492
# Test Prediction Score 71.40572459607972

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72     14371
#            1       0.61      0.85      0.71     10015
#
#     accuracy                           0.71     24386
#    macro avg       0.73      0.73      0.71     24386
# weighted avg       0.75      0.71      0.71     24386

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/10
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1771 - accuracy: 0.7379 - val_loss: 0.1494 - val_accuracy: 0.7969
# Epoch 2/10
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1499 - accuracy: 0.7959 - val_loss: 0.1478 - val_accuracy: 0.7947
# Epoch 3/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1487 - accuracy: 0.7949 - val_loss: 0.1468 - val_accuracy: 0.7933
# Epoch 4/10
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1480 - accuracy: 0.7953 - val_loss: 0.1465 - val_accuracy: 0.7925
# Epoch 5/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1475 - accuracy: 0.7961 - val_loss: 0.1457 - val_accuracy: 0.7954
# Epoch 6/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1472 - accuracy: 0.7961 - val_loss: 0.1453 - val_accuracy: 0.7953
# Epoch 7/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1468 - accuracy: 0.7965 - val_loss: 0.1456 - val_accuracy: 0.7953
# Epoch 8/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1466 - accuracy: 0.7967 - val_loss: 0.1448 - val_accuracy: 0.7962
# Epoch 9/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1463 - accuracy: 0.7972 - val_loss: 0.1444 - val_accuracy: 0.8003
# Epoch 10/10
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1460 - accuracy: 0.7974 - val_loss: 0.1456 - val_accuracy: 0.7950

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 79.74%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2 )
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2441 - accuracy: 0.5793 - val_loss: 0.2424 - val_accuracy: 0.5886
# Epoch 2/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2422 - accuracy: 0.5891 - val_loss: 0.2421 - val_accuracy: 0.5886
# Epoch 3/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.2420 - accuracy: 0.5891 - val_loss: 0.2419 - val_accuracy: 0.5886
# Epoch 4/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2416 - accuracy: 0.5891 - val_loss: 0.2413 - val_accuracy: 0.5886
# Epoch 5/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2393 - accuracy: 0.5892 - val_loss: 0.2345 - val_accuracy: 0.6008
# Epoch 6/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.2210 - accuracy: 0.6545 - val_loss: 0.2067 - val_accuracy: 0.6940
# Epoch 7/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1988 - accuracy: 0.7083 - val_loss: 0.1892 - val_accuracy: 0.7265
# Epoch 8/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1803 - accuracy: 0.7408 - val_loss: 0.1697 - val_accuracy: 0.7639
# Epoch 9/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1623 - accuracy: 0.7795 - val_loss: 0.1549 - val_accuracy: 0.7948
# Epoch 10/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1531 - accuracy: 0.7955 - val_loss: 0.1502 - val_accuracy: 0.7970
# Epoch 11/15
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1502 - accuracy: 0.7986 - val_loss: 0.1481 - val_accuracy: 0.7991
# Epoch 12/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1490 - accuracy: 0.7987 - val_loss: 0.1474 - val_accuracy: 0.7984
# Epoch 13/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1483 - accuracy: 0.7984 - val_loss: 0.1470 - val_accuracy: 0.7974
# Epoch 14/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1478 - accuracy: 0.7987 - val_loss: 0.1461 - val_accuracy: 0.7982
# Epoch 15/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1474 - accuracy: 0.7981 - val_loss: 0.1459 - val_accuracy: 0.7969

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 80.00%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2434 - accuracy: 0.5891 - val_loss: 0.2420 - val_accuracy: 0.5886
# Epoch 2/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2418 - accuracy: 0.5891 - val_loss: 0.2417 - val_accuracy: 0.5886
# Epoch 3/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2414 - accuracy: 0.5891 - val_loss: 0.2411 - val_accuracy: 0.5886
# Epoch 4/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2406 - accuracy: 0.5891 - val_loss: 0.2401 - val_accuracy: 0.5886
# Epoch 5/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2389 - accuracy: 0.5891 - val_loss: 0.2370 - val_accuracy: 0.5886
# Epoch 6/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2294 - accuracy: 0.5891 - val_loss: 0.2139 - val_accuracy: 0.5886
# Epoch 7/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1879 - accuracy: 0.7210 - val_loss: 0.1617 - val_accuracy: 0.7817
# Epoch 8/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1509 - accuracy: 0.7969 - val_loss: 0.1423 - val_accuracy: 0.8066
# Epoch 9/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1409 - accuracy: 0.8038 - val_loss: 0.1371 - val_accuracy: 0.8068
# Epoch 10/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1375 - accuracy: 0.8045 - val_loss: 0.1349 - val_accuracy: 0.8056
# Epoch 11/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1356 - accuracy: 0.8065 - val_loss: 0.1326 - val_accuracy: 0.8093
# Epoch 12/30
("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 82.11%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/100
# 78032/78032 [==============================] - 6s 73us/step - loss: 0.1303 - accuracy: 0.8096 - val_loss: 0.1168 - val_accuracy: 0.8288
# Epoch 2/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.1194 - accuracy: 0.8248 - val_loss: 0.1115 - val_accuracy: 0.8355
# Epoch 3/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1165 - accuracy: 0.8298 - val_loss: 0.1082 - val_accuracy: 0.8383
# Epoch 4/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1142 - accuracy: 0.8348 - val_loss: 0.1059 - val_accuracy: 0.8468
# Epoch 5/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1131 - accuracy: 0.8362 - val_loss: 0.1156 - val_accuracy: 0.8279
# Epoch 6/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1120 - accuracy: 0.8384 - val_loss: 0.1041 - val_accuracy: 0.8495
# Epoch 7/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1104 - accuracy: 0.8398 - val_loss: 0.1017 - val_accuracy: 0.8527
# Epoch 8/100
# 78032/78032 [==============================] - 5s 68us/step - loss: 0.1100 - accuracy: 0.8419 - val_loss: 0.0973 - val_accuracy: 0.8596
# Epoch 9/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1087 - accuracy: 0.8433 - val_loss: 0.1038 - val_accuracy: 0.8526
# Epoch 10/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1081 - accuracy: 0.8441 - val_loss: 0.1009 - val_accuracy: 0.8580
# Epoch 11/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.1071 - accuracy: 0.8459 - val_loss: 0.0984 - val_accuracy: 0.8608
# Epoch 12/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1066 - accuracy: 0.8470 - val_loss: 0.0960 - val_accuracy: 0.8612
# Epoch 13/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.1058 - accuracy: 0.8482 - val_loss: 0.0963 - val_accuracy: 0.8602
# Epoch 14/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1050 - accuracy: 0.8508 - val_loss: 0.0965 - val_accuracy: 0.8601
# Epoch 15/100
# Epoch 94/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0890 - accuracy: 0.8733 - val_loss: 0.0819 - val_accuracy: 0.8852
# Epoch 95/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0894 - accuracy: 0.8723 - val_loss: 0.0792 - val_accuracy: 0.8878
# Epoch 96/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0895 - accuracy: 0.8729 - val_loss: 0.0854 - val_accuracy: 0.8780
# Epoch 97/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0890 - accuracy: 0.8735 - val_loss: 0.0790 - val_accuracy: 0.8901
# Epoch 98/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0897 - accuracy: 0.8728 - val_loss: 0.0802 - val_accuracy: 0.8859
# Epoch 99/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0889 - accuracy: 0.8730 - val_loss: 0.0792 - val_accuracy: 0.8874
# Epoch 100/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0895 - accuracy: 0.8722 - val_loss: 0.0805 - val_accuracy: 0.8885

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 88.81%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2) ,
            'max_features':range(0,25,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)
# Out:
# Best parameters: {'max_depth': 24, 'max_features': 24}
# Accuracy : 0.9315262089598747

# %%
dt = DecisionTreeClassifier(max_depth=25,max_features=25,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=25, max_features=25, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 99.13779846423554
# Test Prediction Score 95.66144509144591

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     14371
#            1       0.94      0.95      0.95     10015
#
#     accuracy                           0.96     24386
#    macro avg       0.95      0.96      0.96     24386
# weighted avg       0.96      0.96      0.96     24386

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250],
            'max_features':range(0,25,2)}
dt_g=RandomForestClassifier(random_state=42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=25,max_features=25,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features=25,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 99.74267231215592
# Test Prediction Score 95.88698433527433

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96     14371
#            1       0.93      0.97      0.95     10015
#
#     accuracy                           0.96     24386
#    macro avg       0.96      0.96      0.96     24386
# weighted avg       0.96      0.96      0.96     24386

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250,500],
           'min_child_weight':[1,3,6]}
xgb_g=XGBClassifier(random_state=42)
xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
xgb_cv.fit(X_train,y_train)

print("Best parameters:",xgb_cv.best_params_)
print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=25,min_child_weight=1,n_estimators=500,random_state=42)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=25,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.89440337909187
# Test Prediction Score 97.86762896744034

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     14371
#            1       0.97      0.98      0.97     10015
#
#     accuracy                           0.98     24386
#    macro avg       0.98      0.98      0.98     24386
# weighted avg       0.98      0.98      0.98     24386

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
param_grid = {'n_estimators': [x for x in range(24,40,2)],
              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
lgb_cv.fit(X_train, y_train)

print("Best parameters:",lgb_cv.best_params_)
print("Accuracy :",lgb_cv.best_score_)
# Out:
# Best parameters: {'learning_rate': 0.2, 'n_estimators': 38}
# Accuracy : 0.9121924746743849

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.2,  n_estimators = 500, max_depth = 21, random_state=42, min_child_weight=1,metric='l2')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.2, max_depth=21,
#                metric='l2', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 96.03232030873131
# Test Prediction Score 93.42165957664908

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,5100), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [5098,
#  1898,
#  1041,
#  998,
#  643,
#  630,
#  617,
#  575,
#  536,
#  514,
#  509,
#  476,
#  424,
#  308,
#  274,
#  172,
#  119,
#  68,
#  44,
#  23,
#  20,
#  13]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94     23048
#            1       0.89      0.96      0.92     15974
#
#     accuracy                           0.93     39022
#    macro avg       0.93      0.94      0.93     39022
# weighted avg       0.94      0.93      0.93     39022

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
