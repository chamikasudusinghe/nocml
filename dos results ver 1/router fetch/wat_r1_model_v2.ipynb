# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r1_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
df1 = pd.read_csv('2-fft-normal-n-0-3-data-r1-good.csv')
df2 = pd.read_csv('2-fft-normal-n-0-5-data-r1-good.csv')
df3 = pd.read_csv('2-fft-normal-n-0-10-data-r1-good.csv')
df4 = pd.read_csv('2-fft-normal-n-0-12-data-r1-good.csv')
df5 = pd.read_csv('2-fft-normal-n-0-15-data-r1-good.csv')

# %%
df1m = pd.read_csv('2-fft-normal-n-0-3-data-r1-mal.csv')
df2m = pd.read_csv('2-fft-normal-n-0-5-data-r1-mal.csv')
df3m = pd.read_csv('2-fft-normal-n-0-10-data-r1-mal.csv')
df4m = pd.read_csv('2-fft-normal-n-0-12-data-r1-mal.csv')
df5m = pd.read_csv('2-fft-normal-n-0-15-data-r1-mal.csv')

# %% [markdown]
# Characteristics of Dataset

# %%
df1
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             11        2       4                     1        1          4
# 1             84        4       2                     1        1          4
# 2            216        2       4                     1        1          4
# 3            342        2       4                     1        1          4
# 4            388        1       2                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 56912    3268816        4       2                     6        2          2
# 56913    3268823        4       2                     6        3          2
# 56914    3268830        4       2                     6        4          2
# 56915    3268837        4       2                     6        5          3
# 56916    3268838        4       2                     2        1          4
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       0           0  ...                   2
# 1         3   9       3           3  ...                   2
# 2         3   9       0           0  ...                   1
# 3         3   9       0           0  ...                   1
# 4         3   9       3           3  ...                   1
# ...     ...  ..     ...         ...  ...                 ...
# 56912     3   9      18           2  ...                   5
# 56913     3   9      18           2  ...                   8
# 56914     3   9      18           2  ...                   9
# 56915     3   9      18           2  ...                   8
# 56916     3  10      18           2  ...                   5
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     4           8                           1           4
# 1                     4           8                           1           4
# 2                     1           8                           1           4
# 3                     1           8                           1           4
# 4                     1           2                           1           4
# ...                 ...         ...                         ...         ...
# 56912                25           8                          12          24
# 56913                40           8                          18          36
# 56914                45           8                          24          48
# 56915                40           8                          30          90
# 56916                25           8                           2           8
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    0                           3             27
# 1                    8                           3             27
# 2                   20                           3             27
# 3                   28                           3             27
# 4                   32                           3             27
# ...                ...                         ...            ...
# 56912           480984                          18             27
# 56913           721476                          18             27
# 56914           961968                          18             27
# 56915          1803690                          18             27
# 56916           160336                           6             30
#
#        vnet_vc_cc_index  target
# 0                     9       1
# 1                     9       1
# 2                     9       1
# 3                     9       1
# 4                     9       1
# ...                 ...     ...
# 56912                54       1
# 56913                54       1
# 56914                54       1
# 56915                54       1
# 56916                18       1
#
# [56917 rows x 30 columns]

# %%
df1m
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             11        2       4                     1        1          4
# 2             84        0       1                     4        1          1
# 3             84        4       2                     1        1          4
# 4             85        0       1                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 89536    2490410        0       4                     5        3          2
# 89537    2490417        0       4                     5        4          2
# 89538    2490424        0       4                     5        5          3
# 89539    2490425        0       4                     1        1          4
# 89540    2490432        4       0                     6        1          1
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   8
# 1         3   9       0           0  ...                  14
# 2         5  17      23           7  ...                  18
# 3         3   9       3           3  ...                  20
# 4         5  17      23           7  ...                  20
# ...     ...  ..     ...         ...  ...                 ...
# 89536     3   9       0           0  ...                  15
# 89537     3   9       0           0  ...                  16
# 89538     3   9       0           0  ...                  15
# 89539     3  10       0           0  ...                  12
# 89540     3  10      17           1  ...                   7
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    64           0                           1           4
# 1                   112           8                           1           4
# 2                   144           0                           4           4
# 3                   160           8                           1           4
# 4                   160           0                           8          16
# ...                 ...         ...                         ...         ...
# 89536               105           0                          15          30
# 89537               112           0                          20          40
# 89538               105           0                          25          75
# 89539                84           0                           1           4
# 89540                49           0                           6           6
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    0                           3             27
# 2                    4                          20             85
# 3                   12                           3             27
# 4                   16                          20             85
# ...                ...                         ...            ...
# 89536           607980                          15             27
# 89537           810640                          15             27
# 89538          1519950                          15             27
# 89539            81068                           3             30
# 89540           121596                          18             30
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                     9       0
# 2                   100       0
# 3                     9       0
# 4                   100       0
# ...                 ...     ...
# 89536                45       0
# 89537                45       0
# 89538                45       0
# 89539                 9       0
# 89540                54       0
#
# [89541 rows x 30 columns]

# %%
df1gm = df1.append(df1m, ignore_index=True,sort=False)

# %%
df1gm.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df1gm = df1gm.sort_values('timestamp')
df1gm.to_csv('fft-r1-df1gm.csv',index=False)

# %%
df2gm = df2.append(df2m, ignore_index=True,sort=False)
df2gm = df2gm.sort_values('timestamp')
df2gm.to_csv('fft-r1-df2gm.csv',index=False)

# %%
df3gm = df3.append(df3m, ignore_index=True,sort=False)
df3gm = df3gm.sort_values('timestamp')
df3gm.to_csv('fft-r1-df3gm.csv',index=False)

# %%
df4gm = df4.append(df4m, ignore_index=True,sort=False)
df4gm = df4gm.sort_values('timestamp')
df4gm.to_csv('fft-r1-df4gm.csv',index=False)

# %%
df5gm = df5.append(df5m, ignore_index=True,sort=False)
df5gm = df5gm.sort_values('timestamp')
df5gm.to_csv('fft-r1-df5gm.csv',index=False)

# %%
df1 = pd.read_csv("fft-r1-df1gm.csv")
df2= pd.read_csv("fft-r1-df2gm.csv")
df3= pd.read_csv("fft-r1-df3gm.csv")
df4 = pd.read_csv("fft-r1-df4gm.csv")
df5 = pd.read_csv("fft-r1-df5gm.csv")

# %%
df1.shape
# Out:
# (146458, 30)

# %%
df2.shape
# Out:
# (90096, 30)

# %%
df3.shape
# Out:
# (86568, 30)

# %%
df4.shape
# Out:
# (90177, 30)

# %%
df5.shape
# Out:
# (127563, 30)

# %%
df = df1.append(df2, ignore_index=True,sort=False)
df = df.append(df3, ignore_index=True,sort=False)
df = df.append(df4, ignore_index=True,sort=False)
df
# Out:
#         timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0               7        2       0                     1        1          4
# 1              11        2       4                     1        1          4
# 2              11        2       4                     1        1          4
# 3              84        4       2                     1        1          4
# 4              84        0       1                     4        1          1
# ...           ...      ...     ...                   ...      ...        ...
# 413294    3272305        4       2                     6        3          2
# 413295    3272312        4       2                     6        4          2
# 413296    3272319        4       2                     6        5          3
# 413297    3272320        4       2                     2        1          4
# 413298    3272321        4       2                     7        1          4
#
#         vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0          3   9       1           1  ...                   8
# 1          3   9       0           0  ...                  14
# 2          3   9       0           0  ...                   2
# 3          3   9       3           3  ...                   2
# 4          5  17      23           7  ...                  18
# ...      ...  ..     ...         ...  ...                 ...
# 413294     3   9      18           2  ...                   1
# 413295     3   9      18           2  ...                   1
# 413296     3   9      18           2  ...                   1
# 413297     3  10      18           2  ...                   1
# 413298     3  11      18           2  ...                   1
#
#         packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     64           0                           1           4
# 1                    112           8                           1           4
# 2                      4           8                           1           4
# 3                      4           8                           1           4
# 4                    144           0                           4           4
# ...                  ...         ...                         ...         ...
# 413294                 1           8                          18          36
# 413295                 1           8                          24          48
# 413296                 1           8                          30          90
# 413297                 1           8                           2           8
# 413298                 1           8                           7          28
#
#         traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                     4                           3             27
# 1                     0                           3             27
# 2                     0                           3             27
# 3                     8                           3             27
# 4                     4                          20             85
# ...                 ...                         ...            ...
# 413294           721656                          18             27
# 413295           962208                          18             27
# 413296          1804140                          18             27
# 413297           160376                           6             30
# 413298           561288                          21             33
#
#         vnet_vc_cc_index  target
# 0                      9       0
# 1                      9       0
# 2                      9       1
# 3                      9       1
# 4                    100       0
# ...                  ...     ...
# 413294                54       1
# 413295                54       1
# 413296                54       1
# 413297                18       1
# 413298                63       1
#
# [413299 rows x 30 columns]

# %%
df = df.drop(columns=['timestamp','src_ni','src_router'])

# %%
df.to_csv('fft-r1-df.csv',index=False)

# %%
df = pd.read_csv("fft-r1-df.csv")
df
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  vc  \
# 0             2       0                     1        1          4     3   9
# 1             2       4                     1        1          4     3   9
# 2             2       4                     1        1          4     3   9
# 3             4       2                     1        1          4     3   9
# 4             0       1                     4        1          1     5  17
# ...         ...     ...                   ...      ...        ...   ...  ..
# 413294        4       2                     6        3          2     3   9
# 413295        4       2                     6        4          2     3   9
# 413296        4       2                     6        5          3     3   9
# 413297        4       2                     2        1          4     3  10
# 413298        4       2                     7        1          4     3  11
#
#         dst_ni  dst_router  traversal_id  ...  packet_count_index  \
# 0           23           7             1  ...                   8
# 1           23           7             0  ...                  14
# 2           23           7             0  ...                   2
# 3           24           8             2  ...                   2
# 4            1           1             1  ...                  18
# ...        ...         ...           ...  ...                 ...
# 413294      20           4         20046  ...                   1
# 413295      20           4         20046  ...                   1
# 413296      20           4         20046  ...                   1
# 413297      20           4         20047  ...                   1
# 413298      12          12         20046  ...                   1
#
#         packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     64           0                           1           4
# 1                    112           8                           1           4
# 2                      4           8                           1           4
# 3                      4           8                           1           4
# 4                    144           0                           4           4
# ...                  ...         ...                         ...         ...
# 413294                 1           8                          18          36
# 413295                 1           8                          24          48
# 413296                 1           8                          30          90
# 413297                 1           8                           2           8
# 413298                 1           8                           7          28
#
#         traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                     4                           3             27
# 1                     0                           3             27
# 2                     0                           3             27
# 3                     8                           3             27
# 4                     4                          20             85
# ...                 ...                         ...            ...
# 413294           721656                          18             27
# 413295           962208                          18             27
# 413296          1804140                          18             27
# 413297           160376                           6             30
# 413298           561288                          21             33
#
#         vnet_vc_cc_index  target
# 0                      9       0
# 1                      9       0
# 2                      9       1
# 3                      9       1
# 4                    100       0
# ...                  ...     ...
# 413294                54       1
# 413295                54       1
# 413296                54       1
# 413297                18       1
# 413298                63       1
#
# [413299 rows x 27 columns]

# %%
df.corr()
# Out:
#                              outport    inport  cache_coherence_type  \
# outport                     1.000000 -0.294807              0.275217
# inport                     -0.294807  1.000000             -0.168169
# cache_coherence_type        0.275217 -0.168169              1.000000
# flit_id                     0.012792  0.045435              0.348740
# flit_type                  -0.019012 -0.067502             -0.518125
# vnet                       -0.318187 -0.175422             -0.100040
# vc                         -0.170989 -0.371519             -0.147296
# dst_ni                      0.173205  0.372022             -0.172505
# dst_router                  0.062725  0.363596             -0.060190
# traversal_id               -0.038277  0.031995              0.006150
# hop_count                   0.179472  0.319211             -0.035198
# current_hop                -0.344110  0.078281             -0.090579
# hop_percentage             -0.622184  0.140318             -0.146387
# enqueue_time                0.006157  0.133131             -0.429843
# packet_count_decr          -0.069663 -0.094788              0.037941
# packet_count_incr           0.091613 -0.220395             -0.035757
# max_packet_count            0.014026 -0.201401              0.001396
# packet_count_index          0.027952 -0.173513              0.013076
# packet_max_index            0.016860 -0.140649              0.010936
# port_index                  0.407948  0.622549              0.027551
# cache_coherence_flit_index  0.145124 -0.024615              0.534495
# flit_index                  0.117898 -0.040455              0.431929
# traversal_index             0.066075 -0.012946              0.318323
# cache_coherence_vnet_index  0.163004 -0.222646              0.943624
# vnet_vc_index              -0.262599 -0.267054             -0.123816
# vnet_vc_cc_index           -0.010720 -0.255481              0.709275
# target                      0.063755  0.224370             -0.000537
#
#                              flit_id  flit_type      vnet        vc    dst_ni  \
# outport                     0.012792  -0.019012 -0.318187 -0.170989  0.173205
# inport                      0.045435  -0.067502 -0.175422 -0.371519  0.372022
# cache_coherence_type        0.348740  -0.518125 -0.100040 -0.147296 -0.172505
# flit_id                     1.000000  -0.063630  0.066628 -0.044901  0.121513
# flit_type                  -0.063630   1.000000 -0.098985  0.066713 -0.180539
# vnet                        0.066628  -0.098985  1.000000  0.885297 -0.575234
# vc                         -0.044901   0.066713  0.885297  1.000000 -0.600396
# dst_ni                      0.121513  -0.180539 -0.575234 -0.600396  1.000000
# dst_router                  0.029508  -0.043849 -0.217525 -0.224399  0.730007
# traversal_id                0.018261  -0.027160  0.003823 -0.003255  0.051293
# hop_count                   0.039607  -0.058845 -0.035624 -0.142076  0.479129
# current_hop                 0.006781  -0.010063  0.379543  0.177470 -0.311897
# hop_percentage             -0.015608   0.023202  0.377304  0.177703 -0.474445
# enqueue_time                0.518330   0.512821 -0.090015 -0.090012  0.210806
# packet_count_decr           0.035224  -0.122272  0.111246  0.097810 -0.085109
# packet_count_incr           0.030421   0.161639  0.106891  0.188036 -0.140143
# max_packet_count            0.041947   0.025155  0.139389  0.182655 -0.143935
# packet_count_index          0.055910  -0.010726  0.102461  0.139552 -0.093883
# packet_max_index            0.034809  -0.010914  0.075119  0.107687 -0.078632
# port_index                  0.035175  -0.052259 -0.254251 -0.383473  0.362598
# cache_coherence_flit_index  0.968457  -0.152828 -0.021959 -0.114878  0.103603
# flit_index                  0.928169   0.109141 -0.027672 -0.081444  0.022030
# traversal_index             0.707297   0.078448 -0.019715 -0.065677  0.043502
# cache_coherence_vnet_index  0.362852  -0.539090  0.234958  0.150633 -0.359894
# vnet_vc_index               0.019393  -0.028808  0.978742  0.961852 -0.603204
# vnet_vc_cc_index            0.319275  -0.474345  0.630440  0.512308 -0.542126
# target                     -0.000457   0.000696 -0.204519 -0.221392  0.168968
#
#                             dst_router  traversal_id  ...  packet_count_index  \
# outport                       0.062725     -0.038277  ...            0.027952
# inport                        0.363596      0.031995  ...           -0.173513
# cache_coherence_type         -0.060190      0.006150  ...            0.013076
# flit_id                       0.029508      0.018261  ...            0.055910
# flit_type                    -0.043849     -0.027160  ...           -0.010726
# vnet                         -0.217525      0.003823  ...            0.102461
# vc                           -0.224399     -0.003255  ...            0.139552
# dst_ni                        0.730007      0.051293  ...           -0.093883
# dst_router                    1.000000      0.084486  ...           -0.101967
# traversal_id                  0.084486      1.000000  ...           -0.025578
# hop_count                     0.705892      0.043239  ...           -0.097983
# current_hop                  -0.250640     -0.015576  ...           -0.022855
# hop_percentage               -0.524995     -0.030742  ...           -0.009503
# enqueue_time                  0.018307      0.015691  ...            0.027568
# packet_count_decr            -0.122336     -0.020658  ...            0.679088
# packet_count_incr            -0.062363     -0.020598  ...            0.679088
# max_packet_count             -0.118022     -0.026362  ...            0.867871
# packet_count_index           -0.101967     -0.025578  ...            1.000000
# packet_max_index             -0.089536     -0.024358  ...            0.957660
# port_index                    0.338807     -0.003704  ...           -0.128499
# cache_coherence_flit_index    0.007277      0.011343  ...            0.052132
# flit_index                   -0.006550      0.006621  ...            0.042685
# traversal_index               0.038318      0.511177  ...            0.017962
# cache_coherence_vnet_index   -0.131168      0.007280  ...            0.046861
# vnet_vc_index                -0.226937      0.000814  ...            0.121825
# vnet_vc_cc_index             -0.201071      0.007507  ...            0.082793
# target                        0.096153     -0.033563  ...           -0.231675
#
#                             packet_max_index  port_index  \
# outport                             0.016860    0.407948
# inport                             -0.140649    0.622549
# cache_coherence_type                0.010936    0.027551
# flit_id                             0.034809    0.035175
# flit_type                          -0.010914   -0.052259
# vnet                                0.075119   -0.254251
# vc                                  0.107687   -0.383473
# dst_ni                             -0.078632    0.362598
# dst_router                         -0.089536    0.338807
# traversal_id                       -0.024358   -0.003704
# hop_count                          -0.088290    0.586308
# current_hop                        -0.019313    0.094025
# hop_percentage                     -0.002846   -0.189051
# enqueue_time                        0.015295    0.155375
# packet_count_decr                   0.596824   -0.117798
# packet_count_incr                   0.596824   -0.120680
# max_packet_count                    0.762737   -0.152387
# packet_count_index                  0.957660   -0.128499
# packet_max_index                    1.000000   -0.108404
# port_index                         -0.108404    1.000000
# cache_coherence_flit_index          0.032912    0.055713
# flit_index                          0.026048    0.032109
# traversal_index                     0.005956    0.020896
# cache_coherence_vnet_index          0.035675   -0.057671
# vnet_vc_index                       0.091686   -0.318701
# vnet_vc_cc_index                    0.061753   -0.158639
# target                             -0.198214    0.188898
#
#                             cache_coherence_flit_index  flit_index  \
# outport                                       0.145124    0.117898
# inport                                       -0.024615   -0.040455
# cache_coherence_type                          0.534495    0.431929
# flit_id                                       0.968457    0.928169
# flit_type                                    -0.152828    0.109141
# vnet                                         -0.021959   -0.027672
# vc                                           -0.114878   -0.081444
# dst_ni                                        0.103603    0.022030
# dst_router                                    0.007277   -0.006550
# traversal_id                                  0.011343    0.006621
# hop_count                                     0.024051    0.005931
# current_hop                                  -0.044017   -0.036953
# hop_percentage                               -0.086081   -0.067090
# enqueue_time                                  0.398361    0.482189
# packet_count_decr                             0.031666   -0.002470
# packet_count_incr                             0.021143    0.059853
# max_packet_count                              0.033744    0.036667
# packet_count_index                            0.052132    0.042685
# packet_max_index                              0.032912    0.026048
# port_index                                    0.055713    0.032109
# cache_coherence_flit_index                    1.000000    0.941607
# flit_index                                    0.941607    1.000000
# traversal_index                               0.709461    0.753364
# cache_coherence_vnet_index                    0.514846    0.412748
# vnet_vc_index                                -0.063584   -0.052200
# vnet_vc_cc_index                              0.401429    0.317365
# target                                        0.008968    0.004335
#
#                             traversal_index  cache_coherence_vnet_index  \
# outport                            0.066075                    0.163004
# inport                            -0.012946                   -0.222646
# cache_coherence_type               0.318323                    0.943624
# flit_id                            0.707297                    0.362852
# flit_type                          0.078448                   -0.539090
# vnet                              -0.019715                    0.234958
# vc                                -0.065677                    0.150633
# dst_ni                             0.043502                   -0.359894
# dst_router                         0.038318                   -0.131168
# traversal_id                       0.511177                    0.007280
# hop_count                          0.024896                   -0.046237
# current_hop                       -0.036858                    0.037782
# hop_percentage                    -0.065463                   -0.017482
# enqueue_time                       0.364644                   -0.449863
# packet_count_decr                 -0.012955                    0.074075
# packet_count_incr                  0.034673                    0.000630
# max_packet_count                   0.013877                    0.047736
# packet_count_index                 0.017962                    0.046861
# packet_max_index                   0.005956                    0.035675
# port_index                         0.020896                   -0.057671
# cache_coherence_flit_index         0.709461                    0.514846
# flit_index                         0.753364                    0.412748
# traversal_index                    1.000000                    0.304413
# cache_coherence_vnet_index         0.304413                    1.000000
# vnet_vc_index                     -0.040564                    0.204659
# vnet_vc_cc_index                   0.234373                    0.902634
# target                            -0.014415                   -0.068566
#
#                             vnet_vc_index  vnet_vc_cc_index    target
# outport                         -0.262599         -0.010720  0.063755
# inport                          -0.267054         -0.255481  0.224370
# cache_coherence_type            -0.123816          0.709275 -0.000537
# flit_id                          0.019393          0.319275 -0.000457
# flit_type                       -0.028808         -0.474345  0.000696
# vnet                             0.978742          0.630440 -0.204519
# vc                               0.961852          0.512308 -0.221392
# dst_ni                          -0.603204         -0.542126  0.168968
# dst_router                      -0.226937         -0.201071  0.096153
# traversal_id                     0.000814          0.007507 -0.033563
# hop_count                       -0.083618         -0.052698  0.083506
# current_hop                      0.301553          0.198236 -0.041024
# hop_percentage                   0.300338          0.153111 -0.046369
# enqueue_time                    -0.092654         -0.399117  0.044525
# packet_count_decr                0.108583          0.108416 -0.215498
# packet_count_incr                0.145814          0.047835 -0.215498
# max_packet_count                 0.162559          0.099844 -0.275405
# packet_count_index               0.121825          0.082793 -0.231675
# packet_max_index                 0.091686          0.061753 -0.198214
# port_index                      -0.318701         -0.158639  0.188898
# cache_coherence_flit_index      -0.063584          0.401429  0.008968
# flit_index                      -0.052200          0.317365  0.004335
# traversal_index                 -0.040564          0.234373 -0.014415
# cache_coherence_vnet_index       0.204659          0.902634 -0.068566
# vnet_vc_index                    1.000000          0.596830 -0.217960
# vnet_vc_cc_index                 0.596830          1.000000 -0.145318
# target                          -0.217960         -0.145318  1.000000
#
# [27 rows x 27 columns]

# %%
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target'])
train_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  vc  \
# 0             2       0                     1        1          4     3   9
# 1             2       4                     1        1          4     3   9
# 2             2       4                     1        1          4     3   9
# 3             4       2                     1        1          4     3   9
# 4             0       1                     4        1          1     5  17
# ...         ...     ...                   ...      ...        ...   ...  ..
# 413294        4       2                     6        3          2     3   9
# 413295        4       2                     6        4          2     3   9
# 413296        4       2                     6        5          3     3   9
# 413297        4       2                     2        1          4     3  10
# 413298        4       2                     7        1          4     3  11
#
#         dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0           23           7             1  ...                 8
# 1           23           7             0  ...                 8
# 2           23           7             0  ...                 2
# 3           24           8             2  ...                 2
# 4            1           1             1  ...                 8
# ...        ...         ...           ...  ...               ...
# 413294      20           4         20046  ...                 1
# 413295      20           4         20046  ...                 1
# 413296      20           4         20046  ...                 1
# 413297      20           4         20047  ...                 1
# 413298      12          12         20046  ...                 1
#
#         packet_count_index  packet_max_index  port_index  \
# 0                        8                64           0
# 1                       14               112           8
# 2                        2                 4           8
# 3                        2                 4           8
# 4                       18               144           0
# ...                    ...               ...         ...
# 413294                   1                 1           8
# 413295                   1                 1           8
# 413296                   1                 1           8
# 413297                   1                 1           8
# 413298                   1                 1           8
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                                1           4                4
# 1                                1           4                0
# 2                                1           4                0
# 3                                1           4                8
# 4                                4           4                4
# ...                            ...         ...              ...
# 413294                          18          36           721656
# 413295                          24          48           962208
# 413296                          30          90          1804140
# 413297                           2           8           160376
# 413298                           7          28           561288
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                                3             27                 9
# 1                                3             27                 9
# 2                                3             27                 9
# 3                                3             27                 9
# 4                               20             85               100
# ...                            ...            ...               ...
# 413294                          18             27                54
# 413295                          18             27                54
# 413296                          18             27                54
# 413297                           6             30                18
# 413298                          21             33                63
#
# [413299 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  \
# 0           0.5    0.00              0.000000     0.00   1.000000   0.0
# 1           0.5    1.00              0.000000     0.00   1.000000   0.0
# 2           0.5    1.00              0.000000     0.00   1.000000   0.0
# 3           1.0    0.50              0.000000     0.00   1.000000   0.0
# 4           0.0    0.25              0.500000     0.00   0.000000   1.0
# ...         ...     ...                   ...      ...        ...   ...
# 413294      1.0    0.50              0.833333     0.50   0.333333   0.0
# 413295      1.0    0.50              0.833333     0.75   0.333333   0.0
# 413296      1.0    0.50              0.833333     1.00   0.666667   0.0
# 413297      1.0    0.50              0.166667     0.00   1.000000   0.0
# 413298      1.0    0.50              1.000000     0.00   1.000000   0.0
#
#            vc    dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0       0.000  0.741935    0.466667      0.000048  ...          0.205882
# 1       0.000  0.741935    0.466667      0.000000  ...          0.205882
# 2       0.000  0.741935    0.466667      0.000000  ...          0.029412
# 3       0.000  0.774194    0.533333      0.000095  ...          0.029412
# 4       1.000  0.032258    0.066667      0.000048  ...          0.205882
# ...       ...       ...         ...           ...  ...               ...
# 413294  0.000  0.645161    0.266667      0.956439  ...          0.000000
# 413295  0.000  0.645161    0.266667      0.956439  ...          0.000000
# 413296  0.000  0.645161    0.266667      0.956439  ...          0.000000
# 413297  0.125  0.645161    0.266667      0.956486  ...          0.000000
# 413298  0.250  0.387097    0.800000      0.956439  ...          0.000000
#
#         packet_count_index  packet_max_index  port_index  \
# 0                 0.021672          0.005556         0.0
# 1                 0.040248          0.009789         1.0
# 2                 0.003096          0.000265         1.0
# 3                 0.003096          0.000265         1.0
# 4                 0.052632          0.012611         0.0
# ...                    ...               ...         ...
# 413294            0.000000          0.000000         1.0
# 413295            0.000000          0.000000         1.0
# 413296            0.000000          0.000000         1.0
# 413297            0.000000          0.000000         1.0
# 413298            0.000000          0.000000         1.0
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                         0.000000    0.000000         0.000002
# 1                         0.000000    0.000000         0.000000
# 2                         0.000000    0.000000         0.000000
# 3                         0.000000    0.000000         0.000004
# 4                         0.103448    0.000000         0.000002
# ...                            ...         ...              ...
# 413294                    0.586207    0.372093         0.382776
# 413295                    0.793103    0.511628         0.510369
# 413296                    1.000000    1.000000         0.956941
# 413297                    0.034483    0.046512         0.085066
# 413298                    0.206897    0.279070         0.297715
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                         0.000000       0.000000          0.000000
# 1                         0.000000       0.000000          0.000000
# 2                         0.000000       0.000000          0.000000
# 3                         0.000000       0.000000          0.000000
# 4                         0.944444       1.000000          1.000000
# ...                            ...            ...               ...
# 413294                    0.833333       0.000000          0.494505
# 413295                    0.833333       0.000000          0.494505
# 413296                    0.833333       0.000000          0.494505
# 413297                    0.166667       0.051724          0.098901
# 413298                    1.000000       0.103448          0.593407
#
# [413299 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (19155, 26)

# %%
test_X = df5.drop(columns=['timestamp','src_ni','src_router','target'])
test_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  vc  \
# 0             2       0                     1        1          4     3   9
# 1             2       4                     1        1          4     3   9
# 2             2       4                     1        1          4     3   9
# 3             0       1                     4        1          1     5  17
# 4             0       1                     4        2          2     5  17
# ...         ...     ...                   ...      ...        ...   ...  ..
# 127558        4       2                     6        2          2     3   9
# 127559        4       2                     6        3          2     3   9
# 127560        4       2                     6        4          2     3   9
# 127561        4       2                     6        5          3     3   9
# 127562        4       2                     2        1          4     3  10
#
#         dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0           23           7             1  ...                 7
# 1           23           7             0  ...                 7
# 2           23           7             0  ...                 1
# 3            1           1             1  ...                 7
# 4            1           1             1  ...                 7
# ...        ...         ...           ...  ...               ...
# 127558      20           4         20056  ...                 1
# 127559      20           4         20056  ...                 1
# 127560      20           4         20056  ...                 1
# 127561      20           4         20056  ...                 1
# 127562      20           4         20057  ...                 1
#
#         packet_count_index  packet_max_index  port_index  \
# 0                        7                49           0
# 1                       12                84           8
# 2                        1                 1           8
# 3                       15               105           0
# 4                       16               112           0
# ...                    ...               ...         ...
# 127558                   1                 1           8
# 127559                   1                 1           8
# 127560                   1                 1           8
# 127561                   1                 1           8
# 127562                   1                 1           8
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                                1           4                4
# 1                                1           4                0
# 2                                1           4                0
# 3                                4           4                4
# 4                                8          16               16
# ...                            ...         ...              ...
# 127558                          12          24           481344
# 127559                          18          36           722016
# 127560                          24          48           962688
# 127561                          30          90          1805040
# 127562                           2           8           160456
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                                3             27                 9
# 1                                3             27                 9
# 2                                3             27                 9
# 3                               20             85               100
# 4                               20             85               100
# ...                            ...            ...               ...
# 127558                          18             27                54
# 127559                          18             27                54
# 127560                          18             27                54
# 127561                          18             27                54
# 127562                           6             30                18
#
# [127563 rows x 26 columns]

# %%
#standardization
x = test_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X = pd.DataFrame(x_scaled)
test_X.columns = columns
test_X
# Out:
#         outport  inport  cache_coherence_type  flit_id  flit_type  vnet  \
# 0           0.5    0.00              0.000000     0.00   1.000000   0.0
# 1           0.5    1.00              0.000000     0.00   1.000000   0.0
# 2           0.5    1.00              0.000000     0.00   1.000000   0.0
# 3           0.0    0.25              0.500000     0.00   0.000000   1.0
# 4           0.0    0.25              0.500000     0.25   0.333333   1.0
# ...         ...     ...                   ...      ...        ...   ...
# 127558      1.0    0.50              0.833333     0.25   0.333333   0.0
# 127559      1.0    0.50              0.833333     0.50   0.333333   0.0
# 127560      1.0    0.50              0.833333     0.75   0.333333   0.0
# 127561      1.0    0.50              0.833333     1.00   0.666667   0.0
# 127562      1.0    0.50              0.166667     0.00   1.000000   0.0
#
#            vc    dst_ni  dst_router  traversal_id  ...  max_packet_count  \
# 0       0.000  0.741935    0.466667      0.000049  ...          0.171429
# 1       0.000  0.741935    0.466667      0.000000  ...          0.171429
# 2       0.000  0.741935    0.466667      0.000000  ...          0.000000
# 3       1.000  0.032258    0.066667      0.000049  ...          0.171429
# 4       1.000  0.032258    0.066667      0.000049  ...          0.171429
# ...       ...       ...         ...           ...  ...               ...
# 127558  0.000  0.645161    0.266667      0.987397  ...          0.000000
# 127559  0.000  0.645161    0.266667      0.987397  ...          0.000000
# 127560  0.000  0.645161    0.266667      0.987397  ...          0.000000
# 127561  0.000  0.645161    0.266667      0.987397  ...          0.000000
# 127562  0.125  0.645161    0.266667      0.987446  ...          0.000000
#
#         packet_count_index  packet_max_index  port_index  \
# 0                 0.017595          0.003899         0.0
# 1                 0.032258          0.006742         1.0
# 2                 0.000000          0.000000         1.0
# 3                 0.041056          0.008448         0.0
# 4                 0.043988          0.009016         0.0
# ...                    ...               ...         ...
# 127558            0.000000          0.000000         1.0
# 127559            0.000000          0.000000         1.0
# 127560            0.000000          0.000000         1.0
# 127561            0.000000          0.000000         1.0
# 127562            0.000000          0.000000         1.0
#
#         cache_coherence_flit_index  flit_index  traversal_index  \
# 0                         0.000000    0.000000         0.000002
# 1                         0.000000    0.000000         0.000000
# 2                         0.000000    0.000000         0.000000
# 3                         0.103448    0.000000         0.000002
# 4                         0.241379    0.139535         0.000009
# ...                            ...         ...              ...
# 127558                    0.379310    0.232558         0.263526
# 127559                    0.586207    0.372093         0.395289
# 127560                    0.793103    0.511628         0.527053
# 127561                    1.000000    1.000000         0.988224
# 127562                    0.034483    0.046512         0.087846
#
#         cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                         0.000000       0.000000          0.000000
# 1                         0.000000       0.000000          0.000000
# 2                         0.000000       0.000000          0.000000
# 3                         0.944444       1.000000          1.000000
# 4                         0.944444       1.000000          1.000000
# ...                            ...            ...               ...
# 127558                    0.833333       0.000000          0.494505
# 127559                    0.833333       0.000000          0.494505
# 127560                    0.833333       0.000000          0.494505
# 127561                    0.833333       0.000000          0.494505
# 127562                    0.166667       0.051724          0.098901
#
# [127563 rows x 26 columns]

# %%
test_X[test_X.duplicated()].shape
# Out:
# (178, 26)

# %%
test_Y = df5["target"]

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 0    217876
# 1    195423
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs         Score
# 5                    flit_type  13161.130971
# 24                  flit_index   9680.694082
# 6                         vnet   7602.839100
# 16                enqueue_time   5347.657259
# 19            max_packet_count   4660.765228
# 1                      outport   4370.923061
# 14                 current_hop   2674.325614
# 15              hop_percentage   2673.331723
# 17           packet_count_decr   2357.177882
# 18           packet_count_incr   1503.173752
# 7                           vc    750.752454
# 25             traversal_index    725.942246
# 8                       src_ni    661.692484
# 0                    timestamp    348.400995
# 10                      dst_ni    198.713432
# 12                traversal_id    188.579852
# 23  cache_coherence_flit_index    184.201164

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.608860
#          Iterations: 35
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\base\model.py:1354: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                                       Results: Logit
# ===========================================================================================
# Model:                       Logit                    Pseudo R-squared:         0.120
# Dependent Variable:          target                   AIC:                      503326.6917
# Date:                        2020-05-13 20:35         BIC:                      503567.1940
# No. Observations:            413299                   Log-Likelihood:           -2.5164e+05
# Df Model:                    21                       LL-Null:                  -2.8587e+05
# Df Residuals:                413277                   LLR p-value:              0.0000
# Converged:                   0.0000                   Scale:                    1.0000
# No. Iterations:              35.0000
# -------------------------------------------------------------------------------------------
#                             Coef.     Std.Err.      z     P>|z|      [0.025       0.975]
# -------------------------------------------------------------------------------------------
# outport                      1.5509       0.0275  56.3572 0.0000        1.4970       1.6049
# inport                       1.9531       0.0232  84.3210 0.0000        1.9077       1.9985
# cache_coherence_type         3.4978  145278.7794   0.0000 1.0000  -284737.6776  284744.6731
# flit_id                      0.5515       0.0934   5.9068 0.0000        0.3685       0.7345
# flit_type                   -0.2258       0.0207 -10.9207 0.0000       -0.2664      -0.1853
# vnet                       -10.6568  704198.0723  -0.0000 1.0000 -1380213.5165 1380192.2030
# vc                           2.2748  489590.0460   0.0000 1.0000  -959576.5826  959581.1322
# dst_ni                      -0.9352       0.0340 -27.4940 0.0000       -1.0019      -0.8685
# dst_router                   0.4451       0.0474   9.3808 0.0000        0.3521       0.5381
# traversal_id                -0.3378       0.0206 -16.4220 0.0000       -0.3782      -0.2975
# hop_count                   -0.2251       0.0680  -3.3110 0.0009       -0.3584      -0.0919
# current_hop                  1.2806       0.0708  18.0844 0.0000        1.1418       1.4194
# hop_percentage               0.0428       0.0297   1.4397 0.1499       -0.0155       0.1010
# enqueue_time                -0.8860       0.0607 -14.6079 0.0000       -1.0049      -0.7671
# packet_count_decr           -1.2983          nan      nan    nan           nan          nan
# packet_count_incr           -0.9277          nan      nan    nan           nan          nan
# max_packet_count            -2.2260          nan      nan    nan           nan          nan
# packet_count_index           3.5351       0.3168  11.1588 0.0000        2.9142       4.1560
# packet_max_index            -6.6814       0.4640 -14.3992 0.0000       -7.5908      -5.7720
# port_index                  -0.8838       0.0209 -42.3031 0.0000       -0.9248      -0.8429
# cache_coherence_flit_index  -0.0663       0.1323  -0.5014 0.6161       -0.3257       0.1930
# flit_index                   0.1198       0.0580   2.0644 0.0390        0.0061       0.2336
# traversal_index             -0.0571       0.0469  -1.2171 0.2236       -0.1491       0.0349
# cache_coherence_vnet_index  -1.2386  126642.6222  -0.0000 1.0000  -248216.2170  248213.7399
# vnet_vc_index               -5.3058 1183175.9446  -0.0000 1.0000 -2318987.5446 2318976.9330
# vnet_vc_cc_index            -5.4193  135280.2116  -0.0000 1.0000  -265149.7618  265138.9233
# ===========================================================================================

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 65.17712671523927
# Test Prediction  65.57827244132591

# %%
y_pred = logreg.predict(test_X)
logreg_score_test = accuracy_score(test_Y,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-7bdf92992eac> in <module>
# ----> 1 y_pred = logreg.predict(test_X)
#       2 logreg_score_test = accuracy_score(test_Y,y_pred)
#       3 print("Test Prediction ",logreg_score_test*100)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     291             Predicted class label per sample.
#     292         """
# --> 293         scores = self.decision_function(X)
#     294         if len(scores.shape) == 1:
#     295             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     271         if X.shape[1] != n_features:
#     272             raise ValueError("X has %d features per sample; expecting %d"
# --> 273                              % (X.shape[1], n_features))
#     274
#     275         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 29 features per sample; expecting 26

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 7                       dst_ni    4.430778
# 1                       inport    4.034577
# 11                 current_hop    4.017661
# 0                      outport    2.700167
# 2         cache_coherence_type    2.698352
# 17          packet_count_index    2.496695
# 4                    flit_type    1.751927
# 6                           vc    1.739502
# 20  cache_coherence_flit_index    1.034562
# 23  cache_coherence_vnet_index    0.619224
# 13                enqueue_time    0.267729
# 22             traversal_index    0.016473
# 9                 traversal_id   -0.284317
# 12              hop_percentage   -0.403028
# 3                      flit_id   -0.681823
# 21                  flit_index   -1.270603
# 10                   hop_count   -1.367117
# 15           packet_count_incr   -1.375566
# 8                   dst_router   -1.657292
# 25            vnet_vc_cc_index   -1.688830
# 19                  port_index   -1.817383
# 14           packet_count_decr   -1.833771
# 24               vnet_vc_index   -2.022505
# 16            max_packet_count   -3.209338
# 5                         vnet   -4.678040
# 18            packet_max_index   -6.206137

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80     18075
#            1       0.68      0.73      0.70     11217
#
#     accuracy                           0.76     29292
#    macro avg       0.75      0.76      0.75     29292
# weighted avg       0.77      0.76      0.76     29292

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 88.43691855999181
# Test Prediction  83.20701898129182

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89     14371
#            1       0.82      0.89      0.85     10015
#
#     accuracy                           0.87     24386
#    macro avg       0.87      0.88      0.87     24386
# weighted avg       0.88      0.87      0.87     24386

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 71.13931577490492
# Test Prediction Score 71.40572459607972

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72     14371
#            1       0.61      0.85      0.71     10015
#
#     accuracy                           0.71     24386
#    macro avg       0.73      0.73      0.71     24386
# weighted avg       0.75      0.71      0.71     24386

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/10
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1771 - accuracy: 0.7379 - val_loss: 0.1494 - val_accuracy: 0.7969
# Epoch 2/10
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1499 - accuracy: 0.7959 - val_loss: 0.1478 - val_accuracy: 0.7947
# Epoch 3/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1487 - accuracy: 0.7949 - val_loss: 0.1468 - val_accuracy: 0.7933
# Epoch 4/10
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1480 - accuracy: 0.7953 - val_loss: 0.1465 - val_accuracy: 0.7925
# Epoch 5/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1475 - accuracy: 0.7961 - val_loss: 0.1457 - val_accuracy: 0.7954
# Epoch 6/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1472 - accuracy: 0.7961 - val_loss: 0.1453 - val_accuracy: 0.7953
# Epoch 7/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1468 - accuracy: 0.7965 - val_loss: 0.1456 - val_accuracy: 0.7953
# Epoch 8/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1466 - accuracy: 0.7967 - val_loss: 0.1448 - val_accuracy: 0.7962
# Epoch 9/10
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1463 - accuracy: 0.7972 - val_loss: 0.1444 - val_accuracy: 0.8003
# Epoch 10/10
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1460 - accuracy: 0.7974 - val_loss: 0.1456 - val_accuracy: 0.7950

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 79.74%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2 )
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2441 - accuracy: 0.5793 - val_loss: 0.2424 - val_accuracy: 0.5886
# Epoch 2/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2422 - accuracy: 0.5891 - val_loss: 0.2421 - val_accuracy: 0.5886
# Epoch 3/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.2420 - accuracy: 0.5891 - val_loss: 0.2419 - val_accuracy: 0.5886
# Epoch 4/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2416 - accuracy: 0.5891 - val_loss: 0.2413 - val_accuracy: 0.5886
# Epoch 5/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2393 - accuracy: 0.5892 - val_loss: 0.2345 - val_accuracy: 0.6008
# Epoch 6/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.2210 - accuracy: 0.6545 - val_loss: 0.2067 - val_accuracy: 0.6940
# Epoch 7/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1988 - accuracy: 0.7083 - val_loss: 0.1892 - val_accuracy: 0.7265
# Epoch 8/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1803 - accuracy: 0.7408 - val_loss: 0.1697 - val_accuracy: 0.7639
# Epoch 9/15
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1623 - accuracy: 0.7795 - val_loss: 0.1549 - val_accuracy: 0.7948
# Epoch 10/15
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1531 - accuracy: 0.7955 - val_loss: 0.1502 - val_accuracy: 0.7970
# Epoch 11/15
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1502 - accuracy: 0.7986 - val_loss: 0.1481 - val_accuracy: 0.7991
# Epoch 12/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1490 - accuracy: 0.7987 - val_loss: 0.1474 - val_accuracy: 0.7984
# Epoch 13/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1483 - accuracy: 0.7984 - val_loss: 0.1470 - val_accuracy: 0.7974
# Epoch 14/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1478 - accuracy: 0.7987 - val_loss: 0.1461 - val_accuracy: 0.7982
# Epoch 15/15
# 78032/78032 [==============================] - 3s 33us/step - loss: 0.1474 - accuracy: 0.7981 - val_loss: 0.1459 - val_accuracy: 0.7969

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 80.00%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2434 - accuracy: 0.5891 - val_loss: 0.2420 - val_accuracy: 0.5886
# Epoch 2/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.2418 - accuracy: 0.5891 - val_loss: 0.2417 - val_accuracy: 0.5886
# Epoch 3/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2414 - accuracy: 0.5891 - val_loss: 0.2411 - val_accuracy: 0.5886
# Epoch 4/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2406 - accuracy: 0.5891 - val_loss: 0.2401 - val_accuracy: 0.5886
# Epoch 5/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.2389 - accuracy: 0.5891 - val_loss: 0.2370 - val_accuracy: 0.5886
# Epoch 6/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.2294 - accuracy: 0.5891 - val_loss: 0.2139 - val_accuracy: 0.5886
# Epoch 7/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1879 - accuracy: 0.7210 - val_loss: 0.1617 - val_accuracy: 0.7817
# Epoch 8/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1509 - accuracy: 0.7969 - val_loss: 0.1423 - val_accuracy: 0.8066
# Epoch 9/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1409 - accuracy: 0.8038 - val_loss: 0.1371 - val_accuracy: 0.8068
# Epoch 10/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1375 - accuracy: 0.8045 - val_loss: 0.1349 - val_accuracy: 0.8056
# Epoch 11/30
# 78032/78032 [==============================] - 3s 34us/step - loss: 0.1356 - accuracy: 0.8065 - val_loss: 0.1326 - val_accuracy: 0.8093
# Epoch 12/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1339 - accuracy: 0.8082 - val_loss: 0.1311 - val_accuracy: 0.8127
# Epoch 13/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1327 - accuracy: 0.8093 - val_loss: 0.1300 - val_accuracy: 0.8154
# Epoch 14/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1319 - accuracy: 0.8111 - val_loss: 0.1292 - val_accuracy: 0.8156
# Epoch 15/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1311 - accuracy: 0.8118 - val_loss: 0.1285 - val_accuracy: 0.8146
# Epoch 16/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1305 - accuracy: 0.8124 - val_loss: 0.1279 - val_accuracy: 0.8197
# Epoch 17/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1299 - accuracy: 0.8139 - val_loss: 0.1276 - val_accuracy: 0.8191
# Epoch 18/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1294 - accuracy: 0.8140 - val_loss: 0.1268 - val_accuracy: 0.8184
# Epoch 19/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1289 - accuracy: 0.8144 - val_loss: 0.1266 - val_accuracy: 0.8207
# Epoch 20/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1284 - accuracy: 0.8144 - val_loss: 0.1260 - val_accuracy: 0.8201
# Epoch 21/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1280 - accuracy: 0.8153 - val_loss: 0.1254 - val_accuracy: 0.8202
# Epoch 22/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1275 - accuracy: 0.8150 - val_loss: 0.1251 - val_accuracy: 0.8212
# Epoch 23/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1271 - accuracy: 0.8153 - val_loss: 0.1258 - val_accuracy: 0.8194
# Epoch 24/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1267 - accuracy: 0.8150 - val_loss: 0.1254 - val_accuracy: 0.8210
# Epoch 25/30
# 78032/78032 [==============================] - 3s 37us/step - loss: 0.1262 - accuracy: 0.8156 - val_loss: 0.1250 - val_accuracy: 0.8184
# Epoch 26/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1260 - accuracy: 0.8156 - val_loss: 0.1238 - val_accuracy: 0.8222
# Epoch 27/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1257 - accuracy: 0.8170 - val_loss: 0.1236 - val_accuracy: 0.8224
# Epoch 28/30
# 78032/78032 [==============================] - 3s 36us/step - loss: 0.1253 - accuracy: 0.8172 - val_loss: 0.1244 - val_accuracy: 0.8214
# Epoch 29/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1251 - accuracy: 0.8165 - val_loss: 0.1235 - val_accuracy: 0.8231
# Epoch 30/30
# 78032/78032 [==============================] - 3s 35us/step - loss: 0.1248 - accuracy: 0.8173 - val_loss: 0.1228 - val_accuracy: 0.8226

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 82.11%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 78032 samples, validate on 19509 samples
# Epoch 1/100
# 78032/78032 [==============================] - 6s 73us/step - loss: 0.1303 - accuracy: 0.8096 - val_loss: 0.1168 - val_accuracy: 0.8288
# Epoch 2/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.1194 - accuracy: 0.8248 - val_loss: 0.1115 - val_accuracy: 0.8355
# Epoch 3/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1165 - accuracy: 0.8298 - val_loss: 0.1082 - val_accuracy: 0.8383
# Epoch 4/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1142 - accuracy: 0.8348 - val_loss: 0.1059 - val_accuracy: 0.8468
# Epoch 5/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1131 - accuracy: 0.8362 - val_loss: 0.1156 - val_accuracy: 0.8279
# Epoch 6/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1120 - accuracy: 0.8384 - val_loss: 0.1041 - val_accuracy: 0.8495
# Epoch 7/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1104 - accuracy: 0.8398 - val_loss: 0.1017 - val_accuracy: 0.8527
# Epoch 8/100
# 78032/78032 [==============================] - 5s 68us/step - loss: 0.1100 - accuracy: 0.8419 - val_loss: 0.0973 - val_accuracy: 0.8596
# Epoch 9/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1087 - accuracy: 0.8433 - val_loss: 0.1038 - val_accuracy: 0.8526
# Epoch 10/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1081 - accuracy: 0.8441 - val_loss: 0.1009 - val_accuracy: 0.8580
# Epoch 11/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.1071 - accuracy: 0.8459 - val_loss: 0.0984 - val_accuracy: 0.8608
# Epoch 12/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1066 - accuracy: 0.8470 - val_loss: 0.0960 - val_accuracy: 0.8612
# Epoch 13/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.1058 - accuracy: 0.8482 - val_loss: 0.0963 - val_accuracy: 0.8602
# Epoch 14/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1050 - accuracy: 0.8508 - val_loss: 0.0965 - val_accuracy: 0.8601
# Epoch 15/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1038 - accuracy: 0.8521 - val_loss: 0.0962 - val_accuracy: 0.8646
# Epoch 16/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.1042 - accuracy: 0.8514 - val_loss: 0.0954 - val_accuracy: 0.8618
# Epoch 17/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.1035 - accuracy: 0.8531 - val_loss: 0.0939 - val_accuracy: 0.8682
# Epoch 18/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.1033 - accuracy: 0.8531 - val_loss: 0.0927 - val_accuracy: 0.8687
# Epoch 19/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1024 - accuracy: 0.8542 - val_loss: 0.0962 - val_accuracy: 0.8666
# Epoch 20/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1016 - accuracy: 0.8564 - val_loss: 0.0919 - val_accuracy: 0.8691
# Epoch 21/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.1017 - accuracy: 0.8549 - val_loss: 0.0973 - val_accuracy: 0.8575
# Epoch 22/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.1015 - accuracy: 0.8546 - val_loss: 0.0985 - val_accuracy: 0.8586
# Epoch 23/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1010 - accuracy: 0.8556 - val_loss: 0.0995 - val_accuracy: 0.8590
# Epoch 24/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1003 - accuracy: 0.8565 - val_loss: 0.1086 - val_accuracy: 0.8448
# Epoch 25/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.1003 - accuracy: 0.8570 - val_loss: 0.0906 - val_accuracy: 0.8687
# Epoch 26/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0996 - accuracy: 0.8579 - val_loss: 0.0907 - val_accuracy: 0.8721
# Epoch 27/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0990 - accuracy: 0.8587 - val_loss: 0.0908 - val_accuracy: 0.8684
# Epoch 28/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0987 - accuracy: 0.8601 - val_loss: 0.0900 - val_accuracy: 0.8692
# Epoch 29/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0985 - accuracy: 0.8595 - val_loss: 0.0898 - val_accuracy: 0.8708
# Epoch 30/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0982 - accuracy: 0.8606 - val_loss: 0.0908 - val_accuracy: 0.8714
# Epoch 31/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0982 - accuracy: 0.8604 - val_loss: 0.0889 - val_accuracy: 0.8750
# Epoch 32/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0982 - accuracy: 0.8607 - val_loss: 0.0929 - val_accuracy: 0.8658
# Epoch 33/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0977 - accuracy: 0.8608 - val_loss: 0.0891 - val_accuracy: 0.8723
# Epoch 34/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0975 - accuracy: 0.8604 - val_loss: 0.0872 - val_accuracy: 0.8761
# Epoch 35/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0968 - accuracy: 0.8609 - val_loss: 0.0865 - val_accuracy: 0.8736
# Epoch 36/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0967 - accuracy: 0.8621 - val_loss: 0.0881 - val_accuracy: 0.8739
# Epoch 37/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0967 - accuracy: 0.8621 - val_loss: 0.0881 - val_accuracy: 0.8769
# Epoch 38/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0965 - accuracy: 0.8634 - val_loss: 0.0884 - val_accuracy: 0.8727
# Epoch 39/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0966 - accuracy: 0.8633 - val_loss: 0.0883 - val_accuracy: 0.8745
# Epoch 40/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0960 - accuracy: 0.8633 - val_loss: 0.0909 - val_accuracy: 0.8695
# Epoch 41/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0958 - accuracy: 0.8642 - val_loss: 0.0906 - val_accuracy: 0.8745
# Epoch 42/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0954 - accuracy: 0.8642 - val_loss: 0.0882 - val_accuracy: 0.8761
# Epoch 43/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0960 - accuracy: 0.8634 - val_loss: 0.0928 - val_accuracy: 0.8690
# Epoch 44/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0956 - accuracy: 0.8639 - val_loss: 0.0860 - val_accuracy: 0.8769
# Epoch 45/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0952 - accuracy: 0.8647 - val_loss: 0.0861 - val_accuracy: 0.8810
# Epoch 46/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0946 - accuracy: 0.8661 - val_loss: 0.0868 - val_accuracy: 0.8757
# Epoch 47/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0945 - accuracy: 0.8647 - val_loss: 0.0844 - val_accuracy: 0.8798
# Epoch 48/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0949 - accuracy: 0.8648 - val_loss: 0.0865 - val_accuracy: 0.8786
# Epoch 49/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0942 - accuracy: 0.8650 - val_loss: 0.0879 - val_accuracy: 0.8728
# Epoch 50/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0939 - accuracy: 0.8663 - val_loss: 0.0858 - val_accuracy: 0.8771
# Epoch 51/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0946 - accuracy: 0.8654 - val_loss: 0.0854 - val_accuracy: 0.8767
# Epoch 52/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0941 - accuracy: 0.8663 - val_loss: 0.0873 - val_accuracy: 0.8788
# Epoch 53/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0938 - accuracy: 0.8659 - val_loss: 0.0876 - val_accuracy: 0.8757
# Epoch 54/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0940 - accuracy: 0.8654 - val_loss: 0.0832 - val_accuracy: 0.8802
# Epoch 55/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0934 - accuracy: 0.8663 - val_loss: 0.0862 - val_accuracy: 0.8770
# Epoch 56/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0935 - accuracy: 0.8663 - val_loss: 0.0846 - val_accuracy: 0.8799
# Epoch 57/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0938 - accuracy: 0.8654 - val_loss: 0.0869 - val_accuracy: 0.8776
# Epoch 58/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0926 - accuracy: 0.8682 - val_loss: 0.0843 - val_accuracy: 0.8806
# Epoch 59/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0935 - accuracy: 0.8675 - val_loss: 0.0843 - val_accuracy: 0.8811
# Epoch 60/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0929 - accuracy: 0.8670 - val_loss: 0.0836 - val_accuracy: 0.8834
# Epoch 61/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0927 - accuracy: 0.8678 - val_loss: 0.0860 - val_accuracy: 0.8785
# Epoch 62/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0924 - accuracy: 0.8680 - val_loss: 0.0819 - val_accuracy: 0.8838
# Epoch 63/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0922 - accuracy: 0.8695 - val_loss: 0.0878 - val_accuracy: 0.8750
# Epoch 64/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0920 - accuracy: 0.8685 - val_loss: 0.0820 - val_accuracy: 0.8831
# Epoch 65/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0922 - accuracy: 0.8691 - val_loss: 0.0818 - val_accuracy: 0.8862
# Epoch 66/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0922 - accuracy: 0.8688 - val_loss: 0.0845 - val_accuracy: 0.8813
# Epoch 67/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0924 - accuracy: 0.8692 - val_loss: 0.0822 - val_accuracy: 0.8843
# Epoch 68/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0916 - accuracy: 0.8689 - val_loss: 0.0827 - val_accuracy: 0.8829
# Epoch 69/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0916 - accuracy: 0.8696 - val_loss: 0.0814 - val_accuracy: 0.8848
# Epoch 70/100
# 78032/78032 [==============================] - 6s 71us/step - loss: 0.0917 - accuracy: 0.8694 - val_loss: 0.0870 - val_accuracy: 0.8733
# Epoch 71/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0916 - accuracy: 0.8695 - val_loss: 0.0810 - val_accuracy: 0.8857
# Epoch 72/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0917 - accuracy: 0.8686 - val_loss: 0.0813 - val_accuracy: 0.8823
# Epoch 73/100
# 78032/78032 [==============================] - 5s 61us/step - loss: 0.0916 - accuracy: 0.8695 - val_loss: 0.0815 - val_accuracy: 0.8854
# Epoch 74/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0913 - accuracy: 0.8707 - val_loss: 0.0842 - val_accuracy: 0.8836
# Epoch 75/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0913 - accuracy: 0.8699 - val_loss: 0.0831 - val_accuracy: 0.8830
# Epoch 76/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0907 - accuracy: 0.8711 - val_loss: 0.0825 - val_accuracy: 0.8839
# Epoch 77/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0911 - accuracy: 0.8706 - val_loss: 0.0807 - val_accuracy: 0.8851
# Epoch 78/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0909 - accuracy: 0.8699 - val_loss: 0.0819 - val_accuracy: 0.8837
# Epoch 79/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0913 - accuracy: 0.8704 - val_loss: 0.0811 - val_accuracy: 0.8856
# Epoch 80/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0907 - accuracy: 0.8717 - val_loss: 0.0817 - val_accuracy: 0.8836
# Epoch 81/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0904 - accuracy: 0.8715 - val_loss: 0.0836 - val_accuracy: 0.8836
# Epoch 82/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0906 - accuracy: 0.8709 - val_loss: 0.0834 - val_accuracy: 0.8844
# Epoch 83/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0908 - accuracy: 0.8703 - val_loss: 0.0815 - val_accuracy: 0.8833
# Epoch 84/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0906 - accuracy: 0.8710 - val_loss: 0.0805 - val_accuracy: 0.8877
# Epoch 85/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0905 - accuracy: 0.8717 - val_loss: 0.0799 - val_accuracy: 0.8874
# Epoch 86/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0898 - accuracy: 0.8724 - val_loss: 0.0811 - val_accuracy: 0.8873
# Epoch 87/100
# 78032/78032 [==============================] - 5s 63us/step - loss: 0.0902 - accuracy: 0.8707 - val_loss: 0.0823 - val_accuracy: 0.8819
# Epoch 88/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0899 - accuracy: 0.8722 - val_loss: 0.0814 - val_accuracy: 0.8854
# Epoch 89/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0903 - accuracy: 0.8713 - val_loss: 0.0800 - val_accuracy: 0.8885
# Epoch 90/100
# 78032/78032 [==============================] - 5s 62us/step - loss: 0.0900 - accuracy: 0.8718 - val_loss: 0.0798 - val_accuracy: 0.8871
# Epoch 91/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0898 - accuracy: 0.8732 - val_loss: 0.0813 - val_accuracy: 0.8847
# Epoch 92/100
# 78032/78032 [==============================] - 6s 80us/step - loss: 0.0892 - accuracy: 0.8731 - val_loss: 0.0807 - val_accuracy: 0.8849
# Epoch 93/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0895 - accuracy: 0.8719 - val_loss: 0.0843 - val_accuracy: 0.8808
# Epoch 94/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0890 - accuracy: 0.8733 - val_loss: 0.0819 - val_accuracy: 0.8852
# Epoch 95/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0894 - accuracy: 0.8723 - val_loss: 0.0792 - val_accuracy: 0.8878
# Epoch 96/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0895 - accuracy: 0.8729 - val_loss: 0.0854 - val_accuracy: 0.8780
# Epoch 97/100
# 78032/78032 [==============================] - 5s 64us/step - loss: 0.0890 - accuracy: 0.8735 - val_loss: 0.0790 - val_accuracy: 0.8901
# Epoch 98/100
# 78032/78032 [==============================] - 5s 65us/step - loss: 0.0897 - accuracy: 0.8728 - val_loss: 0.0802 - val_accuracy: 0.8859
# Epoch 99/100
# 78032/78032 [==============================] - 5s 66us/step - loss: 0.0889 - accuracy: 0.8730 - val_loss: 0.0792 - val_accuracy: 0.8874
# Epoch 100/100
# 78032/78032 [==============================] - 5s 67us/step - loss: 0.0895 - accuracy: 0.8722 - val_loss: 0.0805 - val_accuracy: 0.8885

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 88.81%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2) ,
            'max_features':range(0,25,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)
# Out:
# Best parameters: {'max_depth': 24, 'max_features': 24}
# Accuracy : 0.9315262089598747

# %%
dt = DecisionTreeClassifier(max_depth=25,max_features=25,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=25, max_features=25, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 99.13779846423554
# Test Prediction Score 95.66144509144591

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     14371
#            1       0.94      0.95      0.95     10015
#
#     accuracy                           0.96     24386
#    macro avg       0.95      0.96      0.96     24386
# weighted avg       0.96      0.96      0.96     24386

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250],
            'max_features':range(0,25,2)}
dt_g=RandomForestClassifier(random_state=42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=25,max_features=25,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features=25,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 99.74267231215592
# Test Prediction Score 95.88698433527433

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96     14371
#            1       0.93      0.97      0.95     10015
#
#     accuracy                           0.96     24386
#    macro avg       0.96      0.96      0.96     24386
# weighted avg       0.96      0.96      0.96     24386

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2),
            'n_estimators':[125,250,500],
           'min_child_weight':[1,3,6]}
xgb_g=XGBClassifier(random_state=42)
xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
xgb_cv.fit(X_train,y_train)

print("Best parameters:",xgb_cv.best_params_)
print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=25,min_child_weight=1,n_estimators=500,random_state=42)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=25,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.89440337909187
# Test Prediction Score 97.86762896744034

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     14371
#            1       0.97      0.98      0.97     10015
#
#     accuracy                           0.98     24386
#    macro avg       0.98      0.98      0.98     24386
# weighted avg       0.98      0.98      0.98     24386

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
param_grid = {'n_estimators': [x for x in range(24,40,2)],
              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
lgb_cv.fit(X_train, y_train)

print("Best parameters:",lgb_cv.best_params_)
print("Accuracy :",lgb_cv.best_score_)
# Out:
# Best parameters: {'learning_rate': 0.2, 'n_estimators': 38}
# Accuracy : 0.9121924746743849

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.2,  n_estimators = 500, max_depth = 21, random_state=42, min_child_weight=1,metric='l2')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.2, max_depth=21,
#                metric='l2', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 96.03232030873131
# Test Prediction Score 93.42165957664908

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,5100), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [5098,
#  1898,
#  1041,
#  998,
#  643,
#  630,
#  617,
#  575,
#  536,
#  514,
#  509,
#  476,
#  424,
#  308,
#  274,
#  172,
#  119,
#  68,
#  44,
#  23,
#  20,
#  13]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94     23048
#            1       0.89      0.96      0.92     15974
#
#     accuracy                           0.93     39022
#    macro avg       0.93      0.94      0.93     39022
# weighted avg       0.94      0.93      0.93     39022

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
