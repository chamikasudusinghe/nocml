# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/fft_test_unbalanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
root_dir = "/content/drive/My Drive/models"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE
import pickle

# %%
import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Importing Dataset from GitHub

# %% [markdown]
# Test Data

# %%
df0_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-15-m-12-r0.csv?token=AKVFSODVIIX4P6ZW6PEDU7262AAIE')
df0_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-15-m-7-r0.csv?token=AKVFSOBIJYMM6FVL5RUT2IK62AAII')
df0_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-4-m-12-r0.csv?token=AKVFSOCF7L5INJ5U6AGPWYC62AAIU')
df0_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-4-m-7-r0.csv?token=AKVFSOG2GUFVGIC6L42PLHC62AAIY')
df0_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-6-m-12-r0.csv?token=AKVFSOB3IPAUNBIIN7SAXBS62AAJI')
df0_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-6-m-7-r0.csv?token=AKVFSOGJ6MOSFNVOXBLYXXK62AAJO')
df0_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-9-m-12-r0.csv?token=AKVFSOC7RY5UV63X4GDHC4C62AAJ4')
df0_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r0/2-fft-malicious-n-0-9-m-7-r0.csv?token=AKVFSOAS5FOGGBFSE7KVIHS62AAKA')

df0_1['target'] = 0
df0_2['target'] = 0
df0_3['target'] = 0
df0_4['target'] = 0
df0_5['target'] = 0
df0_6['target'] = 0
df0_7['target'] = 0
df0_8['target'] = 0

# %%
df1_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-15-m-12-r1.csv?token=AKVFSOFVIDVPGV5BIT6ZLSK62AL4C')
df1_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-15-m-7-r1.csv?token=AKVFSOENTXSBKGQKX3SEPJK62AL4G')
df1_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-4-m-12-r1.csv?token=AKVFSOBA3XYPAOZW7VSB7FK62AL4Y')
df1_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-4-m-7-r1.csv?token=AKVFSOEDZ55N3MQDVBRCQVC62AL42')
df1_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-6-m-12-r1.csv?token=AKVFSOCOLU7EK3ISPCNUI7C62AL5K')
df1_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-6-m-7-r1.csv?token=AKVFSOGQ23N3PWMFBSTX7MC62AL5M')
df1_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-9-m-12-r1.csv?token=AKVFSOG5CFYYOJ7KFJQP6D262AL5Y')
df1_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r1/2-fft-malicious-n-0-9-m-7-r1.csv?token=AKVFSOGHA5OZP4AS7RX34IK62AL56')

df1_1['target'] = 0
df1_2['target'] = 0
df1_3['target'] = 0
df1_4['target'] = 0
df1_5['target'] = 0
df1_6['target'] = 0
df1_7['target'] = 0
df1_8['target'] = 0

# %%
df2_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-15-m-12-r2.csv?token=AKVFSOFMESJW3XDJKPCJNSC62AN7A')
df2_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-15-m-7-r2.csv?token=AKVFSOEKH6JEFOMOE4YQFWC62AN7G')
df2_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-4-m-12-r2.csv?token=AKVFSOEUJFROKVU5HGRRHOC62AQDE')
df2_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-4-m-7-r2.csv?token=AKVFSOHB26JO7UQHCQUEWQS62AN74')
df2_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-6-m-12-r2.csv?token=AKVFSOAVUCCQGJV4Y7355CS62AOAK')
df2_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-6-m-7-r2.csv?token=AKVFSOC4PSW5DJ2KZ3ZLTGS62AOAO')
df2_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-9-m-12-r2.csv?token=AKVFSOHQMSVA5NDAMCHC4M262AOA4')
df2_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r2/2-fft-malicious-n-0-9-m-7-r2.csv?token=AKVFSOFAVN5BAVDUS5MCCEK62AOBA')

df2_1['target'] = 0
df2_2['target'] = 0
df2_3['target'] = 0
df2_4['target'] = 0
df2_5['target'] = 0
df2_6['target'] = 0
df2_7['target'] = 0
df2_8['target'] = 0

# %%
df3_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-15-m-12-r3.csv?token=AKVFSODMLYRMZSB3VS33CGC62ATWK')
df3_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-15-m-7-r3.csv?token=AKVFSOHPLRDRYQVQBKUUYPS62ATWM')
df3_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-4-m-12-r3.csv?token=AKVFSOBVHXMU57MEUQNU5NS62ATWW')
df3_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-4-m-7-r3.csv?token=AKVFSOHDONC5IXEHPM2TIWK62ATW2')
df3_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-6-m-12-r3.csv?token=AKVFSOBPULJ3SMDXUHP2K6C62ATXC')
df3_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-6-m-7-r3.csv?token=AKVFSOFZN7KYEIOQDJXEG4C62ATXG')
df3_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-9-m-12-r3.csv?token=AKVFSOG2NJ34YJQG3WRVOJC62ATXO')
df3_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r3/2-fft-malicious-n-0-9-m-7-r3.csv?token=AKVFSOG7S4743PUWXMCXH4K62ATXS')

df3_1['target'] = 0
df3_2['target'] = 0
df3_3['target'] = 0
df3_4['target'] = 0
df3_5['target'] = 0
df3_6['target'] = 0
df3_7['target'] = 0
df3_8['target'] = 0

# %%
df4_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-15-m-12-r4.csv?token=AKVFSOFLDELBUGOHH2QKK4C62AVSS')
df4_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-15-m-7-r4.csv?token=AKVFSODNB7JRX5FM7HPFZX262AVSU')
df4_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-4-m-12-r4.csv?token=AKVFSOA42ITKWVVH44SMUJS62AVS4')
df4_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-4-m-7-r4.csv?token=AKVFSOAHMO7PPRPXSTLEGGC62AVS6')
df4_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-6-m-12-r4.csv?token=AKVFSOCSJJV27QJZRTQOMSK62AVTK')
df4_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-6-m-7-r4.csv?token=AKVFSOBT77CBSFFDQGMXDPC62AVTM')
df4_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-9-m-12-r4.csv?token=AKVFSOHOQZPJ7HBIJHY5WGK62AVTU')
df4_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r4/2-fft-malicious-n-0-9-m-7-r4.csv?token=AKVFSOAMF2VYNAAI25OYRCC62AVTY')

df4_1['target'] = 0
df4_2['target'] = 0
df4_3['target'] = 0
df4_4['target'] = 0
df4_5['target'] = 0
df4_6['target'] = 0
df4_7['target'] = 0
df4_8['target'] = 0

# %%
df5_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-15-m-12-r5.csv?token=AKVFSOGBACKZVIHGDQFMUMK62AZIU')
df5_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-15-m-7-r5.csv?token=AKVFSOB5PDKV5JP7ER3SYFS62AY4I')
df5_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-4-m-12-r5.csv?token=AKVFSOAHOMC7CQXA7UMWTS262AZK2')
df5_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-4-m-7-r5.csv?token=AKVFSOGGE4Z5EW6YWCRNBAS62AZLU')
df5_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-6-m-12-r5.csv?token=AKVFSOE5L6BQUDJMN7ZJCJC62AZMQ')
df5_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-6-m-7-r5.csv?token=AKVFSOCYY7KDTSS5DJ2K6VC62AZMU')
df5_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-9-m-12-r5.csv?token=AKVFSOEBCZVQINSRCJVUZOK62AZN2')
df5_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r5/2-fft-malicious-n-0-9-m-7-r5.csv?token=AKVFSOE3LQNC74GV77BH7P262AZN4')

df5_1['target'] = 0
df5_3['target'] = 0
df5_3['target'] = 0
df5_4['target'] = 0
df5_5['target'] = 0
df5_6['target'] = 0
df5_7['target'] = 0
df5_8['target'] = 0

# %%
df6_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-15-m-12-r6.csv?token=AKVFSOBZYD27MEC5FMK3CZC62EE6U')
df6_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-15-m-7-r6.csv?token=AKVFSOGLIORGONLU6QDSS2262EE6Y')
df6_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-4-m-12-r6.csv?token=AKVFSODJ3NM4FPLP62MBGRS62EFMK')
df6_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-4-m-7-r6.csv?token=AKVFSOA5F5P7R57CJWBYMCC62EFMM')
df6_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-6-m-12-r6.csv?token=AKVFSOAWDNDXXUQWCLRII3S62EFMQ')
df6_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-6-m-7-r6.csv?token=AKVFSOEHEMDKFTBRHSMOEZS62EFMQ')
df6_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-9-m-12-r6.csv?token=AKVFSOESBJNSB4USY4ET4Z262EFMU')
df6_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r6/2-fft-malicious-n-0-9-m-7-r6.csv?token=AKVFSOEA7545LFBCF7HSLHC62EFMY')

df6_1['target'] = 0
df6_2['target'] = 0
df6_3['target'] = 0
df6_4['target'] = 0
df6_5['target'] = 0
df6_6['target'] = 0
df6_7['target'] = 0
df6_8['target'] = 0

# %%
df7_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-15-m-12-r7.csv?token=AKVFSOAA2TKQBEJKWHORCE262EIL2')
df7_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-15-m-7-r7.csv?token=AKVFSOB47BJTPUYNCXAFE3S62EIL4')
df7_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-4-m-12-r7.csv?token=AKVFSOARDMUK2HZLGKD3KVS62EIL6')
df7_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-4-m-7-r7.csv?token=AKVFSOGODYHZQ6QMTKEYMZ262EIMC')
df7_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-6-m-12-r7.csv?token=AKVFSOCW3HCNVXWQ6OVLAQS62EIME')
df7_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-6-m-7-r7.csv?token=AKVFSODQNA4AW3BATEDCEGC62EIMI')
df7_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-9-m-12-r7.csv?token=AKVFSOFN36UQ6B5QGBVHCEC62EIMK')
df7_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r7/2-fft-malicious-n-0-9-m-7-r7.csv?token=AKVFSOCTAI6WHQN6WR3OLF262EIMQ')

df7_1['target'] = 0
df7_2['target'] = 0
df7_3['target'] = 0
df7_4['target'] = 0
df7_5['target'] = 0
df7_6['target'] = 0
df7_7['target'] = 0
df7_8['target'] = 0

# %%
df8_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-15-m-12-r8.csv?token=AKVFSOHNSTQZGH5SL36TE5262EKC4')
df8_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-15-m-7-r8.csv?token=AKVFSOHC2QNBQ75GAMG5VG262EKC6')
df8_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-4-m-12-r8.csv?token=AKVFSOF3QYDD3QALREOROXS62EKDC')
df8_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-4-m-7-r8.csv?token=AKVFSOCHJSWNA25AYTDM7YS62EKDE')
df8_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-6-m-12-r8.csv?token=AKVFSOG5WBR4IVLTTBZR2WS62EKDG')
df8_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-6-m-7-r8.csv?token=AKVFSODJJV3VHCL5TFBHQ4K62EKDI')
df8_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-9-m-12-r8.csv?token=AKVFSOGJ7MFPRAFYF2WMODC62EKDM')
df8_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r8/2-fft-malicious-n-0-9-m-7-r8.csv?token=AKVFSOEARUU6CR7PXIFTXNK62EKDO')

df8_1['target'] = 0
df8_2['target'] = 0
df8_3['target'] = 0
df8_4['target'] = 0
df8_5['target'] = 0
df8_6['target'] = 0
df8_7['target'] = 0
df8_8['target'] = 0

# %%
df9_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-15-m-12-r9.csv?token=AKVFSOFUBDKMIYDT3YXQDFK62EMK2')
df9_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-15-m-7-r9.csv?token=AKVFSOEF6HP6UHL72H6MNGK62EMK2')
df9_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-4-m-12-r9.csv?token=AKVFSOG5VGBDH5J6W35ZLBC62EMK2')
df9_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-4-m-7-r9.csv?token=AKVFSOF6FTRNJINHMGN3OVC62EMK2')
df9_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-6-m-12-r9.csv?token=AKVFSOHJ6SSYAELIWA4O4VC62EMK4')
df9_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-6-m-7-r9.csv?token=AKVFSOCWKRI2P3R72TJIBCS62EMLA')
df9_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-9-m-12-r9.csv?token=AKVFSOAZC5L2QHJ2ADBYR2C62EMLG')
df9_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r9/2-fft-malicious-n-0-9-m-7-r9.csv?token=AKVFSOHZCQ6QUVG3HRMISO262EMLI')

df9_1['target'] = 0
df9_2['target'] = 0
df9_3['target'] = 0
df9_4['target'] = 0
df9_5['target'] = 0
df9_6['target'] = 0
df9_7['target'] = 0
df9_8['target'] = 0

# %%
df10_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-15-m-12-r10.csv?token=AKVFSOA4TVH4SKY74CX6OWS62EQDG')
df10_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-15-m-7-r10.csv?token=AKVFSOGXJAS2OYGKTVU7GLC62EQDI')
df10_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-4-m-12-r10.csv?token=AKVFSOENQ5WWLG3OPAJUJDK62EQDK')
df10_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-4-m-7-r10.csv?token=AKVFSOFICOX2GKWP3CQ5TPS62EQDM')
df10_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-6-m-12-r10.csv?token=AKVFSOHRH43XVZXNTUKPJL262EQDQ')
df10_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-6-m-7-r10.csv?token=AKVFSOCBY35PLJVNY7IKY6262EQDU')
df10_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-9-m-12-r10.csv?token=AKVFSODVRSIROUKKZPUEBL262EQDY')
df10_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r10/2-fft-malicious-n-0-9-m-7-r10.csv?token=AKVFSOG4CNNI2LIN4WMLFU262EQD2')

df10_1['target'] = 0
df10_2['target'] = 0
df10_3['target'] = 0
df10_4['target'] = 0
df10_5['target'] = 0
df10_6['target'] = 0
df10_7['target'] = 0
df10_8['target'] = 0

# %%
df11_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-15-m-12-r11.csv?token=AKVFSOFZGKCTUJHNMVAVGL262ETYI')
df11_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-15-m-7-r11.csv?token=AKVFSOEOYRI6E77YSNE5YT262ETYK')
df11_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-4-m-12-r11.csv?token=AKVFSOBL4USCQF4ZJF3YJGS62ETYM')
df11_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-4-m-7-r11.csv?token=AKVFSOCZLWFR3TD6G654JDK62ETYO')
df11_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-6-m-12-r11.csv?token=AKVFSOAPQD3Z43GFW7QW7U262ETYS')
df11_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-6-m-7-r11.csv?token=AKVFSOFVRSWSKVKLECP57G262ETYU')
df11_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-9-m-12-r11.csv?token=AKVFSODEUDPKWSADE4Z2YJ262ETYW')
df11_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r11/2-fft-malicious-n-0-9-m-7-r11.csv?token=AKVFSOCQNMSU2UW2HX4YGC262ETY2')

df11_1['target'] = 0
df11_2['target'] = 0
df11_3['target'] = 0
df11_4['target'] = 0
df11_5['target'] = 0
df11_6['target'] = 0
df11_7['target'] = 0
df11_8['target'] = 0

# %%
df12_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-15-m-12-r12.csv?token=AKVFSOATBWOIN7ST6HO64ZC62EXQU')
df12_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-15-m-7-r12.csv?token=AKVFSOGNNCBYFXUZVY2ZJC262EXQW')
df12_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-4-m-12-r12.csv?token=AKVFSOEFG25XJZ7CT3PEHGC62EXQ2')
df12_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-4-m-7-r12.csv?token=AKVFSOHGRUELIVB2R4S3MQC62EXQ4')
df12_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-6-m-12-r12.csv?token=AKVFSOFLMHOCRZ2QAPYUMGC62EXQ6')
df12_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-6-m-7-r12.csv?token=AKVFSODPIEOQP52SHGKV24K62EXRA')
df12_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-9-m-12-r12.csv?token=AKVFSOCXFXUSMCZUG2IEKVC62EXRE')
df12_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r12/2-fft-malicious-n-0-9-m-7-r12.csv?token=AKVFSOF55ZEB336HTRYDTPC62EXRG')

df12_1['target'] = 0
df12_2['target'] = 0
df12_3['target'] = 0
df12_4['target'] = 0
df12_5['target'] = 0
df12_6['target'] = 0
df12_7['target'] = 0
df12_8['target'] = 0

# %%
df13_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-15-m-12-r13.csv?token=AKVFSOCJHDHH7AZ7CBRFR3C62EY3M')
df13_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-15-m-7-r13.csv?token=AKVFSOHOV2SATTP74CW4FN262EY3Q')
df13_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-4-m-12-r13.csv?token=AKVFSOE5Z7LIPMH3C3IY6SK62EY3S')
df13_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-4-m-7-r13.csv?token=AKVFSOAFRSBSUBQMYE4G3TS62EY3W')
df13_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-6-m-12-r13.csv?token=AKVFSOCF6YPGSM37Z3PGW7S62EY3Y')
df13_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-6-m-7-r13.csv?token=AKVFSODKRJ7WM5T3GS6CQ6K62EY32')
df13_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-9-m-12-r13.csv?token=AKVFSOH4QTOLXELJT4WF4PK62EY34')
df13_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r13/2-fft-malicious-n-0-9-m-7-r13.csv?token=AKVFSODUNIVWCT343PVKF2262EY36')

df13_1['target'] = 0
df13_2['target'] = 0
df13_3['target'] = 0
df13_4['target'] = 0
df13_5['target'] = 0
df13_6['target'] = 0
df13_7['target'] = 0
df13_8['target'] = 0

# %%
df14_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-15-m-12-r14.csv?token=AKVFSODTDWTDOUCMU3HZ4YK62EZ66')
df14_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-15-m-7-r14.csv?token=AKVFSOH6WKSOJG3PLIM7R7K62EZ7A')
df14_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-4-m-12-r14.csv?token=AKVFSOASON57244LKQWI3TK62EZ7C')
df14_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-4-m-7-r14.csv?token=AKVFSOCQATYAHMKF4B62WZK62EZ7E')
df14_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-6-m-12-r14.csv?token=AKVFSOCGWSYR5M4B5EUY34S62EZ7I')
df14_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-6-m-7-r14.csv?token=AKVFSOC3BY4N6JXWVPQG7AK62EZ7K')
df14_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-9-m-12-r14.csv?token=AKVFSOA44UGHRMFUNEZI3AK62EZ7O')
df14_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r14/2-fft-malicious-n-0-9-m-7-r14.csv?token=AKVFSOAWODGGAVSKCGB3Y5262EZ7Q')

df14_1['target'] = 0
df14_2['target'] = 0
df14_3['target'] = 0
df14_4['target'] = 0
df14_5['target'] = 0
df14_6['target'] = 0
df14_7['target'] = 0
df14_8['target'] = 0

# %%
df15_1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-15-m-12-r15.csv?token=AKVFSODA34LVQRUUE7TJZV262E24A')
df15_2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-15-m-7-r15.csv?token=AKVFSOBRAR7I73SMIWYDSPK62E24C')
df15_3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-4-m-12-r15.csv?token=AKVFSOBXDAEWXWEUOQW5F2K62E24E')
df15_4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-4-m-7-r15.csv?token=AKVFSOFJFYTW6Y36VMFOVP262E24G')
df15_5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-6-m-12-r15.csv?token=AKVFSODIRBQX27QX56ZMEI262E24K')
df15_6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-6-m-7-r15.csv?token=AKVFSOCYXLCGO7XRPX7VG2C62E24Q')
df15_7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-9-m-12-r15.csv?token=AKVFSOBSNMGFHC2EFR23YSS62E24Y')
df15_8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%203/fetch-router/r15/2-fft-malicious-n-0-9-m-7-r15.csv?token=AKVFSOCBEKYILKZQGXGHPYS62E242')

df15_1['target'] = 0
df15_2['target'] = 0
df15_3['target'] = 0
df15_4['target'] = 0
df15_5['target'] = 0
df15_6['target'] = 0
df15_7['target'] = 0
df15_8['target'] = 0

# %%
print(df15_8.shape)
df15_8
# Out:
# (29188, 30)
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            751        3       4  ...             27                18       0
# 1            804        3       4  ...             27                18       0
# 2            857        3       4  ...             27                18       0
# 3           1167        3       4  ...             27                18       0
# 4           1189        3       4  ...             27                18       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 29183    3265316        3       4  ...             27                54       0
# 29184    3265323        3       4  ...             27                54       0
# 29185    3265330        3       4  ...             27                54       0
# 29186    3265337        3       4  ...             27                54       0
# 29187    3265338        3       4  ...             30                18       0
#
# ...

# %%
import math
def roundup(x):
  return int(math.ceil(x / 100.0)) * 100

# %%
print(roundup(100))
# Out:
# 100

# %%
def timecount(df):
    timearr = []
    interval = 99
    count = 0
    for index, row in df.iterrows():
        if row["timestamp"]<=interval :
            count+=1
        else:
            timearr.append([interval+1,count])
            count=1
            if (row["timestamp"] == roundup(row["timestamp"])):
              interval = row["timestamp"]+99
            else:
              interval = roundup(row["timestamp"])-1
    timearr.append([interval+1,count])
    return timearr

# %%
def standardize(df):
  test_X = df.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
  test_Y = df['target']
  x = test_X.values
  min_max_scaler = preprocessing.MinMaxScaler()
  columns = test_X.columns
  x_scaled = min_max_scaler.fit_transform(x)
  test_X = pd.DataFrame(x_scaled)
  test_X.columns = columns
  print(test_X[test_X.duplicated()].shape)
  return test_X,test_Y

# %%
xgb_r0 = pickle.load(open(root_dir+"/xgbc-r0.pickle.dat", "rb"))
xgb_r1 = pickle.load(open(root_dir+"/xgbc-r1.pickle.dat", "rb"))
xgb_r2 = pickle.load(open(root_dir+"/xgbc-r2.pickle.dat", "rb"))
xgb_r3 = pickle.load(open(root_dir+"/xgbc-r3.pickle.dat", "rb"))
xgb_r4 = pickle.load(open(root_dir+"/xgbc-r4.pickle.dat", "rb"))
xgb_r5 = pickle.load(open(root_dir+"/xgbc-r5.pickle.dat", "rb"))
xgb_r6 = pickle.load(open(root_dir+"/xgbc-r6.pickle.dat", "rb"))
xgb_r7 = pickle.load(open(root_dir+"/xgbc-r7.pickle.dat", "rb"))
xgb_r8 = pickle.load(open(root_dir+"/xgbc-r8.pickle.dat", "rb"))
xgb_r9 = pickle.load(open(root_dir+"/xgbc-r9.pickle.dat", "rb"))
xgb_r10 = pickle.load(open(root_dir+"/xgbc-r10.pickle.dat", "rb"))
xgb_r11 = pickle.load(open(root_dir+"/xgbc-r11.pickle.dat", "rb"))
xgb_r12 = pickle.load(open(root_dir+"/xgbc-r12.pickle.dat", "rb"))
xgb_r13 = pickle.load(open(root_dir+"/xgbc-r13.pickle.dat", "rb"))
xgb_r14 = pickle.load(open(root_dir+"/xgbc-r14.pickle.dat", "rb"))
xgb_r15 = pickle.load(open(root_dir+"/xgbc-r15.pickle.dat", "rb"))

# %%
df0_1.shape
# Out:
# (97992, 30)

# %%
timearr0_1 = timecount(df0_1)
timearr1_1 = timecount(df1_1)
timearr2_1 = timecount(df2_1)
timearr3_1 = timecount(df3_1)
timearr4_1 = timecount(df4_1)
timearr5_1 = timecount(df5_1)
timearr6_1 = timecount(df6_1)
timearr7_1 = timecount(df7_1)
timearr8_1 = timecount(df8_1)
timearr9_1 = timecount(df9_1)
timearr10_1 = timecount(df10_1)
timearr11_1 = timecount(df11_1)
timearr12_1 = timecount(df12_1)
timearr13_1 = timecount(df13_1)
timearr14_1 = timecount(df14_1)
timearr15_1 = timecount(df15_1)

print(timearr0_1)
# Out:
# [[100, 6], [200, 6], [300, 1], [400.0, 6], [500, 6], [600, 8], [700, 7], [800, 13], [900, 2], [1000, 6], [1100, 6], [1200, 6], [1300, 6], [1400, 6], [1500, 6], [1600, 5], [1700, 6], [1800, 1], [1900, 7], [2000, 7], [2100.0, 7], [2200, 8], [2300, 9], [2400, 7], [2500, 9], [2600, 8], [2700, 9], [2800, 5], [2900, 1], [3000, 6], [3100, 5], [3300, 2], [3400.0, 4], [3500, 3], [3600, 7], [3700, 6], [3800, 5], [3900, 1], [4000, 5], [4100, 6], [4200, 7], [4300, 5], [4400, 1], [4500, 6], [4600, 8], [4700, 10], [4800, 12], [4900, 12], [5000, 6], [5100, 1], [5200, 5], [5300, 6], [5400, 6], [5500, 5], [5600.0, 7], [5700, 7], [5800, 5], [5900, 6], [6000, 5], [6100, 6], [6200.0, 2], [6300.0, 12], [6400.0, 3], [6500, 6], [6600, 6], [6700, 6], [6800, 5], [6900, 6], [7000, 6], [7100, 6], [7200, 9], [7300, 6], [7400, 8], [7500, 6], [7600, 4], [7700.0, 9], [7800, 2], [7900, 13], [8000, 10], [8100.0, 9], [8200, 9], [8300, 1], [8400, 8], [8500, 6], [8600, 6], [8700, 11], [8800, 6], [8900, 1], [9000, 6], [
# ...

# %%
print(max(timearr0_1[-1],timearr1_1[-1],timearr2_1[-1],timearr3_1[-1],timearr4_1[-1],timearr5_1[-1],timearr6_1[-1],timearr7_1[-1],timearr8_1[-1],timearr9_1[-1],timearr10_1[-1],timearr11_1[-1],timearr12_1[-1],timearr13_1[-1],timearr14_1[-1],timearr15_1[-1]))
# Out:
# [3278900, 3]

# %%
timearr0_1[-1]
# Out:
# [3278600, 3]

# %%
test_X,test_Y = standardize (df0_1)
counter = timearr0_1[0][1]
result_r0 = []

begin = counter
text_X0 = test_X[:counter]
text_Y0 = test_Y[:counter]
y_pred_xgbc_test= xgb_r0.predict(text_X0)
xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)
result_r0.append(xgbc_score_test*100)

for i in range(1,len(timearr0_1)):

  counter += timearr0_1[i][1]
  text_X0 = test_X[begin:counter]
  text_Y0 = test_Y[begin:counter]
  y_pred_xgbc_test= xgb_r0.predict(text_X0)
  xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)
  result_r0.append(xgbc_score_test*100)
  begin = counter
  #print(timearr0_1[i][0],length,text_X0.shape,text_Y0.shape,xgbc_score_test*100,begin,end,i,counter)
print(result_r0)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2090800 3 (6, 24) (6,) 100.0 58490 110739 7750 58490
# 2091000 3 (4, 24) (4,) 100.0 58494 110739 7751 58494
# 2091100.0 3 (14, 24) (14,) 100.0 58508 110739 7752 58508
# 2091400 3 (8, 24) (8,) 100.0 58516 110739 7753 58516
# 2091500 3 (10, 24) (10,) 100.0 58526 110739 7754 58526
# 2091800 3 (10, 24) (10,) 100.0 58536 110739 7755 58536
# 2091900 3 (8, 24) (8,) 25.0 58544 110739 7756 58544
# 2092100 3 (1, 24) (1,) 100.0 58545 110739 7757 58545
# 2092200 3 (6, 24) (6,) 100.0 58551 110739 7758 58551
# 2092300 3 (5, 24) (5,) 0.0 58556 110739 7759 58556
# 2092500 3 (4, 24) (4,) 100.0 58560 110739 7760 58560
# 2092600 3 (3, 24) (3,) 100.0 58563 110739 7761 58563
# 2092700 3 (5, 24) (5,) 0.0 58568 110739 7762 58568
# 2093200 3 (6, 24) (6,) 100.0 58574 110739 7763 58574
# 2093300 3 (12, 24) (12,) 0.0 58586 110739 7764 58586
# 2093400 3 (1, 24) (1,) 100.0 58587 110739 7765 58587
# 2093500 3 (5, 24) (5,) 0.0 58592 110739 7766 58592
# ...

# %%
test_X,test_Y = standardize (df1_1)#
counter = timearr1_1[0][1]#
result_r1 = []#

begin = counter
text_X0 = test_X[:counter]
text_Y0 = test_Y[:counter]

y_pred_xgbc_test= xgb_r1.predict(text_X0)#

xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)

result_r1.append(xgbc_score_test*100)#

for i in range(1,len(timearr1_1)):#

  counter += timearr1_1[i][1]#

  text_X0 = test_X[begin:counter]
  text_Y0 = test_Y[begin:counter]

  y_pred_xgbc_test= xgb_r1.predict(text_X0)#

  xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)

  result_r1.append(xgbc_score_test*100)##

  begin = counter
  #print(timearr0_1[i][0],length,text_X0.shape,text_Y0.shape,xgbc_score_test*100,begin,end,i,counter)
print(result_r1)#

# %%
def prediction(df,timearr,xgb):

  test_X,test_Y = standardize (df)
  counter = timearr[0][1]
  result = []
  begin = counter
  text_X0 = test_X[:counter]
  text_Y0 = test_Y[:counter]

  y_pred_xgbc_test= xgb.predict(text_X0)

  xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)
  
  result.append([timearr[0][0],xgbc_score_test*100]) 
  #print(result)


  for i in range(1,len(timearr)):

    counter += timearr[i][1]

    text_X0 = test_X[begin:counter]
    text_Y0 = test_Y[begin:counter]

    y_pred_xgbc_test= xgb.predict(text_X0)

    xgbc_score_test = accuracy_score(text_Y0,y_pred_xgbc_test)

    result.append([timearr[i][0],xgbc_score_test*100])

    #print(result)

    begin = counter
    #print(timearr0_1[i][0],length,text_X0.shape,text_Y0.shape,xgbc_score_test*100,begin,end,i,counter)

  return result

# %%
result0_1 = prediction(df0_1,timearr0_1,xgb_r0)
# Out:
# (35, 24)

# %%
result1_1 = prediction(df1_1,timearr1_1,xgb_r1)
result2_1 = prediction(df2_1,timearr2_1,xgb_r2)
result3_1 = prediction(df3_1,timearr3_1,xgb_r3)
result4_1 = prediction(df4_1,timearr4_1,xgb_r4)
result5_1 = prediction(df5_1,timearr5_1,xgb_r5)
result6_1 = prediction(df6_1,timearr6_1,xgb_r6)
result7_1 = prediction(df7_1,timearr7_1,xgb_r7)
result8_1 = prediction(df8_1,timearr8_1,xgb_r8)
result9_1 = prediction(df9_1,timearr9_1,xgb_r9)
result10_1 = prediction(df10_1,timearr10_1,xgb_r10)
result11_1 = prediction(df11_1,timearr11_1,xgb_r11)
result12_1 = prediction(df12_1,timearr12_1,xgb_r12)
result13_1 = prediction(df13_1,timearr13_1,xgb_r13)
result14_1 = prediction(df14_1,timearr14_1,xgb_r14)
result15_1 = prediction(df15_1,timearr15_1,xgb_r15)
# Out:
# (32, 24)
# (32, 24)
# (30, 24)
# (61, 24)
# (18, 24)
# (18, 24)
# (15, 24)
# (47, 24)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (7, 24)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (22, 24)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
print(result15_1)
# Out:
# [[100, 75.0], [200, 100.0], [300, 16.666666666666664], [400, 75.0], [500, 100.0], [600, 100.0], [700.0, 0.0], [800, 83.33333333333334], [900, 100.0], [1000, 100.0], [1100, 85.71428571428571], [1200, 100.0], [1300, 100.0], [1400, 100.0], [1500, 100.0], [1600, 100.0], [1700, 100.0], [1800, 100.0], [1900, 100.0], [2000, 100.0], [2100, 33.33333333333333], [2200, 100.0], [2300, 50.0], [2400, 100.0], [2500, 14.285714285714285], [2600, 83.33333333333334], [2700, 16.666666666666664], [2800, 100.0], [2900, 100.0], [3000.0, 100.0], [3100, 100.0], [3200, 100.0], [3300, 37.5], [3400, 100.0], [3500, 0.0], [3600, 85.71428571428571], [3700, 90.0], [3800, 100.0], [3900, 100.0], [4000.0, 100.0], [4100, 100.0], [4200, 100.0], [4300, 100.0], [4400.0, 0.0], [4500, 0.0], [4600, 66.66666666666666], [4700, 100.0], [4800, 100.0], [5000, 80.0], [5100, 100.0], [5200, 100.0], [5300, 100.0], [5400, 83.33333333333334], [5500, 100.0], [5600, 100.0], [5700, 83.33333333333334], [5800, 16.666666666666664], [5900, 0.
# ...

# %%
indexarr = []

for i in range(100,3278901,100):
  indexarr.append(i)

print(indexarr)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900, 12000, 12100, 12200, 12300, 12400, 12500, 12600, 12700, 12800, 12900, 13000, 13100, 13200, 13300, 13400, 13500, 13600, 13700, 13800, 13900, 14000, 14100, 14200, 14300, 14400, 14500, 14600, 14700, 14800, 14900, 15000, 15100, 15200, 15300, 15400, 15500, 15600, 15700, 15800,
# ...

# %%
df = pd.DataFrame()

# %%
df = df.assign(index=indexarr)
df
# Out:
#          index
# 0          100
# 1          200
# 2          300
# 3          400
# 4          500
# ...        ...
# 32784  3278500
# 32785  3278600
# 32786  3278700
# 32787  3278800
# 32788  3278900
#
# [32789 rows x 1 columns]

# %%
df0 = pd.DataFrame()
df0 = df0.assign(index=[i[0] for i in result0_1])
df0 = df0.assign(count0=[i[1] for i in result0_1])
df0
# Out:
#            index      count0
# 0          100.0    0.000000
# 1          200.0    0.000000
# 2          300.0    0.000000
# 3          400.0   16.666667
# 4          500.0   83.333333
# ...          ...         ...
# 12743  3276700.0  100.000000
# 12744  3276900.0  100.000000
# 12745  3278300.0  100.000000
# 12746  3278500.0  100.000000
# 12747  3278600.0  100.000000
#
# [12748 rows x 2 columns]

# %%
df1 = pd.DataFrame()
df1 = df1.assign(index=[i[0] for i in result1_1])
df1 = df1.assign(count1=[i[1] for i in result1_1])

df2= pd.DataFrame()
df2 = df2.assign(index=[i[0] for i in result2_1])
df2 = df2.assign(count2=[i[1] for i in result2_1])

df3 = pd.DataFrame()
df3 = df3.assign(index=[i[0] for i in result3_1])
df3 = df3.assign(count3=[i[1] for i in result3_1])

df4 = pd.DataFrame()
df4 = df4.assign(index=[i[0] for i in result4_1])
df4 = df4.assign(count4=[i[1] for i in result4_1])

df5 = pd.DataFrame()
df5 = df5.assign(index=[i[0] for i in result5_1])
df5 = df5.assign(count5=[i[1] for i in result5_1])

df6 = pd.DataFrame()
df6 = df6.assign(index=[i[0] for i in result6_1])
df6 = df6.assign(count6=[i[1] for i in result6_1])

df7= pd.DataFrame()
df7 = df7.assign(index=[i[0] for i in result7_1])
df7 = df7.assign(count7=[i[1] for i in result7_1])

df8 = pd.DataFrame()
df8 = df8.assign(index=[i[0] for i in result8_1])
df8 = df8.assign(count8=[i[1] for i in result8_1])

df9 = pd.DataFrame()
df9 = df9.assign(index=[i[0] for i in result9_1])
df9 = df9.assign(count9=[i[1] for i in result9_1])

df10 = pd.DataFrame()
df10 = df10.assign(index=[i[0] for i in result10_1])
df10 = df10.assign(count10=[i[1] for i in result10_1])

df11 = pd.DataFrame()
df11 = df11.assign(index=[i[0] for i in result11_1])
df11 = df11.assign(count11=[i[1] for i in result11_1])

df12= pd.DataFrame()
df12 = df12.assign(index=[i[0] for i in result12_1])
df12 = df12.assign(count12=[i[1] for i in result12_1])

df13 = pd.DataFrame()
df13 = df13.assign(index=[i[0] for i in result13_1])
df13 = df13.assign(count13=[i[1] for i in result13_1])

df14 = pd.DataFrame()
df14 = df14.assign(index=[i[0] for i in result14_1])
df14 = df14.assign(count14=[i[1] for i in result14_1])

df15 = pd.DataFrame()
df15 = df15.assign(index=[i[0] for i in result15_1])
df15 = df15.assign(count15=[i[1] for i in result15_1])

# %%
df0 = pd.merge(df,df0,on='index',how='left')
df1 = pd.merge(df,df1,on='index',how='left')
df2 = pd.merge(df,df2,on='index',how='left')
df3 = pd.merge(df,df3,on='index',how='left')
df4 = pd.merge(df,df4,on='index',how='left')
df5 = pd.merge(df,df5,on='index',how='left')
df6 = pd.merge(df,df6,on='index',how='left')
df7 = pd.merge(df,df7,on='index',how='left')
df8 = pd.merge(df,df8,on='index',how='left')
df9 = pd.merge(df,df9,on='index',how='left')
df10 = pd.merge(df,df10,on='index',how='left')
df11 = pd.merge(df,df11,on='index',how='left')
df12 = pd.merge(df,df12,on='index',how='left')
df13 = pd.merge(df,df13,on='index',how='left')
df14 = pd.merge(df,df14,on='index',how='left')
df15 = pd.merge(df,df15,on='index',how='left')

# %%
dfs = [df0, df1, df2, df3, df4, df5, df6,df7,df8,df9,df10,df11,df12,df13,df14,df15]

# %%
from functools import reduce

df_final = reduce(lambda left,right: pd.merge(left,right,on='index'), dfs)
df_final
# Out:
#          index      count0  count1  ...  count13  count14     count15
# 0          100    0.000000     0.0  ...    100.0      0.0   75.000000
# 1          200    0.000000     NaN  ...      NaN      NaN  100.000000
# 2          300    0.000000     0.0  ...      0.0     50.0   16.666667
# 3          400   16.666667   100.0  ...      0.0      0.0   75.000000
# 4          500   83.333333   100.0  ...    100.0      NaN  100.000000
# ...        ...         ...     ...  ...      ...      ...         ...
# 32784  3278500  100.000000   100.0  ...      NaN    100.0  100.000000
# 32785  3278600  100.000000   100.0  ...      NaN      NaN  100.000000
# 32786  3278700         NaN     NaN  ...      NaN    100.0  100.000000
# 32787  3278800         NaN     NaN  ...      NaN      NaN  100.000000
# 32788  3278900         NaN     NaN  ...      NaN      NaN  100.000000
#
# [32789 rows x 17 columns]

# %%
df_final.isnull().sum()
# Out:
# index          0
# count0     20041
# count1     23672
# count2     25971
# count3     27419
# count4     20213
# count5     23743
# count6     24225
# count7     23671
# count8     21605
# count9     24227
# count10    24730
# count11    21245
# count12    20857
# count13    23609
# count14    23411
# count15    20182
# dtype: int64

# %%
df_final.to_csv('fft-results.csv',index=False)
