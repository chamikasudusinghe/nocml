# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 10]
df = df.drop(columns=['router'])
df.to_csv('wat-r10-good.csv',index=False)

# %%
df = pd.read_csv('wat-r10-good.csv')
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           820        1       3                     1        1          4
# 1           936        4       2                     2        1          4
# 2          1358        0       3                     1        1          4
# 3          1366        4       0                     2        1          4
# 4          1418        0       1                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8592    3250453        1       3                     5        2          2
# 8593    3250460        1       3                     5        3          2
# 8594    3250467        1       3                     5        4          2
# 8595    3250474        1       3                     5        5          3
# 8596    3250475        1       3                     1        1          4
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       0           0      30          14             8
# 1        3   9      27          11      29          13             9
# 2        3   9       0           0      26          10            13
# 3        3   9      26          10      29          13            13
# 4        3   9      29          13      26          10            13
# ...    ...  ..     ...         ...     ...         ...           ...
# 8592     3   9       0           0      30          14         10016
# 8593     3   9       0           0      30          14         10016
# 8594     3   9       0           0      30          14         10016
# 8595     3   9       0           0      30          14         10016
# 8596     3  10       0           0      30          14         10017
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             5            4        0.800000            20
# 1             3            1        0.333333             8
# 2             4            4        1.000000            20
# 3             2            0        0.000000             4
# 4             2            2        1.000000            12
# ...         ...          ...             ...           ...
# 8592          5            4        0.800000            27
# 8593          5            4        0.800000            34
# 8594          5            4        0.800000            41
# 8595          5            4        0.800000            48
# 8596          5            4        0.800000            48
#
# [8597 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 8597

# %%
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           820        1       3                     1        1          4
# 1           936        4       2                     2        1          4
# 2          1358        0       3                     1        1          4
# 3          1366        4       0                     2        1          4
# 4          1418        0       1                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8592    3250453        1       3                     5        2          2
# 8593    3250460        1       3                     5        3          2
# 8594    3250467        1       3                     5        4          2
# 8595    3250474        1       3                     5        5          3
# 8596    3250475        1       3                     1        1          4
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       0           0      30          14             8
# 1        3   9      27          11      29          13             9
# 2        3   9       0           0      26          10            13
# 3        3   9      26          10      29          13            13
# 4        3   9      29          13      26          10            13
# ...    ...  ..     ...         ...     ...         ...           ...
# 8592     3   9       0           0      30          14         10016
# 8593     3   9       0           0      30          14         10016
# 8594     3   9       0           0      30          14         10016
# 8595     3   9       0           0      30          14         10016
# 8596     3  10       0           0      30          14         10017
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             5            4        0.800000            20
# 1             3            1        0.333333             8
# 2             4            4        1.000000            20
# 3             2            0        0.000000             4
# 4             2            2        1.000000            12
# ...         ...          ...             ...           ...
# 8592          5            4        0.800000            27
# 8593          5            4        0.800000            34
# 8594          5            4        0.800000            41
# 8595          5            4        0.800000            48
# 8596          5            4        0.800000            48
#
# [8597 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         820        1       3                     1        1          4
# 1         936        4       2                     2        1          4
# 2        1358        0       3                     1        1          4
# 3        1366        4       0                     2        1          4
# 4        1418        0       1                     3        1          4
# 5        1685        1       3                     1        1          4
# 6        2258        4       2                     2        1          4
# 7        2453        0       3                     1        1          4
# 8        2461        4       0                     2        1          4
# 9        2518        0       1                     3        1          4
# 10       2570        0       3                     1        1          4
# 11       2578        4       0                     2        1          4
# 12       2630        0       1                     3        1          4
# 13       2900        4       2                     2        1          4
# 14       4958        1       3                     1        1          4
# 15       5699        0       3                     1        1          4
# 16       5707        4       0                     2        1          4
# 17       5763        0       1                     3        1          4
# 18       5830        4       2                     2        1          4
# 19       5928        0       3                     1        1          4
# 20       5936        4       0                     2        1          4
# 21       5988        0       1                     3        1          4
# 22       6360        4       2                     2        1          4
# 23       7826        0       3                     1        1          4
# 24       7834        4       0                     2        1          4
# 25       7886        0       1                     3        1          4
# 26       8405        4       2                     2        1          4
# 27       8813        1       3                     1        1          4
# 28       9301        0       3                     5        1          1
# 29       9308        0       3                     5        2          2
# 30       9315        0       3                     5        3          2
# 31       9322        0       3                     5        4          2
# 32       9329        0       3                     5        5          3
# 33       9330        0       3                     1        1          4
# 34       9337        4       0                     6        1          1
# 35       9344        4       0                     6        2          2
# 36       9351        4       0                     6        3          2
# 37       9358        4       0                     6        4          2
# 38       9365        4       0                     6        5          3
# 39       9366        4       0                     2        1          4
# 40       9368        4       0                     7        1          4
# 41       9418        0       1                     3        1          4
# 42      10904        0       3                     1        1          4
# 43      10912        4       0                     2        1          4
# 44      10964        0       1                     3        1          4
# 45      11021        0       3                     5        1          1
# 46      11028        0       3                     5        2          2
# 47      11035        0       3                     5        3          2
# 48      11042        0       3                     5        4          2
# 49      11049        0       3                     5        5          3
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       0           0  ...                 1                   1
# 1      3   9      27          11  ...                 1                   1
# 2      3   9       0           0  ...                 1                   1
# 3      3   9      26          10  ...                 1                   1
# 4      3   9      29          13  ...                 1                   1
# 5      3   9       0           0  ...                 1                   1
# 6      3   9      27          11  ...                 1                   1
# 7      3   9       0           0  ...                 1                   1
# 8      3  10      26          10  ...                 1                   1
# 9      3   9      29          13  ...                 1                   1
# 10     3   9       0           0  ...                 1                   1
# 11     3  11      26          10  ...                 1                   1
# 12     3   9      29          13  ...                 1                   1
# 13     3   9      27          11  ...                 1                   1
# 14     3   9       0           0  ...                 1                   1
# 15     3   9       0           0  ...                 1                   1
# 16     3  12      26          10  ...                 1                   1
# 17     3   9      29          13  ...                 1                   1
# 18     3   9      27          11  ...                 1                   1
# 19     3   9       0           0  ...                 1                   1
# 20     3   9      26          10  ...                 1                   1
# 21     3   9      29          13  ...                 1                   1
# 22     3   9      27          11  ...                 1                   1
# 23     3   9       0           0  ...                 1                   1
# 24     3  10      26          10  ...                 1                   1
# 25     3   9      29          13  ...                 1                   1
# 26     3   9      27          11  ...                 1                   1
# 27     3   9       0           0  ...                 1                   1
# 28     3   9       0           0  ...                 1                   1
# 29     3   9       0           0  ...                 1                   1
# 30     3   9       0           0  ...                 1                   1
# 31     3   9       0           0  ...                 1                   1
# 32     3   9       0           0  ...                 1                   1
# 33     3  10       0           0  ...                 1                   1
# 34     3  11      26          10  ...                 1                   1
# 35     3  11      26          10  ...                 1                   1
# 36     3  11      26          10  ...                 1                   1
# 37     3  11      26          10  ...                 1                   1
# 38     3  11      26          10  ...                 1                   1
# 39     3  12      26          10  ...                 1                   1
# 40     3   9      26          10  ...                 1                   1
# 41     3   9      29          13  ...                 1                   1
# 42     3   9       0           0  ...                 1                   1
# 43     3  10      26          10  ...                 1                   1
# 44     3   9      29          13  ...                 1                   1
# 45     3   9       0           0  ...                 1                   1
# 46     3   9       0           0  ...                 1                   1
# 47     3   9       0           0  ...                 1                   1
# 48     3   9       0           0  ...                 1                   1
# 49     3   9       0           0  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                  1           3                           1           4
# 1                  1           8                           2           8
# 2                  1           0                           1           4
# 3                  1           0                           2           8
# 4                  1           0                           3          12
# 5                  1           3                           1           4
# 6                  1           8                           2           8
# 7                  1           0                           1           4
# 8                  1           0                           2           8
# 9                  1           0                           3          12
# 10                 1           0                           1           4
# 11                 1           0                           2           8
# 12                 1           0                           3          12
# 13                 1           8                           2           8
# 14                 1           3                           1           4
# 15                 1           0                           1           4
# 16                 1           0                           2           8
# 17                 1           0                           3          12
# 18                 1           8                           2           8
# 19                 1           0                           1           4
# 20                 1           0                           2           8
# 21                 1           0                           3          12
# 22                 1           8                           2           8
# 23                 1           0                           1           4
# 24                 1           0                           2           8
# 25                 1           0                           3          12
# 26                 1           8                           2           8
# 27                 1           3                           1           4
# 28                 1           0                           5           5
# 29                 1           0                          10          20
# 30                 1           0                          15          30
# 31                 1           0                          20          40
# 32                 1           0                          25          75
# 33                 1           0                           1           4
# 34                 1           0                           6           6
# 35                 1           0                          12          24
# 36                 1           0                          18          36
# 37                 1           0                          24          48
# 38                 1           0                          30          90
# 39                 1           0                           2           8
# 40                 1           0                           7          28
# 41                 1           0                           3          12
# 42                 1           0                           1           4
# 43                 1           0                           2           8
# 44                 1           0                           3          12
# 45                 1           0                           5           5
# 46                 1           0                          10          20
# 47                 1           0                          15          30
# 48                 1           0                          20          40
# 49                 1           0                          25          75
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                32                           3             27
# 1                72                           6             27
# 2                52                           3             27
# 3               104                           6             27
# 4               156                           9             27
# 5                64                           3             27
# 6               176                           6             27
# 7                96                           3             27
# 8               192                           6             30
# 9               288                           9             27
# 10              100                           3             27
# 11              200                           6             33
# 12              300                           9             27
# 13              216                           6             27
# 14              168                           3             27
# 15              196                           3             27
# 16              392                           6             36
# 17              588                           9             27
# 18              400                           6             27
# 19              204                           3             27
# 20              408                           6             27
# 21              612                           9             27
# 22              440                           6             27
# 23              268                           3             27
# 24              536                           6             30
# 25              804                           9             27
# 26              576                           6             27
# 27              304                           3             27
# 28              405                          15             27
# 29             1620                          15             27
# 30             2430                          15             27
# 31             3240                          15             27
# 32             6075                          15             27
# 33              328                           3             30
# 34              486                          18             33
# 35             1944                          18             33
# 36             2916                          18             33
# 37             3888                          18             33
# 38             7290                          18             33
# 39              656                           6             36
# 40             2268                          21             27
# 41              984                           9             27
# 42              392                           3             27
# 43              784                           6             30
# 44             1176                           9             27
# 45              495                          15             27
# 46             1980                          15             27
# 47             2970                          15             27
# 48             3960                          15             27
# 49             7425                          15             27
#
#     vnet_vc_cc_index
# 0                  9
# 1                 18
# 2                  9
# 3                 18
# 4                 27
# 5                  9
# 6                 18
# 7                  9
# 8                 18
# 9                 27
# 10                 9
# 11                18
# 12                27
# 13                18
# 14                 9
# 15                 9
# 16                18
# 17                27
# 18                18
# 19                 9
# 20                18
# 21                27
# 22                18
# 23                 9
# 24                18
# 25                27
# 26                18
# 27                 9
# 28                45
# 29                45
# 30                45
# 31                45
# 32                45
# 33                 9
# 34                54
# 35                54
# 36                54
# 37                54
# 38                54
# 39                18
# 40                63
# 41                27
# 42                 9
# 43                18
# 44                27
# 45                45
# 46                45
# 47                45
# 48                45
# 49                45
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           820        1       3                     1        1          4
# 1           936        4       2                     2        1          4
# 2          1358        0       3                     1        1          4
# 3          1366        4       0                     2        1          4
# 4          1418        0       1                     3        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8592    3250453        1       3                     5        2          2
# 8593    3250460        1       3                     5        3          2
# 8594    3250467        1       3                     5        4          2
# 8595    3250474        1       3                     5        5          3
# 8596    3250475        1       3                     1        1          4
#
#       vnet  vc  src_ni  src_router  ...  packet_count_index  packet_max_index  \
# 0        3   9       0           0  ...                   1                 1
# 1        3   9      27          11  ...                   1                 1
# 2        3   9       0           0  ...                   1                 1
# 3        3   9      26          10  ...                   1                 1
# 4        3   9      29          13  ...                   1                 1
# ...    ...  ..     ...         ...  ...                 ...               ...
# 8592     3   9       0           0  ...                   1                 1
# 8593     3   9       0           0  ...                   1                 1
# 8594     3   9       0           0  ...                   1                 1
# 8595     3   9       0           0  ...                   1                 1
# 8596     3  10       0           0  ...                   1                 1
#
#       port_index  cache_coherence_flit_index  flit_index  traversal_index  \
# 0              3                           1           4               32
# 1              8                           2           8               72
# 2              0                           1           4               52
# 3              0                           2           8              104
# 4              0                           3          12              156
# ...          ...                         ...         ...              ...
# 8592           3                          10          20           200320
# 8593           3                          15          30           300480
# 8594           3                          20          40           400640
# 8595           3                          25          75           751200
# 8596           3                           1           4            40068
#
#       cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index  target
# 0                              3             27                 9       1
# 1                              6             27                18       1
# 2                              3             27                 9       1
# 3                              6             27                18       1
# 4                              9             27                27       1
# ...                          ...            ...               ...     ...
# 8592                          15             27                45       1
# 8593                          15             27                45       1
# 8594                          15             27                45       1
# 8595                          15             27                45       1
# 8596                           3             30                 9       1
#
# [8597 rows x 30 columns]

# %%
df.to_csv('wat-r10-good.csv',index=False)
