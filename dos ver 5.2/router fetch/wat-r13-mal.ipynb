# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 13]
df = df.drop(columns=['router'])
df.to_csv('wat-r13-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r13-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            129        0       3                     2        1          4
# 1            150        0       3                     2        1          4
# 2            168        4       0                     3        1          4
# 3            169        3       0                     4        1          1
# 4            170        3       0                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 27153    2021439        3       0                     4        2          2
# 27154    2021440        3       0                     4        3          2
# 27155    2021441        3       0                     4        4          2
# 27156    2021442        2       0                     3        1          4
# 27157    2021445        3       0                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      24           8      29          13             2
# 1         3   9      24           8      29          13             3
# 2         3   9      29          13      24           8             2
# 3         5  17      29          13       1           1             2
# 4         5  17      29          13       1           1             2
# ...     ...  ..     ...         ...     ...         ...           ...
# 27153     5  17      29          13       1           1         11079
# 27154     5  17      29          13       1           1         11079
# 27155     5  17      29          13       1           1         11079
# 27156     3  10      29          13      26          10         11079
# 27157     5  17      29          13       1           1         11079
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            2             1.0            12
# 1              2            2             1.0            12
# 2              2            0             0.0             4
# 3              3            0             0.0             5
# 4              3            0             0.0             6
# ...          ...          ...             ...           ...
# 27153          3            0             0.0             5
# 27154          3            0             0.0             6
# 27155          3            0             0.0             7
# 27156          2            0             0.0             8
# 27157          3            0             0.0            11
#
# [27158 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 27158

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         129        0       3                     2        1          4
# 1         150        0       3                     2        1          4
# 2         168        4       0                     3        1          4
# 3         169        3       0                     4        1          1
# 4         170        3       0                     4        2          2
# 5         171        3       0                     4        3          2
# 6         172        3       0                     4        4          2
# 7         176        3       0                     4        5          3
# 8         190        4       0                     4        1          1
# 9         191        4       0                     4        2          2
# 10        192        4       0                     4        3          2
# 11        193        4       0                     3        1          4
# 12        194        4       0                     4        4          2
# 13        197        4       0                     4        5          3
# 14        810        3       2                     4        1          1
# 15        811        3       2                     4        2          2
# 16        812        3       2                     4        3          2
# 17        813        3       2                     4        4          2
# 18        817        3       2                     4        5          3
# 19        880        0       3                     2        1          4
# 20        880        4       2                     4        1          1
# 21        881        4       2                     4        2          2
# 22        882        4       2                     4        3          2
# 23        883        4       2                     4        4          2
# 24        887        4       2                     4        5          3
# 25        916        2       0                     3        1          4
# 26        917        3       0                     4        1          1
# 27        918        3       0                     4        2          2
# 28        919        3       0                     4        3          2
# 29        920        3       0                     4        4          2
# 30        924        3       0                     4        5          3
# 31        958        0       3                     2        1          4
# 32        975        0       3                     2        1          4
# 33        994        2       0                     3        1          4
# 34        995        4       0                     4        1          1
# 35        996        4       0                     4        2          2
# 36        997        4       0                     4        3          2
# 37        998        4       0                     4        4          2
# 38       1002        4       0                     4        5          3
# 39       1012        3       0                     4        1          1
# 40       1013        3       0                     4        2          2
# 41       1014        3       0                     4        3          2
# 42       1015        3       0                     3        1          4
# 43       1016        3       0                     4        4          2
# 44       1019        3       0                     4        5          3
# 45       1061        0       3                     2        1          4
# 46       1098        3       0                     3        1          4
# 47       1099        4       0                     4        1          1
# 48       1100        4       0                     4        2          2
# 49       1101        4       0                     4        3          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9      24           8  ...                14                  14
# 1      3   9      24           8  ...                14                  26
# 2      3   9      29          13  ...                14                  36
# 3      5  17      29          13  ...                14                  44
# 4      5  17      29          13  ...                14                  50
# 5      5  17      29          13  ...                14                  54
# 6      5  17      29          13  ...                14                  56
# 7      5  17      29          13  ...                14                  56
# 8      5  18      29          13  ...                14                  54
# 9      5  18      29          13  ...                14                  50
# 10     5  18      29          13  ...                14                  44
# 11     3  10      29          13  ...                14                  36
# 12     5  18      29          13  ...                14                  26
# 13     5  18      29          13  ...                14                  14
# 14     5  17      30          14  ...                 1                   1
# 15     5  17      30          14  ...                 1                   1
# 16     5  17      30          14  ...                 1                   1
# 17     5  17      30          14  ...                 1                   1
# 18     5  17      30          14  ...                 1                   1
# 19     3   9      27          11  ...                 1                   1
# 20     5  17      30          14  ...                 5                   5
# 21     5  17      30          14  ...                 5                   8
# 22     5  17      30          14  ...                 5                   9
# 23     5  17      30          14  ...                 5                   8
# 24     5  17      30          14  ...                 5                   5
# 25     3  11      29          13  ...                13                  13
# 26     5  19      29          13  ...                13                  24
# 27     5  19      29          13  ...                13                  33
# 28     5  19      29          13  ...                13                  40
# 29     5  19      29          13  ...                13                  45
# 30     5  19      29          13  ...                13                  48
# 31     3   9      27          11  ...                13                  49
# 32     3   9      25           9  ...                13                  48
# 33     3  12      29          13  ...                13                  45
# 34     5  20      29          13  ...                13                  40
# 35     5  20      29          13  ...                13                  33
# 36     5  20      29          13  ...                13                  24
# 37     5  20      29          13  ...                13                  13
# 38     5  20      29          13  ...                10                  10
# 39     5  17      29          13  ...                10                  18
# 40     5  17      29          13  ...                10                  24
# 41     5  17      29          13  ...                10                  28
# 42     3   9      29          13  ...                10                  30
# 43     5  17      29          13  ...                10                  30
# 44     5  17      29          13  ...                10                  28
# 45     3   9      25           9  ...                10                  24
# 46     3  10      29          13  ...                10                  18
# 47     5  18      29          13  ...                10                  10
# 48     5  18      29          13  ...                 5                   5
# 49     5  18      29          13  ...                 5                   8
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                196           0                           2           8
# 1                364           0                           2           8
# 2                504           0                           3          12
# 3                616           0                           4           4
# 4                700           0                           8          16
# 5                756           0                          12          24
# 6                784           0                          16          32
# 7                784           0                          20          60
# 8                756           0                           4           4
# 9                700           0                           8          16
# 10               616           0                          12          24
# 11               504           0                           3          12
# 12               364           0                          16          32
# 13               196           0                          20          60
# 14                 1           6                           4           4
# 15                 1           6                           8          16
# 16                 1           6                          12          24
# 17                 1           6                          16          32
# 18                 1           6                          20          60
# 19                 1           0                           2           8
# 20                25           8                           4           4
# 21                40           8                           8          16
# 22                45           8                          12          24
# 23                40           8                          16          32
# 24                25           8                          20          60
# 25               169           0                           3          12
# 26               312           0                           4           4
# 27               429           0                           8          16
# 28               520           0                          12          24
# 29               585           0                          16          32
# 30               624           0                          20          60
# 31               637           0                           2           8
# 32               624           0                           2           8
# 33               585           0                           3          12
# 34               520           0                           4           4
# 35               429           0                           8          16
# 36               312           0                          12          24
# 37               169           0                          16          32
# 38               100           0                          20          60
# 39               180           0                           4           4
# 40               240           0                           8          16
# 41               280           0                          12          24
# 42               300           0                           3          12
# 43               300           0                          16          32
# 44               280           0                          20          60
# 45               240           0                           2           8
# 46               180           0                           3          12
# 47               100           0                           4           4
# 48                25           0                           8          16
# 49                40           0                          12          24
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                16                           6             27
# 1                24                           6             27
# 2                24                           9             27
# 3                 8                          20             85
# 4                32                          20             85
# 5                48                          20             85
# 6                64                          20             85
# 7               120                          20             85
# 8                12                          20             90
# 9                48                          20             90
# 10               72                          20             90
# 11               36                           9             30
# 12               96                          20             90
# 13              180                          20             90
# 14               64                          20             85
# 15              256                          20             85
# 16              384                          20             85
# 17              512                          20             85
# 18              960                          20             85
# 19              144                           6             27
# 20               68                          20             85
# 21              272                          20             85
# 22              408                          20             85
# 23              544                          20             85
# 24             1020                          20             85
# 25              216                           9             33
# 26               72                          20             95
# 27              288                          20             95
# 28              432                          20             95
# 29              576                          20             95
# 30             1080                          20             95
# 31              152                           6             27
# 32              160                           6             27
# 33              228                           9             36
# 34               76                          20            100
# 35              304                          20            100
# 36              456                          20            100
# 37              608                          20            100
# 38             1140                          20            100
# 39               80                          20             85
# 40              320                          20             85
# 41              480                          20             85
# 42              240                           9             27
# 43              640                          20             85
# 44             1200                          20             85
# 45              168                           6             27
# 46              252                           9             30
# 47               84                          20             90
# 48              336                          20             90
# 49              504                          20             90
#
#     vnet_vc_cc_index
# 0                 18
# 1                 18
# 2                 27
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11                27
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19                18
# 20               100
# 21               100
# 22               100
# 23               100
# 24               100
# 25                27
# 26               100
# 27               100
# 28               100
# 29               100
# 30               100
# 31                18
# 32                18
# 33                27
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42                27
# 43               100
# 44               100
# 45                18
# 46                27
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            129        0       3                     2        1          4
# 1            150        0       3                     2        1          4
# 2            168        4       0                     3        1          4
# 3            169        3       0                     4        1          1
# 4            170        3       0                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 27153    2021439        3       0                     4        2          2
# 27154    2021440        3       0                     4        3          2
# 27155    2021441        3       0                     4        4          2
# 27156    2021442        2       0                     3        1          4
# 27157    2021445        3       0                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9      24           8  ...                14
# 1         3   9      24           8  ...                14
# 2         3   9      29          13  ...                14
# 3         5  17      29          13  ...                14
# 4         5  17      29          13  ...                14
# ...     ...  ..     ...         ...  ...               ...
# 27153     5  17      29          13  ...                 1
# 27154     5  17      29          13  ...                 1
# 27155     5  17      29          13  ...                 1
# 27156     3  10      29          13  ...                 1
# 27157     5  17      29          13  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                      14               196           0
# 1                      26               364           0
# 2                      36               504           0
# 3                      44               616           0
# 4                      50               700           0
# ...                   ...               ...         ...
# 27153                   1                 1           0
# 27154                   1                 1           0
# 27155                   1                 1           0
# 27156                   1                 1           0
# 27157                   1                 1           0
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               2           8               16
# 1                               2           8               24
# 2                               3          12               24
# 3                               4           4                8
# 4                               8          16               32
# ...                           ...         ...              ...
# 27153                           8          16           177264
# 27154                          12          24           265896
# 27155                          16          32           354528
# 27156                           3          12           132948
# 27157                          20          60           664740
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               6             27                18
# 1                               6             27                18
# 2                               9             27                27
# 3                              20             85               100
# 4                              20             85               100
# ...                           ...            ...               ...
# 27153                          20             85               100
# 27154                          20             85               100
# 27155                          20             85               100
# 27156                           9             30                27
# 27157                          20             85               100
#
# [27158 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            129        0       3                     2        1          4
# 1            150        0       3                     2        1          4
# 2            168        4       0                     3        1          4
# 3            169        3       0                     4        1          1
# 4            170        3       0                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 27153    2021439        3       0                     4        2          2
# 27154    2021440        3       0                     4        3          2
# 27155    2021441        3       0                     4        4          2
# 27156    2021442        2       0                     3        1          4
# 27157    2021445        3       0                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9      24           8  ...                  14
# 1         3   9      24           8  ...                  26
# 2         3   9      29          13  ...                  36
# 3         5  17      29          13  ...                  44
# 4         5  17      29          13  ...                  50
# ...     ...  ..     ...         ...  ...                 ...
# 27153     5  17      29          13  ...                   1
# 27154     5  17      29          13  ...                   1
# 27155     5  17      29          13  ...                   1
# 27156     3  10      29          13  ...                   1
# 27157     5  17      29          13  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                   196           0                           2           8
# 1                   364           0                           2           8
# 2                   504           0                           3          12
# 3                   616           0                           4           4
# 4                   700           0                           8          16
# ...                 ...         ...                         ...         ...
# 27153                 1           0                           8          16
# 27154                 1           0                          12          24
# 27155                 1           0                          16          32
# 27156                 1           0                           3          12
# 27157                 1           0                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                   16                           6             27
# 1                   24                           6             27
# 2                   24                           9             27
# 3                    8                          20             85
# 4                   32                          20             85
# ...                ...                         ...            ...
# 27153           177264                          20             85
# 27154           265896                          20             85
# 27155           354528                          20             85
# 27156           132948                           9             30
# 27157           664740                          20             85
#
#        vnet_vc_cc_index  target
# 0                    18       0
# 1                    18       0
# 2                    27       0
# 3                   100       0
# 4                   100       0
# ...                 ...     ...
# 27153               100       0
# 27154               100       0
# 27155               100       0
# 27156                27       0
# 27157               100       0
#
# [27158 rows x 30 columns]

# %%
df.to_csv('wat-r13-mal.csv',index=False)
