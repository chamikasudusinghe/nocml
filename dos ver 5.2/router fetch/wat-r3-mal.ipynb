# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 3]
df = df.drop(columns=['router'])
df.to_csv('wat-r3-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r3-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             15        1       4                     1        1          4
# 1             19        1       4                     1        1          4
# 2             78        1       4                     3        1          4
# 3            103        1       4                     3        1          4
# 4            341        1       4                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 15020    2008984        1       4                     5        4          2
# 15021    2008991        1       4                     5        5          3
# 15022    2008992        1       4                     1        1          4
# 15023    2021706        1       4                     5        1          1
# 15024    2021713        1       4                     5        2          2
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       1           1      23           7             1
# 1         3  10       0           0      23           7             0
# 2         3   9      18           2      23           7             1
# 3         3   9      18           2      23           7             0
# 4         3   9       1           1      23           7             6
# ...     ...  ..     ...         ...     ...         ...           ...
# 15020     3   9       0           0      27          11         11064
# 15021     3   9       0           0      27          11         11064
# 15022     3  10       0           0      27          11         11065
# 15023     3   9       1           1      27          11         11080
# 15024     3   9       1           1      27          11         11080
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              3            2        0.666667            12
# 1              4            3        0.750000            16
# 2              2            1        0.500000             8
# 3              2            1        0.500000            11
# 4              3            2        0.666667            12
# ...          ...          ...             ...           ...
# 15020          5            3        0.600000            37
# 15021          5            3        0.600000            44
# 15022          5            3        0.600000            44
# 15023          4            2        0.500000            12
# 15024          4            2        0.500000            19
#
# [15025 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 15025

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0          15        1       4                     1        1          4
# 1          19        1       4                     1        1          4
# 2          78        1       4                     3        1          4
# 3         103        1       4                     3        1          4
# 4         341        1       4                     1        1          4
# 5         377        1       4                     1        1          4
# 6         405        1       4                     3        1          4
# 7         438        1       4                     3        1          4
# 8         592        1       4                     1        1          4
# 9         650        1       4                     1        1          4
# 10        654        1       4                     3        1          4
# 11        710        1       4                     3        1          4
# 12        852        1       4                     1        1          4
# 13        930        1       4                     1        1          4
# 14       1932        0       4                     1        1          4
# 15       1940        4       0                     2        1          4
# 16       1996        0       4                     3        1          4
# 17       2073        0       4                     1        1          4
# 18       2081        4       0                     2        1          4
# 19       2092        1       4                     1        1          4
# 20       2134        0       4                     3        1          4
# 21       2252        1       4                     1        1          4
# 22       2701        1       4                     1        1          4
# 23       2892        1       4                     1        1          4
# 24       3517        1       4                     1        1          4
# 25       3578        1       4                     3        1          4
# 26       3729        1       4                     1        1          4
# 27       3794        1       4                     3        1          4
# 28       3997        1       4                     1        1          4
# 29       4237        1       4                     1        1          4
# 30       4816        1       4                     1        1          4
# 31       4878        1       4                     3        1          4
# 32       5100        1       4                     1        1          4
# 33       5164        1       4                     3        1          4
# 34       5513        1       4                     1        1          4
# 35       5736        1       4                     1        1          4
# 36       5796        1       4                     3        1          4
# 37       5845        1       4                     1        1          4
# 38       6012        1       4                     1        1          4
# 39       6085        1       4                     1        1          4
# 40       6150        1       4                     3        1          4
# 41       6378        1       4                     1        1          4
# 42       6865        0       4                     1        1          4
# 43       6873        4       0                     2        1          4
# 44       6926        0       4                     3        1          4
# 45       7275        0       4                     1        1          4
# 46       7283        4       0                     2        1          4
# 47       7336        0       4                     3        1          4
# 48       7750        1       4                     1        1          4
# 49       7810        1       4                     3        1          4
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       1           1  ...                 3                   3
# 1      3  10       0           0  ...                 3                   4
# 2      3   9      18           2  ...                 3                   3
# 3      3   9      18           2  ...                 1                   1
# 4      3   9       1           1  ...                 1                   1
# 5      3   9       0           0  ...                 1                   1
# 6      3   9      18           2  ...                 2                   2
# 7      3   9      18           2  ...                 2                   2
# 8      3   9       1           1  ...                 1                   1
# 9      3   9       0           0  ...                 2                   2
# 10     3  10      18           2  ...                 2                   2
# 11     3   9      18           2  ...                 1                   1
# 12     3   9       1           1  ...                 1                   1
# 13     3   9       0           0  ...                 1                   1
# 14     3   9       1           1  ...                 1                   1
# 15     3   9      19           3  ...                 1                   1
# 16     3   9      17           1  ...                 1                   1
# 17     3   9       0           0  ...                 1                   1
# 18     3  10      19           3  ...                 1                   1
# 19     3   9       1           1  ...                 1                   1
# 20     3   9      17           1  ...                 1                   1
# 21     3   9       0           0  ...                 1                   1
# 22     3   9       1           1  ...                 1                   1
# 23     3   9       0           0  ...                 1                   1
# 24     3   9       1           1  ...                 1                   1
# 25     3   9      18           2  ...                 1                   1
# 26     3   9       0           0  ...                 1                   1
# 27     3   9      18           2  ...                 1                   1
# 28     3   9       1           1  ...                 1                   1
# 29     3   9       0           0  ...                 1                   1
# 30     3   9       1           1  ...                 1                   1
# 31     3   9      18           2  ...                 1                   1
# 32     3   9       0           0  ...                 1                   1
# 33     3   9      18           2  ...                 1                   1
# 34     3   9       1           1  ...                 1                   1
# 35     3   9       1           1  ...                 1                   1
# 36     3   9      18           2  ...                 1                   1
# 37     3   9       0           0  ...                 1                   1
# 38     3   9       1           1  ...                 1                   1
# 39     3   9       0           0  ...                 1                   1
# 40     3   9      18           2  ...                 1                   1
# 41     3   9       0           0  ...                 1                   1
# 42     3   9       1           1  ...                 1                   1
# 43     3  11      19           3  ...                 1                   1
# 44     3   9      17           1  ...                 1                   1
# 45     3   9       0           0  ...                 1                   1
# 46     3  12      19           3  ...                 1                   1
# 47     3   9      17           1  ...                 1                   1
# 48     3   9       1           1  ...                 1                   1
# 49     3   9      18           2  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                  9           4                           1           4
# 1                 12           4                           1           4
# 2                  9           4                           3          12
# 3                  1           4                           3          12
# 4                  1           4                           1           4
# 5                  1           4                           1           4
# 6                  4           4                           3          12
# 7                  4           4                           3          12
# 8                  1           4                           1           4
# 9                  4           4                           1           4
# 10                 4           4                           3          12
# 11                 1           4                           3          12
# 12                 1           4                           1           4
# 13                 1           4                           1           4
# 14                 1           0                           1           4
# 15                 1           0                           2           8
# 16                 1           0                           3          12
# 17                 1           0                           1           4
# 18                 1           0                           2           8
# 19                 1           4                           1           4
# 20                 1           0                           3          12
# 21                 1           4                           1           4
# 22                 1           4                           1           4
# 23                 1           4                           1           4
# 24                 1           4                           1           4
# 25                 1           4                           3          12
# 26                 1           4                           1           4
# 27                 1           4                           3          12
# 28                 1           4                           1           4
# 29                 1           4                           1           4
# 30                 1           4                           1           4
# 31                 1           4                           3          12
# 32                 1           4                           1           4
# 33                 1           4                           3          12
# 34                 1           4                           1           4
# 35                 1           4                           1           4
# 36                 1           4                           3          12
# 37                 1           4                           1           4
# 38                 1           4                           1           4
# 39                 1           4                           1           4
# 40                 1           4                           3          12
# 41                 1           4                           1           4
# 42                 1           0                           1           4
# 43                 1           0                           2           8
# 44                 1           0                           3          12
# 45                 1           0                           1           4
# 46                 1           0                           2           8
# 47                 1           0                           3          12
# 48                 1           4                           1           4
# 49                 1           4                           3          12
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 4                           3             27
# 1                 0                           3             30
# 2                12                           9             27
# 3                 0                           9             27
# 4                24                           3             27
# 5                28                           3             27
# 6                72                           9             27
# 7                84                           9             27
# 8                48                           3             27
# 9                52                           3             27
# 10              144                           9             30
# 11              156                           9             27
# 12               72                           3             27
# 13               76                           3             27
# 14              156                           3             27
# 15              312                           6             27
# 16              468                           9             27
# 17              168                           3             27
# 18              336                           6             30
# 19              172                           3             27
# 20              504                           9             27
# 21              184                           3             27
# 22              212                           3             27
# 23              220                           3             27
# 24              252                           3             27
# 25              756                           9             27
# 26              264                           3             27
# 27              792                           9             27
# 28              280                           3             27
# 29              300                           3             27
# 30              340                           3             27
# 31             1020                           9             27
# 32              360                           3             27
# 33             1080                           9             27
# 34              392                           3             27
# 35              408                           3             27
# 36             1224                           9             27
# 37              416                           3             27
# 38              428                           3             27
# 39              432                           3             27
# 40             1296                           9             27
# 41              452                           3             27
# 42              484                           3             27
# 43              968                           6             33
# 44             1452                           9             27
# 45              512                           3             27
# 46             1024                           6             36
# 47             1536                           9             27
# 48              544                           3             27
# 49             1632                           9             27
#
#     vnet_vc_cc_index
# 0                  9
# 1                  9
# 2                 27
# 3                 27
# 4                  9
# 5                  9
# 6                 27
# 7                 27
# 8                  9
# 9                  9
# 10                27
# 11                27
# 12                 9
# 13                 9
# 14                 9
# 15                18
# 16                27
# 17                 9
# 18                18
# 19                 9
# 20                27
# 21                 9
# 22                 9
# 23                 9
# 24                 9
# 25                27
# 26                 9
# 27                27
# 28                 9
# 29                 9
# 30                 9
# 31                27
# 32                 9
# 33                27
# 34                 9
# 35                 9
# 36                27
# 37                 9
# 38                 9
# 39                 9
# 40                27
# 41                 9
# 42                 9
# 43                18
# 44                27
# 45                 9
# 46                18
# 47                27
# 48                 9
# 49                27
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             15        1       4                     1        1          4
# 1             19        1       4                     1        1          4
# 2             78        1       4                     3        1          4
# 3            103        1       4                     3        1          4
# 4            341        1       4                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 15020    2008984        1       4                     5        4          2
# 15021    2008991        1       4                     5        5          3
# 15022    2008992        1       4                     1        1          4
# 15023    2021706        1       4                     5        1          1
# 15024    2021713        1       4                     5        2          2
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9       1           1  ...                 3
# 1         3  10       0           0  ...                 3
# 2         3   9      18           2  ...                 3
# 3         3   9      18           2  ...                 1
# 4         3   9       1           1  ...                 1
# ...     ...  ..     ...         ...  ...               ...
# 15020     3   9       0           0  ...                 1
# 15021     3   9       0           0  ...                 1
# 15022     3  10       0           0  ...                 1
# 15023     3   9       1           1  ...                 1
# 15024     3   9       1           1  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       3                 9           4
# 1                       4                12           4
# 2                       3                 9           4
# 3                       1                 1           4
# 4                       1                 1           4
# ...                   ...               ...         ...
# 15020                   1                 1           4
# 15021                   1                 1           4
# 15022                   1                 1           4
# 15023                   1                 1           4
# 15024                   1                 1           4
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               1           4                4
# 1                               1           4                0
# 2                               3          12               12
# 3                               3          12                0
# 4                               1           4               24
# ...                           ...         ...              ...
# 15020                          20          40           442560
# 15021                          25          75           829800
# 15022                           1           4            44260
# 15023                           5           5            55400
# 15024                          10          20           221600
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               3             27                 9
# 1                               3             30                 9
# 2                               9             27                27
# 3                               9             27                27
# 4                               3             27                 9
# ...                           ...            ...               ...
# 15020                          15             27                45
# 15021                          15             27                45
# 15022                           3             30                 9
# 15023                          15             27                45
# 15024                          15             27                45
#
# [15025 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0             15        1       4                     1        1          4
# 1             19        1       4                     1        1          4
# 2             78        1       4                     3        1          4
# 3            103        1       4                     3        1          4
# 4            341        1       4                     1        1          4
# ...          ...      ...     ...                   ...      ...        ...
# 15020    2008984        1       4                     5        4          2
# 15021    2008991        1       4                     5        5          3
# 15022    2008992        1       4                     1        1          4
# 15023    2021706        1       4                     5        1          1
# 15024    2021713        1       4                     5        2          2
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   3
# 1         3  10       0           0  ...                   4
# 2         3   9      18           2  ...                   3
# 3         3   9      18           2  ...                   1
# 4         3   9       1           1  ...                   1
# ...     ...  ..     ...         ...  ...                 ...
# 15020     3   9       0           0  ...                   1
# 15021     3   9       0           0  ...                   1
# 15022     3  10       0           0  ...                   1
# 15023     3   9       1           1  ...                   1
# 15024     3   9       1           1  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                     9           4                           1           4
# 1                    12           4                           1           4
# 2                     9           4                           3          12
# 3                     1           4                           3          12
# 4                     1           4                           1           4
# ...                 ...         ...                         ...         ...
# 15020                 1           4                          20          40
# 15021                 1           4                          25          75
# 15022                 1           4                           1           4
# 15023                 1           4                           5           5
# 15024                 1           4                          10          20
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    0                           3             30
# 2                   12                           9             27
# 3                    0                           9             27
# 4                   24                           3             27
# ...                ...                         ...            ...
# 15020           442560                          15             27
# 15021           829800                          15             27
# 15022            44260                           3             30
# 15023            55400                          15             27
# 15024           221600                          15             27
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                     9       0
# 2                    27       0
# 3                    27       0
# 4                     9       0
# ...                 ...     ...
# 15020                45       0
# 15021                45       0
# 15022                 9       0
# 15023                45       0
# 15024                45       0
#
# [15025 rows x 30 columns]

# %%
df.to_csv('wat-r3-mal.csv',index=False)
