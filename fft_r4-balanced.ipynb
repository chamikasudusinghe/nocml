# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/fft_r4-balanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %% [markdown]
# Train Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-normal-n-0-3-r4.csv?token=AKVFSODCGUQEJLFDLMTI2P26ZLKWC')
print(df.shape)
df
# Out:
# (76013, 30)
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             84        3       2  ...             85               100       1
# 1             85        3       2  ...             85               100       1
# 2             86        3       2  ...             85               100       1
# 3             87        3       2  ...             85               100       1
# 4             91        3       2  ...             85               100       1
# ...          ...      ...     ...  ...            ...               ...     ...
# 76008    3268883        2       0  ...             85               100       1
# 76009    3268884        2       0  ...             85               100       1
# 76010    3268885        2       0  ...             85               100       1
# 76011    3268886        2       0  ...             85               100       1
# 76012    3268890        2       0  ...             85               100       1
#
# [76013 rows x 30 columns]

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-1-r4.csv?token=AKVFSOCTZPYFOTR3BO7VOJK6ZLKWG', nrows=80000)
df2 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-6-r4.csv?token=AKVFSOFVBLKLVWE3GR23WQC6ZLKWK', nrows=80000)
df3 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-9-r4.csv?token=AKVFSOHAZPFWQTJHAVZ4M3K6ZLKWM', nrows=80000)
df4 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-14-r4.csv?token=AKVFSOCJWBJRF5YXP26YUWS6ZLKWQ', nrows=80000)

df11 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-normal-n-0-5-r4.csv?token=AKVFSOCSMO3OEUCHJKXGL3S6ZLLTM')
df12 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-normal-n-0-10-r4.csv?token=AKVFSOFVG7PHQBTJAQ3YYTS6ZLLTQ')
df13 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-normal-n-0-12-r4.csv?token=AKVFSOEJ2RZSOXGFWDUUJEC6ZLLTU')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df11.shape)
print(df12.shape)
print(df13.shape)
# Out:
# (80000, 30)
# (80000, 30)
# (80000, 30)
# (80000, 30)
# (78025, 30)
# (74553, 30)
# (82425, 30)

# %%
df = df.append(df1, ignore_index=True,sort=False)
df = df.append(df2, ignore_index=True,sort=False)
df = df.append(df3, ignore_index=True,sort=False)
df = df.append(df4, ignore_index=True,sort=False)
df = df.append(df11, ignore_index=True,sort=False)
df = df.append(df12, ignore_index=True,sort=False)
df = df.append(df13, ignore_index=True,sort=False)
df = df.sort_values('timestamp')
df.to_csv('fft-r1-train.csv',index=False)

# %%
df = pd.read_csv('fft-r1-train.csv')
df
# Out:
#         timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0              74        3       2  ...             85               100       1
# 1              75        3       2  ...             85               100       1
# 2              76        3       2  ...             85               100       1
# 3              77        3       2  ...             85               100       1
# 4              81        3       2  ...             85               100       1
# ...           ...      ...     ...  ...            ...               ...     ...
# 631011    3272365        1       0  ...             85               100       1
# 631012    3272366        1       0  ...             85               100       1
# 631013    3272367        1       0  ...             85               100       1
# 631014    3272368        1       0  ...             85               100       1
# 631015    3272372        1       0  ...             85               100       1
#
# [631016 rows x 30 columns]

# %%
df.shape
# Out:
# (631016, 30)

# %% [markdown]
# Test Data

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-2-r4.csv?token=AKVFSOC22BUJED46EF2DJJK6ZLLXG', nrows=30000)
df6 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-5-r4.csv?token=AKVFSODJ5TJSVEKC4PR4UWC6ZLLXK', nrows=30000)
df7 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-10-r4.csv?token=AKVFSOASVI4FW3G6HELXJZC6ZLLXM', nrows=30000)
df8 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-12-r4.csv?token=AKVFSOGTU3IQQJN2HVR63F26ZLLXQ', nrows=30000)
df9 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-13-r4.csv?token=AKVFSODJEIW33OFURAFV6XK6ZLLXU', nrows=30000)
df10 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-malicious-n-0-3-m-15-r4.csv?token=AKVFSOC54MGSXKPTFOYWT6S6ZLLXY', nrows=30000)

df14 = pd.read_csv('https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/dos%20results%20ver%201.1/router-data/r4/2-fft-normal-n-0-10-r4.csv?token=AKVFSOD43QPO4RVFTLSYRQC6ZLL3I', nrows=30000)
print(df5.shape)
print(df6.shape)
print(df7.shape)
print(df8.shape)
print(df9.shape)
print(df10.shape)
print(df14.shape)
# Out:
# (30000, 30)
# (30000, 30)
# (30000, 30)
# (30000, 30)
# (30000, 30)
# (30000, 30)
# (30000, 30)

# %%
df5
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0             92        1       3  ...             27                 9       0
# 1            106        3       2  ...             85               100       0
# 2            107        3       2  ...             85               100       0
# 3            108        3       2  ...             85               100       0
# 4            109        3       2  ...             85               100       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 29995     894164        0       3  ...             30                18       0
# 29996     894200        2       0  ...             36                27       0
# 29997     894201        2       0  ...             90               100       0
# 29998     894202        2       0  ...             90               100       0
# 29999     894203        2       0  ...             90               100       0
#
# [30000 rows x 30 columns]

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df = df.drop(columns=['timestamp','src_ni','src_router','dst_ni','dst_router'])

# %%
df.corr()
# Out:
#                              outport    inport  ...  vnet_vc_cc_index    target
# outport                     1.000000 -0.739617  ...          0.661283  0.059031
# inport                     -0.739617  1.000000  ...         -0.539522 -0.006833
# cache_coherence_type       -0.261433  0.294664  ...          0.015045  0.002416
# flit_id                     0.024846  0.000995  ...          0.312028 -0.000146
# flit_type                  -0.038728 -0.001554  ...         -0.486258  0.000244
# vnet                        0.714811 -0.613876  ...          0.926200  0.043485
# vc                          0.707428 -0.688467  ...          0.882094  0.029598
# traversal_id                0.014256  0.032304  ...         -0.016974 -0.102990
# hop_count                   0.072021  0.110238  ...          0.029270 -0.053808
# current_hop                -0.274844  0.636661  ...         -0.191681  0.011662
# hop_percentage             -0.588080  0.881456  ...         -0.399303  0.010624
# enqueue_time               -0.560318  0.696907  ...         -0.538590 -0.024900
# packet_count_decr          -0.160455  0.089374  ...         -0.129533 -0.116334
# packet_count_incr           0.073102 -0.204819  ...          0.047450 -0.116328
# max_packet_count           -0.059112 -0.078121  ...         -0.055546 -0.157443
# packet_count_index         -0.053843 -0.068183  ...         -0.056725 -0.150521
# packet_max_index           -0.057069 -0.047484  ...         -0.059610 -0.150220
# port_index                  0.515011  0.111780  ...          0.280258  0.088376
# cache_coherence_flit_index -0.179157  0.181847  ...          0.145185 -0.009827
# flit_index                 -0.126420  0.132743  ...          0.072715 -0.004400
# traversal_index            -0.083948  0.110900  ...          0.038973 -0.060560
# cache_coherence_vnet_index  0.399303 -0.280598  ...          0.831709  0.040568
# vnet_vc_index               0.707873 -0.657540  ...          0.909048  0.034713
# vnet_vc_cc_index            0.661283 -0.539522  ...          1.000000  0.047642
# target                      0.059031 -0.006833  ...          0.047642  1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target'])
train_X
# Out:
#         outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0             3       2  ...             85               100
# 1             3       2  ...             85               100
# 2             3       2  ...             85               100
# 3             3       2  ...             85               100
# 4             3       2  ...             85               100
# ...         ...     ...  ...            ...               ...
# 631011        1       0  ...             85               100
# 631012        1       0  ...             85               100
# 631013        1       0  ...             85               100
# 631014        1       0  ...             85               100
# 631015        1       0  ...             85               100
#
# [631016 rows x 24 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#          outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0       1.000000  0.666667  ...       0.794521               1.0
# 1       1.000000  0.666667  ...       0.794521               1.0
# 2       1.000000  0.666667  ...       0.794521               1.0
# 3       1.000000  0.666667  ...       0.794521               1.0
# 4       1.000000  0.666667  ...       0.794521               1.0
# ...          ...       ...  ...            ...               ...
# 631011  0.333333  0.000000  ...       0.794521               1.0
# 631012  0.333333  0.000000  ...       0.794521               1.0
# 631013  0.333333  0.000000  ...       0.794521               1.0
# 631014  0.333333  0.000000  ...       0.794521               1.0
# 631015  0.333333  0.000000  ...       0.794521               1.0
#
# [631016 rows x 24 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (18297, 24)

# %%
test_X = df5.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y = df5['target']

# %%
#standardization
x = test_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X = pd.DataFrame(x_scaled)
test_X.columns = columns
test_X
# Out:
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...       0.000000          0.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  1.000000  ...       0.041096          0.098901
# 29996  0.666667  0.000000  ...       0.123288          0.197802
# 29997  0.666667  0.000000  ...       0.863014          1.000000
# 29998  0.666667  0.000000  ...       0.863014          1.000000
# 29999  0.666667  0.000000  ...       0.863014          1.000000
#
# [30000 rows x 24 columns]

# %%
test_X[test_X.duplicated()].shape
# Out:
# (0, 24)

# %%
test_X1 = df6.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y1 = df6['target']
x = test_X1.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X1.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X1 = pd.DataFrame(x_scaled)
test_X1.columns = columns
print(test_X1[test_X1.duplicated()].shape)
test_X1
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...       0.000000          0.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      0.333333  0.666667  ...       0.000000          0.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  0.666667  ...       0.000000          0.395604
# 29996  0.000000  0.666667  ...       0.041096          0.000000
# 29997  0.666667  0.000000  ...       0.041096          0.494505
# 29998  0.666667  0.000000  ...       0.041096          0.494505
# 29999  0.666667  0.000000  ...       0.041096          0.494505
#
# [30000 rows x 24 columns]

# %%
test_X2 = df7.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y2 = df7['target']
x = test_X2.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X2.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X2 = pd.DataFrame(x_scaled)
test_X2.columns = columns
print(test_X2[test_X2.duplicated()].shape)
test_X2
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...       0.000000          0.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  1.000000  ...       0.041096          0.098901
# 29996  0.666667  0.000000  ...       0.931507          1.000000
# 29997  0.666667  0.000000  ...       0.931507          1.000000
# 29998  0.666667  0.000000  ...       0.931507          1.000000
# 29999  0.666667  0.000000  ...       0.931507          1.000000
#
# [30000 rows x 24 columns]

# %%
test_X3 = df8.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y3 = df8['target']
x = test_X3.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X3.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X3 = pd.DataFrame(x_scaled)
test_X3.columns = columns
print(test_X3[test_X3.duplicated()].shape)
test_X3
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      1.000000  0.666667  ...       0.794521          1.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  1.000000  ...       0.000000          0.494505
# 29996  0.000000  1.000000  ...       0.041096          0.098901
# 29997  0.666667  0.000000  ...       0.123288          0.197802
# 29998  0.666667  0.000000  ...       1.000000          1.000000
# 29999  0.666667  0.000000  ...       1.000000          1.000000
#
# [30000 rows x 24 columns]

# %%
test_X4 = df9.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y4 = df9['target']
x = test_X4.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X4.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X4 = pd.DataFrame(x_scaled)
test_X4.columns = columns
print(test_X4[test_X4.duplicated()].shape)
test_X4
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...       0.000000          0.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  1.000000  ...       0.041096          0.098901
# 29996  1.000000  0.333333  ...       0.000000          0.395604
# 29997  1.000000  0.333333  ...       0.000000          0.395604
# 29998  0.666667  0.000000  ...       0.123288          0.197802
# 29999  1.000000  0.000000  ...       0.863014          1.000000
#
# [30000 rows x 24 columns]

# %%
test_X5 = df10.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y5 = df10['target']
x = test_X5.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X5.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X5 = pd.DataFrame(x_scaled)
test_X5.columns = columns
print(test_X5[test_X5.duplicated()].shape)
test_X5
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...       0.000000          0.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.000000  1.000000  ...       0.000000          0.494505
# 29996  0.000000  1.000000  ...       0.000000          0.494505
# 29997  0.000000  1.000000  ...       0.041096          0.098901
# 29998  1.000000  0.000000  ...       0.931507          1.000000
# 29999  1.000000  0.000000  ...       0.931507          1.000000
#
# [30000 rows x 24 columns]

# %%
test_X6 = df14.drop(columns=['target','timestamp','src_ni','src_router','dst_ni','dst_router'])
test_Y6 = df14['target']
x = test_X6.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = test_X6.columns
x_scaled = min_max_scaler.fit_transform(x)
test_X6 = pd.DataFrame(x_scaled)
test_X6.columns = columns
print(test_X6[test_X6.duplicated()].shape)
test_X6
# Out:
# (0, 24)
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      1.000000  0.666667  ...       0.794521          1.000000
# 1      1.000000  0.666667  ...       0.794521          1.000000
# 2      1.000000  0.666667  ...       0.794521          1.000000
# 3      1.000000  0.666667  ...       0.794521          1.000000
# 4      1.000000  0.666667  ...       0.794521          1.000000
# ...         ...       ...  ...            ...               ...
# 29995  0.666667  0.000000  ...       0.931507          1.000000
# 29996  0.666667  0.000000  ...       0.931507          1.000000
# 29997  0.666667  0.000000  ...       0.931507          1.000000
# 29998  0.666667  0.000000  ...       0.041096          0.197802
# 29999  0.666667  0.000000  ...       0.931507          1.000000
#
# [30000 rows x 24 columns]

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 0    320000
# 1    311016
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs        Score
# 14            max_packet_count  2100.256111
# 17                  port_index  1940.101768
# 15          packet_count_index  1387.053054
# 16            packet_max_index  1247.884712
# 13           packet_count_incr  1057.024183
# 12           packet_count_decr  1043.250963
# 7                 traversal_id   826.780108
# 0                      outport   595.080487
# 5                         vnet   537.930953
# 20             traversal_index   303.162517
# 8                    hop_count   284.514895
# 22               vnet_vc_index   277.596921
# 23            vnet_vc_cc_index   187.885475
# 6                           vc   179.021452
# 21  cache_coherence_vnet_index    68.494625
# 11                enqueue_time    43.960646
# 9                  current_hop    20.020249

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
#result=logit_model.fit()
#print(result.summary2())

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 59.26186382257157
# Test Prediction  59.151849386707234

# %%
y_pred_test = logreg.predict(test_X)
logreg_score_test = accuracy_score(test_Y,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  76.39666666666668

# %%
y_pred_test = logreg.predict(test_X1)
logreg_score_test = accuracy_score(test_Y1,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  68.24

# %%
y_pred_test = logreg.predict(test_X2)
logreg_score_test = accuracy_score(test_Y2,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  74.50333333333333

# %%
y_pred_test = logreg.predict(test_X3)
logreg_score_test = accuracy_score(test_Y3,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  70.73

# %%
y_pred_test = logreg.predict(test_X4)
logreg_score_test = accuracy_score(test_Y4,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  73.68666666666667

# %%
y_pred_test = logreg.predict(test_X5)
logreg_score_test = accuracy_score(test_Y5,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  73.58333333333333

# %%
y_pred_test = logreg.predict(test_X6)
logreg_score_test = accuracy_score(test_Y6,y_pred_test)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Test Prediction  42.089999999999996

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 15          packet_count_index    6.687112
# 6                           vc    4.359062
# 9                  current_hop    2.169714
# 5                         vnet    2.134838
# 17                  port_index    2.133051
# 23            vnet_vc_cc_index    1.266644
# 11                enqueue_time    0.651010
# 21  cache_coherence_vnet_index    0.553168
# 4                    flit_type    0.246973
# 3                      flit_id    0.206730
# 20             traversal_index   -0.071100
# 19                  flit_index   -0.102047
# 2         cache_coherence_type   -0.395649
# 12           packet_count_decr   -0.461181
# 18  cache_coherence_flit_index   -0.541606
# 13           packet_count_incr   -0.576970
# 7                 traversal_id   -0.842000
# 10              hop_percentage   -0.937262
# 14            max_packet_count   -1.038151
# 1                       inport   -1.681133
# 0                      outport   -1.887471
# 8                    hop_count   -2.548094
# 22               vnet_vc_index   -7.611330
# 16            packet_max_index  -13.382750

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58     63870
#            1       0.58      0.62      0.60     62334
#
#     accuracy                           0.59    126204
#    macro avg       0.59      0.59      0.59    126204
# weighted avg       0.59      0.59      0.59    126204

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y6, y_pred_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y6, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.42      0.59     30000
#
#     accuracy                           0.42     30000
#    macro avg       0.50      0.21      0.30     30000
# weighted avg       1.00      0.42      0.59     30000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 84.51720640555295
# Test Prediction  76.79788279293842

# %%
y_pred_knn_test= knn.predict(test_X)
knn_score_test = accuracy_score(test_Y,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  57.410000000000004

# %%
y_pred_knn_test= knn.predict(test_X1)
knn_score_test = accuracy_score(test_Y1,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  56.2

# %%
y_pred_knn_test= knn.predict(test_X2)
knn_score_test = accuracy_score(test_Y2,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  56.42

# %%
y_pred_knn_test= knn.predict(test_X3)
knn_score_test = accuracy_score(test_Y3,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  54.986666666666665

# %%
y_pred_knn_test= knn.predict(test_X4)
knn_score_test = accuracy_score(test_Y4,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  53.403333333333336

# %%
y_pred_knn_test= knn.predict(test_X5)
knn_score_test = accuracy_score(test_Y5,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  63.50666666666667

# %%
y_pred_knn_test= knn.predict(test_X6)
knn_score_test = accuracy_score(test_Y6,y_pred_knn_test)
print("Test Prediction ",knn_score_test*100)
# Out:
# Test Prediction  51.976666666666674

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77     63870
#            1       0.76      0.77      0.77     62334
#
#     accuracy                           0.77    126204
#    macro avg       0.77      0.77      0.77    126204
# weighted avg       0.77      0.77      0.77    126204

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %%
cm = confusion_matrix(test_Y6, y_pred_knn_test)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(test_Y6,y_pred_knn_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.52      0.68     30000
#
#     accuracy                           0.52     30000
#    macro avg       0.50      0.26      0.34     30000
# weighted avg       1.00      0.52      0.68     30000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 55.685681005998276
# Test Prediction Score 55.881747012772976

# %%
y_pred_nb_test= nb.predict(test_X)
nb_score_test = accuracy_score(test_Y,y_pred_nb_test)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Test Prediction Score 44.56333333333333

# %%
y_pred_nb_test= nb.predict(test_X1)
nb_score_test = accuracy_score(test_Y1,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  47.50666666666667

# %%
y_pred_nb_test= nb.predict(test_X2)
nb_score_test = accuracy_score(test_Y2,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  47.22

# %%
y_pred_nb_test= nb.predict(test_X3)
nb_score_test = accuracy_score(test_Y3,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  50.78333333333334

# %%
y_pred_nb_test= nb.predict(test_X4)
nb_score_test = accuracy_score(test_Y4,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  42.32666666666667

# %%
y_pred_nb_test= nb.predict(test_X5)
nb_score_test = accuracy_score(test_Y5,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  41.760000000000005

# %%
y_pred_nb_test= nb.predict(test_X6)
nb_score_test = accuracy_score(test_Y6,y_pred_nb_test)
print("Test Prediction ",nb_score_test*100)
# Out:
# Test Prediction  69.65333333333334

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.32      0.42     63870
#            1       0.54      0.80      0.64     62334
#
#     accuracy                           0.56    126204
#    macro avg       0.58      0.56      0.53    126204
# weighted avg       0.58      0.56      0.53    126204

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 403849 samples, validate on 100963 samples
# Epoch 1/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2370 - accuracy: 0.5871 - val_loss: 0.2349 - val_accuracy: 0.5938
# Epoch 2/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2337 - accuracy: 0.5970 - val_loss: 0.2331 - val_accuracy: 0.5981
# Epoch 3/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2322 - accuracy: 0.5986 - val_loss: 0.2327 - val_accuracy: 0.6005
# Epoch 4/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2318 - accuracy: 0.5983 - val_loss: 0.2315 - val_accuracy: 0.5970
# Epoch 5/10
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2316 - accuracy: 0.5991 - val_loss: 0.2315 - val_accuracy: 0.5986
# Epoch 6/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2314 - accuracy: 0.5986 - val_loss: 0.2312 - val_accuracy: 0.5994
# Epoch 7/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2313 - accuracy: 0.5983 - val_loss: 0.2311 - val_accuracy: 0.5969
# Epoch 8/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2312 - accuracy: 0.5998 - val_loss: 0.2310 - val_accuracy: 0.5963
# Epoch 9/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2311 - accuracy: 0.5991 - val_loss: 0.2316 - val_accuracy: 0.5987
# Epoch 10/10
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2310 - accuracy: 0.5998 - val_loss: 0.2311 - val_accuracy: 0.6044

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 60.37%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 77.26%

# %%
scores = model.evaluate(test_X1, test_Y1, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 69.24%

# %%
scores = model.evaluate(test_X2, test_Y2, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 75.07%

# %%
scores = model.evaluate(test_X3, test_Y3, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 67.44%

# %%
scores = model.evaluate(test_X4, test_Y4, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 74.92%

# %%
scores = model.evaluate(test_X5, test_Y5, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 74.92%

# %%
scores = model.evaluate(test_X6, test_Y6, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 39.41%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2 )
# Out:
# Train on 403849 samples, validate on 100963 samples
# Epoch 1/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2499 - accuracy: 0.5122 - val_loss: 0.2496 - val_accuracy: 0.5224
# Epoch 2/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2481 - accuracy: 0.5434 - val_loss: 0.2452 - val_accuracy: 0.5714
# Epoch 3/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2403 - accuracy: 0.5890 - val_loss: 0.2377 - val_accuracy: 0.5969
# Epoch 4/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2364 - accuracy: 0.6001 - val_loss: 0.2351 - val_accuracy: 0.6037
# Epoch 5/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2340 - accuracy: 0.6056 - val_loss: 0.2331 - val_accuracy: 0.6066
# Epoch 6/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2321 - accuracy: 0.6078 - val_loss: 0.2315 - val_accuracy: 0.6069
# Epoch 7/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2305 - accuracy: 0.6092 - val_loss: 0.2305 - val_accuracy: 0.6078
# Epoch 8/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2295 - accuracy: 0.6098 - val_loss: 0.2293 - val_accuracy: 0.6069
# Epoch 9/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2289 - accuracy: 0.6101 - val_loss: 0.2288 - val_accuracy: 0.6143
# Epoch 10/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2285 - accuracy: 0.6113 - val_loss: 0.2281 - val_accuracy: 0.6108
# Epoch 11/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2282 - accuracy: 0.6126 - val_loss: 0.2279 - val_accuracy: 0.6086
# Epoch 12/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2280 - accuracy: 0.6132 - val_loss: 0.2310 - val_accuracy: 0.6092
# Epoch 13/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2277 - accuracy: 0.6163 - val_loss: 0.2273 - val_accuracy: 0.6138
# Epoch 14/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2275 - accuracy: 0.6180 - val_loss: 0.2273 - val_accuracy: 0.6229
# Epoch 15/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2272 - accuracy: 0.6200 - val_loss: 0.2282 - val_accuracy: 0.6217
# Epoch 16/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2270 - accuracy: 0.6210 - val_loss: 0.2273 - val_accuracy: 0.6155
# Epoch 17/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2268 - accuracy: 0.6222 - val_loss: 0.2269 - val_accuracy: 0.6238
# Epoch 18/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2266 - accuracy: 0.6235 - val_loss: 0.2268 - val_accuracy: 0.6270
# Epoch 19/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2264 - accuracy: 0.6237 - val_loss: 0.2259 - val_accuracy: 0.6228
# Epoch 20/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2263 - accuracy: 0.6247 - val_loss: 0.2259 - val_accuracy: 0.6240
# Epoch 21/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2261 - accuracy: 0.6253 - val_loss: 0.2257 - val_accuracy: 0.6243
# Epoch 22/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2260 - accuracy: 0.6248 - val_loss: 0.2263 - val_accuracy: 0.6296
# Epoch 23/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2258 - accuracy: 0.6252 - val_loss: 0.2265 - val_accuracy: 0.6189
# Epoch 24/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2257 - accuracy: 0.6257 - val_loss: 0.2256 - val_accuracy: 0.6279
# Epoch 25/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2256 - accuracy: 0.6260 - val_loss: 0.2252 - val_accuracy: 0.6261
# Epoch 26/30
# 403849/403849 [==============================] - 18s 44us/step - loss: 0.2255 - accuracy: 0.6262 - val_loss: 0.2251 - val_accuracy: 0.6271
# Epoch 27/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2253 - accuracy: 0.6268 - val_loss: 0.2250 - val_accuracy: 0.6250
# Epoch 28/30
# 403849/403849 [==============================] - 15s 36us/step - loss: 0.2252 - accuracy: 0.6269 - val_loss: 0.2266 - val_accuracy: 0.6183
# Epoch 29/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2250 - accuracy: 0.6279 - val_loss: 0.2256 - val_accuracy: 0.6208
# Epoch 30/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2248 - accuracy: 0.6284 - val_loss: 0.2246 - val_accuracy: 0.6316

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 63.20%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X1, test_Y1, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X2, test_Y2, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X3, test_Y3, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X4, test_Y4, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X5, test_Y5, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X6, test_Y6, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 78.46%
# accuracy: 70.30%
# accuracy: 77.43%
# accuracy: 65.87%
# accuracy: 76.30%
# accuracy: 76.27%
# accuracy: 35.91%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 403849 samples, validate on 100963 samples
# Epoch 1/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2498 - accuracy: 0.5195 - val_loss: 0.2496 - val_accuracy: 0.5296
# Epoch 2/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2487 - accuracy: 0.5431 - val_loss: 0.2471 - val_accuracy: 0.5589
# Epoch 3/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2414 - accuracy: 0.5847 - val_loss: 0.2368 - val_accuracy: 0.5997
# Epoch 4/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2347 - accuracy: 0.6057 - val_loss: 0.2335 - val_accuracy: 0.6088
# Epoch 5/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2320 - accuracy: 0.6120 - val_loss: 0.2336 - val_accuracy: 0.6163
# Epoch 6/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2300 - accuracy: 0.6155 - val_loss: 0.2293 - val_accuracy: 0.6181
# Epoch 7/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2285 - accuracy: 0.6182 - val_loss: 0.2277 - val_accuracy: 0.6206
# Epoch 8/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2273 - accuracy: 0.6199 - val_loss: 0.2267 - val_accuracy: 0.6172
# Epoch 9/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2265 - accuracy: 0.6211 - val_loss: 0.2260 - val_accuracy: 0.6256
# Epoch 10/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2257 - accuracy: 0.6229 - val_loss: 0.2250 - val_accuracy: 0.6244
# Epoch 11/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2251 - accuracy: 0.6257 - val_loss: 0.2243 - val_accuracy: 0.6325
# Epoch 12/30
# 403849/403849 [==============================] - 16s 38us/step - loss: 0.2245 - accuracy: 0.6266 - val_loss: 0.2245 - val_accuracy: 0.6281
# Epoch 13/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2237 - accuracy: 0.6270 - val_loss: 0.2274 - val_accuracy: 0.6216
# Epoch 14/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2231 - accuracy: 0.6284 - val_loss: 0.2225 - val_accuracy: 0.6302
# Epoch 15/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2228 - accuracy: 0.6288 - val_loss: 0.2222 - val_accuracy: 0.6322
# Epoch 16/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2225 - accuracy: 0.6299 - val_loss: 0.2239 - val_accuracy: 0.6240
# Epoch 17/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2221 - accuracy: 0.6310 - val_loss: 0.2215 - val_accuracy: 0.6293
# Epoch 18/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2219 - accuracy: 0.6313 - val_loss: 0.2247 - val_accuracy: 0.6281
# Epoch 19/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2217 - accuracy: 0.6325 - val_loss: 0.2242 - val_accuracy: 0.6282
# Epoch 20/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2216 - accuracy: 0.6321 - val_loss: 0.2206 - val_accuracy: 0.6333
# Epoch 21/30
# 403849/403849 [==============================] - 16s 39us/step - loss: 0.2214 - accuracy: 0.6325 - val_loss: 0.2202 - val_accuracy: 0.6369
# Epoch 22/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2212 - accuracy: 0.6326 - val_loss: 0.2218 - val_accuracy: 0.6362
# Epoch 23/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2210 - accuracy: 0.6335 - val_loss: 0.2218 - val_accuracy: 0.6365
# Epoch 24/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2202 - accuracy: 0.6362 - val_loss: 0.2205 - val_accuracy: 0.6380
# Epoch 25/30
# 403849/403849 [==============================] - 15s 37us/step - loss: 0.2196 - accuracy: 0.6391 - val_loss: 0.2192 - val_accuracy: 0.6404
# Epoch 26/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2192 - accuracy: 0.6400 - val_loss: 0.2189 - val_accuracy: 0.6382
# Epoch 27/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2190 - accuracy: 0.6409 - val_loss: 0.2320 - val_accuracy: 0.6072
# Epoch 28/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2188 - accuracy: 0.6407 - val_loss: 0.2214 - val_accuracy: 0.6311
# Epoch 29/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2186 - accuracy: 0.6416 - val_loss: 0.2173 - val_accuracy: 0.6452
# Epoch 30/30
# 403849/403849 [==============================] - 15s 38us/step - loss: 0.2185 - accuracy: 0.6420 - val_loss: 0.2188 - val_accuracy: 0.6437

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 64.18%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X1, test_Y1, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X2, test_Y2, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X3, test_Y3, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X4, test_Y4, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X5, test_Y5, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X6, test_Y6, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 81.85%
# accuracy: 77.65%
# accuracy: 81.50%
# accuracy: 68.76%
# accuracy: 79.99%
# accuracy: 80.66%
# accuracy: 26.07%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 403849 samples, validate on 100963 samples
# Epoch 1/100
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.2209 - accuracy: 0.6331 - val_loss: 0.2198 - val_accuracy: 0.6394
# Epoch 2/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.2055 - accuracy: 0.6687 - val_loss: 0.2021 - val_accuracy: 0.6798
# Epoch 3/100
# 403849/403849 [==============================] - 31s 78us/step - loss: 0.2001 - accuracy: 0.6788 - val_loss: 0.1917 - val_accuracy: 0.7008
# Epoch 4/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1970 - accuracy: 0.6850 - val_loss: 0.1875 - val_accuracy: 0.7037
# Epoch 5/100
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1951 - accuracy: 0.6888 - val_loss: 0.1842 - val_accuracy: 0.7094
# Epoch 6/100
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1923 - accuracy: 0.6949 - val_loss: 0.1818 - val_accuracy: 0.7155
# Epoch 7/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1896 - accuracy: 0.6988 - val_loss: 0.1881 - val_accuracy: 0.7005
# Epoch 8/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1879 - accuracy: 0.7023 - val_loss: 0.1772 - val_accuracy: 0.7255
# Epoch 9/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1870 - accuracy: 0.7046 - val_loss: 0.1723 - val_accuracy: 0.7364
# Epoch 10/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1862 - accuracy: 0.7060 - val_loss: 0.1724 - val_accuracy: 0.7327
# Epoch 11/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1855 - accuracy: 0.7080 - val_loss: 0.1731 - val_accuracy: 0.7299
# Epoch 12/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1851 - accuracy: 0.7080 - val_loss: 0.1704 - val_accuracy: 0.7369
# Epoch 13/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1840 - accuracy: 0.7099 - val_loss: 0.1774 - val_accuracy: 0.7189
# Epoch 14/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1834 - accuracy: 0.7107 - val_loss: 0.1714 - val_accuracy: 0.7358
# Epoch 15/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1828 - accuracy: 0.7125 - val_loss: 0.1707 - val_accuracy: 0.7376
# Epoch 16/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1824 - accuracy: 0.7128 - val_loss: 0.1719 - val_accuracy: 0.7384
# Epoch 17/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1819 - accuracy: 0.7147 - val_loss: 0.1751 - val_accuracy: 0.7214
# Epoch 18/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1820 - accuracy: 0.7139 - val_loss: 0.1718 - val_accuracy: 0.7362
# Epoch 19/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1814 - accuracy: 0.7157 - val_loss: 0.1686 - val_accuracy: 0.7384
# Epoch 20/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1814 - accuracy: 0.7163 - val_loss: 0.1694 - val_accuracy: 0.7413
# Epoch 21/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1811 - accuracy: 0.7159 - val_loss: 0.1711 - val_accuracy: 0.7390
# Epoch 22/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1808 - accuracy: 0.7171 - val_loss: 0.1684 - val_accuracy: 0.7438
# Epoch 23/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1808 - accuracy: 0.7173 - val_loss: 0.1670 - val_accuracy: 0.7461
# Epoch 24/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1807 - accuracy: 0.7168 - val_loss: 0.1678 - val_accuracy: 0.7453
# Epoch 25/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1802 - accuracy: 0.7180 - val_loss: 0.1696 - val_accuracy: 0.7395
# Epoch 26/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1799 - accuracy: 0.7190 - val_loss: 0.1695 - val_accuracy: 0.7470
# Epoch 27/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1799 - accuracy: 0.7188 - val_loss: 0.1689 - val_accuracy: 0.7393
# Epoch 28/100
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1798 - accuracy: 0.7192 - val_loss: 0.1691 - val_accuracy: 0.7368
# Epoch 29/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1796 - accuracy: 0.7205 - val_loss: 0.1694 - val_accuracy: 0.7429
# Epoch 30/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1793 - accuracy: 0.7198 - val_loss: 0.1686 - val_accuracy: 0.7437
# Epoch 31/100
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1791 - accuracy: 0.7199 - val_loss: 0.1689 - val_accuracy: 0.7413
# Epoch 32/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1794 - accuracy: 0.7203 - val_loss: 0.1720 - val_accuracy: 0.7353
# Epoch 33/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1789 - accuracy: 0.7207 - val_loss: 0.1681 - val_accuracy: 0.7442
# Epoch 34/100
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1787 - accuracy: 0.7206 - val_loss: 0.1712 - val_accuracy: 0.7379
# Epoch 35/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1787 - accuracy: 0.7205 - val_loss: 0.1677 - val_accuracy: 0.7493
# Epoch 36/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1789 - accuracy: 0.7209 - val_loss: 0.1655 - val_accuracy: 0.7488
# Epoch 37/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1786 - accuracy: 0.7212 - val_loss: 0.1662 - val_accuracy: 0.7433
# Epoch 38/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1784 - accuracy: 0.7222 - val_loss: 0.1661 - val_accuracy: 0.7477
# Epoch 39/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1781 - accuracy: 0.7219 - val_loss: 0.1666 - val_accuracy: 0.7416
# Epoch 40/100
# 403849/403849 [==============================] - 27s 67us/step - loss: 0.1782 - accuracy: 0.7219 - val_loss: 0.1701 - val_accuracy: 0.7362
# Epoch 41/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1779 - accuracy: 0.7228 - val_loss: 0.1715 - val_accuracy: 0.7317
# Epoch 42/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1781 - accuracy: 0.7222 - val_loss: 0.1637 - val_accuracy: 0.7475
# Epoch 43/100
# 403849/403849 [==============================] - 27s 67us/step - loss: 0.1779 - accuracy: 0.7227 - val_loss: 0.1656 - val_accuracy: 0.7429
# Epoch 44/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1777 - accuracy: 0.7232 - val_loss: 0.1690 - val_accuracy: 0.7366
# Epoch 45/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1778 - accuracy: 0.7234 - val_loss: 0.1660 - val_accuracy: 0.7472
# Epoch 46/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1779 - accuracy: 0.7226 - val_loss: 0.1672 - val_accuracy: 0.7408
# Epoch 47/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1778 - accuracy: 0.7226 - val_loss: 0.1701 - val_accuracy: 0.7382
# Epoch 48/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1776 - accuracy: 0.7232 - val_loss: 0.1670 - val_accuracy: 0.7430
# Epoch 49/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1776 - accuracy: 0.7232 - val_loss: 0.1679 - val_accuracy: 0.7455
# Epoch 50/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1776 - accuracy: 0.7227 - val_loss: 0.1661 - val_accuracy: 0.7453
# Epoch 51/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1775 - accuracy: 0.7235 - val_loss: 0.1683 - val_accuracy: 0.7389
# Epoch 52/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1774 - accuracy: 0.7236 - val_loss: 0.1647 - val_accuracy: 0.7522
# Epoch 53/100
# 403849/403849 [==============================] - 27s 67us/step - loss: 0.1775 - accuracy: 0.7241 - val_loss: 0.1671 - val_accuracy: 0.7448
# Epoch 54/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1777 - accuracy: 0.7239 - val_loss: 0.1642 - val_accuracy: 0.7455
# Epoch 55/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1772 - accuracy: 0.7237 - val_loss: 0.1706 - val_accuracy: 0.7334
# Epoch 56/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1774 - accuracy: 0.7232 - val_loss: 0.1652 - val_accuracy: 0.7461
# Epoch 57/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1770 - accuracy: 0.7241 - val_loss: 0.1669 - val_accuracy: 0.7457
# Epoch 58/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1770 - accuracy: 0.7245 - val_loss: 0.1650 - val_accuracy: 0.7505
# Epoch 59/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1771 - accuracy: 0.7241 - val_loss: 0.1645 - val_accuracy: 0.7513
# Epoch 60/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1773 - accuracy: 0.7234 - val_loss: 0.1656 - val_accuracy: 0.7460
# Epoch 61/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1769 - accuracy: 0.7239 - val_loss: 0.1651 - val_accuracy: 0.7481
# Epoch 62/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1770 - accuracy: 0.7251 - val_loss: 0.1657 - val_accuracy: 0.7463
# Epoch 63/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1766 - accuracy: 0.7249 - val_loss: 0.1654 - val_accuracy: 0.7457
# Epoch 64/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1768 - accuracy: 0.7244 - val_loss: 0.1660 - val_accuracy: 0.7446
# Epoch 65/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1766 - accuracy: 0.7255 - val_loss: 0.1665 - val_accuracy: 0.7462
# Epoch 66/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1767 - accuracy: 0.7250 - val_loss: 0.1659 - val_accuracy: 0.7453
# Epoch 67/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1767 - accuracy: 0.7242 - val_loss: 0.1650 - val_accuracy: 0.7474
# Epoch 68/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1767 - accuracy: 0.7249 - val_loss: 0.1643 - val_accuracy: 0.7529
# Epoch 69/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1768 - accuracy: 0.7245 - val_loss: 0.1861 - val_accuracy: 0.7107
# Epoch 70/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1767 - accuracy: 0.7247 - val_loss: 0.1689 - val_accuracy: 0.7384
# Epoch 71/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1764 - accuracy: 0.7254 - val_loss: 0.1730 - val_accuracy: 0.7306
# Epoch 72/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1763 - accuracy: 0.7259 - val_loss: 0.1661 - val_accuracy: 0.7462
# Epoch 73/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1765 - accuracy: 0.7254 - val_loss: 0.1654 - val_accuracy: 0.7487
# Epoch 74/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1766 - accuracy: 0.7243 - val_loss: 0.1634 - val_accuracy: 0.7490
# Epoch 75/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1761 - accuracy: 0.7266 - val_loss: 0.1644 - val_accuracy: 0.7473
# Epoch 76/100
# 403849/403849 [==============================] - 27s 66us/step - loss: 0.1760 - accuracy: 0.7261 - val_loss: 0.1664 - val_accuracy: 0.7439
# Epoch 77/100
# 403849/403849 [==============================] - 27s 67us/step - loss: 0.1759 - accuracy: 0.7263 - val_loss: 0.1638 - val_accuracy: 0.7506
# Epoch 78/100
# 403849/403849 [==============================] - 28s 68us/step - loss: 0.1761 - accuracy: 0.7257 - val_loss: 0.1638 - val_accuracy: 0.7502
# Epoch 79/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1760 - accuracy: 0.7252 - val_loss: 0.1645 - val_accuracy: 0.7472
# Epoch 80/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1761 - accuracy: 0.7256 - val_loss: 0.1680 - val_accuracy: 0.7464
# Epoch 81/100
# 403849/403849 [==============================] - 27s 67us/step - loss: 0.1761 - accuracy: 0.7263 - val_loss: 0.1662 - val_accuracy: 0.7471
# Epoch 82/100
# 403849/403849 [==============================] - 27s 68us/step - loss: 0.1763 - accuracy: 0.7255 - val_loss: 0.1673 - val_accuracy: 0.7397
# Epoch 83/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1759 - accuracy: 0.7257 - val_loss: 0.1643 - val_accuracy: 0.7492
# Epoch 84/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1758 - accuracy: 0.7267 - val_loss: 0.1696 - val_accuracy: 0.7391
# Epoch 85/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1758 - accuracy: 0.7261 - val_loss: 0.1801 - val_accuracy: 0.7248
# Epoch 86/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1759 - accuracy: 0.7265 - val_loss: 0.1667 - val_accuracy: 0.7409
# Epoch 87/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1759 - accuracy: 0.7260 - val_loss: 0.1643 - val_accuracy: 0.7512
# Epoch 88/100
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1758 - accuracy: 0.7272 - val_loss: 0.1656 - val_accuracy: 0.7503
# Epoch 89/100
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1754 - accuracy: 0.7275 - val_loss: 0.1657 - val_accuracy: 0.7405
# Epoch 90/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1757 - accuracy: 0.7267 - val_loss: 0.1650 - val_accuracy: 0.7425
# Epoch 91/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1755 - accuracy: 0.7275 - val_loss: 0.1653 - val_accuracy: 0.7456
# Epoch 92/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1754 - accuracy: 0.7269 - val_loss: 0.1654 - val_accuracy: 0.7471
# Epoch 93/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1752 - accuracy: 0.7272 - val_loss: 0.1682 - val_accuracy: 0.7375
# Epoch 94/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1756 - accuracy: 0.7267 - val_loss: 0.1631 - val_accuracy: 0.7545
# Epoch 95/100
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1752 - accuracy: 0.7270 - val_loss: 0.1664 - val_accuracy: 0.7420
# Epoch 96/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1753 - accuracy: 0.7270 - val_loss: 0.1634 - val_accuracy: 0.7514
# Epoch 97/100
# 403849/403849 [==============================] - 28s 69us/step - loss: 0.1754 - accuracy: 0.7267 - val_loss: 0.1657 - val_accuracy: 0.7463
# Epoch 98/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1753 - accuracy: 0.7277 - val_loss: 0.1657 - val_accuracy: 0.7432
# Epoch 99/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1755 - accuracy: 0.7271 - val_loss: 0.1638 - val_accuracy: 0.7480
# Epoch 100/100
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1750 - accuracy: 0.7280 - val_loss: 0.1644 - val_accuracy: 0.7482

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 74.65%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X1, test_Y1, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X2, test_Y2, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X3, test_Y3, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X4, test_Y4, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X5, test_Y5, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X6, test_Y6, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 59.40%
# accuracy: 56.52%
# accuracy: 55.71%
# accuracy: 56.79%
# accuracy: 54.31%
# accuracy: 65.54%
# accuracy: 50.81%

# %%
#6layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(Dense(2))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Train on 403849 samples, validate on 100963 samples
# Epoch 1/50
# 403849/403849 [==============================] - 29s 73us/step - loss: 0.2189 - accuracy: 0.6365 - val_loss: 0.2032 - val_accuracy: 0.6729
# Epoch 2/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.2041 - accuracy: 0.6671 - val_loss: 0.1938 - val_accuracy: 0.6912
# Epoch 3/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1995 - accuracy: 0.6769 - val_loss: 0.1930 - val_accuracy: 0.6928
# Epoch 4/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1967 - accuracy: 0.6849 - val_loss: 0.1960 - val_accuracy: 0.6890
# Epoch 5/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1937 - accuracy: 0.6900 - val_loss: 0.1851 - val_accuracy: 0.7084
# Epoch 6/50
# 403849/403849 [==============================] - 29s 73us/step - loss: 0.1908 - accuracy: 0.6967 - val_loss: 0.1855 - val_accuracy: 0.7075
# Epoch 7/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1889 - accuracy: 0.7007 - val_loss: 0.1790 - val_accuracy: 0.7215
# Epoch 8/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1873 - accuracy: 0.7038 - val_loss: 0.1805 - val_accuracy: 0.7164
# Epoch 9/50
# 403849/403849 [==============================] - 32s 78us/step - loss: 0.1857 - accuracy: 0.7081 - val_loss: 0.1759 - val_accuracy: 0.7245
# Epoch 10/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1844 - accuracy: 0.7107 - val_loss: 0.1741 - val_accuracy: 0.7313
# Epoch 11/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1831 - accuracy: 0.7129 - val_loss: 0.1725 - val_accuracy: 0.7321
# Epoch 12/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1821 - accuracy: 0.7143 - val_loss: 0.1711 - val_accuracy: 0.7303
# Epoch 13/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1818 - accuracy: 0.7153 - val_loss: 0.1696 - val_accuracy: 0.7376
# Epoch 14/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1805 - accuracy: 0.7181 - val_loss: 0.1725 - val_accuracy: 0.7326
# Epoch 15/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1801 - accuracy: 0.7176 - val_loss: 0.1719 - val_accuracy: 0.7336
# Epoch 16/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1794 - accuracy: 0.7193 - val_loss: 0.1734 - val_accuracy: 0.7333
# Epoch 17/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1790 - accuracy: 0.7201 - val_loss: 0.1685 - val_accuracy: 0.7400
# Epoch 18/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1782 - accuracy: 0.7215 - val_loss: 0.1690 - val_accuracy: 0.7327
# Epoch 19/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1776 - accuracy: 0.7229 - val_loss: 0.1682 - val_accuracy: 0.7433
# Epoch 20/50
# 403849/403849 [==============================] - 29s 73us/step - loss: 0.1780 - accuracy: 0.7223 - val_loss: 0.1673 - val_accuracy: 0.7392
# Epoch 21/50
# 403849/403849 [==============================] - 29s 73us/step - loss: 0.1774 - accuracy: 0.7228 - val_loss: 0.1684 - val_accuracy: 0.7352
# Epoch 22/50
# 403849/403849 [==============================] - 30s 74us/step - loss: 0.1769 - accuracy: 0.7242 - val_loss: 0.1675 - val_accuracy: 0.7391
# Epoch 23/50
# 403849/403849 [==============================] - 29s 73us/step - loss: 0.1768 - accuracy: 0.7239 - val_loss: 0.1687 - val_accuracy: 0.7451
# Epoch 24/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1767 - accuracy: 0.7243 - val_loss: 0.1660 - val_accuracy: 0.7452
# Epoch 25/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1762 - accuracy: 0.7250 - val_loss: 0.1653 - val_accuracy: 0.7436
# Epoch 26/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1756 - accuracy: 0.7264 - val_loss: 0.1647 - val_accuracy: 0.7437
# Epoch 27/50
# 403849/403849 [==============================] - 30s 74us/step - loss: 0.1754 - accuracy: 0.7261 - val_loss: 0.1662 - val_accuracy: 0.7423
# Epoch 28/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1754 - accuracy: 0.7269 - val_loss: 0.1635 - val_accuracy: 0.7491
# Epoch 29/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1751 - accuracy: 0.7275 - val_loss: 0.1652 - val_accuracy: 0.7451
# Epoch 30/50
# 403849/403849 [==============================] - 32s 80us/step - loss: 0.1749 - accuracy: 0.7272 - val_loss: 0.1657 - val_accuracy: 0.7415
# Epoch 31/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1743 - accuracy: 0.7282 - val_loss: 0.1637 - val_accuracy: 0.7512
# Epoch 32/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1744 - accuracy: 0.7289 - val_loss: 0.1661 - val_accuracy: 0.7437
# Epoch 33/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1741 - accuracy: 0.7288 - val_loss: 0.1641 - val_accuracy: 0.7435
# Epoch 34/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1740 - accuracy: 0.7294 - val_loss: 0.1643 - val_accuracy: 0.7477
# Epoch 35/50
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1738 - accuracy: 0.7296 - val_loss: 0.1660 - val_accuracy: 0.7446
# Epoch 36/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1737 - accuracy: 0.7301 - val_loss: 0.1666 - val_accuracy: 0.7402
# Epoch 37/50
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1732 - accuracy: 0.7315 - val_loss: 0.1608 - val_accuracy: 0.7566
# Epoch 38/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1733 - accuracy: 0.7317 - val_loss: 0.1660 - val_accuracy: 0.7429
# Epoch 39/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1731 - accuracy: 0.7319 - val_loss: 0.1652 - val_accuracy: 0.7377
# Epoch 40/50
# 403849/403849 [==============================] - 28s 71us/step - loss: 0.1730 - accuracy: 0.7313 - val_loss: 0.1617 - val_accuracy: 0.7521
# Epoch 41/50
# 403849/403849 [==============================] - 28s 70us/step - loss: 0.1729 - accuracy: 0.7321 - val_loss: 0.1628 - val_accuracy: 0.7512
# Epoch 42/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1725 - accuracy: 0.7328 - val_loss: 0.1636 - val_accuracy: 0.7486
# Epoch 43/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1728 - accuracy: 0.7326 - val_loss: 0.1634 - val_accuracy: 0.7521
# Epoch 44/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1725 - accuracy: 0.7333 - val_loss: 0.1624 - val_accuracy: 0.7484
# Epoch 45/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1724 - accuracy: 0.7329 - val_loss: 0.1635 - val_accuracy: 0.7475
# Epoch 46/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1721 - accuracy: 0.7334 - val_loss: 0.1609 - val_accuracy: 0.7498
# Epoch 47/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1719 - accuracy: 0.7346 - val_loss: 0.1640 - val_accuracy: 0.7435
# Epoch 48/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1721 - accuracy: 0.7338 - val_loss: 0.1614 - val_accuracy: 0.7549
# Epoch 49/50
# 403849/403849 [==============================] - 29s 72us/step - loss: 0.1716 - accuracy: 0.7348 - val_loss: 0.1629 - val_accuracy: 0.7463
# Epoch 50/50
# 403849/403849 [==============================] - 29s 71us/step - loss: 0.1715 - accuracy: 0.7345 - val_loss: 0.1609 - val_accuracy: 0.7509

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 74.90%

# %%
scores = model.evaluate(test_X, test_Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X1, test_Y1, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X2, test_Y2, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X3, test_Y3, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X4, test_Y4, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X5, test_Y5, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
scores = model.evaluate(test_X6, test_Y6, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 55.78%
# accuracy: 52.98%
# accuracy: 51.16%
# accuracy: 54.33%
# accuracy: 50.40%
# accuracy: 61.82%
# accuracy: 52.92%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
dt = DecisionTreeClassifier(max_depth=24,max_features=24,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=24, max_features=24, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 95.40066400957188
# Test Prediction Score 89.921080155938

# %%
y_pred_dt_test= dt.predict(test_X)
dt_score_test = accuracy_score(test_Y,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X1)
dt_score_test = accuracy_score(test_Y1,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X2)
dt_score_test = accuracy_score(test_Y2,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X3)
dt_score_test = accuracy_score(test_Y3,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X4)
dt_score_test = accuracy_score(test_Y4,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X5)
dt_score_test = accuracy_score(test_Y5,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
y_pred_dt_test= dt.predict(test_X6)
dt_score_test = accuracy_score(test_Y6,y_pred_dt_test)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Test Prediction Score 58.42
# Test Prediction Score 58.486666666666665
# Test Prediction Score 58.42
# Test Prediction Score 59.28666666666666
# Test Prediction Score 54.56999999999999
# Test Prediction Score 60.84
# Test Prediction Score 47.20666666666667

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90     63870
#            1       0.89      0.90      0.90     62334
#
#     accuracy                           0.90    126204
#    macro avg       0.90      0.90      0.90    126204
# weighted avg       0.90      0.90      0.90    126204

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(max_depth=24,max_features=24,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=24, max_features=24,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 98.02282830043659
# Test Prediction Score 90.84418877373142

# %%
y_pred_rf_test= rf.predict(test_X)
rf_score_test = accuracy_score(test_Y,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X1)
rf_score_test = accuracy_score(test_Y1,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X2)
rf_score_test = accuracy_score(test_Y2,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X3)
rf_score_test = accuracy_score(test_Y3,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X4)
rf_score_test = accuracy_score(test_Y4,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X5)
rf_score_test = accuracy_score(test_Y5,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
y_pred_rf_test= rf.predict(test_X6)
rf_score_test = accuracy_score(test_Y6,y_pred_rf_test)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Test Prediction Score 59.08
# Test Prediction Score 58.373333333333335
# Test Prediction Score 58.54666666666667
# Test Prediction Score 58.723333333333336
# Test Prediction Score 55.276666666666664
# Test Prediction Score 61.32333333333333
# Test Prediction Score 47.82666666666667

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     63870
#            1       0.90      0.92      0.91     62334
#
#     accuracy                           0.91    126204
#    macro avg       0.91      0.91      0.91    126204
# weighted avg       0.91      0.91      0.91    126204

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
xgbc = XGBClassifier(max_depth=24,min_child_weight=1,n_estimators=500,random_state=42,learning_rate=0.2)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=24,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 99.42216112136796
# Test Prediction Score 94.26880289055815

# %%
y_pred_xgbc_test= xgbc.predict(test_X)
xgbc_score_test = accuracy_score(test_Y,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X1)
xgbc_score_test = accuracy_score(test_Y1,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X2)
xgbc_score_test = accuracy_score(test_Y2,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X3)
xgbc_score_test = accuracy_score(test_Y3,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X4)
xgbc_score_test = accuracy_score(test_Y4,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X5)
xgbc_score_test = accuracy_score(test_Y5,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
y_pred_xgbc_test= xgbc.predict(test_X6)
xgbc_score_test = accuracy_score(test_Y6,y_pred_xgbc_test)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Test Prediction Score 58.99333333333333
# Test Prediction Score 58.53333333333334
# Test Prediction Score 58.21333333333333
# Test Prediction Score 58.39666666666666
# Test Prediction Score 54.690000000000005
# Test Prediction Score 61.99
# Test Prediction Score 47.25

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     63870
#            1       0.94      0.95      0.94     62334
#
#     accuracy                           0.94    126204
#    macro avg       0.94      0.94      0.94    126204
# weighted avg       0.94      0.94      0.94    126204

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.6,  n_estimators = 500, max_depth = 24, random_state=42, min_child_weight=1,metric='binary',boosting_type = 'dart')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.6, max_depth=24,
#                metric='binary', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 83.39302552237268
# Test Prediction Score 82.54255015688885

# %%
y_pred_gbm_test = gbm.predict(test_X)
gbm_score_test = accuracy_score(test_Y,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X1)
gbm_score_test = accuracy_score(test_Y1,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X2)
gbm_score_test = accuracy_score(test_Y2,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X3)
gbm_score_test = accuracy_score(test_Y3,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X4)
gbm_score_test = accuracy_score(test_Y4,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X5)
gbm_score_test = accuracy_score(test_Y5,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
y_pred_gbm_test = gbm.predict(test_X6)
gbm_score_test = accuracy_score(test_Y6,y_pred_gbm_test)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Test Prediction Score 58.08333333333333
# Test Prediction Score 56.21000000000001
# Test Prediction Score 55.11333333333334
# Test Prediction Score 56.13666666666667
# Test Prediction Score 52.656666666666666
# Test Prediction Score 60.89333333333333
# Test Prediction Score 50.18

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,6800), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [6841,
#  2436,
#  1082,
#  523,
#  499,
#  472,
#  412,
#  386,
#  329,
#  324,
#  254,
#  247,
#  206,
#  205,
#  203,
#  144,
#  141,
#  85,
#  74,
#  72,
#  40,
#  25,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82     63870
#            1       0.80      0.87      0.83     62334
#
#     accuracy                           0.83    126204
#    macro avg       0.83      0.83      0.83    126204
# weighted avg       0.83      0.83      0.83    126204

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
