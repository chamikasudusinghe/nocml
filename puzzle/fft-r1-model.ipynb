# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r1_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Importing Dataset from GitHub

# %%
df = pd.read_csv('results_tiles_manhattan.csv')
dfms = pd.read_csv('results_mean_std.csv')

# %%
df
# Out:
#       n  misplaced tiles  manhattan dist
# 0     5                8               4
# 1     5                8               6
# 2     5                9              10
# 3     5                8               8
# 4     5                6               9
# ..   ..              ...             ...
# 155  20               27            2868
# 156  20               14            2975
# 157  20               16            2978
# 158  20               13            2950
# 159  20               36            2901
#
# [160 rows x 3 columns]

# %%
df.head(50)
# Out:
#     n  misplaced tiles  manhattan dist
# 0   5                8               4
# 1   5                8               6
# 2   5                9              10
# 3   5                8               8
# 4   5                6               9
# 5   5               10              10
# 6   5                9               6
# 7   5                8              15
# 8   5                8              17
# 9   5                7              14
# 10  6                8              13
# 11  6                7              18
# 12  6                9              20
# 13  6                8              21
# 14  6                6              31
# 15  6                5              27
# 16  6               11              10
# 17  6                8              23
# 18  6                9              18
# 19  6                6              18
# 20  7               45             166
# 21  7               48             152
# 22  7               41             164
# ...

# %%
dfms
# Out:
#      n  mean_tiles  mean_manhatan  std_tiles  std_manhatan
# 0    5        8.12           9.88      1.081         4.329
# 1    6        7.73          19.89      1.503         6.306
# 2    7       44.30         167.30      2.983        14.190
# 3    8       14.40         130.20      3.406        20.596
# 4    9       20.00         166.00      4.295        23.281
# 5   10       17.80         489.90      5.514        27.493
# 6   11       26.60         966.00      6.398        45.609
# 7   12       26.20         585.20      5.827        29.877
# 8   13       15.30         618.00      5.658        38.338
# 9   14      436.50        4645.40     53.244        75.260
# 10  15      243.50        7425.70     59.219       147.481
# 11  16       28.40        2890.00      5.948        59.996
# 12  17      273.20        7431.40     56.503       207.137
# 13  18      121.10        5848.50     31.374       148.017
# 14  19       31.10        4793.30     13.237        92.713
# ...

# %%
dfms.head(20)
# Out:
#      n  mean_tiles  mean_manhatan  std_tiles  std_manhatan
# 0    5        8.12           9.88      1.081         4.329
# 1    6        7.73          19.89      1.503         6.306
# 2    7       44.30         167.30      2.983        14.190
# 3    8       14.40         130.20      3.406        20.596
# 4    9       20.00         166.00      4.295        23.281
# 5   10       17.80         489.90      5.514        27.493
# 6   11       26.60         966.00      6.398        45.609
# 7   12       26.20         585.20      5.827        29.877
# 8   13       15.30         618.00      5.658        38.338
# 9   14      436.50        4645.40     53.244        75.260
# 10  15      243.50        7425.70     59.219       147.481
# 11  16       28.40        2890.00      5.948        59.996
# 12  17      273.20        7431.40     56.503       207.137
# 13  18      121.10        5848.50     31.374       148.017
# 14  19       31.10        4793.30     13.237        92.713
# ...

# %%
x = dfms['n']
y1 = dfms['mean_tiles']
y2 = dfms['mean_manhatan']


fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

plt.title("mean time")
ax1.set_xlabel('n-puzzle')
ax1.set_ylabel('tile time (ms)', color='g')
ax2.set_ylabel('manhatan time (ms)', color='b')

plt.show()

# %%
fig,ax=plt.subplots()
plt.title("mean time")
ax.set_xlabel("n-puzzle")
ax.set_ylabel("time (ms)")
ax.plot(x, y1, marker="o")
ax.plot(x, y2, marker="o")
plt.show()

# %%
y3 = dfms['std_tiles']
y4 = dfms['std_manhatan']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y3, 'g-')
ax2.plot(x, y4, 'b-')

plt.title("standard deviation")
ax1.set_xlabel('n-puzzle')
ax1.set_ylabel('tile time (ms)', color='g')
ax2.set_ylabel('manhatan time (ms)', color='b')

plt.show()

# %%
fig,ax=plt.subplots()
plt.title("standard deviation")
ax.set_xlabel("n-puzzle")
ax.set_ylabel("time (ms)")
ax.plot(x, y3, marker="o")
ax.plot(x, y4, marker="o")
plt.show()

# %%
dfms1 = dfms.drop(columns=['std_tiles','std_manhatan'])

# %%
dfms1
# Out:
#      n  mean_tiles  mean_manhatan
# 0    5        8.12           9.88
# 1    6        7.73          19.89
# 2    7       44.30         167.30
# 3    8       14.40         130.20
# 4    9       20.00         166.00
# 5   10       17.80         489.90
# 6   11       26.60         966.00
# 7   12       26.20         585.20
# 8   13       15.30         618.00
# 9   14      436.50        4645.40
# 10  15      243.50        7425.70
# 11  16       28.40        2890.00
# 12  17      273.20        7431.40
# 13  18      121.10        5848.50
# 14  19       31.10        4793.30
# 15  20       18.20        2923.90

# %%
dfms1.head(20)
# Out:
#      n  mean_tiles  mean_manhatan
# 0    5        8.12           9.88
# 1    6        7.73          19.89
# 2    7       44.30         167.30
# 3    8       14.40         130.20
# 4    9       20.00         166.00
# 5   10       17.80         489.90
# 6   11       26.60         966.00
# 7   12       26.20         585.20
# 8   13       15.30         618.00
# 9   14      436.50        4645.40
# 10  15      243.50        7425.70
# 11  16       28.40        2890.00
# 12  17      273.20        7431.40
# 13  18      121.10        5848.50
# 14  19       31.10        4793.30
# 15  20       18.20        2923.90

# %%
dfms2 = dfms.drop(columns=['mean_tiles','mean_manhatan'])

# %%
dfms2
# Out:
#      n  std_tiles  std_manhatan
# 0    5      1.081         4.329
# 1    6      1.503         6.306
# 2    7      2.983        14.190
# 3    8      3.406        20.596
# 4    9      4.295        23.281
# 5   10      5.514        27.493
# 6   11      6.398        45.609
# 7   12      5.827        29.877
# 8   13      5.658        38.338
# 9   14     53.244        75.260
# 10  15     59.219       147.481
# 11  16      5.948        59.996
# 12  17     56.503       207.137
# 13  18     31.374       148.017
# 14  19     13.237        92.713
# 15  20      8.638        53.919

# %%
dfms2.head(20)
# Out:
#      n  std_tiles  std_manhatan
# 0    5      1.081         4.329
# 1    6      1.503         6.306
# 2    7      2.983        14.190
# 3    8      3.406        20.596
# 4    9      4.295        23.281
# 5   10      5.514        27.493
# 6   11      6.398        45.609
# 7   12      5.827        29.877
# 8   13      5.658        38.338
# 9   14     53.244        75.260
# 10  15     59.219       147.481
# 11  16      5.948        59.996
# 12  17     56.503       207.137
# 13  18     31.374       148.017
# 14  19     13.237        92.713
# 15  20      8.638        53.919
