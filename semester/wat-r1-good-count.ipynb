# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 1]
df = df.drop(columns=['router'])
df.to_csv('wat-r1-good.csv',index=False)

# %%
df = pd.read_csv('wat-r1-good.csv')
df
# Out:
#           time  outport  inport packet_address  packet_type  flit_id  \
# 0           11        2       4         0x1dc0            0        0
# 1           83        4       2         0x1dc0            3        0
# 2           84        4       2         0x1dc0            3        1
# 3           85        4       2         0x1dc0            3        2
# 4           86        4       2         0x1dc0            3        3
# ...        ...      ...     ...            ...          ...      ...
# 50107  3251376        2       4       0x1152c0            4        1
# 50108  3251383        2       4       0x1152c0            4        2
# 50109  3251390        2       4       0x1152c0            4        3
# 50110  3251397        2       4       0x1152c0            4        4
# 50111  3251398        2       4        0x4d2c0            0        0
#
#        flit_type  vnet  vc  src_ni  src_router  dst_ni  dst_router  enq_time  \
# 0              3     2   8       0           0      23           7         3
# 1              0     4  16      18           2       0           0        74
# 2              1     4  16      18           2       0           0        74
# 3              1     4  16      18           2       0           0        74
# 4              1     4  16      18           2       0           0        74
# ...          ...   ...  ..     ...         ...     ...         ...       ...
# 50107          1     2   8       0           0      27          11   3251361
# 50108          1     2   8       0           0      27          11   3251361
# 50109          1     2   8       0           0      27          11   3251361
# 50110          2     2   8       0           0      27          11   3251361
# 50111          3     2   9       0           0      27          11   3251362
#
#        pkt_chuck  pkt_count_all  pkt_max_all  target
# 0              0             25           26       1
# 1              0             12           26       1
# 2              0             11           26       1
# 3              0             10           26       1
# 4              0              9           26       1
# ...          ...            ...          ...     ...
# 50107      10026             22           26       1
# 50108      10026             17           26       1
# 50109      10026             11           26       1
# 50110      10026              4           26       1
# 50111      10027              3           26       1
#
# [50112 rows x 18 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["time"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
print(len(countarr))
# Out:
# 50112

# %%
df = df.assign(pkt_count=countarr)
df = df.assign(pkt_max=maxarr)

# %%
df
# Out:
#           time  outport  inport packet_address  packet_type  flit_id  \
# 0           11        2       4         0x1dc0            0        0
# 1           83        4       2         0x1dc0            3        0
# 2           84        4       2         0x1dc0            3        1
# 3           85        4       2         0x1dc0            3        2
# 4           86        4       2         0x1dc0            3        3
# ...        ...      ...     ...            ...          ...      ...
# 50107  3251376        2       4       0x1152c0            4        1
# 50108  3251383        2       4       0x1152c0            4        2
# 50109  3251390        2       4       0x1152c0            4        3
# 50110  3251397        2       4       0x1152c0            4        4
# 50111  3251398        2       4        0x4d2c0            0        0
#
#        flit_type  vnet  vc  src_ni  src_router  dst_ni  dst_router  enq_time  \
# 0              3     2   8       0           0      23           7         3
# 1              0     4  16      18           2       0           0        74
# 2              1     4  16      18           2       0           0        74
# 3              1     4  16      18           2       0           0        74
# 4              1     4  16      18           2       0           0        74
# ...          ...   ...  ..     ...         ...     ...         ...       ...
# 50107          1     2   8       0           0      27          11   3251361
# 50108          1     2   8       0           0      27          11   3251361
# 50109          1     2   8       0           0      27          11   3251361
# 50110          2     2   8       0           0      27          11   3251361
# 50111          3     2   9       0           0      27          11   3251362
#
#        pkt_chuck  pkt_count_all  pkt_max_all  target  pkt_count  pkt_max
# 0              0             25           26       1          6        6
# 1              0             12           26       1          5        6
# 2              0             11           26       1          4        6
# 3              0             10           26       1          3        6
# 4              0              9           26       1          2        6
# ...          ...            ...          ...     ...        ...      ...
# 50107      10026             22           26       1          5        6
# 50108      10026             17           26       1          4        6
# 50109      10026             11           26       1          3        6
# 50110      10026              4           26       1          2        6
# 50111      10027              3           26       1          1        6
#
# [50112 rows x 20 columns]

# %%
cols = list(df.columns)
a, b = cols.index('target'), cols.index('pkt_count')
cols[b], cols[a] = cols[a], cols[b]
df = df[cols]
df
cols = list(df.columns)
a, b = cols.index('target'), cols.index('pkt_max')
cols[b], cols[a] = cols[a], cols[b]
df = df[cols]
df
# Out:
#           time  outport  inport packet_address  packet_type  flit_id  \
# 0           11        2       4         0x1dc0            0        0
# 1           83        4       2         0x1dc0            3        0
# 2           84        4       2         0x1dc0            3        1
# 3           85        4       2         0x1dc0            3        2
# 4           86        4       2         0x1dc0            3        3
# ...        ...      ...     ...            ...          ...      ...
# 50107  3251376        2       4       0x1152c0            4        1
# 50108  3251383        2       4       0x1152c0            4        2
# 50109  3251390        2       4       0x1152c0            4        3
# 50110  3251397        2       4       0x1152c0            4        4
# 50111  3251398        2       4        0x4d2c0            0        0
#
#        flit_type  vnet  vc  src_ni  src_router  dst_ni  dst_router  enq_time  \
# 0              3     2   8       0           0      23           7         3
# 1              0     4  16      18           2       0           0        74
# 2              1     4  16      18           2       0           0        74
# 3              1     4  16      18           2       0           0        74
# 4              1     4  16      18           2       0           0        74
# ...          ...   ...  ..     ...         ...     ...         ...       ...
# 50107          1     2   8       0           0      27          11   3251361
# 50108          1     2   8       0           0      27          11   3251361
# 50109          1     2   8       0           0      27          11   3251361
# 50110          2     2   8       0           0      27          11   3251361
# 50111          3     2   9       0           0      27          11   3251362
#
#        pkt_chuck  pkt_count_all  pkt_max_all  pkt_count  pkt_max  target
# 0              0             25           26          6        6       1
# 1              0             12           26          5        6       1
# 2              0             11           26          4        6       1
# 3              0             10           26          3        6       1
# 4              0              9           26          2        6       1
# ...          ...            ...          ...        ...      ...     ...
# 50107      10026             22           26          5        6       1
# 50108      10026             17           26          4        6       1
# 50109      10026             11           26          3        6       1
# 50110      10026              4           26          2        6       1
# 50111      10027              3           26          1        6       1
#
# [50112 rows x 20 columns]

# %%
df.to_csv('wat-r1-good.csv',index=False)
