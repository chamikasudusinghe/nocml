# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 0]
df = df.drop(columns=['router'])
df.to_csv('wat-r0-good.csv',index=False)

# %%
df = pd.read_csv('wat-r0-good.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             87        0       2                     4        1          1
# 2             88        0       2                     4        2          2
# 3             89        0       2                     4        3          2
# 4             90        0       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 64411    3251154        2       0                     5        2          2
# 64412    3251161        2       0                     5        3          2
# 64413    3251168        2       0                     5        4          2
# 64414    3251175        2       0                     5        5          3
# 64415    3251176        2       0                     1        1          4
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      23           7             0
# 1         5  17      18           2       0           0             0
# 2         5  17      18           2       0           0             0
# 3         5  17      18           2       0           0             0
# 4         5  17      18           2       0           0             0
# ...     ...  ..     ...         ...     ...         ...           ...
# 64411     3  11       0           0      22           6         10024
# 64412     3  11       0           0      22           6         10024
# 64413     3  11       0           0      22           6         10024
# 64414     3  11       0           0      22           6         10024
# 64415     3  12       0           0      22           6         10025
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              4            0             0.0             4
# 1              2            2             1.0            13
# 2              2            2             1.0            14
# 3              2            2             1.0            15
# 4              2            2             1.0            16
# ...          ...          ...             ...           ...
# 64411          3            0             0.0            11
# 64412          3            0             0.0            18
# 64413          3            0             0.0            25
# 64414          3            0             0.0            32
# 64415          3            0             0.0            32
#
# [64416 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 64416

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             87        0       2                     4        1          1
# 2             88        0       2                     4        2          2
# 3             89        0       2                     4        3          2
# 4             90        0       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 64411    3251154        2       0                     5        2          2
# 64412    3251161        2       0                     5        3          2
# 64413    3251168        2       0                     5        4          2
# 64414    3251175        2       0                     5        5          3
# 64415    3251176        2       0                     1        1          4
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      23           7             0
# 1         5  17      18           2       0           0             0
# 2         5  17      18           2       0           0             0
# 3         5  17      18           2       0           0             0
# 4         5  17      18           2       0           0             0
# ...     ...  ..     ...         ...     ...         ...           ...
# 64411     3  11       0           0      22           6         10024
# 64412     3  11       0           0      22           6         10024
# 64413     3  11       0           0      22           6         10024
# 64414     3  11       0           0      22           6         10024
# 64415     3  12       0           0      22           6         10025
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              4            0             0.0             4
# 1              2            2             1.0            13
# 2              2            2             1.0            14
# 3              2            2             1.0            15
# 4              2            2             1.0            16
# ...          ...          ...             ...           ...
# 64411          3            0             0.0            11
# 64412          3            0             0.0            18
# 64413          3            0             0.0            25
# 64414          3            0             0.0            32
# 64415          3            0             0.0            32
#
# [64416 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           7        2       0                     1        1          4
# 1          87        0       2                     4        1          1
# 2          88        0       2                     4        2          2
# 3          89        0       2                     4        3          2
# 4          90        0       2                     4        4          2
# 5          94        0       2                     4        5          3
# 6         109        1       0                     1        1          4
# 7         189        0       1                     4        1          1
# 8         190        0       1                     4        2          2
# 9         191        0       1                     4        3          2
# 10        192        0       1                     4        4          2
# 11        196        0       1                     4        5          3
# 12        237        2       0                     1        1          4
# 13        306        0       2                     4        1          1
# 14        307        0       2                     4        2          2
# 15        308        0       2                     4        3          2
# 16        310        0       2                     4        4          2
# 17        313        0       2                     4        5          3
# 18        348        2       0                     1        1          4
# 19        425        0       2                     4        1          1
# 20        426        0       2                     4        2          2
# 21        427        0       2                     4        3          2
# 22        428        0       2                     4        4          2
# 23        432        0       2                     4        5          3
# 24        455        2       0                     1        1          4
# 25        525        0       2                     4        1          1
# 26        526        0       2                     4        2          2
# 27        527        0       2                     4        3          2
# 28        528        0       2                     4        4          2
# 29        532        0       2                     4        5          3
# 30        557        2       0                     1        1          4
# 31        604        0       2                     4        1          1
# 32        605        0       2                     4        2          2
# 33        606        0       2                     4        3          2
# 34        607        0       2                     4        4          2
# 35        611        0       2                     4        5          3
# 36        624        2       0                     1        1          4
# 37        700        0       2                     4        1          1
# 38        701        0       2                     4        2          2
# 39        702        0       2                     4        3          2
# 40        704        0       2                     4        4          2
# 41        707        0       2                     4        5          3
# 42        718        2       0                     1        1          4
# 43        762        0       2                     4        1          1
# 44        763        0       2                     4        2          2
# 45        764        0       2                     4        3          2
# 46        765        0       2                     4        4          2
# 47        769        0       2                     4        5          3
# 48        804        2       0                     1        1          4
# 49        882        0       1                     4        1          1
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       0           0  ...                 6                   6
# 1      5  17      18           2  ...                 6                  10
# 2      5  17      18           2  ...                 6                  12
# 3      5  17      18           2  ...                 6                  12
# 4      5  17      18           2  ...                 6                  10
# 5      5  17      18           2  ...                 6                   6
# 6      3  10       0           0  ...                 6                   6
# 7      5  17      29          13  ...                 6                  10
# 8      5  17      29          13  ...                 6                  12
# 9      5  17      29          13  ...                 6                  12
# 10     5  17      29          13  ...                 6                  10
# 11     5  17      29          13  ...                 6                   6
# 12     3  11       0           0  ...                 1                   1
# 13     5  17      18           2  ...                 6                   6
# 14     5  17      18           2  ...                 6                  10
# 15     5  17      18           2  ...                 6                  12
# 16     5  17      18           2  ...                 6                  12
# 17     5  17      18           2  ...                 6                  10
# 18     3  12       0           0  ...                 6                   6
# 19     5  17      18           2  ...                 6                   6
# 20     5  17      18           2  ...                 6                  10
# 21     5  17      18           2  ...                 6                  12
# 22     5  17      18           2  ...                 6                  12
# 23     5  17      18           2  ...                 6                  10
# 24     3   9       0           0  ...                 6                   6
# 25     5  17      18           2  ...                 6                   6
# 26     5  17      18           2  ...                 6                  10
# 27     5  17      18           2  ...                 6                  12
# 28     5  17      18           2  ...                 6                  12
# 29     5  17      18           2  ...                 6                  10
# 30     3  10       0           0  ...                 6                   6
# 31     5  17      17           1  ...                 6                   6
# 32     5  17      17           1  ...                 6                  10
# 33     5  17      17           1  ...                 6                  12
# 34     5  17      17           1  ...                 6                  12
# 35     5  17      17           1  ...                 6                  10
# 36     3  11       0           0  ...                 6                   6
# 37     5  17      18           2  ...                11                  11
# 38     5  17      18           2  ...                11                  20
# 39     5  17      18           2  ...                11                  27
# 40     5  17      18           2  ...                11                  32
# 41     5  17      18           2  ...                11                  35
# 42     3  12       0           0  ...                11                  36
# 43     5  17      17           1  ...                11                  35
# 44     5  17      17           1  ...                11                  32
# 45     5  17      17           1  ...                11                  27
# 46     5  17      17           1  ...                11                  20
# 47     5  17      17           1  ...                11                  11
# 48     3   9       0           0  ...                 6                   6
# 49     5  17      30          14  ...                 6                  10
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 36           0                           1           4
# 1                 60           0                           4           4
# 2                 72           0                           8          16
# 3                 72           0                          12          24
# 4                 60           0                          16          32
# 5                 36           0                          20          60
# 6                 36           0                           1           4
# 7                 60           0                           4           4
# 8                 72           0                           8          16
# 9                 72           0                          12          24
# 10                60           0                          16          32
# 11                36           0                          20          60
# 12                 1           0                           1           4
# 13                36           0                           4           4
# 14                60           0                           8          16
# 15                72           0                          12          24
# 16                72           0                          16          32
# 17                60           0                          20          60
# 18                36           0                           1           4
# 19                36           0                           4           4
# 20                60           0                           8          16
# 21                72           0                          12          24
# 22                72           0                          16          32
# 23                60           0                          20          60
# 24                36           0                           1           4
# 25                36           0                           4           4
# 26                60           0                           8          16
# 27                72           0                          12          24
# 28                72           0                          16          32
# 29                60           0                          20          60
# 30                36           0                           1           4
# 31                36           0                           4           4
# 32                60           0                           8          16
# 33                72           0                          12          24
# 34                72           0                          16          32
# 35                60           0                          20          60
# 36                36           0                           1           4
# 37               121           0                           4           4
# 38               220           0                           8          16
# 39               297           0                          12          24
# 40               352           0                          16          32
# 41               385           0                          20          60
# 42               396           0                           1           4
# 43               385           0                           4           4
# 44               352           0                           8          16
# 45               297           0                          12          24
# 46               220           0                          16          32
# 47               121           0                          20          60
# 48                36           0                           1           4
# 49                60           0                           4           4
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 0                           3             27
# 1                 0                          20             85
# 2                 0                          20             85
# 3                 0                          20             85
# 4                 0                          20             85
# 5                 0                          20             85
# 6                 4                           3             30
# 7                 4                          20             85
# 8                16                          20             85
# 9                24                          20             85
# 10               32                          20             85
# 11               60                          20             85
# 12                8                           3             33
# 13                8                          20             85
# 14               32                          20             85
# 15               48                          20             85
# 16               64                          20             85
# 17              120                          20             85
# 18               12                           3             36
# 19               12                          20             85
# 20               48                          20             85
# 21               72                          20             85
# 22               96                          20             85
# 23              180                          20             85
# 24               16                           3             27
# 25               16                          20             85
# 26               64                          20             85
# 27               96                          20             85
# 28              128                          20             85
# 29              240                          20             85
# 30               20                           3             30
# 31               20                          20             85
# 32               80                          20             85
# 33              120                          20             85
# 34              160                          20             85
# 35              300                          20             85
# 36               24                           3             33
# 37               24                          20             85
# 38               96                          20             85
# 39              144                          20             85
# 40              192                          20             85
# 41              360                          20             85
# 42               28                           3             36
# 43               28                          20             85
# 44              112                          20             85
# 45              168                          20             85
# 46              224                          20             85
# 47              420                          20             85
# 48               32                           3             27
# 49               32                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                100
# 2                100
# 3                100
# 4                100
# 5                100
# 6                  9
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12                 9
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18                 9
# 19               100
# 20               100
# 21               100
# 22               100
# 23               100
# 24                 9
# 25               100
# 26               100
# 27               100
# 28               100
# 29               100
# 30                 9
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36                 9
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42                 9
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48                 9
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             87        0       2                     4        1          1
# 2             88        0       2                     4        2          2
# 3             89        0       2                     4        3          2
# 4             90        0       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 64411    3251154        2       0                     5        2          2
# 64412    3251161        2       0                     5        3          2
# 64413    3251168        2       0                     5        4          2
# 64414    3251175        2       0                     5        5          3
# 64415    3251176        2       0                     1        1          4
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       0           0  ...                   6
# 1         5  17      18           2  ...                  10
# 2         5  17      18           2  ...                  12
# 3         5  17      18           2  ...                  12
# 4         5  17      18           2  ...                  10
# ...     ...  ..     ...         ...  ...                 ...
# 64411     3  11       0           0  ...                  35
# 64412     3  11       0           0  ...                  32
# 64413     3  11       0           0  ...                  27
# 64414     3  11       0           0  ...                  20
# 64415     3  12       0           0  ...                  11
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    36           0                           1           4
# 1                    60           0                           4           4
# 2                    72           0                           8          16
# 3                    72           0                          12          24
# 4                    60           0                          16          32
# ...                 ...         ...                         ...         ...
# 64411               385           0                          10          20
# 64412               352           0                          15          30
# 64413               297           0                          20          40
# 64414               220           0                          25          75
# 64415               121           0                           1           4
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    0                           3             27
# 1                    0                          20             85
# 2                    0                          20             85
# 3                    0                          20             85
# 4                    0                          20             85
# ...                ...                         ...            ...
# 64411           200480                          15             33
# 64412           300720                          15             33
# 64413           400960                          15             33
# 64414           751800                          15             33
# 64415            40100                           3             36
#
#        vnet_vc_cc_index  target
# 0                     9       1
# 1                   100       1
# 2                   100       1
# 3                   100       1
# 4                   100       1
# ...                 ...     ...
# 64411                45       1
# 64412                45       1
# 64413                45       1
# 64414                45       1
# 64415                 9       1
#
# [64416 rows x 30 columns]

# %%
df.to_csv('wat-r0-good.csv',index=False)
