# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 13]
df = df.drop(columns=['router'])
df.to_csv('wat-r13-good.csv',index=False)

# %%
df = pd.read_csv('wat-r13-good.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            133        0       3                     2        1          4
# 1            172        4       0                     3        1          4
# 2            173        4       0                     4        1          1
# 3            174        4       0                     4        2          2
# 4            175        4       0                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 26837    3250540        4       2                     4        1          1
# 26838    3250541        4       2                     4        2          2
# 26839    3250542        4       2                     4        3          2
# 26840    3250543        4       2                     4        4          2
# 26841    3250547        4       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      24           8      29          13             1
# 1         3   9      29          13      24           8             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 26837     5  17      30          14       0           0         10017
# 26838     5  17      30          14       0           0         10017
# 26839     5  17      30          14       0           0         10017
# 26840     5  17      30          14       0           0         10017
# 26841     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            2             1.0            12
# 1              2            0             0.0             4
# 2              4            0             0.0             5
# 3              4            0             0.0             6
# 4              4            0             0.0             7
# ...          ...          ...             ...           ...
# 26837          5            1             0.2             8
# 26838          5            1             0.2             9
# 26839          5            1             0.2            10
# 26840          5            1             0.2            11
# 26841          5            1             0.2            15
#
# [26842 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 26842

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            133        0       3                     2        1          4
# 1            172        4       0                     3        1          4
# 2            173        4       0                     4        1          1
# 3            174        4       0                     4        2          2
# 4            175        4       0                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 26837    3250540        4       2                     4        1          1
# 26838    3250541        4       2                     4        2          2
# 26839    3250542        4       2                     4        3          2
# 26840    3250543        4       2                     4        4          2
# 26841    3250547        4       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      24           8      29          13             1
# 1         3   9      29          13      24           8             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 26837     5  17      30          14       0           0         10017
# 26838     5  17      30          14       0           0         10017
# 26839     5  17      30          14       0           0         10017
# 26840     5  17      30          14       0           0         10017
# 26841     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            2             1.0            12
# 1              2            0             0.0             4
# 2              4            0             0.0             5
# 3              4            0             0.0             6
# 4              4            0             0.0             7
# ...          ...          ...             ...           ...
# 26837          5            1             0.2             8
# 26838          5            1             0.2             9
# 26839          5            1             0.2            10
# 26840          5            1             0.2            11
# 26841          5            1             0.2            15
#
# [26842 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         133        0       3                     2        1          4
# 1         172        4       0                     3        1          4
# 2         173        4       0                     4        1          1
# 3         174        4       0                     4        2          2
# 4         175        4       0                     4        3          2
# 5         176        4       0                     4        4          2
# 6         180        4       0                     4        5          3
# 7         866        4       2                     4        1          1
# 8         867        4       2                     4        2          2
# 9         868        4       2                     4        3          2
# 10        869        4       2                     4        4          2
# 11        873        4       2                     4        5          3
# 12        944        0       3                     2        1          4
# 13        980        4       0                     4        1          1
# 14        981        4       0                     4        2          2
# 15        982        4       0                     4        3          2
# 16        983        2       0                     3        1          4
# 17        984        4       0                     4        4          2
# 18        987        4       0                     4        5          3
# 19       1046        0       3                     2        1          4
# 20       1082        3       0                     3        1          4
# 21       1083        4       0                     4        1          1
# 22       1084        4       0                     4        2          2
# 23       1085        4       0                     4        3          2
# 24       1086        4       0                     4        4          2
# 25       1090        4       0                     4        5          3
# 26       1241        2       4                     2        1          4
# 27       1286        4       2                     4        1          1
# 28       1287        4       2                     4        2          2
# 29       1288        4       2                     4        3          2
# 30       1289        4       2                     4        4          2
# 31       1290        4       2                     3        1          4
# 32       1293        4       2                     4        5          3
# 33       1374        0       3                     2        1          4
# 34       1410        2       0                     3        1          4
# 35       1411        4       0                     4        1          1
# 36       1412        4       0                     4        2          2
# 37       1413        4       0                     4        3          2
# 38       1414        4       0                     4        4          2
# 39       1418        4       0                     4        5          3
# 40       1465        0       3                     1        1          4
# 41       1473        2       0                     2        1          4
# 42       1518        0       2                     3        1          4
# 43       1519        4       2                     4        1          1
# 44       1520        4       2                     4        2          2
# 45       1521        4       2                     4        3          2
# 46       1522        4       2                     4        4          2
# 47       1526        4       2                     4        5          3
# 48       1730        4       2                     4        1          1
# 49       1731        4       2                     4        2          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9      24           8  ...                 7                   7
# 1      3   9      29          13  ...                 7                  12
# 2      5  17      29          13  ...                 7                  15
# 3      5  17      29          13  ...                 7                  16
# 4      5  17      29          13  ...                 7                  15
# 5      5  17      29          13  ...                 7                  12
# 6      5  17      29          13  ...                 7                   7
# 7      5  17      30          14  ...                 1                   1
# 8      5  17      30          14  ...                 1                   1
# 9      5  17      30          14  ...                 1                   1
# 10     5  17      30          14  ...                 1                   1
# 11     5  17      30          14  ...                 1                   1
# 12     3   9      27          11  ...                 1                   1
# 13     5  18      29          13  ...                 1                   1
# 14     5  18      29          13  ...                 5                   5
# 15     5  18      29          13  ...                 5                   8
# 16     3  10      29          13  ...                 5                   9
# 17     5  18      29          13  ...                 5                   8
# 18     5  18      29          13  ...                 5                   5
# 19     3   9      25           9  ...                 7                   7
# 20     3  11      29          13  ...                 7                  12
# 21     5  19      29          13  ...                 7                  15
# 22     5  19      29          13  ...                 7                  16
# 23     5  19      29          13  ...                 7                  15
# 24     5  19      29          13  ...                 7                  12
# 25     5  19      29          13  ...                 7                   7
# 26     3   9      28          12  ...                 1                   1
# 27     5  17      30          14  ...                 6                   6
# 28     5  17      30          14  ...                 6                  10
# 29     5  17      30          14  ...                 6                  12
# 30     5  17      30          14  ...                 6                  12
# 31     3   9      30          14  ...                 6                  10
# 32     5  17      30          14  ...                 6                   6
# 33     3   9      26          10  ...                 1                   1
# 34     3  12      29          13  ...                 8                   8
# 35     5  20      29          13  ...                 8                  14
# 36     5  20      29          13  ...                 8                  18
# 37     5  20      29          13  ...                 8                  20
# 38     5  20      29          13  ...                 8                  20
# 39     5  20      29          13  ...                 8                  18
# 40     3   9       0           0  ...                 8                  14
# 41     3   9      29          13  ...                 8                   8
# 42     3   9      30          14  ...                 6                   6
# 43     5  17      30          14  ...                 6                  10
# 44     5  17      30          14  ...                 6                  12
# 45     5  17      30          14  ...                 6                  12
# 46     5  17      30          14  ...                 6                  10
# 47     5  17      30          14  ...                 6                   6
# 48     5  17      30          14  ...                 1                   1
# 49     5  17      30          14  ...                 4                   4
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 49           0                           2           8
# 1                 84           0                           3          12
# 2                105           0                           4           4
# 3                112           0                           8          16
# 4                105           0                          12          24
# 5                 84           0                          16          32
# 6                 49           0                          20          60
# 7                  1           8                           4           4
# 8                  1           8                           8          16
# 9                  1           8                          12          24
# 10                 1           8                          16          32
# 11                 1           8                          20          60
# 12                 1           0                           2           8
# 13                 1           0                           4           4
# 14                25           0                           8          16
# 15                40           0                          12          24
# 16                45           0                           3          12
# 17                40           0                          16          32
# 18                25           0                          20          60
# 19                49           0                           2           8
# 20                84           0                           3          12
# 21               105           0                           4           4
# 22               112           0                           8          16
# 23               105           0                          12          24
# 24                84           0                          16          32
# 25                49           0                          20          60
# 26                 1           8                           2           8
# 27                36           8                           4           4
# 28                60           8                           8          16
# 29                72           8                          12          24
# 30                72           8                          16          32
# 31                60           8                           3          12
# 32                36           8                          20          60
# 33                 1           0                           2           8
# 34                64           0                           3          12
# 35               112           0                           4           4
# 36               144           0                           8          16
# 37               160           0                          12          24
# 38               160           0                          16          32
# 39               144           0                          20          60
# 40               112           0                           1           4
# 41                64           0                           2           8
# 42                36           0                           3          12
# 43                60           8                           4           4
# 44                72           8                           8          16
# 45                72           8                          12          24
# 46                60           8                          16          32
# 47                36           8                          20          60
# 48                 1           8                           4           4
# 49                16           8                           8          16
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 8                           6             27
# 1                12                           9             27
# 2                 4                          20             85
# 3                16                          20             85
# 4                24                          20             85
# 5                32                          20             85
# 6                60                          20             85
# 7                32                          20             85
# 8               128                          20             85
# 9               192                          20             85
# 10              256                          20             85
# 11              480                          20             85
# 12               72                           6             27
# 13               36                          20             90
# 14              144                          20             90
# 15              216                          20             90
# 16              108                           9             30
# 17              288                          20             90
# 18              540                          20             90
# 19               80                           6             27
# 20              120                           9             33
# 21               40                          20             95
# 22              160                          20             95
# 23              240                          20             95
# 24              320                          20             95
# 25              600                          20             95
# 26               96                           6             27
# 27               48                          20             85
# 28              192                          20             85
# 29              288                          20             85
# 30              384                          20             85
# 31              144                           9             27
# 32              720                          20             85
# 33              104                           6             27
# 34              156                           9             36
# 35               52                          20            100
# 36              208                          20            100
# 37              312                          20            100
# 38              416                          20            100
# 39              780                          20            100
# 40               56                           3             27
# 41              112                           6             27
# 42              168                           9             27
# 43               56                          20             85
# 44              224                          20             85
# 45              336                          20             85
# 46              448                          20             85
# 47              840                          20             85
# 48               64                          20             85
# 49              256                          20             85
#
#     vnet_vc_cc_index
# 0                 18
# 1                 27
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12                18
# 13               100
# 14               100
# 15               100
# 16                27
# 17               100
# 18               100
# 19                18
# 20                27
# 21               100
# 22               100
# 23               100
# 24               100
# 25               100
# 26                18
# 27               100
# 28               100
# 29               100
# 30               100
# 31                27
# 32               100
# 33                18
# 34                27
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40                 9
# 41                18
# 42                27
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            133        0       3                     2        1          4
# 1            172        4       0                     3        1          4
# 2            173        4       0                     4        1          1
# 3            174        4       0                     4        2          2
# 4            175        4       0                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 26837    3250540        4       2                     4        1          1
# 26838    3250541        4       2                     4        2          2
# 26839    3250542        4       2                     4        3          2
# 26840    3250543        4       2                     4        4          2
# 26841    3250547        4       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9      24           8  ...                   7
# 1         3   9      29          13  ...                  12
# 2         5  17      29          13  ...                  15
# 3         5  17      29          13  ...                  16
# 4         5  17      29          13  ...                  15
# ...     ...  ..     ...         ...  ...                 ...
# 26837     5  17      30          14  ...                   1
# 26838     5  17      30          14  ...                   1
# 26839     5  17      30          14  ...                   1
# 26840     5  17      30          14  ...                   1
# 26841     5  17      30          14  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    49           0                           2           8
# 1                    84           0                           3          12
# 2                   105           0                           4           4
# 3                   112           0                           8          16
# 4                   105           0                          12          24
# ...                 ...         ...                         ...         ...
# 26837                 1           8                           4           4
# 26838                 1           8                           8          16
# 26839                 1           8                          12          24
# 26840                 1           8                          16          32
# 26841                 1           8                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    8                           6             27
# 1                   12                           9             27
# 2                    4                          20             85
# 3                   16                          20             85
# 4                   24                          20             85
# ...                ...                         ...            ...
# 26837            40068                          20             85
# 26838           160272                          20             85
# 26839           240408                          20             85
# 26840           320544                          20             85
# 26841           601020                          20             85
#
#        vnet_vc_cc_index  target
# 0                    18       1
# 1                    27       1
# 2                   100       1
# 3                   100       1
# 4                   100       1
# ...                 ...     ...
# 26837               100       1
# 26838               100       1
# 26839               100       1
# 26840               100       1
# 26841               100       1
#
# [26842 rows x 30 columns]

# %%
df.to_csv('wat-r13-good.csv',index=False)
