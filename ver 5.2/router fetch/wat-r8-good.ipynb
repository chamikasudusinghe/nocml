# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 8]
df = df.drop(columns=['router'])
df.to_csv('wat-r8-good.csv',index=False)

# %%
df = pd.read_csv('wat-r8-good.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            117        0       3                     1        1          4
# 1            125        2       0                     2        1          4
# 2            180        0       1                     3        1          4
# 3            181        3       1                     4        1          1
# 4            182        3       1                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 20204    3250548        3       1                     4        1          1
# 20205    3250549        3       1                     4        2          2
# 20206    3250550        3       1                     4        3          2
# 20207    3250551        3       1                     4        4          2
# 20208    3250555        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      24           8             1
# 1         3   9      24           8      29          13             1
# 2         3   9      29          13      24           8             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 20204     5  17      30          14       0           0         10017
# 20205     5  17      30          14       0           0         10017
# 20206     5  17      30          14       0           0         10017
# 20207     5  17      30          14       0           0         10017
# 20208     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            2             1.0            12
# 1              2            0             0.0             4
# 2              2            2             1.0            12
# 3              4            2             0.5            13
# 4              4            2             0.5            14
# ...          ...          ...             ...           ...
# 20204          5            3             0.6            16
# 20205          5            3             0.6            17
# 20206          5            3             0.6            18
# 20207          5            3             0.6            19
# 20208          5            3             0.6            23
#
# [20209 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 20209

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            117        0       3                     1        1          4
# 1            125        2       0                     2        1          4
# 2            180        0       1                     3        1          4
# 3            181        3       1                     4        1          1
# 4            182        3       1                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 20204    3250548        3       1                     4        1          1
# 20205    3250549        3       1                     4        2          2
# 20206    3250550        3       1                     4        3          2
# 20207    3250551        3       1                     4        4          2
# 20208    3250555        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      24           8             1
# 1         3   9      24           8      29          13             1
# 2         3   9      29          13      24           8             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 20204     5  17      30          14       0           0         10017
# 20205     5  17      30          14       0           0         10017
# 20206     5  17      30          14       0           0         10017
# 20207     5  17      30          14       0           0         10017
# 20208     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            2             1.0            12
# 1              2            0             0.0             4
# 2              2            2             1.0            12
# 3              4            2             0.5            13
# 4              4            2             0.5            14
# ...          ...          ...             ...           ...
# 20204          5            3             0.6            16
# 20205          5            3             0.6            17
# 20206          5            3             0.6            18
# 20207          5            3             0.6            19
# 20208          5            3             0.6            23
#
# [20209 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         117        0       3                     1        1          4
# 1         125        2       0                     2        1          4
# 2         180        0       1                     3        1          4
# 3         181        3       1                     4        1          1
# 4         182        3       1                     4        2          2
# 5         183        3       1                     4        3          2
# 6         184        3       1                     4        4          2
# 7         188        3       1                     4        5          3
# 8         874        3       1                     4        1          1
# 9         875        3       1                     4        2          2
# 10        876        3       1                     4        3          2
# 11        877        3       1                     4        4          2
# 12        881        3       1                     4        5          3
# 13        988        3       1                     4        1          1
# 14        989        3       1                     4        2          2
# 15        990        3       1                     4        3          2
# 16        992        3       1                     4        4          2
# 17        995        3       1                     4        5          3
# 18       1091        3       1                     4        1          1
# 19       1092        3       1                     4        2          2
# 20       1093        3       1                     4        3          2
# 21       1094        3       1                     4        4          2
# 22       1098        3       1                     4        5          3
# 23       1225        1       3                     1        1          4
# 24       1294        3       1                     4        1          1
# 25       1295        3       1                     4        2          2
# 26       1296        3       1                     4        3          2
# 27       1297        3       1                     4        4          2
# 28       1301        3       1                     4        5          3
# 29       1419        3       1                     4        1          1
# 30       1420        3       1                     4        2          2
# 31       1421        3       1                     4        3          2
# 32       1422        3       1                     4        4          2
# 33       1426        3       1                     4        5          3
# 34       1527        3       1                     4        1          1
# 35       1528        3       1                     4        2          2
# 36       1529        3       1                     4        3          2
# 37       1530        3       1                     4        4          2
# 38       1534        3       1                     4        5          3
# 39       1738        3       1                     4        1          1
# 40       1739        3       1                     4        2          2
# 41       1740        3       1                     4        3          2
# 42       1741        3       1                     4        4          2
# 43       1745        3       1                     4        5          3
# 44       2311        3       1                     4        1          1
# 45       2312        3       1                     4        2          2
# 46       2313        3       1                     4        3          2
# 47       2314        3       1                     4        4          2
# 48       2318        3       1                     4        5          3
# 49       2514        3       1                     4        1          1
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       0           0  ...                 8                   8
# 1      3   9      24           8  ...                 8                  14
# 2      3   9      29          13  ...                 8                  18
# 3      5  17      29          13  ...                 8                  20
# 4      5  17      29          13  ...                 8                  20
# 5      5  17      29          13  ...                 8                  18
# 6      5  17      29          13  ...                 8                  14
# 7      5  17      29          13  ...                 8                   8
# 8      5  17      30          14  ...                 1                   1
# 9      5  17      30          14  ...                 1                   1
# 10     5  17      30          14  ...                 1                   1
# 11     5  17      30          14  ...                 1                   1
# 12     5  17      30          14  ...                 1                   1
# 13     5  17      29          13  ...                 1                   1
# 14     5  17      29          13  ...                 1                   1
# 15     5  17      29          13  ...                 3                   3
# 16     5  17      29          13  ...                 3                   4
# 17     5  17      29          13  ...                 3                   3
# 18     5  17      29          13  ...                 5                   5
# 19     5  17      29          13  ...                 5                   8
# 20     5  17      29          13  ...                 5                   9
# 21     5  17      29          13  ...                 5                   8
# 22     5  17      29          13  ...                 5                   5
# 23     3   9       0           0  ...                 1                   1
# 24     5  17      30          14  ...                 4                   4
# 25     5  17      30          14  ...                 4                   6
# 26     5  17      30          14  ...                 4                   6
# 27     5  17      30          14  ...                 4                   4
# 28     5  17      30          14  ...                 1                   1
# 29     5  17      29          13  ...                 5                   5
# 30     5  17      29          13  ...                 5                   8
# 31     5  17      29          13  ...                 5                   9
# 32     5  17      29          13  ...                 5                   8
# 33     5  17      29          13  ...                 5                   5
# 34     5  17      30          14  ...                 5                   5
# 35     5  17      30          14  ...                 5                   8
# 36     5  17      30          14  ...                 5                   9
# 37     5  17      30          14  ...                 5                   8
# 38     5  17      30          14  ...                 5                   5
# 39     5  17      30          14  ...                 1                   1
# 40     5  17      30          14  ...                 4                   4
# 41     5  17      30          14  ...                 4                   6
# 42     5  17      30          14  ...                 4                   6
# 43     5  17      30          14  ...                 4                   4
# 44     5  17      29          13  ...                 1                   1
# 45     5  17      29          13  ...                 1                   1
# 46     5  17      29          13  ...                 1                   1
# 47     5  17      29          13  ...                 1                   1
# 48     5  17      29          13  ...                 1                   1
# 49     5  17      29          13  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 64           0                           1           4
# 1                112           0                           2           8
# 2                144           0                           3          12
# 3                160           3                           4           4
# 4                160           3                           8          16
# 5                144           3                          12          24
# 6                112           3                          16          32
# 7                 64           3                          20          60
# 8                  1           3                           4           4
# 9                  1           3                           8          16
# 10                 1           3                          12          24
# 11                 1           3                          16          32
# 12                 1           3                          20          60
# 13                 1           3                           4           4
# 14                 1           3                           8          16
# 15                 9           3                          12          24
# 16                12           3                          16          32
# 17                 9           3                          20          60
# 18                25           3                           4           4
# 19                40           3                           8          16
# 20                45           3                          12          24
# 21                40           3                          16          32
# 22                25           3                          20          60
# 23                 1           3                           1           4
# 24                16           3                           4           4
# 25                24           3                           8          16
# 26                24           3                          12          24
# 27                16           3                          16          32
# 28                 1           3                          20          60
# 29                25           3                           4           4
# 30                40           3                           8          16
# 31                45           3                          12          24
# 32                40           3                          16          32
# 33                25           3                          20          60
# 34                25           3                           4           4
# 35                40           3                           8          16
# 36                45           3                          12          24
# 37                40           3                          16          32
# 38                25           3                          20          60
# 39                 1           3                           4           4
# 40                16           3                           8          16
# 41                24           3                          12          24
# 42                24           3                          16          32
# 43                16           3                          20          60
# 44                 1           3                           4           4
# 45                 1           3                           8          16
# 46                 1           3                          12          24
# 47                 1           3                          16          32
# 48                 1           3                          20          60
# 49                 1           3                           4           4
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 4                           3             27
# 1                 8                           6             27
# 2                12                           9             27
# 3                 4                          20             85
# 4                16                          20             85
# 5                24                          20             85
# 6                32                          20             85
# 7                60                          20             85
# 8                32                          20             85
# 9               128                          20             85
# 10              192                          20             85
# 11              256                          20             85
# 12              480                          20             85
# 13               36                          20             85
# 14              144                          20             85
# 15              216                          20             85
# 16              288                          20             85
# 17              540                          20             85
# 18               40                          20             85
# 19              160                          20             85
# 20              240                          20             85
# 21              320                          20             85
# 22              600                          20             85
# 23               48                           3             27
# 24               48                          20             85
# 25              192                          20             85
# 26              288                          20             85
# 27              384                          20             85
# 28              720                          20             85
# 29               52                          20             85
# 30              208                          20             85
# 31              312                          20             85
# 32              416                          20             85
# 33              780                          20             85
# 34               56                          20             85
# 35              224                          20             85
# 36              336                          20             85
# 37              448                          20             85
# 38              840                          20             85
# 39               64                          20             85
# 40              256                          20             85
# 41              384                          20             85
# 42              512                          20             85
# 43              960                          20             85
# 44               88                          20             85
# 45              352                          20             85
# 46              528                          20             85
# 47              704                          20             85
# 48             1320                          20             85
# 49               96                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                 18
# 2                 27
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19               100
# 20               100
# 21               100
# 22               100
# 23                 9
# 24               100
# 25               100
# 26               100
# 27               100
# 28               100
# 29               100
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            117        0       3                     1        1          4
# 1            125        2       0                     2        1          4
# 2            180        0       1                     3        1          4
# 3            181        3       1                     4        1          1
# 4            182        3       1                     4        2          2
# ...          ...      ...     ...                   ...      ...        ...
# 20204    3250548        3       1                     4        1          1
# 20205    3250549        3       1                     4        2          2
# 20206    3250550        3       1                     4        3          2
# 20207    3250551        3       1                     4        4          2
# 20208    3250555        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       0           0  ...                   8
# 1         3   9      24           8  ...                  14
# 2         3   9      29          13  ...                  18
# 3         5  17      29          13  ...                  20
# 4         5  17      29          13  ...                  20
# ...     ...  ..     ...         ...  ...                 ...
# 20204     5  17      30          14  ...                   1
# 20205     5  17      30          14  ...                   1
# 20206     5  17      30          14  ...                   1
# 20207     5  17      30          14  ...                   1
# 20208     5  17      30          14  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    64           0                           1           4
# 1                   112           0                           2           8
# 2                   144           0                           3          12
# 3                   160           3                           4           4
# 4                   160           3                           8          16
# ...                 ...         ...                         ...         ...
# 20204                 1           3                           4           4
# 20205                 1           3                           8          16
# 20206                 1           3                          12          24
# 20207                 1           3                          16          32
# 20208                 1           3                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    8                           6             27
# 2                   12                           9             27
# 3                    4                          20             85
# 4                   16                          20             85
# ...                ...                         ...            ...
# 20204            40068                          20             85
# 20205           160272                          20             85
# 20206           240408                          20             85
# 20207           320544                          20             85
# 20208           601020                          20             85
#
#        vnet_vc_cc_index  target
# 0                     9       1
# 1                    18       1
# 2                    27       1
# 3                   100       1
# 4                   100       1
# ...                 ...     ...
# 20204               100       1
# 20205               100       1
# 20206               100       1
# 20207               100       1
# 20208               100       1
#
# [20209 rows x 30 columns]

# %%
df.to_csv('wat-r8-good.csv',index=False)
