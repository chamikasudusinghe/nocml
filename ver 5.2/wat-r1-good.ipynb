# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 1]
df = df.drop(columns=['router'])
df.to_csv('wat-r1-good.csv',index=False)

# %%
df = pd.read_csv('wat-r1-good.csv')
df
# Out:
#           time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  \
# 0           11        2       4            0        0          3     2   8
# 1           83        4       2            3        0          0     4  16
# 2           84        4       2            3        1          1     4  16
# 3           85        4       2            3        2          1     4  16
# 4           86        4       2            3        3          1     4  16
# ...        ...      ...     ...          ...      ...        ...   ...  ..
# 50096  3251158        2       4            4        1          1     2   8
# 50097  3251165        2       4            4        2          1     2   8
# 50098  3251172        2       4            4        3          1     2   8
# 50099  3251179        2       4            4        4          2     2   8
# 50100  3251180        2       4            0        0          3     2   9
#
#        src_ni  src_router  dst_ni  dst_router  pkt_chuck  hop_count  \
# 0           0           0      23           7          0          4
# 1          18           2       0           0          0          2
# 2          18           2       0           0          0          2
# 3          18           2       0           0          0          2
# 4          18           2       0           0          0          2
# ...       ...         ...     ...         ...        ...        ...
# 50096       0           0      22           6      10024          3
# 50097       0           0      22           6      10024          3
# 50098       0           0      22           6      10024          3
# 50099       0           0      22           6      10024          3
# 50100       0           0      22           6      10025          3
#
#        current_hop  hop_percentage  waiting_time
# 0                1        0.250000             8
# 1                1        0.500000             9
# 2                1        0.500000            10
# 3                1        0.500000            11
# 4                1        0.500000            12
# ...            ...             ...           ...
# 50096            1        0.333333            15
# 50097            1        0.333333            22
# 50098            1        0.333333            29
# 50099            1        0.333333            36
# 50100            1        0.333333            36
#
# [50101 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["time"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 50101

# %%
df = df.assign(pkt_count=countarr)
df = df.assign(pkt_count_inc=increarr)
df = df.assign(pkt_max=maxarr)
df["counting_index_pos"] = df["pkt_count"]*df["pkt_count_inc"]
df["counting_index_100"] = df["counting_index_pos"]*df["pkt_max"]
df.head(50)
# Out:
#     time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  src_ni  \
# 0     11        2       4            0        0          3     2   8       0
# 1     83        4       2            3        0          0     4  16      18
# 2     84        4       2            3        1          1     4  16      18
# 3     85        4       2            3        2          1     4  16      18
# 4     86        4       2            3        3          1     4  16      18
# 5     90        4       2            3        4          2     4  16      18
# 6    241        2       4            0        0          3     2   8       0
# 7    302        4       2            3        0          0     4  16      18
# 8    303        4       2            3        1          1     4  16      18
# 9    304        4       2            3        2          1     4  16      18
# 10   306        4       2            3        3          1     4  16      18
# 11   309        4       2            3        4          2     4  16      18
# 12   352        2       4            0        0          3     2   8       0
# 13   421        4       2            3        0          0     4  16      18
# 14   422        4       2            3        1          1     4  16      18
# 15   423        4       2            3        2          1     4  16      18
# 16   424        4       2            3        3          1     4  16      18
# 17   428        4       2            3        4          2     4  16      18
# 18   459        1       4            0        0          3     2   8       0
# 19   520        1       2            2        0          3     2   8      18
# 20   521        4       2            3        0          0     4  16      18
# 21   522        4       2            3        1          1     4  16      18
# 22   523        4       2            3        2          1     4  16      18
# 23   524        4       2            3        3          1     4  16      18
# 24   528        4       2            3        4          2     4  16      18
# 25   561        0       4            0        0          3     2   8       0
# 26   600        4       0            3        0          0     4  16      17
# 27   601        4       0            3        1          1     4  16      17
# 28   602        4       0            3        2          1     4  16      17
# 29   603        4       0            3        3          1     4  16      17
# 30   607        4       0            3        4          2     4  16      17
# 31   628        2       4            0        0          3     2   8       0
# 32   696        4       2            3        0          0     4  16      18
# 33   697        4       2            3        1          1     4  16      18
# 34   698        4       2            3        2          1     4  16      18
# 35   700        4       2            3        3          1     4  16      18
# 36   703        4       2            3        4          2     4  16      18
# 37   722        0       4            0        0          3     2   8       0
# 38   758        4       0            3        0          0     4  17      17
# 39   759        4       0            3        1          1     4  17      17
# 40   760        4       0            3        2          1     4  17      17
# 41   761        4       0            3        3          1     4  17      17
# 42   765        4       0            3        4          2     4  17      17
# 43   808        2       4            0        0          3     2   8       0
# 44   908        2       4            0        0          3     2   8       0
# 45  1026        1       4            0        0          3     2   8       0
# 46  1188        4       2            2        0          3     2   8      18
# 47  1189        4       2            3        0          0     4  16      18
# 48  1190        4       2            3        1          1     4  16      18
# 49  1191        4       2            3        2          1     4  16      18
#
#     src_router  ...  pkt_chuck  hop_count  current_hop  hop_percentage  \
# 0            0  ...          0          4            1        0.250000
# 1            2  ...          0          2            1        0.500000
# 2            2  ...          0          2            1        0.500000
# 3            2  ...          0          2            1        0.500000
# 4            2  ...          0          2            1        0.500000
# 5            2  ...          0          2            1        0.500000
# 6            0  ...          2          3            1        0.333333
# 7            2  ...          2          2            1        0.500000
# 8            2  ...          2          2            1        0.500000
# 9            2  ...          2          2            1        0.500000
# 10           2  ...          2          2            1        0.500000
# 11           2  ...          2          2            1        0.500000
# 12           0  ...          3          4            1        0.250000
# 13           2  ...          3          2            1        0.500000
# 14           2  ...          3          2            1        0.500000
# 15           2  ...          3          2            1        0.500000
# 16           2  ...          3          2            1        0.500000
# 17           2  ...          3          2            1        0.500000
# 18           0  ...          4          2            1        0.500000
# 19           2  ...          4          2            1        0.500000
# 20           2  ...          4          2            1        0.500000
# 21           2  ...          4          2            1        0.500000
# 22           2  ...          4          2            1        0.500000
# 23           2  ...          4          2            1        0.500000
# 24           2  ...          4          2            1        0.500000
# 25           0  ...          5          1            1        1.000000
# 26           1  ...          5          1            0        0.000000
# 27           1  ...          5          1            0        0.000000
# 28           1  ...          5          1            0        0.000000
# 29           1  ...          5          1            0        0.000000
# 30           1  ...          5          1            0        0.000000
# 31           0  ...          6          4            1        0.250000
# 32           2  ...          6          2            1        0.500000
# 33           2  ...          6          2            1        0.500000
# 34           2  ...          6          2            1        0.500000
# 35           2  ...          6          2            1        0.500000
# 36           2  ...          6          2            1        0.500000
# 37           0  ...          7          1            1        1.000000
# 38           1  ...          7          1            0        0.000000
# 39           1  ...          7          1            0        0.000000
# 40           1  ...          7          1            0        0.000000
# 41           1  ...          7          1            0        0.000000
# 42           1  ...          7          1            0        0.000000
# 43           0  ...          8          5            1        0.200000
# 44           0  ...          9          5            1        0.200000
# 45           0  ...         10          3            1        0.333333
# 46           2  ...         11          3            1        0.333333
# 47           2  ...         11          2            1        0.500000
# 48           2  ...         11          2            1        0.500000
# 49           2  ...         11          2            1        0.500000
#
#     waiting_time  pkt_count  pkt_count_inc  pkt_max  counting_index_pos  \
# 0              8          6              1        6                   6
# 1              9          5              2        6                  10
# 2             10          4              3        6                  12
# 3             11          3              4        6                  12
# 4             12          2              5        6                  10
# 5             16          1              6        6                   6
# 6              8          1              1        1                   1
# 7              8          1              1        1                   1
# 8              9          5              1        5                   5
# 9             10          4              2        5                   8
# 10            12          3              3        5                   9
# 11            15          2              4        5                   8
# 12             8          1              5        5                   5
# 13             9          6              1        6                   6
# 14            10          5              2        6                  10
# 15            11          4              3        6                  12
# 16            12          3              4        6                  12
# 17            16          2              5        6                  10
# 18             8          1              6        6                   6
# 19             8          7              1        7                   7
# 20             9          6              2        7                  12
# 21            10          5              3        7                  15
# 22            11          4              4        7                  16
# 23            12          3              5        7                  15
# 24            16          2              6        7                  12
# 25             8          1              7        7                   7
# 26             4          9              1        9                   9
# 27             5          8              2        9                  16
# 28             6          7              3        9                  21
# 29             7          6              4        9                  24
# 30            11          5              5        9                  25
# 31             8          4              6        9                  24
# 32             8          3              7        9                  21
# 33             9          2              8        9                  16
# 34            10          1              9        9                   9
# 35            12          8              1        8                   8
# 36            15          7              2        8                  14
# 37             8          6              3        8                  18
# 38             4          5              4        8                  20
# 39             5          4              5        8                  20
# 40             6          3              6        8                  18
# 41             7          2              7        8                  14
# 42            11          1              8        8                   8
# 43             8          1              1        1                   1
# 44             8          1              1        1                   1
# 45             8          1              1        1                   1
# 46             8          6              1        6                   6
# 47             9          5              2        6                  10
# 48            10          4              3        6                  12
# 49            11          3              4        6                  12
#
#     counting_index_100
# 0                   36
# 1                   60
# 2                   72
# 3                   72
# 4                   60
# 5                   36
# 6                    1
# 7                    1
# 8                   25
# 9                   40
# 10                  45
# 11                  40
# 12                  25
# 13                  36
# 14                  60
# 15                  72
# 16                  72
# 17                  60
# 18                  36
# 19                  49
# 20                  84
# 21                 105
# 22                 112
# 23                 105
# 24                  84
# 25                  49
# 26                  81
# 27                 144
# 28                 189
# 29                 216
# 30                 225
# 31                 216
# 32                 189
# 33                 144
# 34                  81
# 35                  64
# 36                 112
# 37                 144
# 38                 160
# 39                 160
# 40                 144
# 41                 112
# 42                  64
# 43                   1
# 44                   1
# 45                   1
# 46                  36
# 47                  60
# 48                  72
# 49                  72
#
# [50 rows x 22 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# time                    int64
# outport                 int64
# inport                  int64
# packet_type             int64
# flit_id                 int64
# flit_type               int64
# vnet                    int64
# vc                      int64
# src_ni                  int64
# src_router              int64
# dst_ni                  int64
# dst_router              int64
# pkt_chuck               int64
# hop_count               int64
# current_hop             int64
# hop_percentage        float64
# waiting_time            int64
# pkt_count               int64
# pkt_count_inc           int64
# pkt_max                 int64
# counting_index_pos      int64
# counting_index_100      int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#           time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  \
# 0           11        2       4            0        0          3     2   8
# 1           83        4       2            3        0          0     4  16
# 2           84        4       2            3        1          1     4  16
# 3           85        4       2            3        2          1     4  16
# 4           86        4       2            3        3          1     4  16
# ...        ...      ...     ...          ...      ...        ...   ...  ..
# 50096  3251158        2       4            4        1          1     2   8
# 50097  3251165        2       4            4        2          1     2   8
# 50098  3251172        2       4            4        3          1     2   8
# 50099  3251179        2       4            4        4          2     2   8
# 50100  3251180        2       4            0        0          3     2   9
#
#        src_ni  src_router  ...  hop_count  current_hop  hop_percentage  \
# 0           0           0  ...          4            1        0.250000
# 1          18           2  ...          2            1        0.500000
# 2          18           2  ...          2            1        0.500000
# 3          18           2  ...          2            1        0.500000
# 4          18           2  ...          2            1        0.500000
# ...       ...         ...  ...        ...          ...             ...
# 50096       0           0  ...          3            1        0.333333
# 50097       0           0  ...          3            1        0.333333
# 50098       0           0  ...          3            1        0.333333
# 50099       0           0  ...          3            1        0.333333
# 50100       0           0  ...          3            1        0.333333
#
#        waiting_time  pkt_count  pkt_count_inc  pkt_max  counting_index_pos  \
# 0                 8          6              1        6                   6
# 1                 9          5              2        6                  10
# 2                10          4              3        6                  12
# 3                11          3              4        6                  12
# 4                12          2              5        6                  10
# ...             ...        ...            ...      ...                 ...
# 50096            15          5              8       12                  40
# 50097            22          4              9       12                  36
# 50098            29          3             10       12                  30
# 50099            36          2             11       12                  22
# 50100            36          1             12       12                  12
#
#        counting_index_100  target
# 0                      36       1
# 1                      60       1
# 2                      72       1
# 3                      72       1
# 4                      60       1
# ...                   ...     ...
# 50096                 480       1
# 50097                 432       1
# 50098                 360       1
# 50099                 264       1
# 50100                 144       1
#
# [50101 rows x 23 columns]

# %%
df.to_csv('wat-r1-good.csv',index=False)
