# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 1]
df = df.drop(columns=['router'])
df.to_csv('wat-r1-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r1-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             11        2       4                     1        1          4
# 2             79        0       2                     4        1          1
# 3             80        0       2                     4        2          2
# 4             81        0       2                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 71821    2021453        0       1                     4        4          2
# 71822    2021457        0       1                     4        5          3
# 71823    2021698        2       0                     5        1          1
# 71824    2021705        2       0                     5        2          2
# 71825    2021712        2       0                     5        3          2
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       1           1      23           7             1
# 1         3   9       0           0      23           7             0
# 2         5  17      18           2       1           1             1
# 3         5  17      18           2       1           1             1
# 4         5  17      18           2       1           1             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 71821     5  17      29          13       1           1         11079
# 71822     5  17      29          13       1           1         11079
# 71823     3   9       1           1      27          11         11080
# 71824     3   9       1           1      27          11         11080
# 71825     3   9       1           1      27          11         11080
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              3            0            0.00             4
# 1              4            1            0.25             8
# 2              1            1            1.00             9
# 3              1            1            1.00            10
# 4              1            1            1.00            11
# ...          ...          ...             ...           ...
# 71821          3            3            1.00            19
# 71822          3            3            1.00            23
# 71823          4            0            0.00             4
# 71824          4            0            0.00            11
# 71825          4            0            0.00            18
#
# [71826 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 71826

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           7        2       0                     1        1          4
# 1          11        2       4                     1        1          4
# 2          79        0       2                     4        1          1
# 3          80        0       2                     4        2          2
# 4          81        0       2                     4        3          2
# 5          82        0       2                     4        4          2
# 6          86        0       2                     4        5          3
# 7         100        4       2                     4        1          1
# 8         101        4       0                     1        1          4
# 9         102        4       2                     4        2          2
# 10        103        4       2                     4        3          2
# 11        104        4       2                     4        4          2
# 12        107        4       2                     4        5          3
# 13        181        0       1                     4        1          1
# 14        182        0       1                     4        2          2
# 15        183        0       1                     4        3          2
# 16        184        0       1                     4        4          2
# 17        188        0       1                     4        5          3
# 18        229        2       0                     1        1          4
# 19        258        2       4                     1        1          4
# 20        291        0       2                     4        1          1
# 21        292        0       2                     4        2          2
# 22        293        0       2                     4        3          2
# 23        294        0       2                     4        4          2
# 24        298        0       2                     4        5          3
# 25        319        4       2                     4        1          1
# 26        320        4       2                     4        2          2
# 27        321        4       2                     4        3          2
# 28        322        4       2                     4        4          2
# 29        326        4       2                     4        5          3
# 30        333        2       0                     1        1          4
# 31        369        2       4                     1        1          4
# 32        402        0       2                     4        1          1
# 33        403        0       2                     4        2          2
# 34        404        0       2                     4        3          2
# 35        406        0       2                     4        4          2
# 36        409        0       2                     4        5          3
# 37        432        1       0                     1        1          4
# 38        439        4       2                     4        1          1
# 39        440        4       2                     4        2          2
# 40        441        4       2                     4        3          2
# 41        442        4       2                     4        4          2
# 42        446        4       2                     4        5          3
# 43        477        1       4                     1        1          4
# 44        492        1       2                     3        1          4
# 45        493        0       2                     4        1          1
# 46        494        0       2                     4        2          2
# 47        495        0       2                     4        3          2
# 48        496        0       2                     4        4          2
# 49        500        0       2                     4        5          3
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       1           1  ...                 7                   7
# 1      3   9       0           0  ...                 7                  12
# 2      5  17      18           2  ...                 7                  15
# 3      5  17      18           2  ...                 7                  16
# 4      5  17      18           2  ...                 7                  15
# 5      5  17      18           2  ...                 7                  12
# 6      5  17      18           2  ...                 7                   7
# 7      5  17      18           2  ...                11                  11
# 8      3  10       1           1  ...                11                  20
# 9      5  17      18           2  ...                11                  27
# 10     5  17      18           2  ...                11                  32
# 11     5  17      18           2  ...                11                  35
# 12     5  17      18           2  ...                11                  36
# 13     5  17      29          13  ...                11                  35
# 14     5  17      29          13  ...                11                  32
# 15     5  17      29          13  ...                11                  27
# 16     5  17      29          13  ...                11                  20
# 17     5  17      29          13  ...                11                  11
# 18     3  11       1           1  ...                 7                   7
# 19     3   9       0           0  ...                 7                  12
# 20     5  17      18           2  ...                 7                  15
# 21     5  17      18           2  ...                 7                  16
# 22     5  17      18           2  ...                 7                  15
# 23     5  17      18           2  ...                 7                  12
# 24     5  17      18           2  ...                 7                   7
# 25     5  17      18           2  ...                 7                   7
# 26     5  17      18           2  ...                 7                  12
# 27     5  17      18           2  ...                 7                  15
# 28     5  17      18           2  ...                 7                  16
# 29     5  17      18           2  ...                 7                  15
# 30     3  12       1           1  ...                 7                  12
# 31     3   9       0           0  ...                 7                   7
# 32     5  17      18           2  ...                17                  17
# 33     5  17      18           2  ...                17                  32
# 34     5  17      18           2  ...                17                  45
# 35     5  17      18           2  ...                17                  56
# 36     5  17      18           2  ...                17                  65
# 37     3   9       1           1  ...                17                  72
# 38     5  17      18           2  ...                17                  77
# 39     5  17      18           2  ...                17                  80
# 40     5  17      18           2  ...                17                  81
# 41     5  17      18           2  ...                17                  80
# 42     5  17      18           2  ...                17                  77
# 43     3   9       0           0  ...                17                  72
# 44     3   9      18           2  ...                17                  65
# 45     5  17      18           2  ...                17                  56
# 46     5  17      18           2  ...                17                  45
# 47     5  17      18           2  ...                17                  32
# 48     5  17      18           2  ...                17                  17
# 49     5  17      18           2  ...                15                  15
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 49           0                           1           4
# 1                 84           8                           1           4
# 2                105           0                           4           4
# 3                112           0                           8          16
# 4                105           0                          12          24
# 5                 84           0                          16          32
# 6                 49           0                          20          60
# 7                121           8                           4           4
# 8                220           0                           1           4
# 9                297           8                           8          16
# 10               352           8                          12          24
# 11               385           8                          16          32
# 12               396           8                          20          60
# 13               385           0                           4           4
# 14               352           0                           8          16
# 15               297           0                          12          24
# 16               220           0                          16          32
# 17               121           0                          20          60
# 18                49           0                           1           4
# 19                84           8                           1           4
# 20               105           0                           4           4
# 21               112           0                           8          16
# 22               105           0                          12          24
# 23                84           0                          16          32
# 24                49           0                          20          60
# 25                49           8                           4           4
# 26                84           8                           8          16
# 27               105           8                          12          24
# 28               112           8                          16          32
# 29               105           8                          20          60
# 30                84           0                           1           4
# 31                49           8                           1           4
# 32               289           0                           4           4
# 33               544           0                           8          16
# 34               765           0                          12          24
# 35               952           0                          16          32
# 36              1105           0                          20          60
# 37              1224           0                           1           4
# 38              1309           8                           4           4
# 39              1360           8                           8          16
# 40              1377           8                          12          24
# 41              1360           8                          16          32
# 42              1309           8                          20          60
# 43              1224           4                           1           4
# 44              1105           2                           3          12
# 45               952           0                           4           4
# 46               765           0                           8          16
# 47               544           0                          12          24
# 48               289           0                          16          32
# 49               225           0                          20          60
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 4                           3             27
# 1                 0                           3             27
# 2                 4                          20             85
# 3                16                          20             85
# 4                24                          20             85
# 5                32                          20             85
# 6                60                          20             85
# 7                 0                          20             85
# 8                 8                           3             30
# 9                 0                          20             85
# 10                0                          20             85
# 11                0                          20             85
# 12                0                          20             85
# 13                8                          20             85
# 14               32                          20             85
# 15               48                          20             85
# 16               64                          20             85
# 17              120                          20             85
# 18               16                           3             33
# 19               20                           3             27
# 20               16                          20             85
# 21               64                          20             85
# 22               96                          20             85
# 23              128                          20             85
# 24              240                          20             85
# 25               20                          20             85
# 26               80                          20             85
# 27              120                          20             85
# 28              160                          20             85
# 29              300                          20             85
# 30               24                           3             36
# 31               28                           3             27
# 32               24                          20             85
# 33               96                          20             85
# 34              144                          20             85
# 35              192                          20             85
# 36              360                          20             85
# 37               32                           3             27
# 38               28                          20             85
# 39              112                          20             85
# 40              168                          20             85
# 41              224                          20             85
# 42              420                          20             85
# 43               36                           3             27
# 44               96                           9             27
# 45               32                          20             85
# 46              128                          20             85
# 47              192                          20             85
# 48              256                          20             85
# 49              480                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                  9
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                  9
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18                 9
# 19                 9
# 20               100
# 21               100
# 22               100
# 23               100
# 24               100
# 25               100
# 26               100
# 27               100
# 28               100
# 29               100
# 30                 9
# 31                 9
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37                 9
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43                 9
# 44                27
# 45               100
# 46               100
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             11        2       4                     1        1          4
# 2             79        0       2                     4        1          1
# 3             80        0       2                     4        2          2
# 4             81        0       2                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 71821    2021453        0       1                     4        4          2
# 71822    2021457        0       1                     4        5          3
# 71823    2021698        2       0                     5        1          1
# 71824    2021705        2       0                     5        2          2
# 71825    2021712        2       0                     5        3          2
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9       1           1  ...                 7
# 1         3   9       0           0  ...                 7
# 2         5  17      18           2  ...                 7
# 3         5  17      18           2  ...                 7
# 4         5  17      18           2  ...                 7
# ...     ...  ..     ...         ...  ...               ...
# 71821     5  17      29          13  ...                 1
# 71822     5  17      29          13  ...                 1
# 71823     3   9       1           1  ...                 1
# 71824     3   9       1           1  ...                 1
# 71825     3   9       1           1  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       7                49           0
# 1                      12                84           8
# 2                      15               105           0
# 3                      16               112           0
# 4                      15               105           0
# ...                   ...               ...         ...
# 71821                   1                 1           0
# 71822                   1                 1           0
# 71823                   1                 1           0
# 71824                   1                 1           0
# 71825                   1                 1           0
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               1           4                4
# 1                               1           4                0
# 2                               4           4                4
# 3                               8          16               16
# 4                              12          24               24
# ...                           ...         ...              ...
# 71821                          16          32           354528
# 71822                          20          60           664740
# 71823                           5           5            55400
# 71824                          10          20           221600
# 71825                          15          30           332400
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               3             27                 9
# 1                               3             27                 9
# 2                              20             85               100
# 3                              20             85               100
# 4                              20             85               100
# ...                           ...            ...               ...
# 71821                          20             85               100
# 71822                          20             85               100
# 71823                          15             27                45
# 71824                          15             27                45
# 71825                          15             27                45
#
# [71826 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0              7        2       0                     1        1          4
# 1             11        2       4                     1        1          4
# 2             79        0       2                     4        1          1
# 3             80        0       2                     4        2          2
# 4             81        0       2                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 71821    2021453        0       1                     4        4          2
# 71822    2021457        0       1                     4        5          3
# 71823    2021698        2       0                     5        1          1
# 71824    2021705        2       0                     5        2          2
# 71825    2021712        2       0                     5        3          2
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       1           1  ...                   7
# 1         3   9       0           0  ...                  12
# 2         5  17      18           2  ...                  15
# 3         5  17      18           2  ...                  16
# 4         5  17      18           2  ...                  15
# ...     ...  ..     ...         ...  ...                 ...
# 71821     5  17      29          13  ...                   1
# 71822     5  17      29          13  ...                   1
# 71823     3   9       1           1  ...                   1
# 71824     3   9       1           1  ...                   1
# 71825     3   9       1           1  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    49           0                           1           4
# 1                    84           8                           1           4
# 2                   105           0                           4           4
# 3                   112           0                           8          16
# 4                   105           0                          12          24
# ...                 ...         ...                         ...         ...
# 71821                 1           0                          16          32
# 71822                 1           0                          20          60
# 71823                 1           0                           5           5
# 71824                 1           0                          10          20
# 71825                 1           0                          15          30
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    0                           3             27
# 2                    4                          20             85
# 3                   16                          20             85
# 4                   24                          20             85
# ...                ...                         ...            ...
# 71821           354528                          20             85
# 71822           664740                          20             85
# 71823            55400                          15             27
# 71824           221600                          15             27
# 71825           332400                          15             27
#
#        vnet_vc_cc_index  target
# 0                     9       0
# 1                     9       0
# 2                   100       0
# 3                   100       0
# 4                   100       0
# ...                 ...     ...
# 71821               100       0
# 71822               100       0
# 71823                45       0
# 71824                45       0
# 71825                45       0
#
# [71826 rows x 30 columns]

# %%
df.to_csv('wat-r1-mal.csv',index=False)
