# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 1]
df = df.drop(columns=['router'])
df.to_csv('wat-r1-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r1-mal.csv')
df
# Out:
#           time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  \
# 0            7        2       0            0        0          3     2   8
# 1           11        2       4            0        0          3     2   8
# 2           79        0       2            3        0          0     4  16
# 3           80        0       2            3        1          1     4  16
# 4           81        0       2            3        2          1     4  16
# ...        ...      ...     ...          ...      ...        ...   ...  ..
# 71836  2022096        4       0            4        1          1     2  10
# 71837  2022103        4       0            4        2          1     2  10
# 71838  2022110        4       0            4        3          1     2  10
# 71839  2022117        4       0            4        4          2     2  10
# 71840  2022118        4       0            0        0          3     2  11
#
#        src_ni  src_router  dst_ni  dst_router  pkt_chuck  hop_count  \
# 0           1           1      23           7          1          3
# 1           0           0      23           7          0          4
# 2          18           2       1           1          1          1
# 3          18           2       1           1          1          1
# 4          18           2       1           1          1          1
# ...       ...         ...     ...         ...        ...        ...
# 71836       1           1      28          12      11082          5
# 71837       1           1      28          12      11082          5
# 71838       1           1      28          12      11082          5
# 71839       1           1      28          12      11082          5
# 71840       1           1      28          12      11083          5
#
#        current_hop  hop_percentage  waiting_time
# 0                0            0.00             4
# 1                1            0.25             8
# 2                1            1.00             9
# 3                1            1.00            10
# 4                1            1.00            11
# ...            ...             ...           ...
# 71836            0            0.00            11
# 71837            0            0.00            18
# 71838            0            0.00            25
# 71839            0            0.00            32
# 71840            0            0.00            32
#
# [71841 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["time"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 71841

# %%
df = df.assign(pkt_count=countarr)
df = df.assign(pkt_count_inc=increarr)
df = df.assign(pkt_max=maxarr)
df["counting_index_pos"] = df["pkt_count"]*df["pkt_count_inc"]
df["counting_index_100"] = df["counting_index_pos"]*df["pkt_max"]
df.head(50)
# Out:
#     time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  src_ni  \
# 0      7        2       0            0        0          3     2   8       1
# 1     11        2       4            0        0          3     2   8       0
# 2     79        0       2            3        0          0     4  16      18
# 3     80        0       2            3        1          1     4  16      18
# 4     81        0       2            3        2          1     4  16      18
# 5     82        0       2            3        3          1     4  16      18
# 6     86        0       2            3        4          2     4  16      18
# 7    100        4       2            3        0          0     4  16      18
# 8    101        4       0            0        0          3     2   9       1
# 9    102        4       2            3        1          1     4  16      18
# 10   103        4       2            3        2          1     4  16      18
# 11   104        4       2            3        3          1     4  16      18
# 12   107        4       2            3        4          2     4  16      18
# 13   181        0       1            3        0          0     4  16      29
# 14   182        0       1            3        1          1     4  16      29
# 15   183        0       1            3        2          1     4  16      29
# 16   184        0       1            3        3          1     4  16      29
# 17   188        0       1            3        4          2     4  16      29
# 18   229        2       0            0        0          3     2  10       1
# 19   258        2       4            0        0          3     2   8       0
# 20   291        0       2            3        0          0     4  16      18
# 21   292        0       2            3        1          1     4  16      18
# 22   293        0       2            3        2          1     4  16      18
# 23   294        0       2            3        3          1     4  16      18
# 24   298        0       2            3        4          2     4  16      18
# 25   319        4       2            3        0          0     4  16      18
# 26   320        4       2            3        1          1     4  16      18
# 27   321        4       2            3        2          1     4  16      18
# 28   322        4       2            3        3          1     4  16      18
# 29   326        4       2            3        4          2     4  16      18
# 30   333        2       0            0        0          3     2  11       1
# 31   369        2       4            0        0          3     2   8       0
# 32   402        0       2            3        0          0     4  16      18
# 33   403        0       2            3        1          1     4  16      18
# 34   404        0       2            3        2          1     4  16      18
# 35   406        0       2            3        3          1     4  16      18
# 36   409        0       2            3        4          2     4  16      18
# 37   432        1       0            0        0          3     2   8       1
# 38   439        4       2            3        0          0     4  16      18
# 39   440        4       2            3        1          1     4  16      18
# 40   441        4       2            3        2          1     4  16      18
# 41   442        4       2            3        3          1     4  16      18
# 42   446        4       2            3        4          2     4  16      18
# 43   477        1       4            0        0          3     2   8       0
# 44   492        1       2            2        0          3     2   8      18
# 45   493        0       2            3        0          0     4  16      18
# 46   494        0       2            3        1          1     4  16      18
# 47   495        0       2            3        2          1     4  16      18
# 48   496        0       2            3        3          1     4  16      18
# 49   500        0       2            3        4          2     4  16      18
#
#     src_router  ...  pkt_chuck  hop_count  current_hop  hop_percentage  \
# 0            1  ...          1          3            0        0.000000
# 1            0  ...          0          4            1        0.250000
# 2            2  ...          1          1            1        1.000000
# 3            2  ...          1          1            1        1.000000
# 4            2  ...          1          1            1        1.000000
# 5            2  ...          1          1            1        1.000000
# 6            2  ...          1          1            1        1.000000
# 7            2  ...          0          2            1        0.500000
# 8            1  ...          2          3            0        0.000000
# 9            2  ...          0          2            1        0.500000
# 10           2  ...          0          2            1        0.500000
# 11           2  ...          0          2            1        0.500000
# 12           2  ...          0          2            1        0.500000
# 13          13  ...          2          3            3        1.000000
# 14          13  ...          2          3            3        1.000000
# 15          13  ...          2          3            3        1.000000
# 16          13  ...          2          3            3        1.000000
# 17          13  ...          2          3            3        1.000000
# 18           1  ...          4          2            0        0.000000
# 19           0  ...          5          3            1        0.333333
# 20           2  ...          4          1            1        1.000000
# 21           2  ...          4          1            1        1.000000
# 22           2  ...          4          1            1        1.000000
# 23           2  ...          4          1            1        1.000000
# 24           2  ...          4          1            1        1.000000
# 25           2  ...          5          2            1        0.500000
# 26           2  ...          5          2            1        0.500000
# 27           2  ...          5          2            1        0.500000
# 28           2  ...          5          2            1        0.500000
# 29           2  ...          5          2            1        0.500000
# 30           1  ...          6          3            0        0.000000
# 31           0  ...          7          4            1        0.250000
# 32           2  ...          6          1            1        1.000000
# 33           2  ...          6          1            1        1.000000
# 34           2  ...          6          1            1        1.000000
# 35           2  ...          6          1            1        1.000000
# 36           2  ...          6          1            1        1.000000
# 37           1  ...          8          1            0        0.000000
# 38           2  ...          7          2            1        0.500000
# 39           2  ...          7          2            1        0.500000
# 40           2  ...          7          2            1        0.500000
# 41           2  ...          7          2            1        0.500000
# 42           2  ...          7          2            1        0.500000
# 43           0  ...          9          2            1        0.500000
# 44           2  ...          8          2            1        0.500000
# 45           2  ...          8          1            1        1.000000
# 46           2  ...          8          1            1        1.000000
# 47           2  ...          8          1            1        1.000000
# 48           2  ...          8          1            1        1.000000
# 49           2  ...          8          1            1        1.000000
#
#     waiting_time  pkt_count  pkt_count_inc  pkt_max  counting_index_pos  \
# 0              4          7              1        7                   7
# 1              8          6              2        7                  12
# 2              9          5              3        7                  15
# 3             10          4              4        7                  16
# 4             11          3              5        7                  15
# 5             12          2              6        7                  12
# 6             16          1              7        7                   7
# 7              8         11              1       11                  11
# 8              4         10              2       11                  20
# 9             10          9              3       11                  27
# 10            11          8              4       11                  32
# 11            12          7              5       11                  35
# 12            15          6              6       11                  36
# 13            17          5              7       11                  35
# 14            18          4              8       11                  32
# 15            19          3              9       11                  27
# 16            20          2             10       11                  20
# 17            24          1             11       11                  11
# 18             4          7              1        7                   7
# 19             8          6              2        7                  12
# 20             9          5              3        7                  15
# 21            10          4              4        7                  16
# 22            11          3              5        7                  15
# 23            12          2              6        7                  12
# 24            16          1              7        7                   7
# 25             9          7              1        7                   7
# 26            10          6              2        7                  12
# 27            11          5              3        7                  15
# 28            12          4              4        7                  16
# 29            16          3              5        7                  15
# 30             4          2              6        7                  12
# 31             8          1              7        7                   7
# 32             8         17              1       17                  17
# 33             9         16              2       17                  32
# 34            10         15              3       17                  45
# 35            12         14              4       17                  56
# 36            15         13              5       17                  65
# 37             4         12              6       17                  72
# 38             9         11              7       17                  77
# 39            10         10              8       17                  80
# 40            11          9              9       17                  81
# 41            12          8             10       17                  80
# 42            16          7             11       17                  77
# 43             8          6             12       17                  72
# 44             8          5             13       17                  65
# 45             9          4             14       17                  56
# 46            10          3             15       17                  45
# 47            11          2             16       17                  32
# 48            12          1             17       17                  17
# 49            16         15              1       15                  15
#
#     counting_index_100
# 0                   49
# 1                   84
# 2                  105
# 3                  112
# 4                  105
# 5                   84
# 6                   49
# 7                  121
# 8                  220
# 9                  297
# 10                 352
# 11                 385
# 12                 396
# 13                 385
# 14                 352
# 15                 297
# 16                 220
# 17                 121
# 18                  49
# 19                  84
# 20                 105
# 21                 112
# 22                 105
# 23                  84
# 24                  49
# 25                  49
# 26                  84
# 27                 105
# 28                 112
# 29                 105
# 30                  84
# 31                  49
# 32                 289
# 33                 544
# 34                 765
# 35                 952
# 36                1105
# 37                1224
# 38                1309
# 39                1360
# 40                1377
# 41                1360
# 42                1309
# 43                1224
# 44                1105
# 45                 952
# 46                 765
# 47                 544
# 48                 289
# 49                 225
#
# [50 rows x 22 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# time                    int64
# outport                 int64
# inport                  int64
# packet_type             int64
# flit_id                 int64
# flit_type               int64
# vnet                    int64
# vc                      int64
# src_ni                  int64
# src_router              int64
# dst_ni                  int64
# dst_router              int64
# pkt_chuck               int64
# hop_count               int64
# current_hop             int64
# hop_percentage        float64
# waiting_time            int64
# pkt_count               int64
# pkt_count_inc           int64
# pkt_max                 int64
# counting_index_pos      int64
# counting_index_100      int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#           time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  \
# 0            7        2       0            0        0          3     2   8
# 1           11        2       4            0        0          3     2   8
# 2           79        0       2            3        0          0     4  16
# 3           80        0       2            3        1          1     4  16
# 4           81        0       2            3        2          1     4  16
# ...        ...      ...     ...          ...      ...        ...   ...  ..
# 71836  2022096        4       0            4        1          1     2  10
# 71837  2022103        4       0            4        2          1     2  10
# 71838  2022110        4       0            4        3          1     2  10
# 71839  2022117        4       0            4        4          2     2  10
# 71840  2022118        4       0            0        0          3     2  11
#
#        src_ni  src_router  ...  pkt_chuck  hop_count  current_hop  \
# 0           1           1  ...          1          3            0
# 1           0           0  ...          0          4            1
# 2          18           2  ...          1          1            1
# 3          18           2  ...          1          1            1
# 4          18           2  ...          1          1            1
# ...       ...         ...  ...        ...        ...          ...
# 71836       1           1  ...      11082          5            0
# 71837       1           1  ...      11082          5            0
# 71838       1           1  ...      11082          5            0
# 71839       1           1  ...      11082          5            0
# 71840       1           1  ...      11083          5            0
#
#        hop_percentage  waiting_time  pkt_count  pkt_count_inc  pkt_max  \
# 0                0.00             4          7              1        7
# 1                0.25             8          6              2        7
# 2                1.00             9          5              3        7
# 3                1.00            10          4              4        7
# 4                1.00            11          3              5        7
# ...               ...           ...        ...            ...      ...
# 71836            0.00            11          1              1        1
# 71837            0.00            18          1              1        1
# 71838            0.00            25          1              1        1
# 71839            0.00            32          1              1        1
# 71840            0.00            32          1              1        1
#
#        counting_index_pos  counting_index_100
# 0                       7                  49
# 1                      12                  84
# 2                      15                 105
# 3                      16                 112
# 4                      15                 105
# ...                   ...                 ...
# 71836                   1                   1
# 71837                   1                   1
# 71838                   1                   1
# 71839                   1                   1
# 71840                   1                   1
#
# [71841 rows x 22 columns]

# %%
df['target'] = 0
df
# Out:
#           time  outport  inport  packet_type  flit_id  flit_type  vnet  vc  \
# 0            7        2       0            0        0          3     2   8
# 1           11        2       4            0        0          3     2   8
# 2           79        0       2            3        0          0     4  16
# 3           80        0       2            3        1          1     4  16
# 4           81        0       2            3        2          1     4  16
# ...        ...      ...     ...          ...      ...        ...   ...  ..
# 71836  2022096        4       0            4        1          1     2  10
# 71837  2022103        4       0            4        2          1     2  10
# 71838  2022110        4       0            4        3          1     2  10
# 71839  2022117        4       0            4        4          2     2  10
# 71840  2022118        4       0            0        0          3     2  11
#
#        src_ni  src_router  ...  hop_count  current_hop  hop_percentage  \
# 0           1           1  ...          3            0            0.00
# 1           0           0  ...          4            1            0.25
# 2          18           2  ...          1            1            1.00
# 3          18           2  ...          1            1            1.00
# 4          18           2  ...          1            1            1.00
# ...       ...         ...  ...        ...          ...             ...
# 71836       1           1  ...          5            0            0.00
# 71837       1           1  ...          5            0            0.00
# 71838       1           1  ...          5            0            0.00
# 71839       1           1  ...          5            0            0.00
# 71840       1           1  ...          5            0            0.00
#
#        waiting_time  pkt_count  pkt_count_inc  pkt_max  counting_index_pos  \
# 0                 4          7              1        7                   7
# 1                 8          6              2        7                  12
# 2                 9          5              3        7                  15
# 3                10          4              4        7                  16
# 4                11          3              5        7                  15
# ...             ...        ...            ...      ...                 ...
# 71836            11          1              1        1                   1
# 71837            18          1              1        1                   1
# 71838            25          1              1        1                   1
# 71839            32          1              1        1                   1
# 71840            32          1              1        1                   1
#
#        counting_index_100  target
# 0                      49       0
# 1                      84       0
# 2                     105       0
# 3                     112       0
# 4                     105       0
# ...                   ...     ...
# 71836                   1       0
# 71837                   1       0
# 71838                   1       0
# 71839                   1       0
# 71840                   1       0
#
# [71841 rows x 23 columns]

# %%
df.to_csv('wat-r1-mal.csv',index=False)
