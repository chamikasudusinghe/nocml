# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 10]
df = df.drop(columns=['router'])
df.to_csv('wat-r10-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r10-mal.csv')
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           764        1       3                     1        1          4
# 1           836        1       3                     1        1          4
# 2           872        4       2                     2        1          4
# 3           950        4       2                     2        1          4
# 4          1277        0       3                     1        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8780    2021386        4       0                     6        4          2
# 8781    2021393        4       0                     6        5          3
# 8782    2021394        4       0                     2        1          4
# 8783    2021395        4       0                     7        1          4
# 8784    2021450        0       1                     3        1          4
#
#       vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0        3   9       1           1      30          14            16
# 1        3   9       0           0      30          14            17
# 2        3   9      27          11      29          13            18
# 3        3   9      27          11      29          13            19
# 4        3   9       1           1      26          10            26
# ...    ...  ..     ...         ...     ...         ...           ...
# 8780     3  12      26          10      29          13         11078
# 8781     3  12      26          10      29          13         11078
# 8782     3   9      26          10      29          13         11079
# 8783     3  10      26          10       1           1         11078
# 8784     3   9      29          13      26          10         11079
#
#       hop_count  current_hop  hop_percentage  enqueue_time
# 0             4            3        0.750000            16
# 1             5            4        0.800000            20
# 2             3            1        0.333333             8
# 3             3            1        0.333333             8
# 4             3            3        1.000000            16
# ...         ...          ...             ...           ...
# 8780          2            0        0.000000            25
# 8781          2            0        0.000000            32
# 8782          2            0        0.000000            32
# 8783          3            0        0.000000             5
# 8784          2            2        1.000000            16
#
# [8785 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 8785

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 
# 30     3   9       1           1  ...                 1                   1
# 31     3  11      26          10  ...                 1                   1
# 32     3   9      29          13  ...                 1                   1
# 33     3   9      27          11  ...                 1                   1
# 34     3   9       1           1  ...                 1                   1
# 35     3  12      26          10  ...                 1                   1
# 36     3   9      29          13  ...                 1                   1
# 37     3   9       0           0  ...                 1                   1
# 38     3   9      26          10  ...                 1                   1
# 39     3   9      29          13  ...                 1                   1
# 40     3   9      27          11  ...                 1                   1
# 41     3   9       0           0  ...                 1                   1
# 42     3  10      26          10  ...                 1                   1
# 43     3   9      29          13  ...                 1                   1
# 44     3   9      27          11  ...                 1                   1
# 45     3   9      27          11  ...                 1                   1
# 46     3   9       1           1  ...                 1                   1
# 47     3  11      26          10  ...                 1                   1
# 48     3   9      29          13  ...                 1                   1
# 49     3   9       0           0  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                  1           3                           1           4
# 1                  1           3                           1           4
# 2                  1           8                           2           8
# 3                  1           8                           2           8
# 4                  1           0                           1           4
# 5                  1           0                           2           8
# 6                  1           0                           3          12
# 7                  1           0                           1           4
# 8                  1           0                           2           8
# 9                  1           0                           3          12
# 10                 1           3                           1           4
# 11                 1           3                           1           4
# 12                 1           8                           2           8
# 13                 1           8                           2           8
# 14                 1           0                           1           4
# 15                 1           0                           2           8
# 16                 1           0                           3          12
# 17                 1           0                           1           4
# 18                 1           0                           2           8
# 19                 1           0                           1           4
# 20                 1           0                           3          12
# 21                 1           0                           2           8
# 22                 1           0                           3          12
# 23                 1           0                           1           4
# 24                 1           0                           2           8
# 25                 1           0                           3          12
# 26                 1           8                           2           8
# 27                 1           8                           2           8
# 28                 1           3                           1           4
# 29                 1           3                           1           4
# 30                 1           0                           1           4
# 31                 1           0                           2           8
# 32                 1           0                           3          12
# 33                 1           8                           2           8
# 34                 1           0                           1           4
# 35                 1           0                           2           8
# 36                 1           0                           3          12
# 37                 1           0                           1           4
# 38                 1           0                           2           8
# 39                 1           0                           3          12
# 40                 1           8                           2           8
# 41                 1           0                           1           4
# 42                 1           0                           2           8
# 43                 1           0                           3          12
# 44                 1           8                           2           8
# 45                 1           8                           2           8
# 46                 1           0                           1           4
# 47                 1           0                           2           8
# 48                 1           0                           3          12
# 49                 1           0                           1           4
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                64                           3             27
# 1                68                           3             27
# 2               144                           6             27
# 3               152                           6             27
# 4               104                           3             27
# 5               208                           6             27
# 6               312                           9             27
# 7               108                           3             27
# 8               216                           6             30
# 9               324                           9             27
# 10              124                           3             27
# 11              136                           3             27
# 12              344                           6             27
# 13              368                           6             27
# 14              188                           3             27
# 15              376                           6             33
# 16              564                           9             27
# 17              196                           3             27
# 18              392                           6             36
# 19              200                           3             27
# 20              588                           9             27
# 21              400                           6             27
# 22              600                           9             27
# 23              208                           3             27
# 24              416                           6             30
# 25              624                           9             27
# 26              424                           6             27
# 27              440                           6             27
# 28              332                           3             27
# 29              348                           3             27
# 30              384                           3             27
# 31              768                           6             33
# 32             1152                           9             27
# 33              784                           6             27
# 34              400                           3             27
# 35              800                           6             36
# 36             1200                           9             27
# 37              404                           3             27
# 38              808                           6             27
# 39             1212                           9             27
# 40              832                           6             27
# 41              424                           3             27
# 42              848                           6             30
# 43             1272                           9             27
# 44              856                           6             27
# 45              904                           6             27
# 46              524                           3             27
# 47             1048                           6             33
# 48             1572                           9             27
# 49              556                           3             27
#
#     vnet_vc_cc_index
# 0                  9
# 1                  9
# 2                 18
# 3                 18
# 4                  9
# 5                 18
# 6                 27
# 7                  9
# 8                 18
# 9                 27
# 10                 9
# 11                 9
# 12                18
# 13                18
# 14                 9
# 15                18
# 16                27
# 17                 9
# 18                18
# 19                 9
# 20                27
# 21                18
# 22                27
# 23                 9
# 24                18
# 25                27
# 26                18
# 27                18
# 28                 9
# 29                 9
# 30                 9
# 31                18
# 32                27
# 33                18
# 34                 9
# 35                18
# 36                27
# 37                 9
# 38                18
# 39                27
# 40                18
# 41                 9
# 42                18
# 43                27
# 44                18
# 45                18
# 46                 9
# 47                18
# 48                27
# 49                 9
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           764        1       3                     1        1          4
# 1           836        1       3                     1        1          4
# 2           872        4       2                     2        1          4
# 3           950        4       2                     2        1          4
# 4          1277        0       3                     1        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8780    2021386        4       0                     6        4          2
# 8781    2021393        4       0                     6        5          3
# 8782    2021394        4       0                     2        1          4
# 8783    2021395        4       0                     7        1          4
# 8784    2021450        0       1                     3        1          4
#
#       vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0        3   9       1           1  ...                 1                   1
# 1        3   9       0           0  ...                 1                   1
# 2        3   9      27          11  ...                 1                   1
# 3        3   9      27          11  ...                 1                   1
# 4        3   9       1           1  ...                 1                   1
# ...    ...  ..     ...         ...  ...               ...                 ...
# 8780     3  12      26          10  ...                 1                   1
# 8781     3  12      26          10  ...                 1                   1
# 8782     3   9      26          10  ...                 1                   1
# 8783     3  10      26          10  ...                 1                   1
# 8784     3   9      29          13  ...                 1                   1
#
#       packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    1           3                           1           4
# 1                    1           3                           1           4
# 2                    1           8                           2           8
# 3                    1           8                           2           8
# 4                    1           0                           1           4
# ...                ...         ...                         ...         ...
# 8780                 1           0                          24          48
# 8781                 1           0                          30          90
# 8782                 1           0                           2           8
# 8783                 1           0                           7          28
# 8784                 1           0                           3          12
#
#       traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                  64                           3             27
# 1                  68                           3             27
# 2                 144                           6             27
# 3                 152                           6             27
# 4                 104                           3             27
# ...               ...                         ...            ...
# 8780           531744                          18             36
# 8781           997020                          18             36
# 8782            88632                           6             27
# 8783           310184                          21             30
# 8784           132948                           9             27
#
#       vnet_vc_cc_index
# 0                    9
# 1                    9
# 2                   18
# 3                   18
# 4                    9
# ...                ...
# 8780                54
# 8781                54
# 8782                18
# 8783                63
# 8784                27
#
# [8785 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#       timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0           764        1       3                     1        1          4
# 1           836        1       3                     1        1          4
# 2           872        4       2                     2        1          4
# 3           950        4       2                     2        1          4
# 4          1277        0       3                     1        1          4
# ...         ...      ...     ...                   ...      ...        ...
# 8780    2021386        4       0                     6        4          2
# 8781    2021393        4       0                     6        5          3
# 8782    2021394        4       0                     2        1          4
# 8783    2021395        4       0                     7        1          4
# 8784    2021450        0       1                     3        1          4
#
#       vnet  vc  src_ni  src_router  ...  packet_count_index  packet_max_index  \
# 0        3   9       1           1  ...                   1                 1
# 1        3   9       0           0  ...                   1                 1
# 2        3   9      27          11  ...                   1                 1
# 3        3   9      27          11  ...                   1                 1
# 4        3   9       1           1  ...                   1                 1
# ...    ...  ..     ...         ...  ...                 ...               ...
# 8780     3  12      26          10  ...                   1                 1
# 8781     3  12      26          10  ...                   1                 1
# 8782     3   9      26          10  ...                   1                 1
# 8783     3  10      26          10  ...                   1                 1
# 8784     3   9      29          13  ...                   1                 1
#
#       port_index  cache_coherence_flit_index  flit_index  traversal_index  \
# 0              3                           1           4               64
# 1              3                           1           4               68
# 2              8                           2           8              144
# 3              8                           2           8              152
# 4              0                           1           4              104
# ...          ...                         ...         ...              ...
# 8780           0                          24          48           531744
# 8781           0                          30          90           997020
# 8782           0                           2           8            88632
# 8783           0                           7          28           310184
# 8784           0                           3          12           132948
#
#       cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index  target
# 0                              3             27                 9       0
# 1                              3             27                 9       0
# 2                              6             27                18       0
# 3                              6             27                18       0
# 4                              3             27                 9       0
# ...                          ...            ...               ...     ...
# 8780                          18             36                54       0
# 8781                          18             36                54       0
# 8782                           6             27                18       0
# 8783                          21             30                63       0
# 8784                           9             27                27       0
#
# [8785 rows x 30 columns]

# %%
df.to_csv('wat-r10-mal.csv',index=False)
