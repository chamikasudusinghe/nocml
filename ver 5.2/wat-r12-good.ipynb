# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 12]
df = df.drop(columns=['router'])
df.to_csv('wat-r12-good.csv',index=False)

# %%
df = pd.read_csv('wat-r12-good.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            176        3       2                     3        1          4
# 1            177        3       2                     4        1          1
# 2            178        3       2                     4        2          2
# 3            179        3       2                     4        3          2
# 4            180        3       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 17469    3250544        3       2                     4        1          1
# 17470    3250545        3       2                     4        2          2
# 17471    3250546        3       2                     4        3          2
# 17472    3250547        3       2                     4        4          2
# 17473    3250551        3       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      29          13      24           8             1
# 1         5  17      29          13       0           0             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 17469     5  17      30          14       0           0         10017
# 17470     5  17      30          14       0           0         10017
# 17471     5  17      30          14       0           0         10017
# 17472     5  17      30          14       0           0         10017
# 17473     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            1            0.50             8
# 1              4            1            0.25             9
# 2              4            1            0.25            10
# 3              4            1            0.25            11
# 4              4            1            0.25            12
# ...          ...          ...             ...           ...
# 17469          5            2            0.40            12
# 17470          5            2            0.40            13
# 17471          5            2            0.40            14
# 17472          5            2            0.40            15
# 17473          5            2            0.40            19
#
# [17474 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 17474

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            176        3       2                     3        1          4
# 1            177        3       2                     4        1          1
# 2            178        3       2                     4        2          2
# 3            179        3       2                     4        3          2
# 4            180        3       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 17469    3250544        3       2                     4        1          1
# 17470    3250545        3       2                     4        2          2
# 17471    3250546        3       2                     4        3          2
# 17472    3250547        3       2                     4        4          2
# 17473    3250551        3       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      29          13      24           8             1
# 1         5  17      29          13       0           0             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 17469     5  17      30          14       0           0         10017
# 17470     5  17      30          14       0           0         10017
# 17471     5  17      30          14       0           0         10017
# 17472     5  17      30          14       0           0         10017
# 17473     5  17      30          14       0           0         10017
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            1            0.50             8
# 1              4            1            0.25             9
# 2              4            1            0.25            10
# 3              4            1            0.25            11
# 4              4            1            0.25            12
# ...          ...          ...             ...           ...
# 17469          5            2            0.40            12
# 17470          5            2            0.40            13
# 17471          5            2            0.40            14
# 17472          5            2            0.40            15
# 17473          5            2            0.40            19
#
# [17474 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         176        3       2                     3        1          4
# 1         177        3       2                     4        1          1
# 2         178        3       2                     4        2          2
# 3         179        3       2                     4        3          2
# 4         180        3       2                     4        4          2
# 5         184        3       2                     4        5          3
# 6         870        3       2                     4        1          1
# 7         871        3       2                     4        2          2
# 8         872        3       2                     4        3          2
# 9         873        3       2                     4        4          2
# 10        877        3       2                     4        5          3
# 11        984        3       2                     4        1          1
# 12        985        3       2                     4        2          2
# 13        986        3       2                     4        3          2
# 14        988        3       2                     4        4          2
# 15        991        3       2                     4        5          3
# 16       1087        3       2                     4        1          1
# 17       1088        3       2                     4        2          2
# 18       1089        3       2                     4        3          2
# 19       1090        3       2                     4        4          2
# 20       1094        3       2                     4        5          3
# 21       1229        0       3                     1        1          4
# 22       1237        2       0                     2        1          4
# 23       1290        3       2                     4        1          1
# 24       1291        3       2                     4        2          2
# 25       1292        3       2                     4        3          2
# 26       1293        3       2                     4        4          2
# 27       1294        0       2                     3        1          4
# 28       1297        3       2                     4        5          3
# 29       1415        3       2                     4        1          1
# 30       1416        3       2                     4        2          2
# 31       1417        3       2                     4        3          2
# 32       1418        3       2                     4        4          2
# 33       1422        3       2                     4        5          3
# 34       1523        3       2                     4        1          1
# 35       1524        3       2                     4        2          2
# 36       1525        3       2                     4        3          2
# 37       1526        3       2                     4        4          2
# 38       1530        3       2                     4        5          3
# 39       1734        3       2                     4        1          1
# 40       1735        3       2                     4        2          2
# 41       1736        3       2                     4        3          2
# 42       1737        3       2                     4        4          2
# 43       1741        3       2                     4        5          3
# 44       2307        3       2                     4        1          1
# 45       2308        3       2                     4        2          2
# 46       2309        3       2                     4        3          2
# 47       2310        3       2                     4        4          2
# 48       2314        3       2                     4        5          3
# 49       2510        3       2                     4        1          1
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9      29          13  ...                 6                   6
# 1      5  17      29          13  ...                 6                  10
# 2      5  17      29          13  ...                 6                  12
# 3      5  17      29          13  ...                 6                  12
# 4      5  17      29          13  ...                 6                  10
# 5      5  17      29          13  ...                 6                   6
# 6      5  17      30          14  ...                 1                   1
# 7      5  17      30          14  ...                 1                   1
# 8      5  17      30          14  ...                 1                   1
# 9      5  17      30          14  ...                 1                   1
# 10     5  17      30          14  ...                 1                   1
# 11     5  17      29          13  ...                 1                   1
# 12     5  17      29          13  ...                 1                   1
# 13     5  17      29          13  ...                 3                   3
# 14     5  17      29          13  ...                 3                   4
# 15     5  17      29          13  ...                 3                   3
# 16     5  17      29          13  ...                 5                   5
# 17     5  17      29          13  ...                 5                   8
# 18     5  17      29          13  ...                 5                   9
# 19     5  17      29          13  ...                 5                   8
# 20     5  17      29          13  ...                 5                   5
# 21     3   9       0           0  ...                 1                   1
# 22     3   9      28          12  ...                 7                   7
# 23     5  17      30          14  ...                 7                  12
# 24     5  17      30          14  ...                 7                  15
# 25     5  17      30          14  ...                 7                  16
# 26     5  17      30          14  ...                 7                  15
# 27     3   9      30          14  ...                 7                  12
# 28     5  17      30          14  ...                 7                   7
# 29     5  17      29          13  ...                 1                   1
# 30     5  17      29          13  ...                 4                   4
# 31     5  17      29          13  ...                 4                   6
# 32     5  17      29          13  ...                 4                   6
# 33     5  17      29          13  ...                 4                   4
# 34     5  17      30          14  ...                 5                   5
# 35     5  17      30          14  ...                 5                   8
# 36     5  17      30          14  ...                 5                   9
# 37     5  17      30          14  ...                 5                   8
# 38     5  17      30          14  ...                 5                   5
# 39     5  17      30          14  ...                 1                   1
# 40     5  17      30          14  ...                 4                   4
# 41     5  17      30          14  ...                 4                   6
# 42     5  17      30          14  ...                 4                   6
# 43     5  17      30          14  ...                 4                   4
# 44     5  17      29          13  ...                 1                   1
# 45     5  17      29          13  ...                 1                   1
# 46     5  17      29          13  ...                 1                   1
# 47     5  17      29          13  ...                 1                   1
# 48     5  17      29          13  ...                 1                   1
# 49     5  17      29          13  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 36           6                           3          12
# 1                 60           6                           4           4
# 2                 72           6                           8          16
# 3                 72           6                          12          24
# 4                 60           6                          16          32
# 5                 36           6                          20          60
# 6                  1           6                           4           4
# 7                  1           6                           8          16
# 8                  1           6                          12          24
# 9                  1           6                          16          32
# 10                 1           6                          20          60
# 11                 1           6                           4           4
# 12                 1           6                           8          16
# 13                 9           6                          12          24
# 14                12           6                          16          32
# 15                 9           6                          20          60
# 16                25           6                           4           4
# 17                40           6                           8          16
# 18                45           6                          12          24
# 19                40           6                          16          32
# 20                25           6                          20          60
# 21                 1           0                           1           4
# 22                49           0                           2           8
# 23                84           6                           4           4
# 24               105           6                           8          16
# 25               112           6                          12          24
# 26               105           6                          16          32
# 27                84           0                           3          12
# 28                49           6                          20          60
# 29                 1           6                           4           4
# 30                16           6                           8          16
# 31                24           6                          12          24
# 32                24           6                          16          32
# 33                16           6                          20          60
# 34                25           6                           4           4
# 35                40           6                           8          16
# 36                45           6                          12          24
# 37                40           6                          16          32
# 38                25           6                          20          60
# 39                 1           6                           4           4
# 40                16           6                           8          16
# 41                24           6                          12          24
# 42                24           6                          16          32
# 43                16           6                          20          60
# 44                 1           6                           4           4
# 45                 1           6                           8          16
# 46                 1           6                          12          24
# 47                 1           6                          16          32
# 48                 1           6                          20          60
# 49                 1           6                           4           4
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                12                           9             27
# 1                 4                          20             85
# 2                16                          20             85
# 3                24                          20             85
# 4                32                          20             85
# 5                60                          20             85
# 6                32                          20             85
# 7               128                          20             85
# 8               192                          20             85
# 9               256                          20             85
# 10              480                          20             85
# 11               36                          20             85
# 12              144                          20             85
# 13              216                          20             85
# 14              288                          20             85
# 15              540                          20             85
# 16               40                          20             85
# 17              160                          20             85
# 18              240                          20             85
# 19              320                          20             85
# 20              600                          20             85
# 21               48                           3             27
# 22               96                           6             27
# 23               48                          20             85
# 24              192                          20             85
# 25              288                          20             85
# 26              384                          20             85
# 27              144                           9             27
# 28              720                          20             85
# 29               52                          20             85
# 30              208                          20             85
# 31              312                          20             85
# 32              416                          20             85
# 33              780                          20             85
# 34               56                          20             85
# 35              224                          20             85
# 36              336                          20             85
# 37              448                          20             85
# 38              840                          20             85
# 39               64                          20             85
# 40              256                          20             85
# 41              384                          20             85
# 42              512                          20             85
# 43              960                          20             85
# 44               88                          20             85
# 45              352                          20             85
# 46              528                          20             85
# 47              704                          20             85
# 48             1320                          20             85
# 49               96                          20             85
#
#     vnet_vc_cc_index
# 0                 27
# 1                100
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19               100
# 20               100
# 21                 9
# 22                18
# 23               100
# 24               100
# 25               100
# 26               100
# 27                27
# 28               100
# 29               100
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            176        3       2                     3        1          4
# 1            177        3       2                     4        1          1
# 2            178        3       2                     4        2          2
# 3            179        3       2                     4        3          2
# 4            180        3       2                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 17469    3250544        3       2                     4        1          1
# 17470    3250545        3       2                     4        2          2
# 17471    3250546        3       2                     4        3          2
# 17472    3250547        3       2                     4        4          2
# 17473    3250551        3       2                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9      29          13  ...                   6
# 1         5  17      29          13  ...                  10
# 2         5  17      29          13  ...                  12
# 3         5  17      29          13  ...                  12
# 4         5  17      29          13  ...                  10
# ...     ...  ..     ...         ...  ...                 ...
# 17469     5  17      30          14  ...                   1
# 17470     5  17      30          14  ...                   1
# 17471     5  17      30          14  ...                   1
# 17472     5  17      30          14  ...                   1
# 17473     5  17      30          14  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    36           6                           3          12
# 1                    60           6                           4           4
# 2                    72           6                           8          16
# 3                    72           6                          12          24
# 4                    60           6                          16          32
# ...                 ...         ...                         ...         ...
# 17469                 1           6                           4           4
# 17470                 1           6                           8          16
# 17471                 1           6                          12          24
# 17472                 1           6                          16          32
# 17473                 1           6                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                   12                           9             27
# 1                    4                          20             85
# 2                   16                          20             85
# 3                   24                          20             85
# 4                   32                          20             85
# ...                ...                         ...            ...
# 17469            40068                          20             85
# 17470           160272                          20             85
# 17471           240408                          20             85
# 17472           320544                          20             85
# 17473           601020                          20             85
#
#        vnet_vc_cc_index  target
# 0                    27       1
# 1                   100       1
# 2                   100       1
# 3                   100       1
# 4                   100       1
# ...                 ...     ...
# 17469               100       1
# 17470               100       1
# 17471               100       1
# 17472               100       1
# 17473               100       1
#
# [17474 rows x 30 columns]

# %%
df.to_csv('wat-r12-good.csv',index=False)
