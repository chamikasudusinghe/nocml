# %%
import pandas as pd

# %%
df = pd.read_csv('wat-good.csv')
df = df.loc[df['router'] == 4]
df = df.drop(columns=['router'])
df.to_csv('wat-r4-good.csv',index=False)

# %%
df = pd.read_csv('wat-r4-good.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        1       3                     1        1          4
# 1            185        3       1                     4        1          1
# 2            186        3       1                     4        2          2
# 3            187        3       1                     4        3          2
# 4            188        3       1                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 22873    3250553        3       1                     4        2          2
# 22874    3250554        3       1                     4        3          2
# 22875    3250555        3       1                     4        4          2
# 22876    3250559        3       1                     4        5          3
# 22877    3250744        3       2                     7        1          4
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      24           8             1
# 1         5  17      29          13       0           0             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 22873     5  17      30          14       0           0         10017
# 22874     5  17      30          14       0           0         10017
# 22875     5  17      30          14       0           0         10017
# 22876     5  17      30          14       0           0         10017
# 22877     3   9      23           7       0           0         10018
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            1            0.50             8
# 1              4            3            0.75            17
# 2              4            3            0.75            18
# 3              4            3            0.75            19
# 4              4            3            0.75            20
# ...          ...          ...             ...           ...
# 22873          5            4            0.80            21
# 22874          5            4            0.80            22
# 22875          5            4            0.80            23
# 22876          5            4            0.80            27
# 22877          4            3            0.75            18
#
# [22878 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 22878

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        1       3                     1        1          4
# 1            185        3       1                     4        1          1
# 2            186        3       1                     4        2          2
# 3            187        3       1                     4        3          2
# 4            188        3       1                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 22873    3250553        3       1                     4        2          2
# 22874    3250554        3       1                     4        3          2
# 22875    3250555        3       1                     4        4          2
# 22876    3250559        3       1                     4        5          3
# 22877    3250744        3       2                     7        1          4
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9       0           0      24           8             1
# 1         5  17      29          13       0           0             1
# 2         5  17      29          13       0           0             1
# 3         5  17      29          13       0           0             1
# 4         5  17      29          13       0           0             1
# ...     ...  ..     ...         ...     ...         ...           ...
# 22873     5  17      30          14       0           0         10017
# 22874     5  17      30          14       0           0         10017
# 22875     5  17      30          14       0           0         10017
# 22876     5  17      30          14       0           0         10017
# 22877     3   9      23           7       0           0         10018
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            1            0.50             8
# 1              4            3            0.75            17
# 2              4            3            0.75            18
# 3              4            3            0.75            19
# 4              4            3            0.75            20
# ...          ...          ...             ...           ...
# 22873          5            4            0.80            21
# 22874          5            4            0.80            22
# 22875          5            4            0.80            23
# 22876          5            4            0.80            27
# 22877          4            3            0.75            18
#
# [22878 rows x 17 columns]

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         113        1       3                     1        1          4
# 1         185        3       1                     4        1          1
# 2         186        3       1                     4        2          2
# 3         187        3       1                     4        3          2
# 4         188        3       1                     4        4          2
# 5         192        3       1                     4        5          3
# 6         878        3       1                     4        1          1
# 7         879        3       1                     4        2          2
# 8         880        3       1                     4        3          2
# 9         881        3       1                     4        4          2
# 10        885        3       1                     4        5          3
# 11        992        3       1                     4        1          1
# 12        993        3       1                     4        2          2
# 13        994        3       1                     4        3          2
# 14        996        3       1                     4        4          2
# 15        999        3       1                     4        5          3
# 16       1095        3       1                     4        1          1
# 17       1096        3       1                     4        2          2
# 18       1097        3       1                     4        3          2
# 19       1098        3       1                     4        4          2
# 20       1102        3       1                     4        5          3
# 21       1127        0       3                     1        1          4
# 22       1135        2       0                     2        1          4
# 23       1196        0       3                     3        1          4
# 24       1221        1       3                     1        1          4
# 25       1298        3       1                     4        1          1
# 26       1299        3       1                     4        2          2
# 27       1300        3       1                     4        3          2
# 28       1301        3       1                     4        4          2
# 29       1305        3       1                     4        5          3
# 30       1423        3       1                     4        1          1
# 31       1424        3       1                     4        2          2
# 32       1425        3       1                     4        3          2
# 33       1426        3       1                     4        4          2
# 34       1430        3       1                     4        5          3
# 35       1531        3       1                     4        1          1
# 36       1532        3       1                     4        2          2
# 37       1533        3       1                     4        3          2
# 38       1534        3       1                     4        4          2
# 39       1538        3       1                     4        5          3
# 40       1742        3       1                     4        1          1
# 41       1743        3       1                     4        2          2
# 42       1744        3       1                     4        3          2
# 43       1745        3       1                     4        4          2
# 44       1749        3       1                     4        5          3
# 45       1776        0       3                     1        1          4
# 46       1784        2       0                     2        1          4
# 47       1848        0       3                     3        1          4
# 48       2315        3       1                     4        1          1
# 49       2316        3       1                     4        2          2
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      3   9       0           0  ...                 6                   6
# 1      5  17      29          13  ...                 6                  10
# 2      5  17      29          13  ...                 6                  12
# 3      5  17      29          13  ...                 6                  12
# 4      5  17      29          13  ...                 6                  10
# 5      5  17      29          13  ...                 6                   6
# 6      5  17      30          14  ...                 1                   1
# 7      5  17      30          14  ...                 1                   1
# 8      5  17      30          14  ...                 1                   1
# 9      5  17      30          14  ...                 1                   1
# 10     5  17      30          14  ...                 1                   1
# 11     5  17      29          13  ...                 1                   1
# 12     5  17      29          13  ...                 1                   1
# 13     5  17      29          13  ...                 3                   3
# 14     5  17      29          13  ...                 3                   4
# 15     5  17      29          13  ...                 3                   3
# 16     5  17      29          13  ...                 4                   4
# 17     5  17      29          13  ...                 4                   6
# 18     5  17      29          13  ...                 4                   6
# 19     5  17      29          13  ...                 4                   4
# 20     5  17      29          13  ...                 4                   4
# 21     3   9       0           0  ...                 4                   6
# 22     3   9      20           4  ...                 4                   6
# 23     3   9      18           2  ...                 4                   4
# 24     3   9       0           0  ...                 3                   3
# 25     5  17      30          14  ...                 3                   4
# 26     5  17      30          14  ...                 3                   3
# 27     5  17      30          14  ...                 3                   3
# 28     5  17      30          14  ...                 3                   4
# 29     5  17      30          14  ...                 3                   3
# 30     5  17      29          13  ...                 5                   5
# 31     5  17      29          13  ...                 5                   8
# 32     5  17      29          13  ...                 5                   9
# 33     5  17      29          13  ...                 5                   8
# 34     5  17      29          13  ...                 5                   5
# 35     5  17      30          14  ...                 5                   5
# 36     5  17      30          14  ...                 5                   8
# 37     5  17      30          14  ...                 5                   9
# 38     5  17      30          14  ...                 5                   8
# 39     5  17      30          14  ...                 5                   5
# 40     5  17      30          14  ...                 1                   1
# 41     5  17      30          14  ...                 6                   6
# 42     5  17      30          14  ...                 6                  10
# 43     5  17      30          14  ...                 6                  12
# 44     5  17      30          14  ...                 6                  12
# 45     3   9       0           0  ...                 6                  10
# 46     3  10      20           4  ...                 6                   6
# 47     3   9      18           2  ...                 1                   1
# 48     5  17      29          13  ...                 1                   1
# 49     5  17      29          13  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 36           3                           1           4
# 1                 60           3                           4           4
# 2                 72           3                           8          16
# 3                 72           3                          12          24
# 4                 60           3                          16          32
# 5                 36           3                          20          60
# 6                  1           3                           4           4
# 7                  1           3                           8          16
# 8                  1           3                          12          24
# 9                  1           3                          16          32
# 10                 1           3                          20          60
# 11                 1           3                           4           4
# 12                 1           3                           8          16
# 13                 9           3                          12          24
# 14                12           3                          16          32
# 15                 9           3                          20          60
# 16                16           3                           4           4
# 17                24           3                           8          16
# 18                24           3                          12          24
# 19                16           3                          16          32
# 20                16           3                          20          60
# 21                24           0                           1           4
# 22                24           0                           2           8
# 23                16           0                           3          12
# 24                 9           3                           1           4
# 25                12           3                           4           4
# 26                 9           3                           8          16
# 27                 9           3                          12          24
# 28                12           3                          16          32
# 29                 9           3                          20          60
# 30                25           3                           4           4
# 31                40           3                           8          16
# 32                45           3                          12          24
# 33                40           3                          16          32
# 34                25           3                          20          60
# 35                25           3                           4           4
# 36                40           3                           8          16
# 37                45           3                          12          24
# 38                40           3                          16          32
# 39                25           3                          20          60
# 40                 1           3                           4           4
# 41                36           3                           8          16
# 42                60           3                          12          24
# 43                72           3                          16          32
# 44                72           3                          20          60
# 45                60           0                           1           4
# 46                36           0                           2           8
# 47                 1           0                           3          12
# 48                 1           3                           4           4
# 49                 1           3                           8          16
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 4                           3             27
# 1                 4                          20             85
# 2                16                          20             85
# 3                24                          20             85
# 4                32                          20             85
# 5                60                          20             85
# 6                32                          20             85
# 7               128                          20             85
# 8               192                          20             85
# 9               256                          20             85
# 10              480                          20             85
# 11               36                          20             85
# 12              144                          20             85
# 13              216                          20             85
# 14              288                          20             85
# 15              540                          20             85
# 16               40                          20             85
# 17              160                          20             85
# 18              240                          20             85
# 19              320                          20             85
# 20              600                          20             85
# 21               44                           3             27
# 22               88                           6             27
# 23              132                           9             27
# 24               48                           3             27
# 25               48                          20             85
# 26              192                          20             85
# 27              288                          20             85
# 28              384                          20             85
# 29              720                          20             85
# 30               52                          20             85
# 31              208                          20             85
# 32              312                          20             85
# 33              416                          20             85
# 34              780                          20             85
# 35               56                          20             85
# 36              224                          20             85
# 37              336                          20             85
# 38              448                          20             85
# 39              840                          20             85
# 40               64                          20             85
# 41              256                          20             85
# 42              384                          20             85
# 43              512                          20             85
# 44              960                          20             85
# 45               68                           3             27
# 46              136                           6             30
# 47              204                           9             27
# 48               88                          20             85
# 49              352                          20             85
#
#     vnet_vc_cc_index
# 0                  9
# 1                100
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19               100
# 20               100
# 21                 9
# 22                18
# 23                27
# 24                 9
# 25               100
# 26               100
# 27               100
# 28               100
# 29               100
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41               100
# 42               100
# 43               100
# 44               100
# 45                 9
# 46                18
# 47                27
# 48               100
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_1'] = 0
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df['target'] = 1
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            113        1       3                     1        1          4
# 1            185        3       1                     4        1          1
# 2            186        3       1                     4        2          2
# 3            187        3       1                     4        3          2
# 4            188        3       1                     4        4          2
# ...          ...      ...     ...                   ...      ...        ...
# 22873    3250553        3       1                     4        2          2
# 22874    3250554        3       1                     4        3          2
# 22875    3250555        3       1                     4        4          2
# 22876    3250559        3       1                     4        5          3
# 22877    3250744        3       2                     7        1          4
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9       0           0  ...                   6
# 1         5  17      29          13  ...                  10
# 2         5  17      29          13  ...                  12
# 3         5  17      29          13  ...                  12
# 4         5  17      29          13  ...                  10
# ...     ...  ..     ...         ...  ...                 ...
# 22873     5  17      30          14  ...                   1
# 22874     5  17      30          14  ...                   1
# 22875     5  17      30          14  ...                   1
# 22876     5  17      30          14  ...                   1
# 22877     3   9      23           7  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    36           3                           1           4
# 1                    60           3                           4           4
# 2                    72           3                           8          16
# 3                    72           3                          12          24
# 4                    60           3                          16          32
# ...                 ...         ...                         ...         ...
# 22873                 1           3                           8          16
# 22874                 1           3                          12          24
# 22875                 1           3                          16          32
# 22876                 1           3                          20          60
# 22877                 1           6                           7          28
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    4                           3             27
# 1                    4                          20             85
# 2                   16                          20             85
# 3                   24                          20             85
# 4                   32                          20             85
# ...                ...                         ...            ...
# 22873           160272                          20             85
# 22874           240408                          20             85
# 22875           320544                          20             85
# 22876           601020                          20             85
# 22877           280504                          21             27
#
#        vnet_vc_cc_index  target
# 0                     9       1
# 1                   100       1
# 2                   100       1
# 3                   100       1
# 4                   100       1
# ...                 ...     ...
# 22873               100       1
# 22874               100       1
# 22875               100       1
# 22876               100       1
# 22877                63       1
#
# [22878 rows x 30 columns]

# %%
df.to_csv('wat-r4-good.csv',index=False)
