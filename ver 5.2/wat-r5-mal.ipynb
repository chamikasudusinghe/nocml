# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 5]
df = df.drop(columns=['router'])
df.to_csv('wat-r5-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r5-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            177        3       1                     4        1          1
# 1            178        3       1                     4        2          2
# 2            179        3       1                     4        3          2
# 3            180        3       1                     4        4          2
# 4            184        3       1                     4        5          3
# ...          ...      ...     ...                   ...      ...        ...
# 16788    2021446        3       1                     4        1          1
# 16789    2021447        3       1                     4        2          2
# 16790    2021448        3       1                     4        3          2
# 16791    2021449        3       1                     4        4          2
# 16792    2021453        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         5  17      29          13       1           1             2
# 1         5  17      29          13       1           1             2
# 2         5  17      29          13       1           1             2
# 3         5  17      29          13       1           1             2
# 4         5  17      29          13       1           1             2
# ...     ...  ..     ...         ...     ...         ...           ...
# 16788     5  17      29          13       1           1         11079
# 16789     5  17      29          13       1           1         11079
# 16790     5  17      29          13       1           1         11079
# 16791     5  17      29          13       1           1         11079
# 16792     5  17      29          13       1           1         11079
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              3            2        0.666667            13
# 1              3            2        0.666667            14
# 2              3            2        0.666667            15
# 3              3            2        0.666667            16
# 4              3            2        0.666667            20
# ...          ...          ...             ...           ...
# 16788          3            2        0.666667            12
# 16789          3            2        0.666667            13
# 16790          3            2        0.666667            14
# 16791          3            2        0.666667            15
# 16792          3            2        0.666667            19
#
# [16793 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 16793

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0         177        3       1                     4        1          1
# 1         178        3       1                     4        2          2
# 2         179        3       1                     4        3          2
# 3         180        3       1                     4        4          2
# 4         184        3       1                     4        5          3
# 5         436        0       3                     1        1          4
# 6         444        2       0                     2        1          4
# 7         481        0       3                     1        1          4
# 8         489        2       0                     2        1          4
# 9         496        0       3                     3        1          4
# 10        546        0       3                     3        1          4
# 11        818        3       1                     4        1          1
# 12        819        3       1                     4        2          2
# 13        820        3       1                     4        3          2
# 14        821        3       1                     4        4          2
# 15        825        3       1                     4        5          3
# 16        925        3       1                     4        1          1
# 17        926        3       1                     4        2          2
# 18        927        3       1                     4        3          2
# 19        928        3       1                     4        4          2
# 20        932        3       1                     4        5          3
# 21        959        1       3                     1        1          4
# 22       1020        3       1                     4        1          1
# 23       1021        3       1                     4        2          2
# 24       1022        3       1                     4        3          2
# 25       1024        3       1                     4        4          2
# 26       1027        3       1                     4        5          3
# 27       1045        1       3                     1        1          4
# 28       1068        2       4                     2        1          4
# 29       1155        2       4                     2        1          4
# 30       1221        3       1                     4        1          1
# 31       1222        3       1                     4        2          2
# 32       1223        3       1                     4        3          2
# 33       1224        3       1                     4        4          2
# 34       1228        3       1                     4        5          3
# 35       1339        3       1                     4        1          1
# 36       1340        3       1                     4        2          2
# 37       1341        3       1                     4        3          2
# 38       1342        3       1                     4        4          2
# 39       1346        3       1                     4        5          3
# 40       1369        1       3                     1        1          4
# 41       1438        3       1                     4        1          1
# 42       1439        3       1                     4        2          2
# 43       1440        3       1                     4        3          2
# 44       1441        3       1                     4        4          2
# 45       1445        3       1                     4        5          3
# 46       1470        0       3                     1        1          4
# 47       1472        1       3                     1        1          4
# 48       1478        2       0                     2        1          4
# 49       1530        0       3                     3        1          4
#
#     vnet  vc  src_ni  src_router  ...  max_packet_count  packet_count_index  \
# 0      5  17      29          13  ...                 5                   5
# 1      5  17      29          13  ...                 5                   8
# 2      5  17      29          13  ...                 5                   9
# 3      5  17      29          13  ...                 5                   8
# 4      5  17      29          13  ...                 5                   5
# 5      3   9       1           1  ...                 1                   1
# 6      3   9      21           5  ...                 1                   1
# 7      3   9       0           0  ...                 3                   3
# 8      3  10      21           5  ...                 3                   4
# 9      3   9      18           2  ...                 3                   3
# 10     3   9      18           2  ...                 1                   1
# 11     5  17      30          14  ...                 1                   1
# 12     5  17      30          14  ...                 1                   1
# 13     5  17      30          14  ...                 3                   3
# 14     5  17      30          14  ...                 3                   4
# 15     5  17      30          14  ...                 3                   3
# 16     5  17      29          13  ...                 6                   6
# 17     5  17      29          13  ...                 6                  10
# 18     5  17      29          13  ...                 6                  12
# 19     5  17      29          13  ...                 6                  12
# 20     5  17      29          13  ...                 6                  10
# 21     3   9       1           1  ...                 6                   6
# 22     5  17      29          13  ...                 7                   7
# 23     5  17      29          13  ...                 7                  12
# 24     5  17      29          13  ...                 7                  15
# 25     5  17      29          13  ...                 7                  16
# 26     5  17      29          13  ...                 7                  15
# 27     3   9       0           0  ...                 7                  12
# 28     3   9      20           4  ...                 7                   7
# 29     3   9      20           4  ...                 1                   1
# 30     5  17      30          14  ...                 5                   5
# 31     5  17      30          14  ...                 5                   8
# 32     5  17      30          14  ...                 5                   9
# 33     5  17      30          14  ...                 5                   8
# 34     5  17      30          14  ...                 5                   5
# 35     5  17      29          13  ...                 6                   6
# 36     5  17      29          13  ...                 6                  10
# 37     5  17      29          13  ...                 6                  12
# 38     5  17      29          13  ...                 6                  12
# 39     5  17      29          13  ...                 6                  10
# 40     3   9       1           1  ...                 6                   6
# 41     5  17      30          14  ...                 8                   8
# 42     5  17      30          14  ...                 8                  14
# 43     5  17      30          14  ...                 8                  18
# 44     5  17      30          14  ...                 8                  20
# 45     5  17      30          14  ...                 8                  20
# 46     3   9       1           1  ...                 8                  18
# 47     3  10       0           0  ...                 8                  14
# 48     3  11      21           5  ...                 8                   8
# 49     3   9      18           2  ...                 3                   3
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 25           3                           4           4
# 1                 40           3                           8          16
# 2                 45           3                          12          24
# 3                 40           3                          16          32
# 4                 25           3                          20          60
# 5                  1           0                           1           4
# 6                  1           0                           2           8
# 7                  9           0                           1           4
# 8                 12           0                           2           8
# 9                  9           0                           3          12
# 10                 1           0                           3          12
# 11                 1           3                           4           4
# 12                 1           3                           8          16
# 13                 9           3                          12          24
# 14                12           3                          16          32
# 15                 9           3                          20          60
# 16                36           3                           4           4
# 17                60           3                           8          16
# 18                72           3                          12          24
# 19                72           3                          16          32
# 20                60           3                          20          60
# 21                36           3                           1           4
# 22                49           3                           4           4
# 23                84           3                           8          16
# 24               105           3                          12          24
# 25               112           3                          16          32
# 26               105           3                          20          60
# 27                84           3                           1           4
# 28                49           8                           2           8
# 29                 1           8                           2           8
# 30                25           3                           4           4
# 31                40           3                           8          16
# 32                45           3                          12          24
# 33                40           3                          16          32
# 34                25           3                          20          60
# 35                36           3                           4           4
# 36                60           3                           8          16
# 37                72           3                          12          24
# 38                72           3                          16          32
# 39                60           3                          20          60
# 40                36           3                           1           4
# 41                64           3                           4           4
# 42               112           3                           8          16
# 43               144           3                          12          24
# 44               160           3                          16          32
# 45               160           3                          20          60
# 46               144           0                           1           4
# 47               112           3                           1           4
# 48                64           0                           2           8
# 49                 9           0                           3          12
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                 8                          20             85
# 1                32                          20             85
# 2                48                          20             85
# 3                64                          20             85
# 4               120                          20             85
# 5                32                           3             27
# 6                64                           6             27
# 7                36                           3             27
# 8                72                           6             30
# 9                96                           9             27
# 10              108                           9             27
# 11               64                          20             85
# 12              256                          20             85
# 13              384                          20             85
# 14              512                          20             85
# 15              960                          20             85
# 16               72                          20             85
# 17              288                          20             85
# 18              432                          20             85
# 19              576                          20             85
# 20             1080                          20             85
# 21               80                           3             27
# 22               80                          20             85
# 23              320                          20             85
# 24              480                          20             85
# 25              640                          20             85
# 26             1200                          20             85
# 27               84                           3             27
# 28              176                           6             27
# 29              184                           6             27
# 30               96                          20             85
# 31              384                          20             85
# 32              576                          20             85
# 33              768                          20             85
# 34             1440                          20             85
# 35              104                          20             85
# 36              416                          20             85
# 37              624                          20             85
# 38              832                          20             85
# 39             1560                          20             85
# 40              112                           3             27
# 41              112                          20             85
# 42              448                          20             85
# 43              672                          20             85
# 44              896                          20             85
# 45             1680                          20             85
# 46              120                           3             27
# 47              116                           3             30
# 48              240                           6             33
# 49              360                           9             27
#
#     vnet_vc_cc_index
# 0                100
# 1                100
# 2                100
# 3                100
# 4                100
# 5                  9
# 6                 18
# 7                  9
# 8                 18
# 9                 27
# 10                27
# 11               100
# 12               100
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18               100
# 19               100
# 20               100
# 21                 9
# 22               100
# 23               100
# 24               100
# 25               100
# 26               100
# 27                 9
# 28                18
# 29                18
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35               100
# 36               100
# 37               100
# 38               100
# 39               100
# 40                 9
# 41               100
# 42               100
# 43               100
# 44               100
# 45               100
# 46                 9
# 47                 9
# 48                18
# 49                27
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            177        3       1                     4        1          1
# 1            178        3       1                     4        2          2
# 2            179        3       1                     4        3          2
# 3            180        3       1                     4        4          2
# 4            184        3       1                     4        5          3
# ...          ...      ...     ...                   ...      ...        ...
# 16788    2021446        3       1                     4        1          1
# 16789    2021447        3       1                     4        2          2
# 16790    2021448        3       1                     4        3          2
# 16791    2021449        3       1                     4        4          2
# 16792    2021453        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         5  17      29          13  ...                 5
# 1         5  17      29          13  ...                 5
# 2         5  17      29          13  ...                 5
# 3         5  17      29          13  ...                 5
# 4         5  17      29          13  ...                 5
# ...     ...  ..     ...         ...  ...               ...
# 16788     5  17      29          13  ...                 1
# 16789     5  17      29          13  ...                 1
# 16790     5  17      29          13  ...                 1
# 16791     5  17      29          13  ...                 1
# 16792     5  17      29          13  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       5                25           3
# 1                       8                40           3
# 2                       9                45           3
# 3                       8                40           3
# 4                       5                25           3
# ...                   ...               ...         ...
# 16788                   1                 1           3
# 16789                   1                 1           3
# 16790                   1                 1           3
# 16791                   1                 1           3
# 16792                   1                 1           3
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               4           4                8
# 1                               8          16               32
# 2                              12          24               48
# 3                              16          32               64
# 4                              20          60              120
# ...                           ...         ...              ...
# 16788                           4           4            44316
# 16789                           8          16           177264
# 16790                          12          24           265896
# 16791                          16          32           354528
# 16792                          20          60           664740
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                              20             85               100
# 1                              20             85               100
# 2                              20             85               100
# 3                              20             85               100
# 4                              20             85               100
# ...                           ...            ...               ...
# 16788                          20             85               100
# 16789                          20             85               100
# 16790                          20             85               100
# 16791                          20             85               100
# 16792                          20             85               100
#
# [16793 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            177        3       1                     4        1          1
# 1            178        3       1                     4        2          2
# 2            179        3       1                     4        3          2
# 3            180        3       1                     4        4          2
# 4            184        3       1                     4        5          3
# ...          ...      ...     ...                   ...      ...        ...
# 16788    2021446        3       1                     4        1          1
# 16789    2021447        3       1                     4        2          2
# 16790    2021448        3       1                     4        3          2
# 16791    2021449        3       1                     4        4          2
# 16792    2021453        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         5  17      29          13  ...                   5
# 1         5  17      29          13  ...                   8
# 2         5  17      29          13  ...                   9
# 3         5  17      29          13  ...                   8
# 4         5  17      29          13  ...                   5
# ...     ...  ..     ...         ...  ...                 ...
# 16788     5  17      29          13  ...                   1
# 16789     5  17      29          13  ...                   1
# 16790     5  17      29          13  ...                   1
# 16791     5  17      29          13  ...                   1
# 16792     5  17      29          13  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    25           3                           4           4
# 1                    40           3                           8          16
# 2                    45           3                          12          24
# 3                    40           3                          16          32
# 4                    25           3                          20          60
# ...                 ...         ...                         ...         ...
# 16788                 1           3                           4           4
# 16789                 1           3                           8          16
# 16790                 1           3                          12          24
# 16791                 1           3                          16          32
# 16792                 1           3                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                    8                          20             85
# 1                   32                          20             85
# 2                   48                          20             85
# 3                   64                          20             85
# 4                  120                          20             85
# ...                ...                         ...            ...
# 16788            44316                          20             85
# 16789           177264                          20             85
# 16790           265896                          20             85
# 16791           354528                          20             85
# 16792           664740                          20             85
#
#        vnet_vc_cc_index  target
# 0                   100       0
# 1                   100       0
# 2                   100       0
# 3                   100       0
# 4                   100       0
# ...                 ...     ...
# 16788               100       0
# 16789               100       0
# 16790               100       0
# 16791               100       0
# 16792               100       0
#
# [16793 rows x 30 columns]

# %%
df.to_csv('wat-r5-mal.csv',index=False)
