# %%
import pandas as pd

# %%
df = pd.read_csv('wat-mal.csv')
df = df.loc[df['router'] == 9]
df = df.drop(columns=['router'])
df.to_csv('wat-r9-mal.csv',index=False)

# %%
df = pd.read_csv('wat-r9-mal.csv')
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            125        1       4                     2        1          4
# 1            146        1       4                     2        1          4
# 2            173        3       1                     4        1          1
# 3            174        3       1                     4        2          2
# 4            175        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 18356    2021442        3       1                     4        1          1
# 18357    2021443        3       1                     4        2          2
# 18358    2021444        3       1                     4        3          2
# 18359    2021445        3       1                     4        4          2
# 18360    2021449        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  dst_ni  dst_router  traversal_id  \
# 0         3   9      24           8      29          13             2
# 1         3   9      24           8      29          13             3
# 2         5  17      29          13       1           1             2
# 3         5  17      29          13       1           1             2
# 4         5  17      29          13       1           1             2
# ...     ...  ..     ...         ...     ...         ...           ...
# 18356     5  17      29          13       1           1         11079
# 18357     5  17      29          13       1           1         11079
# 18358     5  17      29          13       1           1         11079
# 18359     5  17      29          13       1           1         11079
# 18360     5  17      29          13       1           1         11079
#
#        hop_count  current_hop  hop_percentage  enqueue_time
# 0              2            1        0.500000             8
# 1              2            1        0.500000             8
# 2              3            1        0.333333             9
# 3              3            1        0.333333            10
# 4              3            1        0.333333            11
# ...          ...          ...             ...           ...
# 18356          3            1        0.333333             8
# 18357          3            1        0.333333             9
# 18358          3            1        0.333333            10
# 18359          3            1        0.333333            11
# 18360          3            1        0.333333            15
#
# [18361 rows x 17 columns]

# %%
timearr = []
interval = 99
count = 0
for index, row in df.iterrows():
    if row["timestamp"]<=interval:
        count+=1
    else:
        timearr.append([interval+1,count])
        count=1
        interval+=100
timearr.append([interval+1,count])

# %%
countarr = []
increarr = []
maxarr = []
for i in range(len(timearr)):
    for cnt in range(timearr[i][1],0,-1):
        countarr.append(cnt)
        maxarr.append(timearr[i][1])
        increment = timearr[i][1] - cnt + 1
        increarr.append(increment)
print(len(countarr))
# Out:
# 18361

# %%
df = df.assign(packet_count_decr=countarr)
df = df.assign(packet_count_incr=increarr)
df = df.assign(max_packet_count=maxarr)
df["packet_count_index"] = df["packet_count_decr"]*df["packet_count_incr"]
df["packet_max_index"] = df["packet_count_index"]*df["max_packet_count"]
df["port_index"] = df["outport"]*df["inport"]
df["cache_coherence_flit_index"] = df["cache_coherence_type"]*df["flit_id"]
df["flit_index"] = df["cache_coherence_flit_index"]*df["flit_type"]
df["traversal_index"] = df["flit_index"]*df["traversal_id"]
df["cache_coherence_vnet_index"] = df["cache_coherence_type"]*df["vnet"]
df["vnet_vc_index"] = df["vnet"]*df["vc"]
df["vnet_vc_cc_index"] = df["vnet"]*df["cache_coherence_vnet_index"]

df.head(50)
# Out:
#     timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 
# 30     5  17      30          14  ...                 6                   6
# 31     5  17      30          14  ...                 6                  10
# 32     5  17      30          14  ...                 6                  12
# 33     5  17      30          14  ...                 6                  12
# 34     5  17      30          14  ...                 6                  10
# 35     3   9      26          10  ...                 6                   6
# 36     5  17      29          13  ...                 7                   7
# 37     5  17      29          13  ...                 7                  12
# 38     5  17      29          13  ...                 7                  15
# 39     5  17      29          13  ...                 7                  16
# 40     5  17      29          13  ...                 7                  15
# 41     3   9       1           1  ...                 7                  12
# 42     3   9      26          10  ...                 7                   7
# 43     5  17      30          14  ...                 6                   6
# 44     5  17      30          14  ...                 6                  10
# 45     5  17      30          14  ...                 6                  12
# 46     5  17      30          14  ...                 6                  12
# 47     5  17      30          14  ...                 6                  10
# 48     3   9       0           0  ...                 6                   6
# 49     5  17      30          14  ...                 1                   1
#
#     packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                 49           4                           2           8
# 1                 84           4                           2           8
# 2                105           3                           4           4
# 3                112           3                           8          16
# 4                105           3                          12          24
# 5                 84           3                          16          32
# 6                 49           3                          20          60
# 7                  1           3                           4           4
# 8                  1           3                           8          16
# 9                  1           3                          12          24
# 10                 1           3                          16          32
# 11                 1           3                          20          60
# 12                 1           2                           2           8
# 13                 1           3                           4           4
# 14                49           3                           8          16
# 15                84           3                          12          24
# 16               105           3                          16          32
# 17               112           3                          20          60
# 18               105           2                           2           8
# 19                84           0                           1           4
# 20                49           0                           2           8
# 21                64           3                           4           4
# 22               112           3                           8          16
# 23               144           3                          12          24
# 24               160           0                           3          12
# 25               160           3                          16          32
# 26               144           3                          20          60
# 27               112           0                           1           4
# 28                64           0                           2           8
# 29                 1           0                           3          12
# 30                36           3                           4           4
# 31                60           3                           8          16
# 32                72           3                          12          24
# 33                72           3                          16          32
# 34                60           3                          20          60
# 35                36           2                           2           8
# 36                49           3                           4           4
# 37                84           3                           8          16
# 38               105           3                          12          24
# 39               112           3                          16          32
# 40               105           3                          20          60
# 41                84           3                           1           4
# 42                49           2                           2           8
# 43                36           3                           4           4
# 44                60           3                           8          16
# 45                72           3                          12          24
# 46                72           3                          16          32
# 47                60           3                          20          60
# 48                36           3                           1           4
# 49                 1           3                           4           4
#
#     traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                16                           6             27
# 1                24                           6             27
# 2                 8                          20             85
# 3                32                          20             85
# 4                48                          20             85
# 5                64                          20             85
# 6               120                          20             85
# 7                64                          20             85
# 8               256                          20             85
# 9               384                          20             85
# 10              512                          20             85
# 11              960                          20             85
# 12              144                           6             27
# 13               72                          20             85
# 14              288                          20             85
# 15              432                          20             85
# 16              576                          20             85
# 17             1080                          20             85
# 18              152                           6             27
# 19               80                           3             27
# 20              160                           6             27
# 21               80                          20             85
# 22              320                          20             85
# 23              480                          20             85
# 24              240                           9             27
# 25              640                          20             85
# 26             1200                          20             85
# 27               84                           3             27
# 28              168                           6             30
# 29              252                           9             27
# 30               96                          20             85
# 31              384                          20             85
# 32              576                          20             85
# 33              768                          20             85
# 34             1440                          20             85
# 35              208                           6             27
# 36              104                          20             85
# 37              416                          20             85
# 38              624                          20             85
# 39              832                          20             85
# 40             1560                          20             85
# 41              112                           3             27
# 42              216                           6             27
# 43              112                          20             85
# 44              448                          20             85
# 45              672                          20             85
# 46              896                          20             85
# 47             1680                          20             85
# 48              116                           3             27
# 49              124                          20             85
#
#     vnet_vc_cc_index
# 0                 18
# 1                 18
# 2                100
# 3                100
# 4                100
# 5                100
# 6                100
# 7                100
# 8                100
# 9                100
# 10               100
# 11               100
# 12                18
# 13               100
# 14               100
# 15               100
# 16               100
# 17               100
# 18                18
# 19                 9
# 20                18
# 21               100
# 22               100
# 23               100
# 24                27
# 25               100
# 26               100
# 27                 9
# 28                18
# 29                27
# 30               100
# 31               100
# 32               100
# 33               100
# 34               100
# 35                18
# 36               100
# 37               100
# 38               100
# 39               100
# 40               100
# 41                 9
# 42                18
# 43               100
# 44               100
# 45               100
# 46               100
# 47               100
# 48                 9
# 49               100
#
# [50 rows x 29 columns]

# %%
#df["packet_types"] = df["packet_type"]
#df=pd.get_dummies(df, prefix=['outport', 'inport', 'packet_type'], columns=['outport', 'inport','packet_type'])

# %%
df.dtypes
# Out:
# timestamp                       int64
# outport                         int64
# inport                          int64
# cache_coherence_type            int64
# flit_id                         int64
# flit_type                       int64
# vnet                            int64
# vc                              int64
# src_ni                          int64
# src_router                      int64
# dst_ni                          int64
# dst_router                      int64
# traversal_id                    int64
# hop_count                       int64
# current_hop                     int64
# hop_percentage                float64
# enqueue_time                    int64
# packet_count_decr               int64
# packet_count_incr               int64
# max_packet_count                int64
# packet_count_index              int64
# packet_max_index                int64
# port_index                      int64
# cache_coherence_flit_index      int64
# flit_index                      int64
# traversal_index                 int64
# cache_coherence_vnet_index      int64
# vnet_vc_index                   int64
# vnet_vc_cc_index                int64
# dtype: object

# %%
#df['inport_3'] = 0
#df['outport_3'] = 0

# %%
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            125        1       4                     2        1          4
# 1            146        1       4                     2        1          4
# 2            173        3       1                     4        1          1
# 3            174        3       1                     4        2          2
# 4            175        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 18356    2021442        3       1                     4        1          1
# 18357    2021443        3       1                     4        2          2
# 18358    2021444        3       1                     4        3          2
# 18359    2021445        3       1                     4        4          2
# 18360    2021449        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  max_packet_count  \
# 0         3   9      24           8  ...                 7
# 1         3   9      24           8  ...                 7
# 2         5  17      29          13  ...                 7
# 3         5  17      29          13  ...                 7
# 4         5  17      29          13  ...                 7
# ...     ...  ..     ...         ...  ...               ...
# 18356     5  17      29          13  ...                 1
# 18357     5  17      29          13  ...                 1
# 18358     5  17      29          13  ...                 1
# 18359     5  17      29          13  ...                 1
# 18360     5  17      29          13  ...                 1
#
#        packet_count_index  packet_max_index  port_index  \
# 0                       7                49           4
# 1                      12                84           4
# 2                      15               105           3
# 3                      16               112           3
# 4                      15               105           3
# ...                   ...               ...         ...
# 18356                   1                 1           3
# 18357                   1                 1           3
# 18358                   1                 1           3
# 18359                   1                 1           3
# 18360                   1                 1           3
#
#        cache_coherence_flit_index  flit_index  traversal_index  \
# 0                               2           8               16
# 1                               2           8               24
# 2                               4           4                8
# 3                               8          16               32
# 4                              12          24               48
# ...                           ...         ...              ...
# 18356                           4           4            44316
# 18357                           8          16           177264
# 18358                          12          24           265896
# 18359                          16          32           354528
# 18360                          20          60           664740
#
#        cache_coherence_vnet_index  vnet_vc_index  vnet_vc_cc_index
# 0                               6             27                18
# 1                               6             27                18
# 2                              20             85               100
# 3                              20             85               100
# 4                              20             85               100
# ...                           ...            ...               ...
# 18356                          20             85               100
# 18357                          20             85               100
# 18358                          20             85               100
# 18359                          20             85               100
# 18360                          20             85               100
#
# [18361 rows x 29 columns]

# %%
df['target'] = 0
df
# Out:
#        timestamp  outport  inport  cache_coherence_type  flit_id  flit_type  \
# 0            125        1       4                     2        1          4
# 1            146        1       4                     2        1          4
# 2            173        3       1                     4        1          1
# 3            174        3       1                     4        2          2
# 4            175        3       1                     4        3          2
# ...          ...      ...     ...                   ...      ...        ...
# 18356    2021442        3       1                     4        1          1
# 18357    2021443        3       1                     4        2          2
# 18358    2021444        3       1                     4        3          2
# 18359    2021445        3       1                     4        4          2
# 18360    2021449        3       1                     4        5          3
#
#        vnet  vc  src_ni  src_router  ...  packet_count_index  \
# 0         3   9      24           8  ...                   7
# 1         3   9      24           8  ...                  12
# 2         5  17      29          13  ...                  15
# 3         5  17      29          13  ...                  16
# 4         5  17      29          13  ...                  15
# ...     ...  ..     ...         ...  ...                 ...
# 18356     5  17      29          13  ...                   1
# 18357     5  17      29          13  ...                   1
# 18358     5  17      29          13  ...                   1
# 18359     5  17      29          13  ...                   1
# 18360     5  17      29          13  ...                   1
#
#        packet_max_index  port_index  cache_coherence_flit_index  flit_index  \
# 0                    49           4                           2           8
# 1                    84           4                           2           8
# 2                   105           3                           4           4
# 3                   112           3                           8          16
# 4                   105           3                          12          24
# ...                 ...         ...                         ...         ...
# 18356                 1           3                           4           4
# 18357                 1           3                           8          16
# 18358                 1           3                          12          24
# 18359                 1           3                          16          32
# 18360                 1           3                          20          60
#
#        traversal_index  cache_coherence_vnet_index  vnet_vc_index  \
# 0                   16                           6             27
# 1                   24                           6             27
# 2                    8                          20             85
# 3                   32                          20             85
# 4                   48                          20             85
# ...                ...                         ...            ...
# 18356            44316                          20             85
# 18357           177264                          20             85
# 18358           265896                          20             85
# 18359           354528                          20             85
# 18360           664740                          20             85
#
#        vnet_vc_cc_index  target
# 0                    18       0
# 1                    18       0
# 2                   100       0
# 3                   100       0
# 4                   100       0
# ...                 ...     ...
# 18356               100       0
# 18357               100       0
# 18358               100       0
# 18359               100       0
# 18360               100       0
#
# [18361 rows x 30 columns]

# %%
df.to_csv('wat-r9-mal.csv',index=False)
