# %% [markdown]
# <a href="https://colab.research.google.com/github/chamikasudusinghe/nocml/blob/master/ver%205.2/wat_r4_model_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Imports for Data Fetiching and Visualization

# %%
import time
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# Module Imports for Data Processing

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %% [markdown]
# Importing Dataset from GitHub

# %%
dfgurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r4-good.csv?token=AKVFSOBN6QLPGMV6YD36YJS6X2LYU"
dfmurl =  "https://raw.githubusercontent.com/chamikasudusinghe/nocml/master/ver%205.2/wat-r4-mal.csv?token=AKVFSODCZGBW4ENI53G3CCC6X2LY2"

dfg = pd.read_csv(dfgurl)
dfm = pd.read_csv(dfmurl)

# %% [markdown]
# Characteristics of Dataset

# %%
dfg
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            113        1       3  ...             27                 9       1
# 1            185        3       1  ...             85               100       1
# 2            186        3       1  ...             85               100       1
# 3            187        3       1  ...             85               100       1
# 4            188        3       1  ...             85               100       1
# ...          ...      ...     ...  ...            ...               ...     ...
# 22873    3250553        3       1  ...             85               100       1
# 22874    3250554        3       1  ...             85               100       1
# 22875    3250555        3       1  ...             85               100       1
# 22876    3250559        3       1  ...             85               100       1
# 22877    3250744        3       2  ...             27                63       1
#
# [22878 rows x 30 columns]

# %%
dfm
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            109        1       3  ...             27                 9       0
# 1            130        1       3  ...             27                 9       0
# 2            202        3       1  ...             85               100       0
# 3            203        3       1  ...             85               100       0
# 4            204        3       1  ...             85               100       0
# ...          ...      ...     ...  ...            ...               ...     ...
# 15574    2009879        3       1  ...             85               100       0
# 15575    2009880        3       1  ...             85               100       0
# 15576    2009881        3       1  ...             85               100       0
# 15577    2009882        3       1  ...             85               100       0
# 15578    2009886        3       1  ...             85               100       0
#
# [15579 rows x 30 columns]

# %%
df = dfg.append(dfm, ignore_index=True,sort=False)

# %%
df.isnull().sum()
# Out:
# timestamp                     0
# outport                       0
# inport                        0
# cache_coherence_type          0
# flit_id                       0
# flit_type                     0
# vnet                          0
# vc                            0
# src_ni                        0
# src_router                    0
# dst_ni                        0
# dst_router                    0
# traversal_id                  0
# hop_count                     0
# current_hop                   0
# hop_percentage                0
# enqueue_time                  0
# packet_count_decr             0
# packet_count_incr             0
# max_packet_count              0
# packet_count_index            0
# packet_max_index              0
# port_index                    0
# cache_coherence_flit_index    0
# flit_index                    0
# traversal_index               0
# cache_coherence_vnet_index    0
# vnet_vc_index                 0
# vnet_vc_cc_index              0
# target                        0
# dtype: int64

# %%
df = df.sort_values('timestamp')
df.to_csv('wat-r1-model.csv',index=False)

# %%
df = pd.read_csv("wat-r1-model.csv")
df
# Out:
#        timestamp  outport  inport  ...  vnet_vc_index  vnet_vc_cc_index  target
# 0            109        1       3  ...             27                 9       0
# 1            113        1       3  ...             27                 9       1
# 2            130        1       3  ...             27                 9       0
# 3            185        3       1  ...             85               100       1
# 4            186        3       1  ...             85               100       1
# ...          ...      ...     ...  ...            ...               ...     ...
# 38452    3250553        3       1  ...             85               100       1
# 38453    3250554        3       1  ...             85               100       1
# 38454    3250555        3       1  ...             85               100       1
# 38455    3250559        3       1  ...             85               100       1
# 38456    3250744        3       2  ...             27                63       1
#
# [38457 rows x 30 columns]

# %%
df.corr()
# Out:
#                             timestamp   outport  ...  vnet_vc_cc_index    target
# timestamp                    1.000000  0.041784  ...          0.031880  0.411779
# outport                      0.041784  1.000000  ...          0.817090  0.150077
# inport                       0.003210 -0.794787  ...         -0.590648 -0.077904
# cache_coherence_type         0.030205  0.129376  ...         -0.028097  0.007298
# flit_id                      0.001149  0.016394  ...          0.273542  0.005478
# flit_type                   -0.001719 -0.024641  ...         -0.411138 -0.008233
# vnet                         0.017237  0.693122  ...          0.920957  0.124790
# vc                           0.012019  0.699346  ...          0.900436  0.117323
# src_ni                       0.016958  0.929322  ...          0.831289  0.131634
# src_router                   0.026815  0.904443  ...          0.904622  0.140274
# dst_ni                      -0.027322 -0.901774  ...         -0.849333 -0.150760
# dst_router                   0.004116 -0.760908  ...         -0.712991 -0.113668
# traversal_id                 0.846235 -0.029499  ...         -0.035609 -0.057874
# hop_count                    0.009210  0.739544  ...          0.699138  0.047474
# current_hop                  0.015847  0.624208  ...          0.740581  0.086792
# hop_percentage               0.002415  0.064837  ...          0.374541  0.058815
# enqueue_time                -0.004762 -0.245177  ...         -0.203497 -0.061628
# packet_count_decr           -0.402016 -0.114035  ...         -0.056991 -0.162171
# packet_count_incr           -0.402010 -0.059425  ...         -0.086168 -0.162171
# max_packet_count            -0.487091 -0.105085  ...         -0.086728 -0.196491
# packet_count_index          -0.364341 -0.120430  ...         -0.105179 -0.173559
# packet_max_index            -0.267854 -0.121465  ...         -0.110718 -0.152703
# port_index                   0.072631  0.557954  ...          0.447352  0.122555
# cache_coherence_flit_index   0.002081 -0.060554  ...          0.142383 -0.015691
# flit_index                   0.006353 -0.006179  ...          0.063441 -0.006247
# traversal_index              0.482589 -0.027241  ...          0.018283 -0.039958
# cache_coherence_vnet_index   0.044087  0.750210  ...          0.808350  0.119995
# vnet_vc_index                0.015170  0.697572  ...          0.915203  0.122111
# vnet_vc_cc_index             0.031880  0.817090  ...          1.000000  0.140257
# target                       0.411779  0.150077  ...          0.140257  1.000000
#
# [30 rows x 30 columns]

# %%
plt.figure(figsize=(32,32))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# Processing Dataset for Training

# %%
train_X = df.drop(columns=['target','timestamp','src_ni','src_router'])
train_X
# Out:
#        outport  inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0            1       3  ...             27                 9
# 1            1       3  ...             27                 9
# 2            1       3  ...             27                 9
# 3            3       1  ...             85               100
# 4            3       1  ...             85               100
# ...        ...     ...  ...            ...               ...
# 38452        3       1  ...             85               100
# 38453        3       1  ...             85               100
# 38454        3       1  ...             85               100
# 38455        3       1  ...             85               100
# 38456        3       2  ...             27                63
#
# [38457 rows x 26 columns]

# %%
#standardization
x = train_X.values
min_max_scaler = preprocessing.MinMaxScaler()
columns = train_X.columns
x_scaled = min_max_scaler.fit_transform(x)
train_X = pd.DataFrame(x_scaled)
train_X.columns = columns
train_X
# Out:
#         outport    inport  ...  vnet_vc_index  vnet_vc_cc_index
# 0      0.333333  1.000000  ...            0.0          0.000000
# 1      0.333333  1.000000  ...            0.0          0.000000
# 2      0.333333  1.000000  ...            0.0          0.000000
# 3      1.000000  0.333333  ...            1.0          1.000000
# 4      1.000000  0.333333  ...            1.0          1.000000
# ...         ...       ...  ...            ...               ...
# 38452  1.000000  0.333333  ...            1.0          1.000000
# 38453  1.000000  0.333333  ...            1.0          1.000000
# 38454  1.000000  0.333333  ...            1.0          1.000000
# 38455  1.000000  0.333333  ...            1.0          1.000000
# 38456  1.000000  0.666667  ...            0.0          0.593407
#
# [38457 rows x 26 columns]

# %%
train_X[train_X.duplicated()].shape
# Out:
# (404, 26)

# %%
corr_df = pd.concat([train_X, df[['target']]], axis = 1)
corr_df.corr()
# Out:
#                              outport    inport  ...  vnet_vc_cc_index    target
# outport                     1.000000 -0.794787  ...          0.817090  0.150077
# inport                     -0.794787  1.000000  ...         -0.590648 -0.077904
# cache_coherence_type        0.129376 -0.170521  ...         -0.028097  0.007298
# flit_id                     0.016394 -0.027553  ...          0.273542  0.005478
# flit_type                  -0.024641  0.041412  ...         -0.411138 -0.008233
# vnet                        0.693122 -0.471020  ...          0.920957  0.124790
# vc                          0.699346 -0.533943  ...          0.900436  0.117323
# dst_ni                     -0.901774  0.682438  ...         -0.849333 -0.150760
# dst_router                 -0.760908  0.774740  ...         -0.712991 -0.113668
# traversal_id               -0.029499  0.045987  ...         -0.035609 -0.057874
# hop_count                   0.739544 -0.504688  ...          0.699138  0.047474
# current_hop                 0.624208 -0.255434  ...          0.740581  0.086792
# hop_percentage              0.064837  0.264401  ...          0.374541  0.058815
# enqueue_time               -0.245177  0.258970  ...         -0.203497 -0.061628
# packet_count_decr          -0.114035  0.023229  ...         -0.056991 -0.162171
# packet_count_incr          -0.059425 -0.077828  ...         -0.086168 -0.162171
# max_packet_count           -0.105085 -0.033077  ...         -0.086728 -0.196491
# packet_count_index         -0.120430 -0.024630  ...         -0.105179 -0.173559
# packet_max_index           -0.121465 -0.014582  ...         -0.110718 -0.152703
# port_index                  0.557954  0.025865  ...          0.447352  0.122555
# cache_coherence_flit_index -0.060554 -0.027850  ...          0.142383 -0.015691
# flit_index                 -0.006179 -0.043590  ...          0.063441 -0.006247
# traversal_index            -0.027241  0.000695  ...          0.018283 -0.039958
# cache_coherence_vnet_index  0.750210 -0.587649  ...          0.808350  0.119995
# vnet_vc_index               0.697572 -0.497828  ...          0.915203  0.122111
# vnet_vc_cc_index            0.817090 -0.590648  ...          1.000000  0.140257
# target                      0.150077 -0.077904  ...          0.140257  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# Principal Component Analysis

# %%
pca = PCA(0.95)
pca.fit(train_X)
principal_components = pca.transform(train_X)
principal_components
# Out:
# array([[ 1.50811283, -0.25612335, -0.80222592, ...,  0.73713598,
#          0.24276591,  0.41367278],
#        [ 1.60043899, -0.25101255, -0.76321048, ...,  0.82186099,
#          0.2341051 ,  0.38985413],
#        [ 1.59734321, -0.25353539, -0.75938558, ...,  0.75829685,
#          0.28890999,  0.38757912],
#        ...,
#        [-1.15257119,  0.34813792,  0.0632716 , ..., -0.30625154,
#          0.26950224, -0.09308944],
#        [-1.13603436,  0.67213642,  0.44331342, ..., -0.19203395,
#          0.40158363, -0.08557092],
#        [ 0.47328401, -0.8183531 ,  0.60000897, ..., -0.51156609,
#          0.02952518,  0.15669761]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.55050271, 0.12344268, 0.10501806, 0.06232393, 0.04616396,
#        0.04115127, 0.03307011])

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xticks(features)
plt.xlabel("PCs")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %%
principal_df = pd.DataFrame(data = principal_components)
principal_df
# Out:
#               0         1         2         3         4         5         6
# 0      1.508113 -0.256123 -0.802226 -0.446483  0.737136  0.242766  0.413673
# 1      1.600439 -0.251013 -0.763210 -0.235566  0.821861  0.234105  0.389854
# 2      1.597343 -0.253535 -0.759386 -0.260012  0.758297  0.288910  0.387579
# 3     -1.058427 -0.415375 -0.547625  0.350264  0.233833 -0.394451  0.075786
# 4     -1.044943 -0.199308 -0.276947  0.164498  0.390001 -0.308186  0.103611
# ...         ...       ...       ...       ...       ...       ...       ...
# 38452 -1.114640 -0.162796 -0.239766 -0.082790 -0.309348  0.295629 -0.079616
# 38453 -1.133606  0.092671 -0.088247 -0.103191 -0.307800  0.282566 -0.086353
# 38454 -1.152571  0.348138  0.063272 -0.123591 -0.306252  0.269502 -0.093089
# 38455 -1.136034  0.672136  0.443313 -0.355932 -0.192034  0.401584 -0.085571
# 38456  0.473284 -0.818353  0.600009 -0.746105 -0.511566  0.029525  0.156698
#
# [38457 rows x 7 columns]

# %%
final_df = pd.concat([principal_df, df[['target']]], axis = 1)
final_df.corr()
# Out:
#                    0             1  ...             6    target
# 0       1.000000e+00 -1.560320e-14  ... -2.823182e-15 -0.136106
# 1      -1.560320e-14  1.000000e+00  ... -1.082616e-15 -0.042614
# 2       4.542472e-16  6.315727e-16  ... -2.270584e-16  0.023781
# 3       1.849356e-15  8.126573e-16  ... -2.531583e-15 -0.030853
# 4       2.369015e-15 -2.570209e-16  ... -1.752721e-15 -0.011597
# 5       1.944409e-15 -5.324680e-16  ... -9.473583e-16 -0.025825
# 6      -2.823182e-15 -1.082616e-15  ...  1.000000e+00  0.020869
# target -1.361059e-01 -4.261390e-02  ...  2.086868e-02  1.000000
#
# [8 rows x 8 columns]

# %%
dimentional_components = pd.DataFrame()
dimentional_components['target'] = corr_df["target"]
dimentional_components['pca-one'] = principal_components[:,0]
dimentional_components['pca-two'] = principal_components[:,1] 
dimentional_components['pca-three'] = principal_components[:,2]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-one", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 2', fontsize = 15)
ax.set_ylabel('Principal Component 3', fontsize = 15)
ax.set_title('2D PCA', fontsize = 20)
sns.scatterplot(
    x="pca-two", y="pca-three",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax
)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-two'], 
    zs=dimentional_components['pca-three'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-one'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-two'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-two')
plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=dimentional_components['pca-two'], 
    ys=dimentional_components['pca-three'], 
    zs=dimentional_components['pca-one'], 
    c=dimentional_components['target'], 
    cmap='RdBu'
)
ax.set_xlabel('pca-two')
ax.set_ylabel('pca-three')
ax.set_zlabel('pca-one')
plt.show()

# %% [markdown]
# T-distributed Stochastic Neighbor Embedding

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_components = tsne.fit_transform(train_X)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 118.69903230667114 seconds

# %%
dimentional_components['tsne-2d-one'] = tsne_components[:,0]
dimentional_components['tsne-2d-two'] = tsne_components[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3
)

# %%
plt.figure(figsize=(16,7))
ax1 = plt.subplot(1, 2, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 2, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=0, perplexity=40, n_iter=300)
tsne_pca_components = tsne.fit_transform(principal_components)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 105.31535863876343 seconds

# %%
dimentional_components['tsne-pca9-one'] = tsne_pca_components[:,0]
dimentional_components['tsne-pca9-two'] = tsne_pca_components[:,1]
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1, 3, 1)
sns.scatterplot(
    x="pca-one", y="pca-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 3, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax2
)
ax3 = plt.subplot(1, 3, 3)
sns.scatterplot(
    x="tsne-pca9-one", y="tsne-pca9-two",
    hue="target",
    palette=sns.color_palette("hls", 2),
    data=dimentional_components,
    legend="full",
    alpha=0.3,
    ax=ax3
)

# %% [markdown]
# #### Machine Learning Models

# %% [markdown]
# Module Imports for Data Processing and Report Generation in Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Labels
#
# 1.   0 -  malicious
# 2.   1 -  good

# %%
train_Y = df['target']
train_Y.value_counts()
# Out:
# 1    22878
# 0    15579
# Name: target, dtype: int64

# %% [markdown]
# Training and Validation Splitting of the Dataset

# %%
seed = 5
np.random.seed(seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.2, random_state=seed, shuffle=True)

# %% [markdown]
# Feature Selection

# %%
#SelectKBest for feature selection
bf = SelectKBest(score_func=chi2, k=17)
fit = bf.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
print(featureScores.nlargest(17,'Score'))
featureScores.plot(kind='barh')
# Out:
#                          Specs       Score
# 16            max_packet_count  420.710330
# 7                       dst_ni  355.998919
# 5                         vnet  237.804089
# 17          packet_count_index  215.595210
# 24               vnet_vc_index  215.222825
# 14           packet_count_decr  210.626458
# 15           packet_count_incr  210.087283
# 8                   dst_router  199.878573
# 6                           vc  185.961844
# 18            packet_max_index  164.241739
# 0                      outport  120.933647
# 25            vnet_vc_cc_index   85.892401
# 19                  port_index   58.784413
# 1                       inport   43.765223
# 11                 current_hop   35.845883
# 23  cache_coherence_vnet_index   31.531159
# 9                 traversal_id   19.320874

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

# %%
logit_model=sm.Logit(train_Y,train_X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.616176
#          Iterations: 35
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#                                      Results: Logit
# =========================================================================================
# Model:                      Logit                    Pseudo R-squared:         0.087
# Dependent Variable:         target                   AIC:                      47436.5406
# Date:                       2020-05-08 13:44         BIC:                      47624.8011
# No. Observations:           38457                    Log-Likelihood:           -23696.
# Df Model:                   21                       LL-Null:                  -25959.
# Df Residuals:               38435                    LLR p-value:              0.0000
# Converged:                  0.0000                   Scale:                    1.0000
# No. Iterations:             35.0000
# -----------------------------------------------------------------------------------------
#                             Coef.    Std.Err.     z     P>|z|      [0.025       0.975]
# -----------------------------------------------------------------------------------------
# outport                     0.5572      0.3758   1.4829 0.1381       -0.1793       1.2937
# inport                     -6.3686      0.5187 -12.2771 0.0000       -7.3853      -5.3519
# cache_coherence_type        0.0510         nan      nan    nan           nan          nan
# flit_id                    -0.6424      0.2946  -2.1808 0.0292       -1.2198      -0.0651
# flit_type                   0.8095      0.1335   6.0645 0.0000        0.5479       1.0711
# vnet                        0.7829 472974.6018   0.0000 1.0000  -927012.4022  927013.9681
# vc                         -0.4400 371453.9362  -0.0000 1.0000  -728036.7768  728035.8968
# dst_ni                      3.2372      0.2521  12.8415 0.0000        2.7431       3.7313
# dst_router                  3.1387      0.2384  13.1667 0.0000        2.6715       3.6059
# traversal_id               -1.3911      0.0717 -19.3888 0.0000       -1.5317      -1.2505
# hop_count                  -7.1359      0.3469 -20.5688 0.0000       -7.8159      -6.4559
# current_hop                 4.4910      0.3541  12.6811 0.0000        3.7969       5.1851
# hop_percentage              2.4126      0.2600   9.2805 0.0000        1.9031       2.9221
# enqueue_time               -0.0551      0.2143  -0.2572 0.7970       -0.4751       0.3649
# packet_count_decr          -2.0441         nan      nan    nan           nan          nan
# packet_count_incr          -2.4188         nan      nan    nan           nan          nan
# max_packet_count           -4.4629         nan      nan    nan           nan          nan
# packet_count_index          1.9187      1.3503   1.4210 0.1553       -0.7278       4.5652
# packet_max_index            3.1436      1.3431   2.3405 0.0193        0.5112       5.7760
# port_index                  2.6955      0.3242   8.3151 0.0000        2.0602       3.3309
# cache_coherence_flit_index  1.0403      0.5564   1.8697 0.0615       -0.0502       2.1308
# flit_index                 -0.2232      0.2482  -0.8995 0.3684       -0.7097       0.2632
# traversal_index            -0.7048      0.1777  -3.9673 0.0001       -1.0530      -0.3566
# cache_coherence_vnet_index  0.3990         nan      nan    nan           nan          nan
# vnet_vc_index               0.2769 897680.3457   0.0000 1.0000 -1759420.8704 1759421.4241
# vnet_vc_cc_index            0.5809         nan      nan    nan           nan          nan
# =========================================================================================

# %%
logreg = LogisticRegression(C=5,penalty='l2',random_state=42, max_iter=500)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
logreg_score_train = logreg.score(X_train,y_train)
print("Train Prediction Score",logreg_score_train*100)
logreg_score_test = accuracy_score(y_test,y_pred)
print("Test Prediction ",logreg_score_test*100)
# Out:
# Train Prediction Score 67.56704046806435
# Test Prediction  67.96671866874675

# %%
feature_importance=pd.DataFrame(np.hstack((np.array([columns[::]]).T, logreg.coef_.T)), columns=['feature', 'importance'])
feature_importance['importance']=pd.to_numeric(feature_importance['importance'])
feature_importance.sort_values(by='importance', ascending=False)
# Out:
#                        feature  importance
# 7                       dst_ni    3.935588
# 11                 current_hop    3.487856
# 17          packet_count_index    2.551995
# 0                      outport    2.431916
# 18            packet_max_index    2.412554
# 12              hop_percentage    2.198093
# 8                   dst_router    2.138196
# 19                  port_index    1.259588
# 4                    flit_type    0.957156
# 5                         vnet    0.732765
# 25            vnet_vc_cc_index    0.674066
# 20  cache_coherence_flit_index    0.611928
# 23  cache_coherence_vnet_index    0.593137
# 24               vnet_vc_index    0.296452
# 2         cache_coherence_type    0.267464
# 13                enqueue_time    0.176229
# 6                           vc   -0.321658
# 3                      flit_id   -0.328355
# 21                  flit_index   -0.525342
# 22             traversal_index   -0.629829
# 9                 traversal_id   -1.430516
# 14           packet_count_decr   -1.991693
# 15           packet_count_incr   -2.495670
# 1                       inport   -4.171512
# 16            max_packet_count   -4.487362
# 10                   hop_count   -6.136346

# %%
cm = confusion_matrix(y_test, y_pred)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.39      0.49      3090
#            1       0.68      0.88      0.77      4602
#
#     accuracy                           0.68      7692
#    macro avg       0.68      0.63      0.63      7692
# weighted avg       0.68      0.68      0.66      7692

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LOG_ROC')
plt.show()

# %% [markdown]
# KNeighbors Classifier

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred_knn= knn.predict(X_test)

# %%
knn_score_train = knn.score(X_train,y_train)
print("Train Prediction Score",knn_score_train*100)
knn_score_test = accuracy_score(y_test,y_pred_knn)
print("Test Prediction ",knn_score_test*100)
# Out:
# Train Prediction Score 79.25889809848854
# Test Prediction  69.40977639105564

# %%
cm = confusion_matrix(y_test, y_pred_knn)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.50      0.57      3090
#            1       0.71      0.83      0.76      4602
#
#     accuracy                           0.69      7692
#    macro avg       0.68      0.66      0.67      7692
# weighted avg       0.69      0.69      0.68      7692

# %%
knn_roc_auc = roc_auc_score(y_test, y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test, knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNeighbors (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('KNN_ROC')
plt.show()

# %% [markdown]
# Naive Bayes Classifier

# %%
#naive_bayes
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred_nb= nb.predict(X_test)

# %%
nb_score_train = nb.score(X_train,y_train)
print("Train Prediction Score",nb_score_train*100)
nb_score_test = accuracy_score(y_test,y_pred_nb)
print("Test Prediction Score",nb_score_test*100)
# Out:
# Train Prediction Score 62.45083699008613
# Test Prediction Score 63.260530421216856

# %%
cm = confusion_matrix(y_test, y_pred_nb)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.28      0.38      3090
#            1       0.64      0.87      0.74      4602
#
#     accuracy                           0.63      7692
#    macro avg       0.62      0.57      0.56      7692
# weighted avg       0.62      0.63      0.59      7692

# %%
nb_roc_auc = roc_auc_score(y_test, y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='NaiveBayes (area = %0.2f)' % nb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %% [markdown]
# ### Neural Networks

# %%
#neuralnetwork
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Dropout
from keras.optimizers import SGD
from keras.layers import PReLU
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2-Layer Neural Network

# %%
#2layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(2, activation='relu', input_shape=(n_cols,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2 )
# Out:
# Train on 24612 samples, validate on 6153 samples
# Epoch 1/10
# 24612/24612 [==============================] - 1s 46us/step - loss: 0.2437 - accuracy: 0.5933 - val_loss: 0.2361 - val_accuracy: 0.6197
# Epoch 2/10
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2301 - accuracy: 0.6303 - val_loss: 0.2272 - val_accuracy: 0.6317
# Epoch 3/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2241 - accuracy: 0.6409 - val_loss: 0.2233 - val_accuracy: 0.6433
# Epoch 4/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2209 - accuracy: 0.6516 - val_loss: 0.2211 - val_accuracy: 0.6550
# Epoch 5/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2187 - accuracy: 0.6578 - val_loss: 0.2191 - val_accuracy: 0.6628
# Epoch 6/10
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2168 - accuracy: 0.6651 - val_loss: 0.2171 - val_accuracy: 0.6659
# Epoch 7/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2135 - accuracy: 0.6739 - val_loss: 0.2123 - val_accuracy: 0.6860
# Epoch 8/10
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2105 - accuracy: 0.6818 - val_loss: 0.2097 - val_accuracy: 0.6923
# Epoch 9/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2083 - accuracy: 0.6881 - val_loss: 0.2075 - val_accuracy: 0.6891
# Epoch 10/10
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2066 - accuracy: 0.6908 - val_loss: 0.2059 - val_accuracy: 0.6933

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 69.18%

# %% [markdown]
# 3-Layer Neural Network

# %%
#3layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(4, activation="relu", input_shape=(n_cols,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2 )
# Out:
# Train on 24612 samples, validate on 6153 samples
# Epoch 1/15
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2451 - accuracy: 0.5939 - val_loss: 0.2424 - val_accuracy: 0.5939
# Epoch 2/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2418 - accuracy: 0.5941 - val_loss: 0.2413 - val_accuracy: 0.5939
# Epoch 3/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2413 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 4/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 5/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 6/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 7/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 8/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 9/15
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2411 - val_accuracy: 0.5939
# Epoch 10/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939
# Epoch 11/15
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2411 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939
# Epoch 12/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2410 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939
# Epoch 13/15
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2410 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939
# Epoch 14/15
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2410 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939
# Epoch 15/15
# 24612/24612 [==============================] - 1s 35us/step - loss: 0.2410 - accuracy: 0.5941 - val_loss: 0.2410 - val_accuracy: 0.5939

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 59.83%

# %% [markdown]
# 4-Layer Neural Network

# %%
#4layer
model = Sequential()
n_cols = X_train.shape[1]
n_cols
model.add(Dense(8, activation='relu', input_shape=(n_cols,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Train on 24612 samples, validate on 6153 samples
# Epoch 1/30
# 24612/24612 [==============================] - 1s 39us/step - loss: 0.2391 - accuracy: 0.5941 - val_loss: 0.2387 - val_accuracy: 0.5939
# Epoch 2/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2379 - accuracy: 0.5941 - val_loss: 0.2379 - val_accuracy: 0.5939
# Epoch 3/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2371 - accuracy: 0.5941 - val_loss: 0.2373 - val_accuracy: 0.5939
# Epoch 4/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2365 - accuracy: 0.5943 - val_loss: 0.2368 - val_accuracy: 0.5921
# Epoch 5/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2359 - accuracy: 0.5938 - val_loss: 0.2364 - val_accuracy: 0.5922
# Epoch 6/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2355 - accuracy: 0.5952 - val_loss: 0.2360 - val_accuracy: 0.5943
# Epoch 7/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2351 - accuracy: 0.5976 - val_loss: 0.2357 - val_accuracy: 0.5986
# Epoch 8/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2347 - accuracy: 0.6021 - val_loss: 0.2354 - val_accuracy: 0.6015
# Epoch 9/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2343 - accuracy: 0.6057 - val_loss: 0.2351 - val_accuracy: 0.6088
# Epoch 10/30
# 24612/24612 [==============================] - 1s 38us/step - loss: 0.2340 - accuracy: 0.6092 - val_loss: 0.2348 - val_accuracy: 0.6099
# Epoch 11/30
# 24612/24612 [==============================] - 1s 38us/step - loss: 0.2337 - accuracy: 0.6130 - val_loss: 0.2345 - val_accuracy: 0.6108
# Epoch 12/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2333 - accuracy: 0.6150 - val_loss: 0.2342 - val_accuracy: 0.6137
# Epoch 13/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2330 - accuracy: 0.6160 - val_loss: 0.2338 - val_accuracy: 0.6135
# Epoch 14/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2326 - accuracy: 0.6178 - val_loss: 0.2333 - val_accuracy: 0.6187
# Epoch 15/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2321 - accuracy: 0.6213 - val_loss: 0.2328 - val_accuracy: 0.6187
# Epoch 16/30
# 24612/24612 [==============================] - 1s 38us/step - loss: 0.2316 - accuracy: 0.6234 - val_loss: 0.2326 - val_accuracy: 0.6181
# Epoch 17/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2311 - accuracy: 0.6260 - val_loss: 0.2317 - val_accuracy: 0.6267
# Epoch 18/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2304 - accuracy: 0.6275 - val_loss: 0.2311 - val_accuracy: 0.6309
# Epoch 19/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2297 - accuracy: 0.6303 - val_loss: 0.2304 - val_accuracy: 0.6303
# Epoch 20/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2290 - accuracy: 0.6363 - val_loss: 0.2294 - val_accuracy: 0.6373
# Epoch 21/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2280 - accuracy: 0.6383 - val_loss: 0.2288 - val_accuracy: 0.6447
# Epoch 22/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2271 - accuracy: 0.6438 - val_loss: 0.2275 - val_accuracy: 0.6483
# Epoch 23/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2261 - accuracy: 0.6474 - val_loss: 0.2274 - val_accuracy: 0.6451
# Epoch 24/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2251 - accuracy: 0.6526 - val_loss: 0.2259 - val_accuracy: 0.6494
# Epoch 25/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2241 - accuracy: 0.6542 - val_loss: 0.2244 - val_accuracy: 0.6598
# Epoch 26/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2230 - accuracy: 0.6595 - val_loss: 0.2239 - val_accuracy: 0.6558
# Epoch 27/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2219 - accuracy: 0.6618 - val_loss: 0.2221 - val_accuracy: 0.6637
# Epoch 28/30
# 24612/24612 [==============================] - 1s 37us/step - loss: 0.2208 - accuracy: 0.6645 - val_loss: 0.2216 - val_accuracy: 0.6621
# Epoch 29/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2198 - accuracy: 0.6678 - val_loss: 0.2200 - val_accuracy: 0.6758
# Epoch 30/30
# 24612/24612 [==============================] - 1s 36us/step - loss: 0.2187 - accuracy: 0.6699 - val_loss: 0.2197 - val_accuracy: 0.6832

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 68.14%

# %% [markdown]
# 5-Layer Neural Network Optimized

# %%
#5layer
model = Sequential()
n_cols = X_train.shape[1]
model.add(Dense(32, input_shape=(n_cols,),kernel_initializer='RandomUniform'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(16))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(8))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dense(4))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.001,seed=5))
model.add(Dense(1, activation='hard_sigmoid', kernel_initializer = "RandomUniform"))
opt = SGD(lr=0.02, momentum=0.9)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=20)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Train on 24612 samples, validate on 6153 samples
# Epoch 1/100
# 24612/24612 [==============================] - 2s 86us/step - loss: 0.2187 - accuracy: 0.6549 - val_loss: 0.2107 - val_accuracy: 0.6766
# Epoch 2/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.2057 - accuracy: 0.6883 - val_loss: 0.2083 - val_accuracy: 0.6701
# Epoch 3/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.2008 - accuracy: 0.6984 - val_loss: 0.1913 - val_accuracy: 0.7052
# Epoch 4/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1986 - accuracy: 0.7040 - val_loss: 0.2031 - val_accuracy: 0.6837
# Epoch 5/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1960 - accuracy: 0.7106 - val_loss: 0.1899 - val_accuracy: 0.7275
# Epoch 6/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1950 - accuracy: 0.7102 - val_loss: 0.1903 - val_accuracy: 0.7076
# Epoch 7/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1951 - accuracy: 0.7105 - val_loss: 0.2003 - val_accuracy: 0.7011
# Epoch 8/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1943 - accuracy: 0.7118 - val_loss: 0.1868 - val_accuracy: 0.7201
# Epoch 9/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1932 - accuracy: 0.7129 - val_loss: 0.1902 - val_accuracy: 0.7187
# Epoch 10/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1927 - accuracy: 0.7134 - val_loss: 0.1845 - val_accuracy: 0.7318
# Epoch 11/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1931 - accuracy: 0.7155 - val_loss: 0.1858 - val_accuracy: 0.7266
# Epoch 12/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1921 - accuracy: 0.7174 - val_loss: 0.1860 - val_accuracy: 0.7328
# Epoch 13/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1913 - accuracy: 0.7180 - val_loss: 0.1878 - val_accuracy: 0.7196
# Epoch 14/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1902 - accuracy: 0.7193 - val_loss: 0.1883 - val_accuracy: 0.7120
# Epoch 15/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1895 - accuracy: 0.7242 - val_loss: 0.1921 - val_accuracy: 0.7192
# Epoch 16/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1891 - accuracy: 0.7209 - val_loss: 0.1828 - val_accuracy: 0.7317
# Epoch 17/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1890 - accuracy: 0.7230 - val_loss: 0.1883 - val_accuracy: 0.7192
# Epoch 18/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1893 - accuracy: 0.7205 - val_loss: 0.1838 - val_accuracy: 0.7351
# Epoch 19/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1884 - accuracy: 0.7237 - val_loss: 0.1819 - val_accuracy: 0.7377
# Epoch 20/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1877 - accuracy: 0.7237 - val_loss: 0.1924 - val_accuracy: 0.7084
# Epoch 21/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1902 - accuracy: 0.7233 - val_loss: 0.1815 - val_accuracy: 0.7284
# Epoch 22/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1880 - accuracy: 0.7248 - val_loss: 0.1855 - val_accuracy: 0.7205
# Epoch 23/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1883 - accuracy: 0.7226 - val_loss: 0.1834 - val_accuracy: 0.7250
# Epoch 24/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1872 - accuracy: 0.7267 - val_loss: 0.1819 - val_accuracy: 0.7276
# Epoch 25/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1886 - accuracy: 0.7232 - val_loss: 0.1897 - val_accuracy: 0.7182
# Epoch 26/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1894 - accuracy: 0.7218 - val_loss: 0.1799 - val_accuracy: 0.7379
# Epoch 27/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1880 - accuracy: 0.7253 - val_loss: 0.1786 - val_accuracy: 0.7385
# Epoch 28/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1867 - accuracy: 0.7283 - val_loss: 0.1837 - val_accuracy: 0.7299
# Epoch 29/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1872 - accuracy: 0.7273 - val_loss: 0.1787 - val_accuracy: 0.7382
# Epoch 30/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1877 - accuracy: 0.7256 - val_loss: 0.1806 - val_accuracy: 0.7310
# Epoch 31/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1878 - accuracy: 0.7248 - val_loss: 0.1846 - val_accuracy: 0.7278
# Epoch 32/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1860 - accuracy: 0.7288 - val_loss: 0.1792 - val_accuracy: 0.7362
# Epoch 33/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1868 - accuracy: 0.7259 - val_loss: 0.1796 - val_accuracy: 0.7310
# Epoch 34/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1860 - accuracy: 0.7266 - val_loss: 0.1763 - val_accuracy: 0.7448
# Epoch 35/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1854 - accuracy: 0.7298 - val_loss: 0.1826 - val_accuracy: 0.7302
# Epoch 36/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1865 - accuracy: 0.7255 - val_loss: 0.1788 - val_accuracy: 0.7374
# Epoch 37/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1862 - accuracy: 0.7269 - val_loss: 0.1759 - val_accuracy: 0.7458
# Epoch 38/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1853 - accuracy: 0.7290 - val_loss: 0.1868 - val_accuracy: 0.7185
# Epoch 39/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1846 - accuracy: 0.7297 - val_loss: 0.1808 - val_accuracy: 0.7305
# Epoch 40/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1857 - accuracy: 0.7278 - val_loss: 0.1773 - val_accuracy: 0.7398
# Epoch 41/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1851 - accuracy: 0.7283 - val_loss: 0.1770 - val_accuracy: 0.7418
# Epoch 42/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1855 - accuracy: 0.7266 - val_loss: 0.1811 - val_accuracy: 0.7403
# Epoch 43/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1844 - accuracy: 0.7299 - val_loss: 0.1800 - val_accuracy: 0.7335
# Epoch 44/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1850 - accuracy: 0.7280 - val_loss: 0.1784 - val_accuracy: 0.7338
# Epoch 45/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1850 - accuracy: 0.7303 - val_loss: 0.1782 - val_accuracy: 0.7366
# Epoch 46/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1850 - accuracy: 0.7277 - val_loss: 0.1802 - val_accuracy: 0.7348
# Epoch 47/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1847 - accuracy: 0.7294 - val_loss: 0.1839 - val_accuracy: 0.7255
# Epoch 48/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1852 - accuracy: 0.7290 - val_loss: 0.1783 - val_accuracy: 0.7429
# Epoch 49/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1838 - accuracy: 0.7303 - val_loss: 0.1764 - val_accuracy: 0.7375
# Epoch 50/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1843 - accuracy: 0.7298 - val_loss: 0.1770 - val_accuracy: 0.7411
# Epoch 51/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1847 - accuracy: 0.7294 - val_loss: 0.1763 - val_accuracy: 0.7409
# Epoch 52/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1845 - accuracy: 0.7303 - val_loss: 0.1763 - val_accuracy: 0.7383
# Epoch 53/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1838 - accuracy: 0.7288 - val_loss: 0.1765 - val_accuracy: 0.7440
# Epoch 54/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1838 - accuracy: 0.7309 - val_loss: 0.1796 - val_accuracy: 0.7379
# Epoch 55/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1833 - accuracy: 0.7320 - val_loss: 0.1775 - val_accuracy: 0.7354
# Epoch 56/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1860 - accuracy: 0.7290 - val_loss: 0.1867 - val_accuracy: 0.7177
# Epoch 57/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1851 - accuracy: 0.7284 - val_loss: 0.1776 - val_accuracy: 0.7361
# Epoch 58/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1848 - accuracy: 0.7297 - val_loss: 0.1894 - val_accuracy: 0.7081
# Epoch 59/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1836 - accuracy: 0.7314 - val_loss: 0.1770 - val_accuracy: 0.7422
# Epoch 60/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1836 - accuracy: 0.7296 - val_loss: 0.1786 - val_accuracy: 0.7375
# Epoch 61/100
# 24612/24612 [==============================] - 2s 67us/step - loss: 0.1824 - accuracy: 0.7329 - val_loss: 0.1880 - val_accuracy: 0.7161
# Epoch 62/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1833 - accuracy: 0.7293 - val_loss: 0.1796 - val_accuracy: 0.7357
# Epoch 63/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1830 - accuracy: 0.7328 - val_loss: 0.1779 - val_accuracy: 0.7401
# Epoch 64/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1830 - accuracy: 0.7305 - val_loss: 0.1771 - val_accuracy: 0.7408
# Epoch 65/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1823 - accuracy: 0.7329 - val_loss: 0.1780 - val_accuracy: 0.7333
# Epoch 66/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1828 - accuracy: 0.7329 - val_loss: 0.1760 - val_accuracy: 0.7424
# Epoch 67/100
# 24612/24612 [==============================] - 2s 66us/step - loss: 0.1837 - accuracy: 0.7311 - val_loss: 0.1780 - val_accuracy: 0.7346
# Epoch 68/100
# 24612/24612 [==============================] - 2s 67us/step - loss: 0.1837 - accuracy: 0.7301 - val_loss: 0.1764 - val_accuracy: 0.7442
# Epoch 69/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1830 - accuracy: 0.7332 - val_loss: 0.1791 - val_accuracy: 0.7323
# Epoch 70/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1833 - accuracy: 0.7319 - val_loss: 0.1768 - val_accuracy: 0.7395
# Epoch 71/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1818 - accuracy: 0.7338 - val_loss: 0.1793 - val_accuracy: 0.7346
# Epoch 72/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1826 - accuracy: 0.7316 - val_loss: 0.1772 - val_accuracy: 0.7356
# Epoch 73/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1824 - accuracy: 0.7324 - val_loss: 0.1793 - val_accuracy: 0.7413
# Epoch 74/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1842 - accuracy: 0.7309 - val_loss: 0.1774 - val_accuracy: 0.7418
# Epoch 75/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1823 - accuracy: 0.7328 - val_loss: 0.1777 - val_accuracy: 0.7403
# Epoch 76/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1833 - accuracy: 0.7316 - val_loss: 0.1786 - val_accuracy: 0.7307
# Epoch 77/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1823 - accuracy: 0.7345 - val_loss: 0.1774 - val_accuracy: 0.7414
# Epoch 78/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1814 - accuracy: 0.7373 - val_loss: 0.1801 - val_accuracy: 0.7361
# Epoch 79/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1829 - accuracy: 0.7308 - val_loss: 0.1753 - val_accuracy: 0.7437
# Epoch 80/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1820 - accuracy: 0.7344 - val_loss: 0.1802 - val_accuracy: 0.7328
# Epoch 81/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1822 - accuracy: 0.7342 - val_loss: 0.1762 - val_accuracy: 0.7427
# Epoch 82/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1816 - accuracy: 0.7342 - val_loss: 0.1782 - val_accuracy: 0.7370
# Epoch 83/100
# 24612/24612 [==============================] - 2s 62us/step - loss: 0.1820 - accuracy: 0.7328 - val_loss: 0.1768 - val_accuracy: 0.7398
# Epoch 84/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1827 - accuracy: 0.7315 - val_loss: 0.1793 - val_accuracy: 0.7361
# Epoch 85/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1851 - accuracy: 0.7285 - val_loss: 0.1757 - val_accuracy: 0.7429
# Epoch 86/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1828 - accuracy: 0.7323 - val_loss: 0.1758 - val_accuracy: 0.7426
# Epoch 87/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1810 - accuracy: 0.7343 - val_loss: 0.1788 - val_accuracy: 0.7406
# Epoch 88/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1826 - accuracy: 0.7327 - val_loss: 0.1769 - val_accuracy: 0.7393
# Epoch 89/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1820 - accuracy: 0.7351 - val_loss: 0.1754 - val_accuracy: 0.7435
# Epoch 90/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1813 - accuracy: 0.7363 - val_loss: 0.1779 - val_accuracy: 0.7393
# Epoch 91/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1827 - accuracy: 0.7319 - val_loss: 0.1761 - val_accuracy: 0.7359
# Epoch 92/100
# 24612/24612 [==============================] - 2s 65us/step - loss: 0.1822 - accuracy: 0.7344 - val_loss: 0.1751 - val_accuracy: 0.7403
# Epoch 93/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1820 - accuracy: 0.7329 - val_loss: 0.1799 - val_accuracy: 0.7354
# Epoch 94/100
# 24612/24612 [==============================] - 2s 63us/step - loss: 0.1813 - accuracy: 0.7347 - val_loss: 0.1779 - val_accuracy: 0.7385
# Epoch 95/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1813 - accuracy: 0.7350 - val_loss: 0.1778 - val_accuracy: 0.7375
# Epoch 96/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1840 - accuracy: 0.7311 - val_loss: 0.1757 - val_accuracy: 0.7414
# Epoch 97/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1826 - accuracy: 0.7344 - val_loss: 0.1773 - val_accuracy: 0.7422
# Epoch 98/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1816 - accuracy: 0.7335 - val_loss: 0.1803 - val_accuracy: 0.7338
# Epoch 99/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1817 - accuracy: 0.7351 - val_loss: 0.1755 - val_accuracy: 0.7403
# Epoch 100/100
# 24612/24612 [==============================] - 2s 64us/step - loss: 0.1810 - accuracy: 0.7356 - val_loss: 0.1759 - val_accuracy: 0.7455

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 74.53%

# %% [markdown]
# Decision Tree Classifier

# %%
#decisiontreee
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
# GridSearchCV
param_grid={'max_depth':range(0,25,2) ,
            'max_features':range(0,25,2)}
dt_g=DecisionTreeClassifier(random_state = 42)
dt_cv=GridSearchCV(dt_g,param_grid,cv=3,scoring='accuracy',n_jobs=-1)
dt_cv.fit(X_train,y_train)

print("Best parameters:",dt_cv.best_params_)
print("Accuracy :",dt_cv.best_score_)
# Out:
# Best parameters: {'max_depth': 24, 'max_features': 24}
# Accuracy : 0.7879408418657565

# %%
dt = DecisionTreeClassifier(max_depth=25,max_features=25,random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=25, max_features=25, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
y_pred_dt= dt.predict(X_test)

# %%
dt_score_train = dt.score(X_train,y_train)
print("Train Prediction Score",dt_score_train*100)
dt_score_test = accuracy_score(y_test,y_pred_dt)
print("Test Prediction Score",dt_score_test*100)
# Out:
# Train Prediction Score 94.35722411831627
# Test Prediction Score 84.4513780551222

# %%
feat_importances = pd.Series(dt.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_dt)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80      3090
#            1       0.85      0.90      0.87      4602
#
#     accuracy                           0.84      7692
#    macro avg       0.84      0.83      0.84      7692
# weighted avg       0.84      0.84      0.84      7692

# %%
dt_roc_auc = roc_auc_score(y_test, y_pred_dt)
fpr, tpr, thresholds = roc_curve(y_test, dt.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='DTree (area = %0.2f)' % dt_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('DT_ROC')
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier

# %%
# GridSearchCV
#param_grid={'max_depth':range(0,25,2),
#            'n_estimators':[125,250],
#            'max_features':range(0,25,2)}
#dt_g=RandomForestClassifier(random_state=42)
#dt_cv=GridSearchCV(dt_g,param_grid,cv=10,scoring='f1_micro',n_jobs=-1)
#dt_cv.fit(X_train,y_train)

#print("Best parameters:",dt_cv.best_params_)
#print("Accuracy :",dt_cv.best_score_)

# %%
rf = RandomForestClassifier(max_depth=25,max_features=25,n_estimators=125,random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features=25,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_rf= rf.predict(X_test)

# %%
rf_score_train = rf.score(X_train,y_train)
print("Train Prediction Score",rf_score_train*100)
rf_score_test = accuracy_score(y_test,y_pred_rf)
print("Test Prediction Score",rf_score_test*100)
# Out:
# Train Prediction Score 97.56216479765968
# Test Prediction Score 83.42433697347894

# %%
feat_importances = pd.Series(rf.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
cm = confusion_matrix(y_test, y_pred_rf)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78      3090
#            1       0.83      0.91      0.87      4602
#
#     accuracy                           0.83      7692
#    macro avg       0.84      0.82      0.82      7692
# weighted avg       0.83      0.83      0.83      7692

# %%
rf_roc_auc = roc_auc_score(y_test, y_pred_rf)
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='RandomForest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %% [markdown]
# XGBoost Classifier

# %%
#xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
# GridSearchCV
#param_grid={'max_depth':range(0,25,2),
#            'n_estimators':[125,250,500],
#           'min_child_weight':[1,3,6]}
#xgb_g=XGBClassifier(random_state=42)
#xgb_cv=GridSearchCV(xgb_g,param_grid,cv=10,scoring='accuracy',n_jobs=-1)
#xgb_cv.fit(X_train,y_train)

#print("Best parameters:",xgb_cv.best_params_)
#print("Accuracy :",xgb_cv.best_score_)

# %%
xgbc = XGBClassifier(max_depth=25,min_child_weight=1,n_estimators=500,random_state=42)
xgbc.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=25,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred_xgbc= xgbc.predict(X_test)

# %%
xgbc_score_train = xgbc.score(X_train,y_train)
print("Train Prediction Score",xgbc_score_train*100)
xgbc_score_test = accuracy_score(y_test,y_pred_xgbc)
print("Test Prediction Score",xgbc_score_test*100)
# Out:
# Train Prediction Score 98.67706809686332
# Test Prediction Score 88.66354654186168

# %%
plot_importance(xgbc)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_xgbc)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_xgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      3090
#            1       0.89      0.93      0.91      4602
#
#     accuracy                           0.89      7692
#    macro avg       0.89      0.88      0.88      7692
# weighted avg       0.89      0.89      0.89      7692

# %%
xgb_roc_auc = roc_auc_score(y_test, y_pred_xgbc)
fpr, tpr, thresholds = roc_curve(y_test, xgbc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % xgb_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('XGB_ROC')
plt.show()

# %% [markdown]
# LightGBM Classifier

# %%
#lightgbm
import lightgbm as lgb

# %%
# GridSearchCV
#param_grid = {'n_estimators': [x for x in range(24,40,2)],
#              'learning_rate': [0.10, 0.125, 0.15, 0.175, 0.2]}
#lgb_g = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l1', n_estimators = 20, num_leaves = 38)
#lgb_cv = GridSearchCV(lgb_g, param_grid,cv=10)
#lgb_cv.fit(X_train, y_train)

#print("Best parameters:",lgb_cv.best_params_)
#print("Accuracy :",lgb_cv.best_score_)

# %%
gbm = lgb.LGBMClassifier(learning_rate = 0.2,  n_estimators = 500, max_depth = 21, random_state=42, min_child_weight=1,metric='l2')
gbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.2, max_depth=21,
#                metric='l2', min_child_samples=20, min_child_weight=1,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred_gbm= gbm.predict(X_test)

# %%
gbm_score_train = gbm.score(X_train,y_train)
print("Train Prediction Score",gbm_score_train*100)
gbm_score_test = accuracy_score(y_test,y_pred_gbm)
print("Test Prediction Score",gbm_score_test*100)
# Out:
# Train Prediction Score 83.37721436697547
# Test Prediction Score 76.18304732189287

# %%
feat_importances = pd.Series(gbm.feature_importances_, index=columns)
feat_importances.plot(kind='barh')

# %%
ax = lgb.plot_importance(gbm, height = 0.5, max_num_features = 17, xlim = (0,6000), ylim = (0,17), figsize = (15,10))
plt.show()

# %%
sorted(gbm.feature_importances_,reverse=True)
# Out:
# [5950,
#  2333,
#  1548,
#  780,
#  716,
#  482,
#  451,
#  277,
#  257,
#  252,
#  251,
#  244,
#  203,
#  203,
#  190,
#  170,
#  170,
#  154,
#  122,
#  97,
#  85,
#  53,
#  12,
#  0,
#  0,
#  0]

# %%
cm = confusion_matrix(y_test, y_pred_gbm)
class_label = ["Anomalous", "Normal"]
df_cm = pd.DataFrame(cm, index=class_label,columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test,y_pred_gbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.56      0.65      3090
#            1       0.75      0.90      0.82      4602
#
#     accuracy                           0.76      7692
#    macro avg       0.77      0.73      0.74      7692
# weighted avg       0.77      0.76      0.75      7692

# %%
lgbm_roc_auc = roc_auc_score(y_test, y_pred_gbm)
fpr, tpr, thresholds = roc_curve(y_test, gbm.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='LGBM (area = %0.2f)' % lgbm_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('LGBM_ROC')
plt.show()
